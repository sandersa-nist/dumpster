# %% [markdown]
# # A sweep of tone spacing for the AWG calibration

# %%
# import the pyMez packages default API
from pyMez import *
# import the Fitting module for Signal Generation and Fitting, note the namespace Code.Analysis.Fitting also works
from pyMez.Code.Analysis.Fitting import *
# Out:
# Importing pyMez, this should take roughly 30 seconds
# Importing Code.DataHandlers.GeneralModels
# It took 0.81 s to import Code.DataHandlers.GeneralModels
# Importing Code.DataHandlers.HTMLModels
# It took 0.134 s to import Code.DataHandlers.HTMLModels
# Importing Code.DataHandlers.NISTModels
# The module smithplot was not found,please put it on the python path
# It took 1.351 s to import Code.DataHandlers.NISTModels
# Importing Code.DataHandlers.TouchstoneModels
# The module smithplot was not found,please put it on the python path
# It took 0.02 s to import Code.DataHandlers.TouchstoneModels
# Importing Code.DataHandlers.XMLModels
# It took 0.15 s to import Code.DataHandlers.XMLModels
# Importing Code.DataHandlers.ZipModels
# It took 0.02 s to import Code.DataHandlers.ZipModels
# Importing Code.InstrumentControl.Experiments
# It took 2.708 s to import Code.InstrumentControl.Experiments
# Importing Code.InstrumentControl.Instruments
# It took 0.01 s to import Code.InstrumentControl.Instruments
# Importing Code.Utils.Names
# It took 0.01 s to import Code.Utils.Names
# It took 5.213 s to import all of the active modules

# %% [markdown]
# ## Setup Variables that do not change with tone spacing

# %%
# none of these instruments have xml instrument sheets, need to add them
psg_address="GPIB1::19"
vna_address="GPIB1::16"
awg_address="GPIB1::10"
scope_address="GPIB1::7::INSTR"
pm_address="GPIB1::13"
# ----------------------
vna=VNA(vna_address)
scope=HighSpeedOscope(scope_address)
awg=VisaInstrument(awg_address)
pm=PowerMeter(pm_address)
# ----------------


# this is local to the computer taking the data, the data should be copied to Q:\public\Aric\AWG_Phase_Calibration_20180927
data_directory=r'C:\Share\AWG_Phase_Calibration_20181001\Comb_Locked_PSG\Zero_Phase_10Hz_Power_Sweep'
# Experimental variables

# the psg frequency acts as the master clock
psg_amplitude=12. #psg amplitude in dBm
psg_frequency=10.*10.**9 # 10 GHz
time_step=1./psg_frequency # time step for the awg
fundamental_frequency = 1.*10.**9 # Center of the passband or fundemental frequency in Hz
number_tones = 11 # Number of tones in the modulation bandwidth including the fundamental, should be odd
number_harmonics = 1# Number of harmonics to use. The frequency grid will be n*(f-df), n*f, n*(f+df), etc
# Select the phase for the multisine    
#multisine_phase="zero"
multisine_phase="schroeder"
number_envelopes=1.

# Measurement Phase Reference Setup 
round_multisine_before_writing=True # Rounds the multisine to a desired bitdepth before writing to AWG
bit_depth=8
waveform_name="Calibration_Phase_Reference" # name of the waveform to write to the 
bin_format=True # If the wave is in 16 bit bin format
marker_1=True # If marker one is to be set
marker_1_n_repeats=1 # the rep rate of the marker as a function of number of repeats per time sequence
marker_2=False
marker_2_n_repeats=1

# VNA setup 
vna_IFBW=10
comb_frequency = 2.5*10**6
number_phases=1
vna.set_IFBW(vna_IFBW)

# Power Meter Setup
pm.set_units("W")
# Out:
# The information sheet was not found defaulting to address
# The information sheet was not found defaulting to address
# The information sheet was not found defaulting to address
# The information sheet was not found defaulting to address

# %%
# Setup the traces that we might want
# Delete all of the traces that we do not need, in this case I will delete  all of them it leaves one trace
trace_string=vna.query("CALC:PAR:CAT?")
trace_list=trace_string.replace("\n","").split(",")[0::3] #remove endline, split on , and then take every third one
for trace in trace_list:
    vna.write("CALC:PAR:DEL '{0}'".format(trace))
print("Existing traces are {0}".format(vna.query("CALC:PAR:CAT?")))
# set up the traces, we use drive_port=1 sense all of the inputs are turned off, there are combs on port 2, port 3

# first we add a trace for a each reference reciever (R1=a1)
for i in range(4):
    vna.add_trace(trace_name="a{0}".format(i+1),trace_parameter="R{0}".format(i+1),drive_port=1)
# now we add a trace for each b reciever (labelled A,B,C,D)
for i,receiver in enumerate(["A","B","C","D"]):
    vna.add_trace(trace_name="b{0}".format(i+1),trace_parameter="{0}".format(receiver),drive_port=1)
    
# now we want a ratio of R1R4 (a1/a4) <- this is the calibration phase reference / measurement phase reference
vna.add_trace(trace_name="ratio",trace_parameter="R1R4",drive_port="1")
vna.add_trace(trace_name="comb_ratio",trace_parameter="a1b2",drive_port="1")
print("Existing traces are {0}".format(vna.query("CALC:PAR:CAT?")))
# Out:
# Existing traces are "a1,a1,1"
#
# Existing traces are "a1,a1,1,a2,R2,1,a3,R3,1,a4,R4,1,b1,A,1,b2,B,1,b3,C,1,b4,D,1,ratio,R1/R4,1,comb_ratio,a1/b2,1"

# %%
tone_spacings=[10*10**6,5*10**6,2.5*10**6,2.5*10**5,2.5*10**4]
tone_spacings=[2.5*10**5,2.5*10**4]
comb_spacings=[10*10**6,5*10**6,2.5*10**6]

# %%
for tone_spacing in tone_spacings:
    comb_spacing=tone_spacing in comb_spacings
    print(comb_spacing)
# Out:
# False
# False

# %%
for tone_spacing in tone_spacings:
    comb_spacing = tone_spacing in comb_spacings
    summary_data=[]
    # now calculate the frequency_list
    frequency_list=[]
    for harmonic in range(number_harmonics):
        frequency_array=np.linspace((harmonic+1)*(fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                    (harmonic+1)*(fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)
        frequency_list=frequency_list+frequency_array.tolist()
    time_max=number_envelopes/tone_spacing
    number_time_points=int(round(time_max/time_step))
    time_shift=0.*time_step
    sweep_wait_time=2.5*float(len(frequency_list))/float(vna_IFBW)
    sweep_directory=os.path.join(data_directory,"{0}_Tones_{1:.0f}KHz_Spacing".format(number_tones,10**-3*tone_spacing))
    os.mkdir(sweep_directory)
    # first create the multisine
    sine_function=FunctionalModel(parameters=["f","phi"],variables=["t"],equation="cos(2*pi*f*t+phi)")
    time_list=np.linspace(0.+time_shift,time_max+time_shift-time_step,number_time_points)

    # calculate the phases 
    phase_list = [0. for i in range(len(frequency_list))]
    if re.search("sch",multisine_phase,re.IGNORECASE):
        phase_list=[]
        for frequency_index,frequency in enumerate(frequency_list):
            k=(frequency_index+1)%number_tones
            schroeder_phase=-k*(k-1)*np.pi/number_tones
            phase_list.append(schroeder_phase)
    # initialize multisine to a set of zeros
    multisine=np.array([0 for i in range(number_time_points)])
    # add each component
    for frequency_index,frequency in enumerate(frequency_list):
        sine_function.set_parameters({"f":frequency,"phi":phase_list[frequency_index]})
        multisine_component=sine_function(time_list)
        multisine=multisine+multisine_component

    # substract the mean
    # multisine=multisine-np.mean(multisine)
    # normalize the multisine
    # multisine=1/max(multisine)*multisine

    # round the multisine to the nearest bitdepth before writing
    if round_multisine_before_writing:
        discrete_steps=np.linspace(min(multisine),max(multisine),2**bit_depth)
        rounded_multisine=[]
        int_multisine=[]
        for value in multisine:
            difference_array=abs(discrete_steps-value)
            minimum_location=np.argmin(difference_array)
            rounded_multisine.append(discrete_steps[minimum_location])
            int_multisine.append(minimum_location)
        if bin_format:
            multisine=np.array(int_multisine,dtype=np.uint16)
            # Shift, now to add the marker add + 2**14 or +2**15 at the desired location
            multisine=multisine*2**6
        else:
            multisine=rounded_multisine

    # now we add the marker. 
    if marker_1:

        distance=int(np.floor(float(len(multisine))/float(marker_1_n_repeats)))
        for i in range(marker_1_n_repeats):
            try:
                multisine[i*distance]=multisine[i*distance]+2**14
            except:
                pass
    # I am guessing that this has the possibility of kiling the oscope trigger
    if bin_format:
        # turn AWG's output 1 & 2 OFF
        awg.write(':OUTPUT1:STATE OFF')
        awg.write(':OUTPUT2:STATE OFF')
        # wait...
        time.sleep(0.1)
        # UNRUN state
        awg.write('AWGCONTROL:STOP')
        # wait...
        time.sleep(0.5)

        # delete any older waveform with the same name
        awg.write('WLISt:WAVeform:DELete "{0}"'.format(waveform_name))
        time.sleep(0.05)

        # create new waveform
        awg.write('WLISt:WAVeform:NEW "{0}", {1}, INT'.format(waveform_name,len(multisine)))
        # download data
        awg.resource.write_binary_values('WLISt:WAVeform:DATA "{0}",'.format(waveform_name), multisine, datatype='H', is_big_endian=False)
        time.sleep(.1)
        # assign new waveform to channel 1 & 2
        awg.write('SOURce1:WAVeform "{0}"'.format(waveform_name))
        awg.write('SOURce2:WAVeform "{0}"'.format(waveform_name))

        # check for errors
        error_str = awg.query('SYSTEM:ERROR:NEXT?')
        # wait...
        time.sleep(.1)
        # AWG on RUN state
        awg.write('AWGCONTROL:RUN')
        # wait...
        time.sleep(0.5)
        # check if there is any errors on AWG's buffer
        error_str = awg.query('SYSTEM:ERROR:NEXT?')
        if error_str == '0,"No error"\n':
            # turn AWG's output 1 OFF
            awg.write(':OUTPUT1:STATE ON')
            awg.write(':OUTPUT2:STATE ON')

    if number_harmonics is 1:    
        vna.set_frequency((fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                        (fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)  
    else:
        for harmonic in range(number_harmonics):
            vna.add_segment((harmonic+1)*(fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                        (harmonic+1)*(fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)

    single_cosine=FunctionalModel(variables=["t"],parameters=["f","phi"],equation="cos(2*pi*f*t+phi)")

    phase_sweep_list=[2*np.pi*i/number_phases for i in range(number_phases)]
    # Loop to measure the phase
    start_timer=datetime.datetime.now()
    print("Calibration Began at {0}".format(start_timer))
    for frequency_index,frequency in enumerate(frequency_list[:]):
        begin_sweep_timer=datetime.datetime.now()
        print("Sweep {0} \nf : {1}\n began at {2} ".format(frequency_index,frequency,begin_sweep_timer))
        for phase_index,phase in enumerate(phase_sweep_list):

             #create the sine to write
            # ----------------------------------------------------------------------------------------------------------
            single_cosine.set_parameters({"f":frequency,"phi":phase})
            tone_data=single_cosine(time_list)

            # round the multisine to the nearest bitdepth before writing
            if round_multisine_before_writing:
                discrete_steps=np.linspace(min(tone_data),max(tone_data),2**bit_depth)
                rounded_tone_data=[]
                int_tone_data=[]
                for value in tone_data:
                    difference_array=abs(discrete_steps-value)
                    minimum_location=np.argmin(difference_array)
                    rounded_tone_data.append(discrete_steps[minimum_location])
                    int_tone_data.append(minimum_location)
                if bin_format:
                    tone_data=np.array(int_tone_data,dtype=np.uint16)
                    # Shift, now to add the marker add + 2**14 or +2**15 at the desired location
                    tone_data=tone_data*2**6
                else:
                    tone_data=rounded_tone_data

            timer=datetime.datetime.now()
            print("Writing to AWG Began at {0} ".format(timer))
            # write tone to AWG
            # --------------------------------------------------------
            tone_waveform_name="Tone_{0}_Phase_{1:.0f}_Calibration".format(frequency_index,phase*180/np.pi)
            # save the wave for good measure
            out_file=open(os.path.join(sweep_directory,"{0}.bin".format(tone_waveform_name)),"wb")
            out_file.write(tone_data)
            out_file.close()
            # plot 
            plt.close()
            plt.plot(time_list,tone_data)
            plt.xlabel("Time (s)")
            plt.ylabel("Amplitude (arb)")
            plt.title(tone_waveform_name)
            plt.savefig(os.path.join(sweep_directory,"{0}.png".format(tone_waveform_name)))
            #plt.show();

            if bin_format:
                # turn AWG's output 1 
                awg.write(':OUTPUT1:STATE OFF')
                time.sleep(0.1)
                # UNRUN state
                awg.write('AWGCONTROL:STOP')
                # wait...
                time.sleep(0.5)

                # delete any older waveform with the same name
                awg.write('WLISt:WAVeform:DELete "{0}"'.format(tone_waveform_name))
                time.sleep(0.05)

                # create new waveform
                awg.write('WLISt:WAVeform:NEW "{0}", {1}, INT'.format(tone_waveform_name,len(tone_data)))
                # download data
                awg.resource.write_binary_values('WLISt:WAVeform:DATA "{0}",'.format(tone_waveform_name), 
                                                 tone_data, datatype='H', is_big_endian=False)
                time.sleep(0.1)
                # assign new waveform to channel 1 
                awg.write('SOURce1:WAVeform "{0}"'.format(tone_waveform_name))


                # check for errors
                error_str = awg.query('SYSTEM:ERROR:NEXT?')
                # wait...
                time.sleep(.1)
                # AWG on RUN state
                awg.write('AWGCONTROL:RUN')
                # wait...
                time.sleep(0.5)
                # check if there is any errors on AWG's buffer
                error_str = awg.query('SYSTEM:ERROR:NEXT?')
                if error_str == '0,"No error"\n':
                    # turn AWG's output 1 ON
                    awg.write(':OUTPUT1:STATE ON')
                    
            timer=datetime.datetime.now()
            print("Measuring on VNA  Began at {0} ".format(timer))                
            # Measure on VNA
            # ---------------------------------------------------------------------------------------------------------
            # now the measured trace should be the multisine we can trigger and display the ratio to be sure
            vna.trigger_sweep()
            time.sleep(sweep_wait_time)
            # read_trace needs to have some work
            # Here we read a1/a4, a1, a4
            #------------------------------------------------------------------------------------
            vna.write("CALC:PAR:SEL '{0}'".format("ratio"))
            ratio_trace_string = vna.query("CALC:DATA? SDATA")
            ratio_trace = ratio_trace_string.replace("\n","").split(",")
            ratio_real = ratio_trace[0::2]
            ratio_imaginary = ratio_trace[1::2]
            complex_ratio =np.array([complex(float(real_value),
                                             float(ratio_imaginary[index])) for index,real_value in enumerate(ratio_real)])

            vna.write("CALC:PAR:SEL '{0}'".format("a1"))
            a1_trace_string = vna.query("CALC:DATA? SDATA")
            a1_trace = a1_trace_string.replace("\n","").split(",")
            a1_real = a1_trace[0::2]
            a1_imaginary = a1_trace[1::2]
            complex_a1 =np.array([complex(float(real_value),
                                             float(a1_imaginary[index])) for index,real_value in enumerate(a1_real)])
            
            vna.write("CALC:PAR:SEL '{0}'".format("b1"))
            b1_trace_string = vna.query("CALC:DATA? SDATA")
            b1_trace = b1_trace_string.replace("\n","").split(",")
            b1_real = b1_trace[0::2]
            b1_imaginary = b1_trace[1::2]
            complex_b1 =np.array([complex(float(real_value),
                                             float(b1_imaginary[index])) for index,real_value in enumerate(b1_real)])

            vna.write("CALC:PAR:SEL '{0}'".format("a4"))
            a4_trace_string = vna.query("CALC:DATA? SDATA")
            a4_trace = a4_trace_string.replace("\n","").split(",")
            a4_real = a4_trace[0::2]
            a4_imaginary = a4_trace[1::2]
            complex_a4 =np.array([complex(float(real_value),
                                             float(a4_imaginary[index])) for index,real_value in enumerate(a4_real)])
            # If the tone spacing is on the comb grid, we want a1/b2, b2, b3
            if comb_spacing:
                # this block should be replaced with vna.read_trace
                vna.write("CALC:PAR:SEL '{0}'".format("b2"))
                b2_trace_string = vna.query("CALC:DATA? SDATA")
                b2_trace = b2_trace_string.replace("\n","").split(",")
                b2_real = b2_trace[0::2]
                b2_imaginary = b2_trace[1::2]
                complex_b2 =np.array([complex(float(real_value),
                                                 float(b2_imaginary[index])) for index,real_value in enumerate(b2_real)])                

                vna.write("CALC:PAR:SEL '{0}'".format("b3"))
                b3_trace_string = vna.query("CALC:DATA? SDATA")
                b3_trace = b3_trace_string.replace("\n","").split(",")
                b3_real = b3_trace[0::2]
                b3_imaginary = b3_trace[1::2]
                complex_b3 =np.array([complex(float(real_value),
                                                 float(b3_imaginary[index])) for index,real_value in enumerate(b3_real)])                
                             
                vna.write("CALC:PAR:SEL '{0}'".format("comb_ratio"))
                comb_ratio_trace_string = vna.query("CALC:DATA? SDATA")
                comb_ratio_trace = comb_ratio_trace_string.replace("\n","").split(",")
                comb_ratio_real = comb_ratio_trace[0::2]
                comb_ratio_imaginary = comb_ratio_trace[1::2]
                complex_comb_ratio =np.array([complex(float(real_value),
                                                 float(comb_ratio_imaginary[index])) for index,real_value in enumerate(comb_ratio_real)])                
                             

                vna_data=[map(lambda x:float(x),[frequency_list[index],
                           real_value,
                           ratio_imaginary[index],
                           a1_real[index],a1_imaginary[index],
                           b1_real[index],b1_imaginary[index],
                           a4_real[index],a4_imaginary[index],
                           comb_ratio_real[index],comb_ratio_imaginary[index],
                           b2_real[index],b2_imaginary[index],
                           b3_real[index],b3_imaginary[index]]) for index,real_value in enumerate(ratio_real)]
                
                
                column_names=["Frequency",
                                         "reA1_Div_A4","imA1_Div_A4",
                                         "reA1","imA1","reB1","imB1",
                                         "reA4","imA4",
                                         "reA1_Div_B2","imA1_Div_B2",
                                         "reB2","imB2","reB3","imB3"]
                options={"column_names":column_names,
                         "column_types":["float" for i in range(len(column_names))],
                         "directory":sweep_directory,"specific_descriptor":tone_waveform_name,
                         "general_descriptor":"Vna_Reciever_Values","extension":"txt","data":vna_data}                    
            else:
                
                vna_data=[map(lambda x:float(x),[frequency_list[index],
                           real_value,
                           ratio_imaginary[index],
                           a1_real[index],a1_imaginary[index],
                           b1_real[index],b1_imaginary[index],                      
                           a4_real[index],a4_imaginary[index]]) for index,real_value in enumerate(ratio_real)]
                column_names=["Frequency","reA1_Div_A4","imA1_Div_A4","reA1","imA1","reB1","imB1","reA4","imA4"]
                options={"column_names":column_names,
                         "column_types":["float" for i in range(len(column_names))],
                         "directory":sweep_directory,"specific_descriptor":tone_waveform_name,
                         "general_descriptor":"Vna_Reciever_Values","extension":"txt","data":vna_data}
            ratio_data_table=AsciiDataTable(None,**options)
            ratio_data_table.save()
            ratio_data_table.save_schema(change_extension(ratio_data_table.path,new_extension="schema"))
            plt.close()
            plt.plot(frequency_list,abs(complex_ratio),'b-o')
            plt.xlabel("Frequency (Hz)")
            plt.ylabel("Linear Magnitude")
            plt.title("Magnitude Measured on VNA")
            plt.savefig(os.path.join(sweep_directory,"Magnitude_Plot_Ratio_{0}.png".format(tone_waveform_name)))
            #plt.show();
            plt.close()
            plt.plot(np.array(frequency_list),np.angle(complex_ratio,deg=1),"b-o")
            plt.xlabel("Frequency(Hz)")
            plt.ylabel("Phase (Degrees)")
            plt.title("Phase Measured on VNA")
            plt.savefig(os.path.join(sweep_directory,"Phase_Plot_Ratio_{0}.png".format(tone_waveform_name)))
            #plt.show();
            timer=datetime.datetime.now()
            print("Measuring on Scope  Began at {0} ".format(timer))
            time.sleep(.1)
            # Measure on Power Meter
            # ---------------------------------------------------------------------------------------------------------
            pm.set_frequency(frequency)
            power_reading=pm.get_reading()
            
            
            
            
            
#             wave_trace=scope.measure_waves()
#             time.sleep(.1)
#             plt.close()            
#             plt.plot(wave_trace["Time"],wave_trace["CHAN2"],label="SUT")
#             plt.plot(wave_trace["Time"],wave_trace["CHAN3"],label="I")
#             plt.plot(wave_trace["Time"],wave_trace["CHAN4"],label="Q")
#             plt.legend()
#             plt.savefig(os.path.join(sweep_directory,"Scope_{0}.png".format(tone_waveform_name)))
#             #plt.show();
#             fit_cosine=FunctionalModel(variables=["t"],parameters=["A","phi"],equation="A*cos(2*pi*t*{0}+phi)".format(frequency))
#             x_data=10**-9*np.array(map(lambda x:float(x),wave_trace["Time"]))
#             y_data=np.array(map(lambda x:float(x),wave_trace["CHAN2"]))
#             fit_cosine.fit_data(x_data=x_data,y_data=y_data)
#             plt.close()
#             plt.plot(x_data,fit_cosine(x_data),label="Fit")
#             plt.plot(x_data,y_data,label="CHAN2")
#             fit_parameters=fit_cosine.parameter_values
#             plt.title("Amplitude: {A} Phase: {phi}".format(**fit_parameters))
#             plt.legend()
#             plt.savefig(os.path.join(sweep_directory,"Scope_Fit_{0}.png".format(tone_waveform_name)))
#             #plt.show();
#             wave_trace.options["fit_equation"]="{0}".format(fit_cosine)
#             wave_trace.options["fit_parameters"]=fit_parameters
#             wave_trace.save(os.path.join(sweep_directory,"{0}_Scope_Measurement.txt".format(tone_waveform_name)))
#             wave_trace.save_schema(change_extension(wave_trace.path,new_extension="schema"))

            
            # Calculate the Summary Row, A table of Tone Index, Frequency, AWG Set Amplitude, AWG Set Phase, Scope Measured Amp
            # Scope MEasured Phase, VNA Measured Amp, VNA Measured Phase and optional values if comb_spacing
            tone_index=frequency_index+1 # starts at 1
            summary_frequency=frequency  # I know it is not needed just a reminder
            AWG_set_amplitude = .5 # set by the awg after the write of the binary wave
            AWG_set_phase=phase*180/np.pi 
            power_meter_measured_amplitude=power_reading 
            vna_measured_amplitude=abs(complex_ratio[frequency_index])
            vna_measured_phase=np.angle(complex_ratio[frequency_index],deg=True)
            if comb_spacing:
                vna_measured_amplitude_comb=abs(complex_comb_ratio[frequency_index])
                vna_measured_phase_comb=np.angle(complex_comb_ratio[frequency_index],deg=True)
                summary_row=[tone_index,summary_frequency,
                             AWG_set_amplitude,AWG_set_phase,
                             power_meter_measured_amplitude,
                             vna_measured_amplitude,vna_measured_phase,
                            vna_measured_amplitude_comb,vna_measured_phase_comb]
            else:
                summary_row=[tone_index,summary_frequency,
                                 AWG_set_amplitude,AWG_set_phase,
                                 power_meter_measured_amplitude,
                                 vna_measured_amplitude,vna_measured_phase]
            # Delete last waveform
            if phase_index>0:
                awg.write('WLISt:WAVeform:DELete "{0}"'.format(last_waveform_name))
            last_waveform_name=tone_waveform_name
            summary_data.append(summary_row)
            
        if comb_spacing:
            summary_column_names=["Tone","Frequency","AWG_Set_Amplitude","AWG_Set_Phase",
                                  "Power","Vna_Amplitude","Vna_Phase",
                                  "Vna_Comb_Referenced_Amplitude","Vna_Comb_Referenced_Phase"]
            summary_column_units=[None,"Hz","Volts","Degrees",
                                  "Watts",
                                  "Volts","Degrees",
                                  "Volts","Degrees"]
        else:
            summary_column_names=["Tone","Frequency","AWG_Set_Amplitude","AWG_Set_Phase",
                                  "Power","Vna_Amplitude","Vna_Phase"]
            summary_column_units=[None,"Hz","Volts","Degrees",
                                  "Watts",
                                  "Volts","Degrees"]
            
        summary_options={"column_names":summary_column_names,
                         "column_types":["float" for i in range(len(summary_column_names))],
                         "column_units":summary_column_units,
                         "directory":sweep_directory,
                         "specific_descriptor":"{0}_Tones_{1:.0f}KHz_Spacing".format(number_tones,10**3*tone_spacing),
                         "general_descriptor":"Summary","extension":"txt","data":summary_data,
                         "metadata":{"Timestamp":"{0}".format(datetime.datetime.now()),
                                     "sweep":"{0}_Tones_{1:.0f}KHz_Spacing".format(number_tones,10**3*tone_spacing),
                                    "tone_spacing":tone_spacing,"number_tones":number_tones,
                                     "multisine_phase":multisine_phase,"number_harmonics":number_harmonics,
                                    "frequnecy_list":frequency_list}} 
        summary_table=AsciiDataTable(None,**summary_options)
        summary_table.save()
        summary_table.save_schema(change_extension(summary_table.path,new_extension="schema"))
        end_sweep_timer=datetime.datetime.now()
        difference=end_sweep_timer-begin_sweep_timer
        print("Sweep {0} \nf : {1}\n ended at {2}\n taking {3} seonds ".format(frequency_index,
                                                                               frequency,
                                                                               end_sweep_timer,
                                                                               difference.seconds))
# Out:
# Calibration Began at 2018-10-12 11:16:10.510000
# Sweep 0
# f : 998750000.0
#  began at 2018-10-12 11:16:10.510000
# Writing to AWG Began at 2018-10-12 11:16:10.773000
# Measuring on VNA  Began at 2018-10-12 11:16:13.891000
# Measuring on Scope  Began at 2018-10-12 11:16:19.167000
# Writing to AWG Began at 2018-10-12 11:16:19.600000
# Measuring on VNA  Began at 2018-10-12 11:16:22.755000
# Measuring on Scope  Began at 2018-10-12 11:16:28.009000
# Writing to AWG Began at 2018-10-12 11:16:28.394000
# Measuring on VNA  Began at 2018-10-12 11:16:31.514000
# Measuring on Scope  Began at 2018-10-12 11:16:36.772000
# Writing to AWG Began at 2018-10-12 11:16:37.172000
# Measuring on VNA  Began at 2018-10-12 11:16:40.258000
# Measuring on Scope  Began at 2018-10-12 11:16:45.492000
# Writing to AWG Began at 2018-10-12 11:16:45.898000
# Measuring on VNA  Began at 2018-10-12 11:16:48.958000
# Measuring on Scope  Began at 2018-10-12 11:16:54.206000
# Writing to AWG Began at 2018-10-12 11:16:54.626000
# Measuring on VNA  Began at 2018-10-12 11:17:00.703000
# Measuring on Scope  Began at 2018-10-12 11:17:05.969000
# Writing to AWG Began at 2018-10-12 11:17:06.436000
# Measuring on VNA  Began at 2018-10-12 11:17:09.716000
# Measuring on Scope  Began at 2018-10-12 11:17:15.010000
# Writing to AWG Began at 2018-10-12 11:17:15.539000
# Measuring on VNA  Began at 2018-10-12 11:17:18.809000
# Measuring on Scope  Began at 2018-10-12 11:17:24.047000
# Writing to AWG Began at 2018-10-12 11:17:24.434000
# Measuring on VNA  Began at 2018-10-12 11:17:27.627000
# Measuring on Scope  Began at 2018-10-12 11:17:32.893000
# Writing to AWG Began at 2018-10-12 11:17:33.273000
# Measuring on VNA  Began at 2018-10-12 11:17:36.480000
# Measuring on Scope  Began at 2018-10-12 11:17:41.715000
# Sweep 0
# f : 998750000.0
#  ended at 2018-10-12 11:17:41.895000
#  taking 91 seonds
# Sweep 1
# f : 999000000.0
#  began at 2018-10-12 11:17:41.895000
# Writing to AWG Began at 2018-10-12 11:17:42.167000
# Measuring on VNA  Began at 2018-10-12 11:17:45.364000
# Measuring on Scope  Began at 2018-10-12 11:17:50.635000
# Writing to AWG Began at 2018-10-12 11:17:51.007000
# Measuring on VNA  Began at 2018-10-12 11:17:54.210000
# Measuring on Scope  Began at 2018-10-12 11:17:59.568000
# Writing to AWG Began at 2018-10-12 11:17:59.959000
# Measuring on VNA  Began at 2018-10-12 11:18:03.192000
# Measuring on Scope  Began at 2018-10-12 11:18:08.441000
# Writing to AWG Began at 2018-10-12 11:18:08.845000
# Measuring on VNA  Began at 2018-10-12 11:18:12.016000
# Measuring on Scope  Began at 2018-10-12 11:18:17.212000
# Writing to AWG Began at 2018-10-12 11:18:17.602000
# Measuring on VNA  Began at 2018-10-12 11:18:20.794000
# Measuring on Scope  Began at 2018-10-12 11:18:26.057000
# Writing to AWG Began at 2018-10-12 11:18:26.436000
# Measuring on VNA  Began at 2018-10-12 11:18:29.582000
# Measuring on Scope  Began at 2018-10-12 11:18:34.786000
# Writing to AWG Began at 2018-10-12 11:18:35.195000
# Measuring on VNA  Began at 2018-10-12 11:18:38.376000
# Measuring on Scope  Began at 2018-10-12 11:18:43.533000
# Writing to AWG Began at 2018-10-12 11:18:43.933000
# Measuring on VNA  Began at 2018-10-12 11:18:47.157000
# Measuring on Scope  Began at 2018-10-12 11:18:52.413000
# Writing to AWG Began at 2018-10-12 11:18:52.840000
# Measuring on VNA  Began at 2018-10-12 11:18:56.069000
# Measuring on Scope  Began at 2018-10-12 11:19:01.376000
# Writing to AWG Began at 2018-10-12 11:19:01.796000
# Measuring on VNA  Began at 2018-10-12 11:19:05.201000
# Measuring on Scope  Began at 2018-10-12 11:19:10.465000
# Sweep 1
# f : 999000000.0
#  ended at 2018-10-12 11:19:10.655000
#  taking 88 seonds
# Sweep 2
# f : 999250000.0
#  began at 2018-10-12 11:19:10.655000
# Writing to AWG Began at 2018-10-12 11:19:10.900000
# Measuring on VNA  Began at 2018-10-12 11:19:14.199000
# Measuring on Scope  Began at 2018-10-12 11:19:19.509000
# Writing to AWG Began at 2018-10-12 11:19:19.904000
# Measuring on VNA  Began at 2018-10-12 11:19:23.120000
# Measuring on Scope  Began at 2018-10-12 11:19:28.382000
# Writing to AWG Began at 2018-10-12 11:19:28.772000
# Measuring on VNA  Began at 2018-10-12 11:19:31.993000
# Measuring on Scope  Began at 2018-10-12 11:19:37.288000
# Writing to AWG Began at 2018-10-12 11:19:37.698000
# Measuring on VNA  Began at 2018-10-12 11:19:40.885000
# Measuring on Scope  Began at 2018-10-12 11:19:46.180000
# Writing to AWG Began at 2018-10-12 11:19:46.582000
# Measuring on VNA  Began at 2018-10-12 11:19:49.736000
# Measuring on Scope  Began at 2018-10-12 11:19:54.955000
# Writing to AWG Began at 2018-10-12 11:19:55.375000
# Measuring on VNA  Began at 2018-10-12 11:19:58.518000
# Measuring on Scope  Began at 2018-10-12 11:20:03.702000
# Writing to AWG Began at 2018-10-12 11:20:04.079000
# Measuring on VNA  Began at 2018-10-12 11:20:07.249000
# Measuring on Scope  Began at 2018-10-12 11:20:12.497000
# Writing to AWG Began at 2018-10-12 11:20:12.919000
# Measuring on VNA  Began at 2018-10-12 11:20:16.096000
# Measuring on Scope  Began at 2018-10-12 11:20:21.397000
# Writing to AWG Began at 2018-10-12 11:20:21.809000
# Measuring on VNA  Began at 2018-10-12 11:20:25.017000
# Measuring on Scope  Began at 2018-10-12 11:20:30.398000
# Writing to AWG Began at 2018-10-12 11:20:30.851000
# Measuring on VNA  Began at 2018-10-12 11:20:34.140000
# Measuring on Scope  Began at 2018-10-12 11:20:39.394000
# Sweep 2
# f : 999250000.0
#  ended at 2018-10-12 11:20:39.574000
#  taking 88 seonds
# Sweep 3
# f : 999500000.0
#  began at 2018-10-12 11:20:39.574000
# Writing to AWG Began at 2018-10-12 11:20:39.821000
# Measuring on VNA  Began at 2018-10-12 11:20:43.034000
# Measuring on Scope  Began at 2018-10-12 11:20:48.310000
# Writing to AWG Began at 2018-10-12 11:20:48.718000
# Measuring on VNA  Began at 2018-10-12 11:20:51.904000
# Measuring on Scope  Began at 2018-10-12 11:20:57.134000
# Writing to AWG Began at 2018-10-12 11:20:57.541000
# Measuring on VNA  Began at 2018-10-12 11:21:00.729000
# Measuring on Scope  Began at 2018-10-12 11:21:05.981000
# Writing to AWG Began at 2018-10-12 11:21:06.412000
# Measuring on VNA  Began at 2018-10-12 11:21:09.721000
# Measuring on Scope  Began at 2018-10-12 11:21:14.974000
# Writing to AWG Began at 2018-10-12 11:21:15.378000
# Measuring on VNA  Began at 2018-10-12 11:21:18.548000
# Measuring on Scope  Began at 2018-10-12 11:21:23.869000
# Writing to AWG Began at 2018-10-12 11:21:24.268000
# Measuring on VNA  Began at 2018-10-12 11:21:27.372000
# Measuring on Scope  Began at 2018-10-12 11:21:32.622000
# Writing to AWG Began at 2018-10-12 11:21:33.016000
# Measuring on VNA  Began at 2018-10-12 11:21:36.205000
# Measuring on Scope  Began at 2018-10-12 11:21:41.436000
# Writing to AWG Began at 2018-10-12 11:21:41.868000
# Measuring on VNA  Began at 2018-10-12 11:21:45.073000
# Measuring on Scope  Began at 2018-10-12 11:21:50.309000
# Writing to AWG Began at 2018-10-12 11:21:50.720000
# Measuring on VNA  Began at 2018-10-12 11:21:53.900000
# Measuring on Scope  Began at 2018-10-12 11:21:59.175000
# Writing to AWG Began at 2018-10-12 11:21:59.566000
# Measuring on VNA  Began at 2018-10-12 11:22:02.763000
# Measuring on Scope  Began at 2018-10-12 11:22:07.930000
# Sweep 3
# f : 999500000.0
#  ended at 2018-10-12 11:22:08.130000
#  taking 88 seonds
# Sweep 4
# f : 999750000.0
#  began at 2018-10-12 11:22:08.130000
# Writing to AWG Began at 2018-10-12 11:22:08.359000
# Measuring on VNA  Began at 2018-10-12 11:22:11.580000
# Measuring on Scope  Began at 2018-10-12 11:22:17.070000
# Writing to AWG Began at 2018-10-12 11:22:17.487000
# Measuring on VNA  Began at 2018-10-12 11:22:20.651000
# Measuring on Scope  Began at 2018-10-12 11:22:25.892000
# Writing to AWG Began at 2018-10-12 11:22:26.264000
# Measuring on VNA  Began at 2018-10-12 11:22:29.404000
# Measuring on Scope  Began at 2018-10-12 11:22:34.732000
# Writing to AWG Began at 2018-10-12 11:22:35.164000
# Measuring on VNA  Began at 2018-10-12 11:22:38.278000
# Measuring on Scope  Began at 2018-10-12 11:22:43.502000
# Writing to AWG Began at 2018-10-12 11:22:43.932000
# Measuring on VNA  Began at 2018-10-12 11:22:47.078000
# Measuring on Scope  Began at 2018-10-12 11:22:52.295000
# Writing to AWG Began at 2018-10-12 11:22:52.705000
# Measuring on VNA  Began at 2018-10-12 11:22:56.462000
# Measuring on Scope  Began at 2018-10-12 11:23:01.762000
# Writing to AWG Began at 2018-10-12 11:23:02.203000
# Measuring on VNA  Began at 2018-10-12 11:23:05.319000
# Measuring on Scope  Began at 2018-10-12 11:23:10.603000
# Writing to AWG Began at 2018-10-12 11:23:10.997000
# Measuring on VNA  Began at 2018-10-12 11:23:14.189000
# Measuring on Scope  Began at 2018-10-12 11:23:19.401000
# Writing to AWG Began at 2018-10-12 11:23:19.837000
# Measuring on VNA  Began at 2018-10-12 11:23:23.103000
# Measuring on Scope  Began at 2018-10-12 11:23:28.327000
# Writing to AWG Began at 2018-10-12 11:23:28.738000
# Measuring on VNA  Began at 2018-10-12 11:23:31.947000
# Measuring on Scope  Began at 2018-10-12 11:23:37.226000
# Sweep 4
# f : 999750000.0
#  ended at 2018-10-12 11:23:37.442000
#  taking 89 seonds
# Sweep 5
# f : 1000000000.0
#  began at 2018-10-12 11:23:37.444000
# Writing to AWG Began at 2018-10-12 11:23:37.673000
# Measuring on VNA  Began at 2018-10-12 11:23:40.921000
# Measuring on Scope  Began at 2018-10-12 11:23:46.155000
# Writing to AWG Began at 2018-10-12 11:23:46.608000
# Measuring on VNA  Began at 2018-10-12 11:23:49.760000
# Measuring on Scope  Began at 2018-10-12 11:23:55.018000
# Writing to AWG Began at 2018-10-12 11:23:55.442000
# Measuring on VNA  Began at 2018-10-12 11:23:58.588000
# Measuring on Scope  Began at 2018-10-12 11:24:03.838000
# Writing to AWG Began at 2018-10-12 11:24:04.271000
# Measuring on VNA  Began at 2018-10-12 11:24:07.392000
# Measuring on Scope  Began at 2018-10-12 11:24:12.641000
# Writing to AWG Began at 2018-10-12 11:24:13.021000
# Measuring on VNA  Began at 2018-10-12 11:24:16.491000
# Measuring on Scope  Began at 2018-10-12 11:24:21.768000
# Writing to AWG Began at 2018-10-12 11:24:22.166000
# Measuring on VNA  Began at 2018-10-12 11:24:25.260000
# Measuring on Scope  Began at 2018-10-12 11:24:30.859000
# Writing to AWG Began at 2018-10-12 11:24:31.286000
# Measuring on VNA  Began at 2018-10-12 11:24:34.371000
# Measuring on Scope  Began at 2018-10-12 11:24:39.550000
# Writing to AWG Began at 2018-10-12 11:24:39.963000
# Measuring on VNA  Began at 2018-10-12 11:24:43.076000
# Measuring on Scope  Began at 2018-10-12 11:24:48.306000
# Writing to AWG Began at 2018-10-12 11:24:48.716000
# Measuring on VNA  Began at 2018-10-12 11:24:51.899000
# Measuring on Scope  Began at 2018-10-12 11:24:57.180000
# Writing to AWG Began at 2018-10-12 11:24:57.587000
# Measuring on VNA  Began at 2018-10-12 11:25:01.181000
# Measuring on Scope  Began at 2018-10-12 11:25:06.448000
# Sweep 5
# f : 1000000000.0
#  ended at 2018-10-12 11:25:06.648000
#  taking 89 seonds
# Sweep 6
# f : 1000250000.0
#  began at 2018-10-12 11:25:06.648000
# Writing to AWG Began at 2018-10-12 11:25:06.883000
# Measuring on VNA  Began at 2018-10-12 11:25:10.103000
# Measuring on Scope  Began at 2018-10-12 11:25:15.273000
# Writing to AWG Began at 2018-10-12 11:25:15.708000
# Measuring on VNA  Began at 2018-10-12 11:25:18.854000
# Measuring on Scope  Began at 2018-10-12 11:25:24.111000
# Writing to AWG Began at 2018-10-12 11:25:24.500000
# Measuring on VNA  Began at 2018-10-12 11:25:27.661000
# Measuring on Scope  Began at 2018-10-12 11:25:32.860000
# Writing to AWG Began at 2018-10-12 11:25:33.247000
# Measuring on VNA  Began at 2018-10-12 11:25:36.371000
# Measuring on Scope  Began at 2018-10-12 11:25:41.561000
# Writing to AWG Began at 2018-10-12 11:25:41.932000
# Measuring on VNA  Began at 2018-10-12 11:25:45.038000
# Measuring on Scope  Began at 2018-10-12 11:25:50.238000
# Writing to AWG Began at 2018-10-12 11:25:50.645000
# Measuring on VNA  Began at 2018-10-12 11:25:53.745000
# Measuring on Scope  Began at 2018-10-12 11:25:58.945000
# Writing to AWG Began at 2018-10-12 11:25:59.315000
# Measuring on VNA  Began at 2018-10-12 11:26:02.432000
# Measuring on Scope  Began at 2018-10-12 11:26:07.672000
# Writing to AWG Began at 2018-10-12 11:26:08.079000
# Measuring on VNA  Began at 2018-10-12 11:26:11.185000
# Measuring on Scope  Began at 2018-10-12 11:26:16.450000
# Writing to AWG Began at 2018-10-12 11:26:16.909000
# Measuring on VNA  Began at 2018-10-12 11:26:20.059000
# Measuring on Scope  Began at 2018-10-12 11:26:25.303000
# Writing to AWG Began at 2018-10-12 11:26:25.708000
# Measuring on VNA  Began at 2018-10-12 11:26:28.863000
# Measuring on Scope  Began at 2018-10-12 11:26:34.070000
# Sweep 6
# f : 1000250000.0
#  ended at 2018-10-12 11:26:34.260000
#  taking 87 seonds
# Sweep 7
# f : 1000500000.0
#  began at 2018-10-12 11:26:34.260000
# Writing to AWG Began at 2018-10-12 11:26:34.497000
# Measuring on VNA  Began at 2018-10-12 11:26:37.681000
# Measuring on Scope  Began at 2018-10-12 11:26:42.922000
# Writing to AWG Began at 2018-10-12 11:26:43.310000
# Measuring on VNA  Began at 2018-10-12 11:26:46.474000
# Measuring on Scope  Began at 2018-10-12 11:26:51.684000
# Writing to AWG Began at 2018-10-12 11:26:52.090000
# Measuring on VNA  Began at 2018-10-12 11:26:55.216000
# Measuring on Scope  Began at 2018-10-12 11:27:00.481000
# Writing to AWG Began at 2018-10-12 11:27:00.898000
# Measuring on VNA  Began at 2018-10-12 11:27:04.071000
# Measuring on Scope  Began at 2018-10-12 11:27:09.692000
# Writing to AWG Began at 2018-10-12 11:27:10.128000
# Measuring on VNA  Began at 2018-10-12 11:27:13.225000
# Measuring on Scope  Began at 2018-10-12 11:27:18.499000
# Writing to AWG Began at 2018-10-12 11:27:18.904000
# Measuring on VNA  Began at 2018-10-12 11:27:22.005000
# Measuring on Scope  Began at 2018-10-12 11:27:27.295000
# Writing to AWG Began at 2018-10-12 11:27:27.696000
# Measuring on VNA  Began at 2018-10-12 11:27:30.832000
# Measuring on Scope  Began at 2018-10-12 11:27:36.109000
# Writing to AWG Began at 2018-10-12 11:27:36.526000
# Measuring on VNA  Began at 2018-10-12 11:27:39.556000
# Measuring on Scope  Began at 2018-10-12 11:27:44.767000
# Writing to AWG Began at 2018-10-12 11:27:45.182000
# Measuring on VNA  Began at 2018-10-12 11:27:48.226000
# Measuring on Scope  Began at 2018-10-12 11:27:53.403000
# Writing to AWG Began at 2018-10-12 11:27:53.826000
# Measuring on VNA  Began at 2018-10-12 11:27:56.850000
# Measuring on Scope  Began at 2018-10-12 11:28:02.103000
# Sweep 7
# f : 1000500000.0
#  ended at 2018-10-12 11:28:02.321000
#  taking 88 seonds
# Sweep 8
# f : 1000750000.0
#  began at 2018-10-12 11:28:02.322000
# Writing to AWG Began at 2018-10-12 11:28:02.567000
# Measuring on VNA  Began at 2018-10-12 11:28:05.614000
# Measuring on Scope  Began at 2018-10-12 11:28:10.883000
# Writing to AWG Began at 2018-10-12 11:28:11.310000
# Measuring on VNA  Began at 2018-10-12 11:28:14.324000
# Measuring on Scope  Began at 2018-10-12 11:28:19.593000
# Writing to AWG Began at 2018-10-12 11:28:20.011000
# Measuring on VNA  Began at 2018-10-12 11:28:23.024000
# Measuring on Scope  Began at 2018-10-12 11:28:28.314000
# Writing to AWG Began at 2018-10-12 11:28:28.764000
# Measuring on VNA  Began at 2018-10-12 11:28:31.801000
# Measuring on Scope  Began at 2018-10-12 11:28:37.047000
# Writing to AWG Began at 2018-10-12 11:28:37.471000
# Measuring on VNA  Began at 2018-10-12 11:28:40.428000
# Measuring on Scope  Began at 2018-10-12 11:28:45.734000
# Writing to AWG Began at 2018-10-12 11:28:46.155000
# Measuring on VNA  Began at 2018-10-12 11:28:49.161000
# Measuring on Scope  Began at 2018-10-12 11:28:54.359000
# Writing to AWG Began at 2018-10-12 11:28:54.768000
# Measuring on VNA  Began at 2018-10-12 11:28:57.823000
# Measuring on Scope  Began at 2018-10-12 11:29:03.134000
# Writing to AWG Began at 2018-10-12 11:29:03.580000
# Measuring on VNA  Began at 2018-10-12 11:29:06.573000
# Measuring on Scope  Began at 2018-10-12 11:29:11.836000
# Writing to AWG Began at 2018-10-12 11:29:12.252000
# Measuring on VNA  Began at 2018-10-12 11:29:15.275000
# Measuring on Scope  Began at 2018-10-12 11:29:20.552000
# Writing to AWG Began at 2018-10-12 11:29:20.983000
# Measuring on VNA  Began at 2018-10-12 11:29:24.023000
# Measuring on Scope  Began at 2018-10-12 11:29:29.287000
# Sweep 8
# f : 1000750000.0
#  ended at 2018-10-12 11:29:29.487000
#  taking 87 seonds
# Sweep 9
# f : 1001000000.0
#  began at 2018-10-12 11:29:29.487000
# Writing to AWG Began at 2018-10-12 11:29:29.734000
# Measuring on VNA  Began at 2018-10-12 11:29:32.793000
# Measuring on Scope  Began at 2018-10-12 11:29:38.089000
# Writing to AWG Began at 2018-10-12 11:29:38.496000
# Measuring on VNA  Began at 2018-10-12 11:29:41.550000
# Measuring on Scope  Began at 2018-10-12 11:29:46.800000
# Writing to AWG Began at 2018-10-12 11:29:47.241000
# Measuring on VNA  Began at 2018-10-12 11:29:50.254000
# Measuring on Scope  Began at 2018-10-12 11:29:55.531000
# Writing to AWG Began at 2018-10-12 11:29:55.944000
# Measuring on VNA  Began at 2018-10-12 11:29:58.945000
# Measuring on Scope  Began at 2018-10-12 11:30:04.268000
# Writing to AWG Began at 2018-10-12 11:30:04.688000
# Measuring on VNA  Began at 2018-10-12 11:30:07.698000
# Measuring on Scope  Began at 2018-10-12 11:30:12.991000
# Writing to AWG Began at 2018-10-12 11:30:13.395000
# Measuring on VNA  Began at 2018-10-12 11:30:16.394000
# Measuring on Scope  Began at 2018-10-12 11:30:21.659000
# Writing to AWG Began at 2018-10-12 11:30:22.065000
# Measuring on VNA  Began at 2018-10-12 11:30:25.071000
# Measuring on Scope  Began at 2018-10-12 11:30:30.785000
# Writing to AWG Began at 2018-10-12 11:30:31.229000
# Measuring on VNA  Began at 2018-10-12 11:30:34.247000
# Measuring on Scope  Began at 2018-10-12 11:30:39.478000
# Writing to AWG Began at 2018-10-12 11:30:39.899000
# Measuring on VNA  Began at 2018-10-12 11:30:42.900000
# Measuring on Scope  Began at 2018-10-12 11:30:48.206000
# Writing to AWG Began at 2018-10-12 11:30:48.632000
# Measuring on VNA  Began at 2018-10-12 11:30:51.685000
# Measuring on Scope  Began at 2018-10-12 11:30:56.946000
# Sweep 9
# f : 1001000000.0
#  ended at 2018-10-12 11:30:57.126000
#  taking 87 seonds
# Sweep 10
# f : 1001250000.0
#  began at 2018-10-12 11:30:57.126000
# Writing to AWG Began at 2018-10-12 11:30:57.351000
# Measuring on VNA  Began at 2018-10-12 11:31:00.393000
# Measuring on Scope  Began at 2018-10-12 11:31:05.676000
# Writing to AWG Began at 2018-10-12 11:31:06.080000
# Measuring on VNA  Began at 2018-10-12 11:31:09.137000
# Measuring on Scope  Began at 2018-10-12 11:31:14.370000
# Writing to AWG Began at 2018-10-12 11:31:14.774000
# Measuring on VNA  Began at 2018-10-12 11:31:17.777000
# Measuring on Scope  Began at 2018-10-12 11:31:23.040000
# Writing to AWG Began at 2018-10-12 11:31:23.450000
# Measuring on VNA  Began at 2018-10-12 11:31:26.444000
# Measuring on Scope  Began at 2018-10-12 11:31:31.610000
# Writing to AWG Began at 2018-10-12 11:31:32.033000
# Measuring on VNA  Began at 2018-10-12 11:31:35.054000
# Measuring on Scope  Began at 2018-10-12 11:31:40.231000
# Writing to AWG Began at 2018-10-12 11:31:40.652000
# Measuring on VNA  Began at 2018-10-12 11:31:43.648000
# Measuring on Scope  Began at 2018-10-12 11:31:48.878000
# Writing to AWG Began at 2018-10-12 11:31:49.265000
# Measuring on VNA  Began at 2018-10-12 11:31:52.241000
# Measuring on Scope  Began at 2018-10-12 11:31:57.498000
# Writing to AWG Began at 2018-10-12 11:31:57.901000
# Measuring on VNA  Began at 2018-10-12 11:32:00.891000
# Measuring on Scope  Began at 2018-10-12 11:32:06.210000
# Writing to AWG Began at 2018-10-12 11:32:06.609000
# Measuring on VNA  Began at 2018-10-12 11:32:09.626000
# Measuring on Scope  Began at 2018-10-12 11:32:14.937000
# Writing to AWG Began at 2018-10-12 11:32:15.343000
# Measuring on VNA  Began at 2018-10-12 11:32:18.359000
# Measuring on Scope  Began at 2018-10-12 11:32:23.599000
# Sweep 10
# f : 1001250000.0
#  ended at 2018-10-12 11:32:23.779000
#  taking 86 seonds
# Calibration Began at 2018-10-12 11:32:29.492000
# Sweep 0
# f : 999875000.0
#  began at 2018-10-12 11:32:29.492000
# Writing to AWG Began at 2018-10-12 11:32:31.680000
# Measuring on VNA  Began at 2018-10-12 11:32:35.816000
# Measuring on Scope  Began at 2018-10-12 11:32:41.087000
# Writing to AWG Began at 2018-10-12 11:32:43.377000
# Measuring on VNA  Began at 2018-10-12 11:32:47.521000
# Measuring on Scope  Began at 2018-10-12 11:32:52.788000
# Writing to AWG Began at 2018-10-12 11:32:55.110000
# Measuring on VNA  Began at 2018-10-12 11:32:59.237000
# Measuring on Scope  Began at 2018-10-12 11:33:04.520000
# Writing to AWG Began at 2018-10-12 11:33:06.835000
# Measuring on VNA  Began at 2018-10-12 11:33:10.907000
# Measuring on Scope  Began at 2018-10-12 11:33:16.181000
# Writing to AWG Began at 2018-10-12 11:33:18.468000
# Measuring on VNA  Began at 2018-10-12 11:33:22.539000
# Measuring on Scope  Began at 2018-10-12 11:33:27.865000
# Writing to AWG Began at 2018-10-12 11:33:30.169000
# Measuring on VNA  Began at 2018-10-12 11:33:34.272000
# Measuring on Scope  Began at 2018-10-12 11:33:39.571000
# Writing to AWG Began at 2018-10-12 11:33:41.889000
# Measuring on VNA  Began at 2018-10-12 11:33:45.984000
# Measuring on Scope  Began at 2018-10-12 11:33:51.243000
# Writing to AWG Began at 2018-10-12 11:33:53.615000
# Measuring on VNA  Began at 2018-10-12 11:33:57.752000
# Measuring on Scope  Began at 2018-10-12 11:34:03.003000
# Writing to AWG Began at 2018-10-12 11:34:05.333000
# Measuring on VNA  Began at 2018-10-12 11:34:09.457000
# Measuring on Scope  Began at 2018-10-12 11:34:14.690000
# Writing to AWG Began at 2018-10-12 11:34:16.986000
# Measuring on VNA  Began at 2018-10-12 11:34:21.100000
# Measuring on Scope  Began at 2018-10-12 11:34:26.332000
# Sweep 0
# f : 999875000.0
#  ended at 2018-10-12 11:34:26.502000
#  taking 117 seonds
# Sweep 1
# f : 999900000.0
#  began at 2018-10-12 11:34:26.502000
# Writing to AWG Began at 2018-10-12 11:34:28.645000
# Measuring on VNA  Began at 2018-10-12 11:34:32.774000
# Measuring on Scope  Began at 2018-10-12 11:34:38.020000
# Writing to AWG Began at 2018-10-12 11:34:40.327000
# Measuring on VNA  Began at 2018-10-12 11:34:44.454000
# Measuring on Scope  Began at 2018-10-12 11:34:49.714000
# Writing to AWG Began at 2018-10-12 11:34:52.002000
# Measuring on VNA  Began at 2018-10-12 11:34:56.133000
# Measuring on Scope  Began at 2018-10-12 11:35:01.292000
# Writing to AWG Began at 2018-10-12 11:35:03.603000
# Measuring on VNA  Began at 2018-10-12 11:35:07.735000
# Measuring on Scope  Began at 2018-10-12 11:35:12.978000
# Writing to AWG Began at 2018-10-12 11:35:15.272000
# Measuring on VNA  Began at 2018-10-12 11:35:19.942000
# Measuring on Scope  Began at 2018-10-12 11:35:25.179000
# Writing to AWG Began at 2018-10-12 11:35:27.479000
# Measuring on VNA  Began at 2018-10-12 11:35:31.583000
# Measuring on Scope  Began at 2018-10-12 11:35:36.880000
# Writing to AWG Began at 2018-10-12 11:35:39.229000
# Measuring on VNA  Began at 2018-10-12 11:35:43.316000
# Measuring on Scope  Began at 2018-10-12 11:35:48.513000
# Writing to AWG Began at 2018-10-12 11:35:50.826000
# Measuring on VNA  Began at 2018-10-12 11:35:54.954000
# Measuring on Scope  Began at 2018-10-12 11:36:00.208000
# Writing to AWG Began at 2018-10-12 11:36:02.536000
# Measuring on VNA  Began at 2018-10-12 11:36:06.644000
# Measuring on Scope  Began at 2018-10-12 11:36:11.879000
# Writing to AWG Began at 2018-10-12 11:36:14.171000
# Measuring on VNA  Began at 2018-10-12 11:36:18.312000
# Measuring on Scope  Began at 2018-10-12 11:36:23.558000
# Sweep 1
# f : 999900000.0
#  ended at 2018-10-12 11:36:23.738000
#  taking 117 seonds
# Sweep 2
# f : 999925000.0
#  began at 2018-10-12 11:36:23.738000
# Writing to AWG Began at 2018-10-12 11:36:25.897000
# Measuring on VNA  Began at 2018-10-12 11:36:30.023000
# Measuring on Scope  Began at 2018-10-12 11:36:35.238000
# Writing to AWG Began at 2018-10-12 11:36:37.549000
# Measuring on VNA  Began at 2018-10-12 11:36:41.688000
# Measuring on Scope  Began at 2018-10-12 11:36:46.953000
# Writing to AWG Began at 2018-10-12 11:36:49.259000
# Measuring on VNA  Began at 2018-10-12 11:36:53.406000
# Measuring on Scope  Began at 2018-10-12 11:36:58.654000
# Writing to AWG Began at 2018-10-12 11:37:00.969000
# Measuring on VNA  Began at 2018-10-12 11:37:05.060000
# Measuring on Scope  Began at 2018-10-12 11:37:10.340000
# Writing to AWG Began at 2018-10-12 11:37:12.659000
# Measuring on VNA  Began at 2018-10-12 11:37:16.749000
# Measuring on Scope  Began at 2018-10-12 11:37:22.023000
# Writing to AWG Began at 2018-10-12 11:37:24.346000
# Measuring on VNA  Began at 2018-10-12 11:37:28.457000
# Measuring on Scope  Began at 2018-10-12 11:37:33.732000
# Writing to AWG Began at 2018-10-12 11:37:36.073000
# Measuring on VNA  Began at 2018-10-12 11:37:40.170000
# Measuring on Scope  Began at 2018-10-12 11:37:45.467000
# Writing to AWG Began at 2018-10-12 11:37:47.866000
# Measuring on VNA  Began at 2018-10-12 11:37:51.990000
# Measuring on Scope  Began at 2018-10-12 11:37:57.284000
# Writing to AWG Began at 2018-10-12 11:37:59.595000
# Measuring on VNA  Began at 2018-10-12 11:38:03.719000
# Measuring on Scope  Began at 2018-10-12 11:38:08.922000
# Writing to AWG Began at 2018-10-12 11:38:11.235000
# Measuring on VNA  Began at 2018-10-12 11:38:15.345000
# Measuring on Scope  Began at 2018-10-12 11:38:20.620000
# Sweep 2
# f : 999925000.0
#  ended at 2018-10-12 11:38:20.820000
#  taking 117 seonds
# Sweep 3
# f : 999950000.0
#  began at 2018-10-12 11:38:20.820000
# Writing to AWG Began at 2018-10-12 11:38:22.939000
# Measuring on VNA  Began at 2018-10-12 11:38:27.047000
# Measuring on Scope  Began at 2018-10-12 11:38:32.295000
# Writing to AWG Began at 2018-10-12 11:38:34.703000
# Measuring on VNA  Began at 2018-10-12 11:38:38.812000
# Measuring on Scope  Began at 2018-10-12 11:38:44.063000
# Writing to AWG Began at 2018-10-12 11:38:46.414000
# Measuring on VNA  Began at 2018-10-12 11:38:50.533000
# Measuring on Scope  Began at 2018-10-12 11:38:55.860000
# Writing to AWG Began at 2018-10-12 11:38:58.208000
# Measuring on VNA  Began at 2018-10-12 11:39:02.311000
# Measuring on Scope  Began at 2018-10-12 11:39:07.553000
# Writing to AWG Began at 2018-10-12 11:39:09.917000
# Measuring on VNA  Began at 2018-10-12 11:39:13.998000
# Measuring on Scope  Began at 2018-10-12 11:39:19.278000
# Writing to AWG Began at 2018-10-12 11:39:21.595000
# Measuring on VNA  Began at 2018-10-12 11:39:25.687000
# Measuring on Scope  Began at 2018-10-12 11:39:30.892000
# Writing to AWG Began at 2018-10-12 11:39:33.265000
# Measuring on VNA  Began at 2018-10-12 11:39:37.343000
# Measuring on Scope  Began at 2018-10-12 11:39:42.675000
# Writing to AWG Began at 2018-10-12 11:39:45.002000
# Measuring on VNA  Began at 2018-10-12 11:39:49.128000
# Measuring on Scope  Began at 2018-10-12 11:39:54.353000
# Writing to AWG Began at 2018-10-12 11:39:56.686000
# Measuring on VNA  Began at 2018-10-12 11:40:00.828000
# Measuring on Scope  Began at 2018-10-12 11:40:06.103000
# Writing to AWG Began at 2018-10-12 11:40:08.410000
# Measuring on VNA  Began at 2018-10-12 11:40:12.542000
# Measuring on Scope  Began at 2018-10-12 11:40:17.806000
# Sweep 3
# f : 999950000.0
#  ended at 2018-10-12 11:40:18.018000
#  taking 117 seonds
# Sweep 4
# f : 999975000.0
#  began at 2018-10-12 11:40:18.019000
# Writing to AWG Began at 2018-10-12 11:40:20.160000
# Measuring on VNA  Began at 2018-10-12 11:40:24.297000
# Measuring on Scope  Began at 2018-10-12 11:40:29.534000
# Writing to AWG Began at 2018-10-12 11:40:31.873000
# Measuring on VNA  Began at 2018-10-12 11:40:35.948000
# Measuring on Scope  Began at 2018-10-12 11:40:41.225000
# Writing to AWG Began at 2018-10-12 11:40:43.527000
# Measuring on VNA  Began at 2018-10-12 11:40:47.658000
# Measuring on Scope  Began at 2018-10-12 11:40:52.902000
# Writing to AWG Began at 2018-10-12 11:40:55.268000
# Measuring on VNA  Began at 2018-10-12 11:40:59.358000
# Measuring on Scope  Began at 2018-10-12 11:41:04.601000
# Writing to AWG Began at 2018-10-12 11:41:06.921000
# Measuring on VNA  Began at 2018-10-12 11:41:11.033000
# Measuring on Scope  Began at 2018-10-12 11:41:16.254000
# Writing to AWG Began at 2018-10-12 11:41:18.611000
# Measuring on VNA  Began at 2018-10-12 11:41:22.701000
# Measuring on Scope  Began at 2018-10-12 11:41:27.932000
# Writing to AWG Began at 2018-10-12 11:41:30.316000
# Measuring on VNA  Began at 2018-10-12 11:41:34.393000
# Measuring on Scope  Began at 2018-10-12 11:41:39.616000
# Writing to AWG Began at 2018-10-12 11:41:42.022000
# Measuring on VNA  Began at 2018-10-12 11:41:46.125000
# Measuring on Scope  Began at 2018-10-12 11:41:51.400000
# Writing to AWG Began at 2018-10-12 11:41:53.732000
# Measuring on VNA  Began at 2018-10-12 11:41:57.841000
# Measuring on Scope  Began at 2018-10-12 11:42:03.863000
# Writing to AWG Began at 2018-10-12 11:42:06.127000
# Measuring on VNA  Began at 2018-10-12 11:42:10.251000
# Measuring on Scope  Began at 2018-10-12 11:42:15.484000
# Sweep 4
# f : 999975000.0
#  ended at 2018-10-12 11:42:15.674000
#  taking 117 seonds
# Sweep 5
# f : 1000000000.0
#  began at 2018-10-12 11:42:15.674000
# Writing to AWG Began at 2018-10-12 11:42:17.792000
# Measuring on VNA  Began at 2018-10-12 11:42:21.964000
# Measuring on Scope  Began at 2018-10-12 11:42:27.252000
# Writing to AWG Began at 2018-10-12 11:42:29.527000
# Measuring on VNA  Began at 2018-10-12 11:42:33.716000
# Measuring on Scope  Began at 2018-10-12 11:42:38.938000
# Writing to AWG Began at 2018-10-12 11:42:41.198000
# Measuring on VNA  Began at 2018-10-12 11:42:45.352000
# Measuring on Scope  Began at 2018-10-12 11:42:50.606000
# Writing to AWG Began at 2018-10-12 11:42:52.961000
# Measuring on VNA  Began at 2018-10-12 11:42:57.076000
# Measuring on Scope  Began at 2018-10-12 11:43:02.262000
# Writing to AWG Began at 2018-10-12 11:43:04.550000
# Measuring on VNA  Began at 2018-10-12 11:43:08.649000
# Measuring on Scope  Began at 2018-10-12 11:43:13.946000
# Writing to AWG Began at 2018-10-12 11:43:16.299000
# Measuring on VNA  Began at 2018-10-12 11:43:20.399000
# Measuring on Scope  Began at 2018-10-12 11:43:25.666000
# Writing to AWG Began at 2018-10-12 11:43:28.005000
# Measuring on VNA  Began at 2018-10-12 11:43:32.090000
# Measuring on Scope  Began at 2018-10-12 11:43:37.338000
# Writing to AWG Began at 2018-10-12 11:43:39.690000
# Measuring on VNA  Began at 2018-10-12 11:43:43.777000
# Measuring on Scope  Began at 2018-10-12 11:43:49.060000
# Writing to AWG Began at 2018-10-12 11:43:51.412000
# Measuring on VNA  Began at 2018-10-12 11:43:55.574000
# Measuring on Scope  Began at 2018-10-12 11:44:00.825000
# Writing to AWG Began at 2018-10-12 11:44:03.134000
# Measuring on VNA  Began at 2018-10-12 11:44:07.261000
# Measuring on Scope  Began at 2018-10-12 11:44:12.522000
# Sweep 5
# f : 1000000000.0
#  ended at 2018-10-12 11:44:12.722000
#  taking 117 seonds
# Sweep 6
# f : 1000025000.0
#  began at 2018-10-12 11:44:12.722000
# Writing to AWG Began at 2018-10-12 11:44:14.845000
# Measuring on VNA  Began at 2018-10-12 11:44:18.951000
# Measuring on Scope  Began at 2018-10-12 11:44:24.192000
# Writing to AWG Began at 2018-10-12 11:44:26.502000
# Measuring on VNA  Began at 2018-10-12 11:44:30.592000
# Measuring on Scope  Began at 2018-10-12 11:44:35.842000
# Writing to AWG Began at 2018-10-12 11:44:38.188000
# Measuring on VNA  Began at 2018-10-12 11:44:42.263000
# Measuring on Scope  Began at 2018-10-12 11:44:47.510000
# Writing to AWG Began at 2018-10-12 11:44:49.803000
# Measuring on VNA  Began at 2018-10-12 11:44:53.891000
# Measuring on Scope  Began at 2018-10-12 11:44:59.120000
# Writing to AWG Began at 2018-10-12 11:45:01.487000
# Measuring on VNA  Began at 2018-10-12 11:45:05.560000
# Measuring on Scope  Began at 2018-10-12 11:45:10.861000
# Writing to AWG Began at 2018-10-12 11:45:13.177000
# Measuring on VNA  Began at 2018-10-12 11:45:17.214000
# Measuring on Scope  Began at 2018-10-12 11:45:22.486000
# Writing to AWG Began at 2018-10-12 11:45:24.797000
# Measuring on VNA  Began at 2018-10-12 11:45:28.857000
# Measuring on Scope  Began at 2018-10-12 11:45:34.141000
# Writing to AWG Began at 2018-10-12 11:45:36.441000
# Measuring on VNA  Began at 2018-10-12 11:45:40.541000
# Measuring on Scope  Began at 2018-10-12 11:45:45.805000
# Writing to AWG Began at 2018-10-12 11:45:48.181000
# Measuring on VNA  Began at 2018-10-12 11:45:52.272000
# Measuring on Scope  Began at 2018-10-12 11:45:57.566000
# Writing to AWG Began at 2018-10-12 11:45:59.858000
# Measuring on VNA  Began at 2018-10-12 11:46:03.960000
# Measuring on Scope  Began at 2018-10-12 11:46:09.232000
# Sweep 6
# f : 1000025000.0
#  ended at 2018-10-12 11:46:09.422000
#  taking 116 seonds
# Sweep 7
# f : 1000050000.0
#  began at 2018-10-12 11:46:09.422000
# Writing to AWG Began at 2018-10-12 11:46:11.576000
# Measuring on VNA  Began at 2018-10-12 11:46:15.729000
# Measuring on Scope  Began at 2018-10-12 11:46:21.016000
# Writing to AWG Began at 2018-10-12 11:46:23.301000
# Measuring on VNA  Began at 2018-10-12 11:46:27.414000
# Measuring on Scope  Began at 2018-10-12 11:46:32.703000
# Writing to AWG Began at 2018-10-12 11:46:35.057000
# Measuring on VNA  Began at 2018-10-12 11:46:39.115000
# Measuring on Scope  Began at 2018-10-12 11:46:44.385000
# Writing to AWG Began at 2018-10-12 11:46:46.761000
# Measuring on VNA  Began at 2018-10-12 11:46:50.827000
# Measuring on Scope  Began at 2018-10-12 11:46:56.045000
# Writing to AWG Began at 2018-10-12 11:46:58.444000
# Measuring on VNA  Began at 2018-10-12 11:47:02.511000
# Measuring on Scope  Began at 2018-10-12 11:47:07.756000
# Writing to AWG Began at 2018-10-12 11:47:10.070000
# Measuring on VNA  Began at 2018-10-12 11:47:14.123000
# Measuring on Scope  Began at 2018-10-12 11:47:19.375000
# Writing to AWG Began at 2018-10-12 11:47:21.678000
# Measuring on VNA  Began at 2018-10-12 11:47:25.775000
# Measuring on Scope  Began at 2018-10-12 11:47:31.006000
# Writing to AWG Began at 2018-10-12 11:47:33.350000
# Measuring on VNA  Began at 2018-10-12 11:47:37.411000
# Measuring on Scope  Began at 2018-10-12 11:47:42.635000
# Writing to AWG Began at 2018-10-12 11:47:44.957000
# Measuring on VNA  Began at 2018-10-12 11:47:49.043000
# Measuring on Scope  Began at 2018-10-12 11:47:54.314000
# Writing to AWG Began at 2018-10-12 11:47:56.609000
# Measuring on VNA  Began at 2018-10-12 11:48:00.726000
# Measuring on Scope  Began at 2018-10-12 11:48:05.966000
# Sweep 7
# f : 1000050000.0
#  ended at 2018-10-12 11:48:06.166000
#  taking 116 seonds
# Sweep 8
# f : 1000075000.0
#  began at 2018-10-12 11:48:06.166000
# Writing to AWG Began at 2018-10-12 11:48:08.307000
# Measuring on VNA  Began at 2018-10-12 11:48:12.402000
# Measuring on Scope  Began at 2018-10-12 11:48:17.623000
# Writing to AWG Began at 2018-10-12 11:48:20.256000
# Measuring on VNA  Began at 2018-10-12 11:48:24.380000
# Measuring on Scope  Began at 2018-10-12 11:48:29.593000
# Writing to AWG Began at 2018-10-12 11:48:31.956000
# Measuring on VNA  Began at 2018-10-12 11:48:36.070000
# Measuring on Scope  Began at 2018-10-12 11:48:41.333000
# Writing to AWG Began at 2018-10-12 11:48:43.657000
# Measuring on VNA  Began at 2018-10-12 11:48:47.758000
# Measuring on Scope  Began at 2018-10-12 11:48:53.100000
# Writing to AWG Began at 2018-10-12 11:48:55.453000
# Measuring on VNA  Began at 2018-10-12 11:48:59.522000
# Measuring on Scope  Began at 2018-10-12 11:49:04.786000
# Writing to AWG Began at 2018-10-12 11:49:07.130000
# Measuring on VNA  Began at 2018-10-12 11:49:11.210000
# Measuring on Scope  Began at 2018-10-12 11:49:16.456000
# Writing to AWG Began at 2018-10-12 11:49:18.794000
# Measuring on VNA  Began at 2018-10-12 11:49:22.840000
# Measuring on Scope  Began at 2018-10-12 11:49:28.107000
# Writing to AWG Began at 2018-10-12 11:49:30.347000
# Measuring on VNA  Began at 2018-10-12 11:49:34.380000
# Measuring on Scope  Began at 2018-10-12 11:49:39.582000
# Writing to AWG Began at 2018-10-12 11:49:41.856000
# Measuring on VNA  Began at 2018-10-12 11:49:45.959000
# Measuring on Scope  Began at 2018-10-12 11:49:51.217000
# Writing to AWG Began at 2018-10-12 11:49:53.517000
# Measuring on VNA  Began at 2018-10-12 11:49:57.649000
# Measuring on Scope  Began at 2018-10-12 11:50:02.904000
# Sweep 8
# f : 1000075000.0
#  ended at 2018-10-12 11:50:03.099000
#  taking 116 seonds
# Sweep 9
# f : 1000100000.0
#  began at 2018-10-12 11:50:03.099000
# Writing to AWG Began at 2018-10-12 11:50:05.190000
# Measuring on VNA  Began at 2018-10-12 11:50:09.286000
# Measuring on Scope  Began at 2018-10-12 11:50:14.582000
# Writing to AWG Began at 2018-10-12 11:50:16.864000
# Measuring on VNA  Began at 2018-10-12 11:50:21.803000
# Measuring on Scope  Began at 2018-10-12 11:50:27.093000
# Writing to AWG Began at 2018-10-12 11:50:29.376000
# Measuring on VNA  Began at 2018-10-12 11:50:33.502000
# Measuring on Scope  Began at 2018-10-12 11:50:38.778000
# Writing to AWG Began at 2018-10-12 11:50:41.083000
# Measuring on VNA  Began at 2018-10-12 11:50:45.166000
# Measuring on Scope  Began at 2018-10-12 11:50:50.427000
# Writing to AWG Began at 2018-10-12 11:50:52.816000
# Measuring on VNA  Began at 2018-10-12 11:50:56.902000
# Measuring on Scope  Began at 2018-10-12 11:51:02.189000
# Writing to AWG Began at 2018-10-12 11:51:04.470000
# Measuring on VNA  Began at 2018-10-12 11:51:08.524000
# Measuring on Scope  Began at 2018-10-12 11:51:13.782000
# Writing to AWG Began at 2018-10-12 11:51:16.086000
# Measuring on VNA  Began at 2018-10-12 11:51:20.193000
# Measuring on Scope  Began at 2018-10-12 11:51:25.430000
# Writing to AWG Began at 2018-10-12 11:51:27.744000
# Measuring on VNA  Began at 2018-10-12 11:51:31.852000
# Measuring on Scope  Began at 2018-10-12 11:51:37.068000
# Writing to AWG Began at 2018-10-12 11:51:39.392000
# Measuring on VNA  Began at 2018-10-12 11:51:43.471000
# Measuring on Scope  Began at 2018-10-12 11:51:48.743000
# Writing to AWG Began at 2018-10-12 11:51:51.052000
# Measuring on VNA  Began at 2018-10-12 11:51:55.189000
# Measuring on Scope  Began at 2018-10-12 11:52:00.499000
# Sweep 9
# f : 1000100000.0
#  ended at 2018-10-12 11:52:00.722000
#  taking 117 seonds
# Sweep 10
# f : 1000125000.0
#  began at 2018-10-12 11:52:00.723000
# Writing to AWG Began at 2018-10-12 11:52:02.838000
# Measuring on VNA  Began at 2018-10-12 11:52:06.932000
# Measuring on Scope  Began at 2018-10-12 11:52:12.162000
# Writing to AWG Began at 2018-10-12 11:52:14.442000
# Measuring on VNA  Began at 2018-10-12 11:52:18.583000
# Measuring on Scope  Began at 2018-10-12 11:52:23.832000
# Writing to AWG Began at 2018-10-12 11:52:26.148000
# Measuring on VNA  Began at 2018-10-12 11:52:30.269000
# Measuring on Scope  Began at 2018-10-12 11:52:35.543000
# Writing to AWG Began at 2018-10-12 11:52:37.819000
# Measuring on VNA  Began at 2018-10-12 11:52:41.909000
# Measuring on Scope  Began at 2018-10-12 11:52:47.248000
# Writing to AWG Began at 2018-10-12 11:52:49.556000
# Measuring on VNA  Began at 2018-10-12 11:52:53.611000
# Measuring on Scope  Began at 2018-10-12 11:52:58.915000
# Writing to AWG Began at 2018-10-12 11:53:01.190000
# Measuring on VNA  Began at 2018-10-12 11:53:06.033000
# Measuring on Scope  Began at 2018-10-12 11:53:11.308000
# Writing to AWG Began at 2018-10-12 11:53:13.626000
# Measuring on VNA  Began at 2018-10-12 11:53:17.738000
# Measuring on Scope  Began at 2018-10-12 11:53:22.981000
# Writing to AWG Began at 2018-10-12 11:53:25.236000
# Measuring on VNA  Began at 2018-10-12 11:53:29.345000
# Measuring on Scope  Began at 2018-10-12 11:53:34.623000
# Writing to AWG Began at 2018-10-12 11:53:36.959000
# Measuring on VNA  Began at 2018-10-12 11:53:41.049000
# Measuring on Scope  Began at 2018-10-12 11:53:46.328000
# Writing to AWG Began at 2018-10-12 11:53:48.591000
# Measuring on VNA  Began at 2018-10-12 11:53:52.722000
# Measuring on Scope  Began at 2018-10-12 11:53:57.919000
# Sweep 10
# f : 1000125000.0
#  ended at 2018-10-12 11:53:58.119000
#  taking 117 seonds
