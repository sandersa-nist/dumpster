# %% [markdown]
# # A sweep of tone spacing for the AWG calibration

# %%
# import the pyMez packages default API
from pyMez import *
# import the Fitting module for Signal Generation and Fitting, note the namespace Code.Analysis.Fitting also works
from pyMez.Code.Analysis.Fitting import *
# Out:
# Importing pyMez, this should take roughly 30 seconds
# Importing Code.DataHandlers.GeneralModels
# It took 1.427 s to import Code.DataHandlers.GeneralModels
# Importing Code.DataHandlers.HTMLModels
# It took 0.3 s to import Code.DataHandlers.HTMLModels
# Importing Code.DataHandlers.NISTModels
# The module smithplot was not found,please put it on the python path
# It took 2.212 s to import Code.DataHandlers.NISTModels
# Importing Code.DataHandlers.TouchstoneModels
# The module smithplot was not found,please put it on the python path
# It took 0.03 s to import Code.DataHandlers.TouchstoneModels
# Importing Code.DataHandlers.XMLModels
# It took 0.268 s to import Code.DataHandlers.XMLModels
# Importing Code.DataHandlers.ZipModels
# It took 0.035 s to import Code.DataHandlers.ZipModels
# Importing Code.InstrumentControl.Experiments
# It took 5.285 s to import Code.InstrumentControl.Experiments
# Importing Code.InstrumentControl.Instruments
# It took 0.01 s to import Code.InstrumentControl.Instruments
# Importing Code.Utils.Names
# It took 0.01 s to import Code.Utils.Names
# It took 9.577 s to import all of the active modules

# %% [markdown]
# ## Setup Variables that do not change with tone spacing

# %%
# none of these instruments have xml instrument sheets, need to add them
psg_address="GPIB1::19"
vna_address="GPIB1::16"
awg_address="GPIB1::10"
scope_address="GPIB1::7::INSTR"
pm_address="GPIB1::13"
# ----------------------
vna=VNA(vna_address)
scope=HighSpeedOscope(scope_address)
awg=VisaInstrument(awg_address)
pm=PowerMeter(pm_address)
# ----------------


# this is local to the computer taking the data, the data should be copied to Q:\public\Aric\AWG_Phase_Calibration_20180927
data_directory=r'C:\Share\AWG_Phase_Calibration_20181001\Comb_Locked_PSG\Zero_Phase_10Hz_Load'
# Experimental variables

# the psg frequency acts as the master clock
psg_amplitude=12. #psg amplitude in dBm
psg_frequency=10.*10.**9 # 10 GHz
time_step=1./psg_frequency # time step for the awg
fundamental_frequency = 1.*10.**9 # Center of the passband or fundemental frequency in Hz
number_tones = 11 # Number of tones in the modulation bandwidth including the fundamental, should be odd
number_harmonics = 1# Number of harmonics to use. The frequency grid will be n*(f-df), n*f, n*(f+df), etc
# Select the phase for the multisine    
multisine_phase="zero"
#multisine_phase="schroeder"
number_envelopes=1.

# Measurement Phase Reference Setup 
round_multisine_before_writing=True # Rounds the multisine to a desired bitdepth before writing to AWG
bit_depth=8
waveform_name="Calibration_Phase_Reference" # name of the waveform to write to the 
bin_format=True # If the wave is in 16 bit bin format
marker_1=True # If marker one is to be set
marker_1_n_repeats=1 # the rep rate of the marker as a function of number of repeats per time sequence
marker_2=False
marker_2_n_repeats=1

# VNA setup 
vna_IFBW=10
comb_frequency = 2.5*10**6
number_phases=10
vna.set_IFBW(vna_IFBW)

# Power Meter Setup
# pm.set_units("W")
# Out:
# The information sheet was not found defaulting to address
# The information sheet was not found defaulting to address
# The information sheet was not found defaulting to address
# The information sheet was not found defaulting to address

# %%
# Setup the traces that we might want
# Delete all of the traces that we do not need, in this case I will delete  all of them it leaves one trace
trace_string=vna.query("CALC:PAR:CAT?")
trace_list=trace_string.replace("\n","").split(",")[0::3] #remove endline, split on , and then take every third one
for trace in trace_list:
    vna.write("CALC:PAR:DEL '{0}'".format(trace))
print("Existing traces are {0}".format(vna.query("CALC:PAR:CAT?")))
# set up the traces, we use drive_port=1 sense all of the inputs are turned off, there are combs on port 2, port 3

# first we add a trace for a each reference reciever (R1=a1)
for i in range(4):
    vna.add_trace(trace_name="a{0}".format(i+1),trace_parameter="R{0}".format(i+1),drive_port=1)
# now we add a trace for each b reciever (labelled A,B,C,D)
for i,receiver in enumerate(["A","B","C","D"]):
    vna.add_trace(trace_name="b{0}".format(i+1),trace_parameter="{0}".format(receiver),drive_port=1)
    
# now we want a ratio of R1R4 (a1/a4) <- this is the calibration phase reference / measurement phase reference
vna.add_trace(trace_name="ratio",trace_parameter="R1R4",drive_port="1")
vna.add_trace(trace_name="b_ratio",trace_parameter="b1a4",drive_port="1")

vna.add_trace(trace_name="comb_ratio",trace_parameter="a1b2",drive_port="1")
print("Existing traces are {0}".format(vna.query("CALC:PAR:CAT?")))
# Out:
# Existing traces are "a1,a1,1"
#
# Existing traces are "a1,a1,1,a2,R2,1,a3,R3,1,a4,R4,1,b1,A,1,b2,B,1,b3,C,1,b4,D,1,ratio,R1/R4,1,b_ratio,b1/a4,1,comb_ratio,a1/b2,1"

# %%
tone_spacings=[10*10**6,5*10**6,2.5*10**6,2.5*10**5,2.5*10**4]
comb_spacings=[10*10**6,5*10**6,2.5*10**6]

# %%
for tone_spacing in tone_spacings:
    comb_spacing=tone_spacing in comb_spacings
    print(comb_spacing)
# Out:
# True
# True
# True
# False
# False

# %%
for tone_spacing in tone_spacings:
    comb_spacing = tone_spacing in comb_spacings
    summary_data=[]
    # now calculate the frequency_list
    frequency_list=[]
    for harmonic in range(number_harmonics):
        frequency_array=np.linspace((harmonic+1)*(fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                    (harmonic+1)*(fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)
        frequency_list=frequency_list+frequency_array.tolist()
    time_max=number_envelopes/tone_spacing
    number_time_points=int(round(time_max/time_step))
    time_shift=0.*time_step
    sweep_wait_time=2.5*float(len(frequency_list))/float(vna_IFBW)
    sweep_directory=os.path.join(data_directory,"{0}_Tones_{1:.0f}KHz_Spacing".format(number_tones,10**-3*tone_spacing))
    os.mkdir(sweep_directory)
    # first create the multisine
    sine_function=FunctionalModel(parameters=["f","phi"],variables=["t"],equation="cos(2*pi*f*t+phi)")
    time_list=np.linspace(0.+time_shift,time_max+time_shift-time_step,number_time_points)

    # calculate the phases 
    phase_list = [0. for i in range(len(frequency_list))]
    if re.search("sch",multisine_phase,re.IGNORECASE):
        phase_list=[]
        for frequency_index,frequency in enumerate(frequency_list):
            k=(frequency_index+1)%number_tones
            schroeder_phase=-k*(k-1)*np.pi/number_tones
            phase_list.append(schroeder_phase)
    # initialize multisine to a set of zeros
    multisine=np.array([0 for i in range(number_time_points)])
    # add each component
    for frequency_index,frequency in enumerate(frequency_list):
        sine_function.set_parameters({"f":frequency,"phi":phase_list[frequency_index]})
        multisine_component=sine_function(time_list)
        multisine=multisine+multisine_component

    # substract the mean
    # multisine=multisine-np.mean(multisine)
    # normalize the multisine
    # multisine=1/max(multisine)*multisine

    # round the multisine to the nearest bitdepth before writing
    if round_multisine_before_writing:
        discrete_steps=np.linspace(min(multisine),max(multisine),2**bit_depth)
        rounded_multisine=[]
        int_multisine=[]
        for value in multisine:
            difference_array=abs(discrete_steps-value)
            minimum_location=np.argmin(difference_array)
            rounded_multisine.append(discrete_steps[minimum_location])
            int_multisine.append(minimum_location)
        if bin_format:
            multisine=np.array(int_multisine,dtype=np.uint16)
            # Shift, now to add the marker add + 2**14 or +2**15 at the desired location
            multisine=multisine*2**6
        else:
            multisine=rounded_multisine

    # now we add the marker. 
    if marker_1:

        distance=int(np.floor(float(len(multisine))/float(marker_1_n_repeats)))
        for i in range(marker_1_n_repeats):
            try:
                multisine[i*distance]=multisine[i*distance]+2**14
            except:
                pass
    # I am guessing that this has the possibility of kiling the oscope trigger
    if bin_format:
        # turn AWG's output 1 & 2 OFF
        awg.write(':OUTPUT1:STATE OFF')
        awg.write(':OUTPUT2:STATE OFF')
        # wait...
        time.sleep(0.1)
        # UNRUN state
        awg.write('AWGCONTROL:STOP')
        # wait...
        time.sleep(0.5)

        # delete any older waveform with the same name
        awg.write('WLISt:WAVeform:DELete "{0}"'.format(waveform_name))
        time.sleep(0.05)

        # create new waveform
        awg.write('WLISt:WAVeform:NEW "{0}", {1}, INT'.format(waveform_name,len(multisine)))
        # download data
        awg.resource.write_binary_values('WLISt:WAVeform:DATA "{0}",'.format(waveform_name), multisine, datatype='H', is_big_endian=False)
        time.sleep(.1)
        # assign new waveform to channel 1 & 2
        awg.write('SOURce1:WAVeform "{0}"'.format(waveform_name))
        awg.write('SOURce2:WAVeform "{0}"'.format(waveform_name))

        # check for errors
        error_str = awg.query('SYSTEM:ERROR:NEXT?')
        # wait...
        time.sleep(.1)
        # AWG on RUN state
        awg.write('AWGCONTROL:RUN')
        # wait...
        time.sleep(0.5)
        # check if there is any errors on AWG's buffer
        error_str = awg.query('SYSTEM:ERROR:NEXT?')
        if error_str == '0,"No error"\n':
            # turn AWG's output 1 OFF
            awg.write(':OUTPUT1:STATE ON')
            awg.write(':OUTPUT2:STATE ON')

    if number_harmonics is 1:    
        vna.set_frequency((fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                        (fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)  
    else:
        for harmonic in range(number_harmonics):
            vna.add_segment((harmonic+1)*(fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                        (harmonic+1)*(fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)

    single_cosine=FunctionalModel(variables=["t"],parameters=["f","phi"],equation="cos(2*pi*f*t+phi)")

    phase_sweep_list=[2*np.pi*i/number_phases for i in range(number_phases)]
    # Loop to measure the phase
    start_timer=datetime.datetime.now()
    print("Calibration Began at {0}".format(start_timer))
    for frequency_index,frequency in enumerate(frequency_list[:]):
        begin_sweep_timer=datetime.datetime.now()
        print("Sweep {0} \nf : {1}\n began at {2} ".format(frequency_index,frequency,begin_sweep_timer))
        for phase_index,phase in enumerate(phase_sweep_list):

             #create the sine to write
            # ----------------------------------------------------------------------------------------------------------
            single_cosine.set_parameters({"f":frequency,"phi":phase})
            tone_data=single_cosine(time_list)

            # round the multisine to the nearest bitdepth before writing
            if round_multisine_before_writing:
                discrete_steps=np.linspace(min(tone_data),max(tone_data),2**bit_depth)
                rounded_tone_data=[]
                int_tone_data=[]
                for value in tone_data:
                    difference_array=abs(discrete_steps-value)
                    minimum_location=np.argmin(difference_array)
                    rounded_tone_data.append(discrete_steps[minimum_location])
                    int_tone_data.append(minimum_location)
                if bin_format:
                    tone_data=np.array(int_tone_data,dtype=np.uint16)
                    # Shift, now to add the marker add + 2**14 or +2**15 at the desired location
                    tone_data=tone_data*2**6
                else:
                    tone_data=rounded_tone_data

            timer=datetime.datetime.now()
            print("Writing to AWG Began at {0} ".format(timer))
            # write tone to AWG
            # --------------------------------------------------------
            tone_waveform_name="Tone_{0}_Phase_{1:.0f}_Calibration".format(frequency_index,phase*180/np.pi)
            # save the wave for good measure
            out_file=open(os.path.join(sweep_directory,"{0}.bin".format(tone_waveform_name)),"wb")
            out_file.write(tone_data)
            out_file.close()
            # plot 
            plt.close()
            plt.plot(time_list,tone_data)
            plt.xlabel("Time (s)")
            plt.ylabel("Amplitude (arb)")
            plt.title(tone_waveform_name)
            plt.savefig(os.path.join(sweep_directory,"{0}.png".format(tone_waveform_name)))
            #plt.show();

            if bin_format:
                # turn AWG's output 1 
                awg.write(':OUTPUT1:STATE OFF')
                time.sleep(0.1)
                # UNRUN state
                awg.write('AWGCONTROL:STOP')
                # wait...
                time.sleep(0.5)

                # delete any older waveform with the same name
                awg.write('WLISt:WAVeform:DELete "{0}"'.format(tone_waveform_name))
                time.sleep(0.05)

                # create new waveform
                awg.write('WLISt:WAVeform:NEW "{0}", {1}, INT'.format(tone_waveform_name,len(tone_data)))
                # download data
                awg.resource.write_binary_values('WLISt:WAVeform:DATA "{0}",'.format(tone_waveform_name), 
                                                 tone_data, datatype='H', is_big_endian=False)
                time.sleep(0.1)
                # assign new waveform to channel 1 
                awg.write('SOURce1:WAVeform "{0}"'.format(tone_waveform_name))


                # check for errors
                error_str = awg.query('SYSTEM:ERROR:NEXT?')
                # wait...
                time.sleep(.1)
                # AWG on RUN state
                awg.write('AWGCONTROL:RUN')
                # wait...
                time.sleep(0.5)
                # check if there is any errors on AWG's buffer
                error_str = awg.query('SYSTEM:ERROR:NEXT?')
                if error_str == '0,"No error"\n':
                    # turn AWG's output 1 ON
                    awg.write(':OUTPUT1:STATE ON')
                    
            timer=datetime.datetime.now()
            print("Measuring on VNA  Began at {0} ".format(timer))                
            # Measure on VNA
            # ---------------------------------------------------------------------------------------------------------
            # now the measured trace should be the multisine we can trigger and display the ratio to be sure
            vna.trigger_sweep()
            time.sleep(sweep_wait_time)
            # read_trace needs to have some work
            # Here we read a1/a4, a1, a4
            #------------------------------------------------------------------------------------
            vna.write("CALC:PAR:SEL '{0}'".format("ratio"))
            ratio_trace_string = vna.query("CALC:DATA? SDATA")
            ratio_trace = ratio_trace_string.replace("\n","").split(",")
            ratio_real = ratio_trace[0::2]
            ratio_imaginary = ratio_trace[1::2]
            complex_ratio =np.array([complex(float(real_value),
                                             float(ratio_imaginary[index])) for index,real_value in enumerate(ratio_real)])
                 
            vna.write("CALC:PAR:SEL '{0}'".format("b_ratio"))    
            b_ratio_trace_string = vna.query("CALC:DATA? SDATA")
            b_ratio_trace = b_ratio_trace_string.replace("\n","").split(",")
            b_ratio_real = b_ratio_trace[0::2]
            b_ratio_imaginary = b_ratio_trace[1::2]
            b_complex_ratio =np.array([complex(float(real_value),
                                             float(b_ratio_imaginary[index])) for index,real_value in enumerate(b_ratio_real)])

            vna.write("CALC:PAR:SEL '{0}'".format("a1"))
            a1_trace_string = vna.query("CALC:DATA? SDATA")
            a1_trace = a1_trace_string.replace("\n","").split(",")
            a1_real = a1_trace[0::2]
            a1_imaginary = a1_trace[1::2]
            complex_a1 =np.array([complex(float(real_value),
                                             float(a1_imaginary[index])) for index,real_value in enumerate(a1_real)])
            
            vna.write("CALC:PAR:SEL '{0}'".format("b1"))
            b1_trace_string = vna.query("CALC:DATA? SDATA")
            b1_trace = b1_trace_string.replace("\n","").split(",")
            b1_real = b1_trace[0::2]
            b1_imaginary = b1_trace[1::2]
            complex_b1 =np.array([complex(float(real_value),
                                             float(b1_imaginary[index])) for index,real_value in enumerate(b1_real)])

            vna.write("CALC:PAR:SEL '{0}'".format("a4"))
            a4_trace_string = vna.query("CALC:DATA? SDATA")
            a4_trace = a4_trace_string.replace("\n","").split(",")
            a4_real = a4_trace[0::2]
            a4_imaginary = a4_trace[1::2]
            complex_a4 =np.array([complex(float(real_value),
                                             float(a4_imaginary[index])) for index,real_value in enumerate(a4_real)])
            # If the tone spacing is on the comb grid, we want a1/b2, b2, b3
            if comb_spacing:
                # this block should be replaced with vna.read_trace
                vna.write("CALC:PAR:SEL '{0}'".format("b2"))
                b2_trace_string = vna.query("CALC:DATA? SDATA")
                b2_trace = b2_trace_string.replace("\n","").split(",")
                b2_real = b2_trace[0::2]
                b2_imaginary = b2_trace[1::2]
                complex_b2 =np.array([complex(float(real_value),
                                                 float(b2_imaginary[index])) for index,real_value in enumerate(b2_real)])                

                vna.write("CALC:PAR:SEL '{0}'".format("b3"))
                b3_trace_string = vna.query("CALC:DATA? SDATA")
                b3_trace = b3_trace_string.replace("\n","").split(",")
                b3_real = b3_trace[0::2]
                b3_imaginary = b3_trace[1::2]
                complex_b3 =np.array([complex(float(real_value),
                                                 float(b3_imaginary[index])) for index,real_value in enumerate(b3_real)])                
                             
                vna.write("CALC:PAR:SEL '{0}'".format("comb_ratio"))
                comb_ratio_trace_string = vna.query("CALC:DATA? SDATA")
                comb_ratio_trace = comb_ratio_trace_string.replace("\n","").split(",")
                comb_ratio_real = comb_ratio_trace[0::2]
                comb_ratio_imaginary = comb_ratio_trace[1::2]
                complex_comb_ratio =np.array([complex(float(real_value),
                                                 float(comb_ratio_imaginary[index])) for index,real_value in enumerate(comb_ratio_real)])                
                             

                vna_data=[map(lambda x:float(x),[frequency_list[index],
                           real_value,
                           ratio_imaginary[index],
                           b_ratio_real[index],b_ratio_imaginary[index],
                           a1_real[index],a1_imaginary[index],
                           b1_real[index],b1_imaginary[index],
                           a4_real[index],a4_imaginary[index],
                           comb_ratio_real[index],comb_ratio_imaginary[index],
                           b2_real[index],b2_imaginary[index],
                           b3_real[index],b3_imaginary[index]]) for index,real_value in enumerate(ratio_real)]
                
                
                column_names=["Frequency",
                                         "reA1_Div_A4","imA1_Div_A4",
                                         "reB1_Div_A4","imB1_Div_A4",
                                         "reA1","imA1","reB1","imB1",
                                         "reA4","imA4",
                                         "reA1_Div_B2","imA1_Div_B2",
                                         "reB2","imB2","reB3","imB3"]
                options={"column_names":column_names,
                         "column_types":["float" for i in range(len(column_names))],
                         "directory":sweep_directory,"specific_descriptor":tone_waveform_name,
                         "general_descriptor":"Vna_Reciever_Values","extension":"txt","data":vna_data}                    
            else:
                
                vna_data=[map(lambda x:float(x),[frequency_list[index],
                           real_value,
                           ratio_imaginary[index],
                           b_ratio_real[index],b_ratio_imaginary[index],
                           a1_real[index],a1_imaginary[index],
                           b1_real[index],b1_imaginary[index],                      
                           a4_real[index],a4_imaginary[index]]) for index,real_value in enumerate(ratio_real)]
                column_names=["Frequency","reA1_Div_A4","imA1_Div_A4",
                              "reB1_Div_A4","imB1_Div_A4",
                              "reA1","imA1","reB1","imB1","reA4","imA4"]
                options={"column_names":column_names,
                         "column_types":["float" for i in range(len(column_names))],
                         "directory":sweep_directory,"specific_descriptor":tone_waveform_name,
                         "general_descriptor":"Vna_Reciever_Values","extension":"txt","data":vna_data}
            ratio_data_table=AsciiDataTable(None,**options)
            ratio_data_table.save()
            ratio_data_table.save_schema(change_extension(ratio_data_table.path,new_extension="schema"))
            plt.close()
            plt.plot(frequency_list,abs(complex_ratio),'b-o')
            plt.xlabel("Frequency (Hz)")
            plt.ylabel("Linear Magnitude")
            plt.title("Magnitude Measured on VNA")
            plt.savefig(os.path.join(sweep_directory,"Magnitude_Plot_Ratio_{0}.png".format(tone_waveform_name)))
            #plt.show();
            plt.close()
            plt.plot(np.array(frequency_list),np.angle(complex_ratio,deg=1),"b-o")
            plt.xlabel("Frequency(Hz)")
            plt.ylabel("Phase (Degrees)")
            plt.title("Phase Measured on VNA")
            plt.savefig(os.path.join(sweep_directory,"Phase_Plot_Ratio_{0}.png".format(tone_waveform_name)))
            #plt.show();
            timer=datetime.datetime.now()
            print("Measuring on Scope  Began at {0} ".format(timer))
            time.sleep(.1)
            # Measure on Power Meter
            # ---------------------------------------------------------------------------------------------------------
#             pm.set_frequency(frequency)
#             power_reading=pm.get_reading()
            
            
            
            
            
#             wave_trace=scope.measure_waves()
#             time.sleep(.1)
#             plt.close()            
#             plt.plot(wave_trace["Time"],wave_trace["CHAN2"],label="SUT")
#             plt.plot(wave_trace["Time"],wave_trace["CHAN3"],label="I")
#             plt.plot(wave_trace["Time"],wave_trace["CHAN4"],label="Q")
#             plt.legend()
#             plt.savefig(os.path.join(sweep_directory,"Scope_{0}.png".format(tone_waveform_name)))
#             #plt.show();
#             fit_cosine=FunctionalModel(variables=["t"],parameters=["A","phi"],equation="A*cos(2*pi*t*{0}+phi)".format(frequency))
#             x_data=10**-9*np.array(map(lambda x:float(x),wave_trace["Time"]))
#             y_data=np.array(map(lambda x:float(x),wave_trace["CHAN2"]))
#             fit_cosine.fit_data(x_data=x_data,y_data=y_data)
#             plt.close()
#             plt.plot(x_data,fit_cosine(x_data),label="Fit")
#             plt.plot(x_data,y_data,label="CHAN2")
#             fit_parameters=fit_cosine.parameter_values
#             plt.title("Amplitude: {A} Phase: {phi}".format(**fit_parameters))
#             plt.legend()
#             plt.savefig(os.path.join(sweep_directory,"Scope_Fit_{0}.png".format(tone_waveform_name)))
#             #plt.show();
#             wave_trace.options["fit_equation"]="{0}".format(fit_cosine)
#             wave_trace.options["fit_parameters"]=fit_parameters
#             wave_trace.save(os.path.join(sweep_directory,"{0}_Scope_Measurement.txt".format(tone_waveform_name)))
#             wave_trace.save_schema(change_extension(wave_trace.path,new_extension="schema"))

            
            # Calculate the Summary Row, A table of Tone Index, Frequency, AWG Set Amplitude, AWG Set Phase, Scope Measured Amp
            # Scope MEasured Phase, VNA Measured Amp, VNA Measured Phase and optional values if comb_spacing
            tone_index=frequency_index+1 # starts at 1
            summary_frequency=frequency  # I know it is not needed just a reminder
            AWG_set_amplitude = .5 # set by the awg after the write of the binary wave
            AWG_set_phase=phase*180/np.pi 
            
            vna_measured_amplitude=abs(complex_ratio[frequency_index])
            vna_measured_phase=np.angle(complex_ratio[frequency_index],deg=True)
            reflected_vna_measured_amplitude=abs(b_complex_ratio[frequency_index])
            reflected_vna_measured_phase=np.angle(b_complex_ratio[frequency_index],deg=True)
            if comb_spacing:
                vna_measured_amplitude_comb=abs(complex_comb_ratio[frequency_index])
                vna_measured_phase_comb=np.angle(complex_comb_ratio[frequency_index],deg=True)
                summary_row=[tone_index,summary_frequency,
                             AWG_set_amplitude,AWG_set_phase,
                             vna_measured_amplitude,vna_measured_phase,
                             reflected_vna_measured_amplitude,reflected_vna_measured_phase,
                             vna_measured_amplitude_comb,vna_measured_phase_comb]
            else:
                summary_row=[tone_index,summary_frequency,
                                 AWG_set_amplitude,AWG_set_phase,
                                 vna_measured_amplitude,vna_measured_phase,
                                 reflected_vna_measured_amplitude,reflected_vna_measured_phase]
            # Delete last waveform
            if phase_index>0:
                awg.write('WLISt:WAVeform:DELete "{0}"'.format(last_waveform_name))
            last_waveform_name=tone_waveform_name
            summary_data.append(summary_row)
            
        if comb_spacing:
            summary_column_names=["Tone","Frequency","AWG_Set_Amplitude","AWG_Set_Phase",
                                  "Vna_Amplitude","Vna_Phase","B1_Vna_Amplitude","B1_Vna_Phase",
                                  "Vna_Comb_Referenced_Amplitude","Vna_Comb_Referenced_Phase"]
            summary_column_units=[None,"Hz","Volts","Degrees",
                                  "Volts","Degrees",
                                  "Volts","Degrees",
                                  "Volts","Degrees"]
        else:
            summary_column_names=["Tone","Frequency","AWG_Set_Amplitude","AWG_Set_Phase",
                                  "Vna_Amplitude","Vna_Phase","B1_Vna_Amplitude","B1_Vna_Phase"]
            summary_column_units=[None,"Hz","Volts","Degrees",
                                  "Volts","Degrees"
                                  "Volts","Degrees"]
            
        summary_options={"column_names":summary_column_names,
                         "column_types":["float" for i in range(len(summary_column_names))],
                         "column_units":summary_column_units,
                         "directory":sweep_directory,
                         "specific_descriptor":"{0}_Tones_{1:.0f}KHz_Spacing".format(number_tones,10**3*tone_spacing),
                         "general_descriptor":"Summary","extension":"txt","data":summary_data,
                         "metadata":{"Timestamp":"{0}".format(datetime.datetime.now()),
                                     "sweep":"{0}_Tones_{1:.0f}KHz_Spacing".format(number_tones,10**3*tone_spacing),
                                    "tone_spacing":tone_spacing,"number_tones":number_tones,
                                     "multisine_phase":multisine_phase,"number_harmonics":number_harmonics,
                                    "frequnecy_list":frequency_list}} 
        summary_table=AsciiDataTable(None,**summary_options)
        summary_table.save()
        summary_table.save_schema(change_extension(summary_table.path,new_extension="schema"))
        end_sweep_timer=datetime.datetime.now()
        difference=end_sweep_timer-begin_sweep_timer
        print("Sweep {0} \nf : {1}\n ended at {2}\n taking {3} seonds ".format(frequency_index,
                                                                               frequency,
                                                                               end_sweep_timer,
                                                                               difference.seconds))
# Out:
# Calibration Began at 2018-10-12 16:20:17.333000
# Sweep 0
# f : 950000000.0
#  began at 2018-10-12 16:20:17.333000
# Writing to AWG Began at 2018-10-12 16:20:17.343000
# Measuring on VNA  Began at 2018-10-12 16:20:19.606000
# Measuring on Scope  Began at 2018-10-12 16:20:24.883000
# Writing to AWG Began at 2018-10-12 16:20:25.003000
# Measuring on VNA  Began at 2018-10-12 16:20:27.075000
# Measuring on Scope  Began at 2018-10-12 16:20:32.304000
# Writing to AWG Began at 2018-10-12 16:20:32.434000
# Measuring on VNA  Began at 2018-10-12 16:20:34.505000
# Measuring on Scope  Began at 2018-10-12 16:20:39.735000
# Writing to AWG Began at 2018-10-12 16:20:39.855000
# Measuring on VNA  Began at 2018-10-12 16:20:42
# Measuring on Scope  Began at 2018-10-12 16:20:47.195000
# Writing to AWG Began at 2018-10-12 16:20:47.315000
# Measuring on VNA  Began at 2018-10-12 16:20:49.363000
# Measuring on Scope  Began at 2018-10-12 16:20:54.524000
# Writing to AWG Began at 2018-10-12 16:20:54.644000
# Measuring on VNA  Began at 2018-10-12 16:20:56.748000
# Measuring on Scope  Began at 2018-10-12 16:21:02.051000
# Writing to AWG Began at 2018-10-12 16:21:02.161000
# Measuring on VNA  Began at 2018-10-12 16:21:04.249000
# Measuring on Scope  Began at 2018-10-12 16:21:09.545000
# Writing to AWG Began at 2018-10-12 16:21:09.675000
# Measuring on VNA  Began at 2018-10-12 16:21:11.771000
# Measuring on Scope  Began at 2018-10-12 16:21:17.041000
# Writing to AWG Began at 2018-10-12 16:21:17.151000
# Measuring on VNA  Began at 2018-10-12 16:21:19.225000
# Measuring on Scope  Began at 2018-10-12 16:21:24.602000
# Writing to AWG Began at 2018-10-12 16:21:24.724000
# Measuring on VNA  Began at 2018-10-12 16:21:26.812000
# Measuring on Scope  Began at 2018-10-12 16:21:32.062000
# Sweep 0
# f : 950000000.0
#  ended at 2018-10-12 16:21:32.182000
#  taking 74 seonds
# Sweep 1
# f : 960000000.0
#  began at 2018-10-12 16:21:32.182000
# Writing to AWG Began at 2018-10-12 16:21:32.202000
# Measuring on VNA  Began at 2018-10-12 16:21:34.316000
# Measuring on Scope  Began at 2018-10-12 16:21:39.559000
# Writing to AWG Began at 2018-10-12 16:21:39.679000
# Measuring on VNA  Began at 2018-10-12 16:21:41.765000
# Measuring on Scope  Began at 2018-10-12 16:21:47.043000
# Writing to AWG Began at 2018-10-12 16:21:47.163000
# Measuring on VNA  Began at 2018-10-12 16:21:49.250000
# Measuring on Scope  Began at 2018-10-12 16:21:54.469000
# Writing to AWG Began at 2018-10-12 16:21:54.589000
# Measuring on VNA  Began at 2018-10-12 16:21:56.668000
# Measuring on Scope  Began at 2018-10-12 16:22:01.986000
# Writing to AWG Began at 2018-10-12 16:22:02.116000
# Measuring on VNA  Began at 2018-10-12 16:22:04.200000
# Measuring on Scope  Began at 2018-10-12 16:22:09.510000
# Writing to AWG Began at 2018-10-12 16:22:09.630000
# Measuring on VNA  Began at 2018-10-12 16:22:11.833000
# Measuring on Scope  Began at 2018-10-12 16:22:17.110000
# Writing to AWG Began at 2018-10-12 16:22:17.230000
# Measuring on VNA  Began at 2018-10-12 16:22:19.318000
# Measuring on Scope  Began at 2018-10-12 16:22:24.544000
# Writing to AWG Began at 2018-10-12 16:22:24.664000
# Measuring on VNA  Began at 2018-10-12 16:22:26.764000
# Measuring on Scope  Began at 2018-10-12 16:22:32.074000
# Writing to AWG Began at 2018-10-12 16:22:32.184000
# Measuring on VNA  Began at 2018-10-12 16:22:34.311000
# Measuring on Scope  Began at 2018-10-12 16:22:39.593000
# Writing to AWG Began at 2018-10-12 16:22:39.713000
# Measuring on VNA  Began at 2018-10-12 16:22:41.732000
# Measuring on Scope  Began at 2018-10-12 16:22:46.975000
# Sweep 1
# f : 960000000.0
#  ended at 2018-10-12 16:22:47.095000
#  taking 74 seonds
# Sweep 2
# f : 970000000.0
#  began at 2018-10-12 16:22:47.105000
# Writing to AWG Began at 2018-10-12 16:22:47.115000
# Measuring on VNA  Began at 2018-10-12 16:22:49.206000
# Measuring on Scope  Began at 2018-10-12 16:22:54.479000
# Writing to AWG Began at 2018-10-12 16:22:54.599000
# Measuring on VNA  Began at 2018-10-12 16:22:56.691000
# Measuring on Scope  Began at 2018-10-12 16:23:01.913000
# Writing to AWG Began at 2018-10-12 16:23:02.033000
# Measuring on VNA  Began at 2018-10-12 16:23:04.160000
# Measuring on Scope  Began at 2018-10-12 16:23:09.420000
# Writing to AWG Began at 2018-10-12 16:23:09.540000
# Measuring on VNA  Began at 2018-10-12 16:23:11.606000
# Measuring on Scope  Began at 2018-10-12 16:23:17.144000
# Writing to AWG Began at 2018-10-12 16:23:17.254000
# Measuring on VNA  Began at 2018-10-12 16:23:19.314000
# Measuring on Scope  Began at 2018-10-12 16:23:24.626000
# Writing to AWG Began at 2018-10-12 16:23:24.757000
# Measuring on VNA  Began at 2018-10-12 16:23:26.831000
# Measuring on Scope  Began at 2018-10-12 16:23:32.126000
# Writing to AWG Began at 2018-10-12 16:23:32.246000
# Measuring on VNA  Began at 2018-10-12 16:23:34.316000
# Measuring on Scope  Began at 2018-10-12 16:23:39.566000
# Writing to AWG Began at 2018-10-12 16:23:39.686000
# Measuring on VNA  Began at 2018-10-12 16:23:41.761000
# Measuring on Scope  Began at 2018-10-12 16:23:47.041000
# Writing to AWG Began at 2018-10-12 16:23:47.161000
# Measuring on VNA  Began at 2018-10-12 16:23:49.167000
# Measuring on Scope  Began at 2018-10-12 16:23:54.509000
# Writing to AWG Began at 2018-10-12 16:23:54.629000
# Measuring on VNA  Began at 2018-10-12 16:23:56.698000
# Measuring on Scope  Began at 2018-10-12 16:24:01.995000
# Sweep 2
# f : 970000000.0
#  ended at 2018-10-12 16:24:02.125000
#  taking 75 seonds
# Sweep 3
# f : 980000000.0
#  began at 2018-10-12 16:24:02.125000
# Writing to AWG Began at 2018-10-12 16:24:02.145000
# Measuring on VNA  Began at 2018-10-12 16:24:04.224000
# Measuring on Scope  Began at 2018-10-12 16:24:09.481000
# Writing to AWG Began at 2018-10-12 16:24:09.601000
# Measuring on VNA  Began at 2018-10-12 16:24:11.667000
# Measuring on Scope  Began at 2018-10-12 16:24:16.951000
# Writing to AWG Began at 2018-10-12 16:24:17.071000
# Measuring on VNA  Began at 2018-10-12 16:24:19.166000
# Measuring on Scope  Began at 2018-10-12 16:24:24.448000
# Writing to AWG Began at 2018-10-12 16:24:24.568000
# Measuring on VNA  Began at 2018-10-12 16:24:26.642000
# Measuring on Scope  Began at 2018-10-12 16:24:32.099000
# Writing to AWG Began at 2018-10-12 16:24:32.219000
# Measuring on VNA  Began at 2018-10-12 16:24:34.325000
# Measuring on Scope  Began at 2018-10-12 16:24:39.545000
# Writing to AWG Began at 2018-10-12 16:24:39.665000
# Measuring on VNA  Began at 2018-10-12 16:24:41.782000
# Measuring on Scope  Began at 2018-10-12 16:24:47.079000
# Writing to AWG Began at 2018-10-12 16:24:47.199000
# Measuring on VNA  Began at 2018-10-12 16:24:49.310000
# Measuring on Scope  Began at 2018-10-12 16:24:54.693000
# Writing to AWG Began at 2018-10-12 16:24:54.833000
# Measuring on VNA  Began at 2018-10-12 16:24:56.886000
# Measuring on Scope  Began at 2018-10-12 16:25:02.200000
# Writing to AWG Began at 2018-10-12 16:25:02.320000
# Measuring on VNA  Began at 2018-10-12 16:25:04.417000
# Measuring on Scope  Began at 2018-10-12 16:25:09.693000
# Writing to AWG Began at 2018-10-12 16:25:09.813000
# Measuring on VNA  Began at 2018-10-12 16:25:11.907000
# Measuring on Scope  Began at 2018-10-12 16:25:17.114000
# Sweep 3
# f : 980000000.0
#  ended at 2018-10-12 16:25:17.244000
#  taking 75 seonds
# Sweep 4
# f : 990000000.0
#  began at 2018-10-12 16:25:17.244000
# Writing to AWG Began at 2018-10-12 16:25:17.264000
# Measuring on VNA  Began at 2018-10-12 16:25:19.360000
# Measuring on Scope  Began at 2018-10-12 16:25:24.664000
# Writing to AWG Began at 2018-10-12 16:25:24.786000
# Measuring on VNA  Began at 2018-10-12 16:25:26.875000
# Measuring on Scope  Began at 2018-10-12 16:25:32.167000
# Writing to AWG Began at 2018-10-12 16:25:32.287000
# Measuring on VNA  Began at 2018-10-12 16:25:34.354000
# Measuring on Scope  Began at 2018-10-12 16:25:39.621000
# Writing to AWG Began at 2018-10-12 16:25:39.741000
# Measuring on VNA  Began at 2018-10-12 16:25:41.862000
# Measuring on Scope  Began at 2018-10-12 16:25:47.114000
# Writing to AWG Began at 2018-10-12 16:25:47.234000
# Measuring on VNA  Began at 2018-10-12 16:25:49.345000
# Measuring on Scope  Began at 2018-10-12 16:25:54.579000
# Writing to AWG Began at 2018-10-12 16:25:54.699000
# Measuring on VNA  Began at 2018-10-12 16:25:56.842000
# Measuring on Scope  Began at 2018-10-12 16:26:02.080000
# Writing to AWG Began at 2018-10-12 16:26:02.190000
# Measuring on VNA  Began at 2018-10-12 16:26:04.292000
# Measuring on Scope  Began at 2018-10-12 16:26:09.835000
# Writing to AWG Began at 2018-10-12 16:26:09.955000
# Measuring on VNA  Began at 2018-10-12 16:26:12.073000
# Measuring on Scope  Began at 2018-10-12 16:26:17.383000
# Writing to AWG Began at 2018-10-12 16:26:17.503000
# Measuring on VNA  Began at 2018-10-12 16:26:19.605000
# Measuring on Scope  Began at 2018-10-12 16:26:24.950000
# Writing to AWG Began at 2018-10-12 16:26:25.070000
# Measuring on VNA  Began at 2018-10-12 16:26:27.149000
# Measuring on Scope  Began at 2018-10-12 16:26:32.419000
# Sweep 4
# f : 990000000.0
#  ended at 2018-10-12 16:26:32.549000
#  taking 75 seonds
# Sweep 5
# f : 1000000000.0
#  began at 2018-10-12 16:26:32.549000
# Writing to AWG Began at 2018-10-12 16:26:32.569000
# Measuring on VNA  Began at 2018-10-12 16:26:34.636000
# Measuring on Scope  Began at 2018-10-12 16:26:40.011000
# Writing to AWG Began at 2018-10-12 16:26:40.131000
# Measuring on VNA  Began at 2018-10-12 16:26:42.219000
# Measuring on Scope  Began at 2018-10-12 16:26:47.536000
# Writing to AWG Began at 2018-10-12 16:26:47.656000
# Measuring on VNA  Began at 2018-10-12 16:26:49.763000
# Measuring on Scope  Began at 2018-10-12 16:26:54.930000
# Writing to AWG Began at 2018-10-12 16:26:55.050000
# Measuring on VNA  Began at 2018-10-12 16:26:57.124000
# Measuring on Scope  Began at 2018-10-12 16:27:02.361000
# Writing to AWG Began at 2018-10-12 16:27:02.481000
# Measuring on VNA  Began at 2018-10-12 16:27:04.558000
# Measuring on Scope  Began at 2018-10-12 16:27:09.825000
# Writing to AWG Began at 2018-10-12 16:27:09.945000
# Measuring on VNA  Began at 2018-10-12 16:27:12.018000
# Measuring on Scope  Began at 2018-10-12 16:27:17.348000
# Writing to AWG Began at 2018-10-12 16:27:17.468000
# Measuring on VNA  Began at 2018-10-12 16:27:19.530000
# Measuring on Scope  Began at 2018-10-12 16:27:24.815000
# Writing to AWG Began at 2018-10-12 16:27:24.935000
# Measuring on VNA  Began at 2018-10-12 16:27:26.981000
# Measuring on Scope  Began at 2018-10-12 16:27:32.328000
# Writing to AWG Began at 2018-10-12 16:27:32.448000
# Measuring on VNA  Began at 2018-10-12 16:27:34.479000
# Measuring on Scope  Began at 2018-10-12 16:27:39.718000
# Writing to AWG Began at 2018-10-12 16:27:39.828000
# Measuring on VNA  Began at 2018-10-12 16:27:41.841000
# Measuring on Scope  Began at 2018-10-12 16:27:47.065000
# Sweep 5
# f : 1000000000.0
#  ended at 2018-10-12 16:27:47.185000
#  taking 74 seonds
# Sweep 6
# f : 1010000000.0
#  began at 2018-10-12 16:27:47.185000
# Writing to AWG Began at 2018-10-12 16:27:47.195000
# Measuring on VNA  Began at 2018-10-12 16:27:49.259000
# Measuring on Scope  Began at 2018-10-12 16:27:54.415000
# Writing to AWG Began at 2018-10-12 16:27:54.535000
# Measuring on VNA  Began at 2018-10-12 16:27:56.574000
# Measuring on Scope  Began at 2018-10-12 16:28:01.801000
# Writing to AWG Began at 2018-10-12 16:28:01.931000
# Measuring on VNA  Began at 2018-10-12 16:28:04.264000
# Measuring on Scope  Began at 2018-10-12 16:28:09.474000
# Writing to AWG Began at 2018-10-12 16:28:09.604000
# Measuring on VNA  Began at 2018-10-12 16:28:11.647000
# Measuring on Scope  Began at 2018-10-12 16:28:16.877000
# Writing to AWG Began at 2018-10-12 16:28:16.987000
# Measuring on VNA  Began at 2018-10-12 16:28:19.061000
# Measuring on Scope  Began at 2018-10-12 16:28:24.285000
# Writing to AWG Began at 2018-10-12 16:28:24.405000
# Measuring on VNA  Began at 2018-10-12 16:28:26.496000
# Measuring on Scope  Began at 2018-10-12 16:28:31.751000
# Writing to AWG Began at 2018-10-12 16:28:31.871000
# Measuring on VNA  Began at 2018-10-12 16:28:33.984000
# Measuring on Scope  Began at 2018-10-12 16:28:39.257000
# Writing to AWG Began at 2018-10-12 16:28:39.387000
# Measuring on VNA  Began at 2018-10-12 16:28:41.455000
# Measuring on Scope  Began at 2018-10-12 16:28:46.854000
# Writing to AWG Began at 2018-10-12 16:28:46.974000
# Measuring on VNA  Began at 2018-10-12 16:28:49.076000
# Measuring on Scope  Began at 2018-10-12 16:28:54.322000
# Writing to AWG Began at 2018-10-12 16:28:54.442000
# Measuring on VNA  Began at 2018-10-12 16:28:56.541000
# Measuring on Scope  Began at 2018-10-12 16:29:01.843000
# Sweep 6
# f : 1010000000.0
#  ended at 2018-10-12 16:29:01.973000
#  taking 74 seonds
# Sweep 7
# f : 1020000000.0
#  began at 2018-10-12 16:29:01.973000
# Writing to AWG Began at 2018-10-12 16:29:01.993000
# Measuring on VNA  Began at 2018-10-12 16:29:04.068000
# Measuring on Scope  Began at 2018-10-12 16:29:09.362000
# Writing to AWG Began at 2018-10-12 16:29:09.482000
# Measuring on VNA  Began at 2018-10-12 16:29:11.577000
# Measuring on Scope  Began at 2018-10-12 16:29:16.832000
# Writing to AWG Began at 2018-10-12 16:29:16.952000
# Measuring on VNA  Began at 2018-10-12 16:29:19.033000
# Measuring on Scope  Began at 2018-10-12 16:29:24.303000
# Writing to AWG Began at 2018-10-12 16:29:24.423000
# Measuring on VNA  Began at 2018-10-12 16:29:26.482000
# Measuring on Scope  Began at 2018-10-12 16:29:31.754000
# Writing to AWG Began at 2018-10-12 16:29:31.874000
# Measuring on VNA  Began at 2018-10-12 16:29:33.970000
# Measuring on Scope  Began at 2018-10-12 16:29:39.196000
# Writing to AWG Began at 2018-10-12 16:29:39.316000
# Measuring on VNA  Began at 2018-10-12 16:29:41.400000
# Measuring on Scope  Began at 2018-10-12 16:29:46.617000
# Writing to AWG Began at 2018-10-12 16:29:46.737000
# Measuring on VNA  Began at 2018-10-12 16:29:48.808000
# Measuring on Scope  Began at 2018-10-12 16:29:54.087000
# Writing to AWG Began at 2018-10-12 16:29:54.207000
# Measuring on VNA  Began at 2018-10-12 16:29:56.303000
# Measuring on Scope  Began at 2018-10-12 16:30:01.615000
# Writing to AWG Began at 2018-10-12 16:30:01.725000
# Measuring on VNA  Began at 2018-10-12 16:30:03.804000
# Measuring on Scope  Began at 2018-10-12 16:30:09.141000
# Writing to AWG Began at 2018-10-12 16:30:09.261000
# Measuring on VNA  Began at 2018-10-12 16:30:11.310000
# Measuring on Scope  Began at 2018-10-12 16:30:16.579000
# Sweep 7
# f : 1020000000.0
#  ended at 2018-10-12 16:30:16.709000
#  taking 74 seonds
# Sweep 8
# f : 1030000000.0
#  began at 2018-10-12 16:30:16.709000
# Writing to AWG Began at 2018-10-12 16:30:16.729000
# Measuring on VNA  Began at 2018-10-12 16:30:18.818000
# Measuring on Scope  Began at 2018-10-12 16:30:24.145000
# Writing to AWG Began at 2018-10-12 16:30:24.265000
# Measuring on VNA  Began at 2018-10-12 16:30:26.371000
# Measuring on Scope  Began at 2018-10-12 16:30:31.985000
# Writing to AWG Began at 2018-10-12 16:30:32.105000
# Measuring on VNA  Began at 2018-10-12 16:30:34.185000
# Measuring on Scope  Began at 2018-10-12 16:30:39.535000
# Writing to AWG Began at 2018-10-12 16:30:39.645000
# Measuring on VNA  Began at 2018-10-12 16:30:41.708000
# Measuring on Scope  Began at 2018-10-12 16:30:46.999000
# Writing to AWG Began at 2018-10-12 16:30:47.119000
# Measuring on VNA  Began at 2018-10-12 16:30:49.193000
# Measuring on Scope  Began at 2018-10-12 16:30:54.434000
# Writing to AWG Began at 2018-10-12 16:30:54.554000
# Measuring on VNA  Began at 2018-10-12 16:30:56.613000
# Measuring on Scope  Began at 2018-10-12 16:31:01.830000
# Writing to AWG Began at 2018-10-12 16:31:01.940000
# Measuring on VNA  Began at 2018-10-12 16:31:04.015000
# Measuring on Scope  Began at 2018-10-12 16:31:09.289000
# Writing to AWG Began at 2018-10-12 16:31:09.409000
# Measuring on VNA  Began at 2018-10-12 16:31:11.523000
# Measuring on Scope  Began at 2018-10-12 16:31:16.791000
# Writing to AWG Began at 2018-10-12 16:31:16.911000
# Measuring on VNA  Began at 2018-10-12 16:31:19.006000
# Measuring on Scope  Began at 2018-10-12 16:31:24.291000
# Writing to AWG Began at 2018-10-12 16:31:24.411000
# Measuring on VNA  Began at 2018-10-12 16:31:26.528000
# Measuring on Scope  Began at 2018-10-12 16:31:31.807000
# Sweep 8
# f : 1030000000.0
#  ended at 2018-10-12 16:31:31.947000
#  taking 75 seonds
# Sweep 9
# f : 1040000000.0
#  began at 2018-10-12 16:31:31.947000
# Writing to AWG Began at 2018-10-12 16:31:31.957000
# Measuring on VNA  Began at 2018-10-12 16:31:34.015000
# Measuring on Scope  Began at 2018-10-12 16:31:39.234000
# Writing to AWG Began at 2018-10-12 16:31:39.354000
# Measuring on VNA  Began at 2018-10-12 16:31:41.458000
# Measuring on Scope  Began at 2018-10-12 16:31:46.771000
# Writing to AWG Began at 2018-10-12 16:31:46.891000
# Measuring on VNA  Began at 2018-10-12 16:31:48.968000
# Measuring on Scope  Began at 2018-10-12 16:31:54.202000
# Writing to AWG Began at 2018-10-12 16:31:54.342000
# Measuring on VNA  Began at 2018-10-12 16:31:56.444000
# Measuring on Scope  Began at 2018-10-12 16:32:01.684000
# Writing to AWG Began at 2018-10-12 16:32:01.794000
# Measuring on VNA  Began at 2018-10-12 16:32:03.889000
# Measuring on Scope  Began at 2018-10-12 16:32:09.226000
# Writing to AWG Began at 2018-10-12 16:32:09.356000
# Measuring on VNA  Began at 2018-10-12 16:32:11.459000
# Measuring on Scope  Began at 2018-10-12 16:32:16.752000
# Writing to AWG Began at 2018-10-12 16:32:16.872000
# Measuring on VNA  Began at 2018-10-12 16:32:18.912000
# Measuring on Scope  Began at 2018-10-12 16:32:24.242000
# Writing to AWG Began at 2018-10-12 16:32:24.362000
# Measuring on VNA  Began at 2018-10-12 16:32:26.435000
# Measuring on Scope  Began at 2018-10-12 16:32:31.736000
# Writing to AWG Began at 2018-10-12 16:32:31.856000
# Measuring on VNA  Began at 2018-10-12 16:32:33.933000
# Measuring on Scope  Began at 2018-10-12 16:32:39.260000
# Writing to AWG Began at 2018-10-12 16:32:39.380000
# Measuring on VNA  Began at 2018-10-12 16:32:41.457000
# Measuring on Scope  Began at 2018-10-12 16:32:46.766000
# Sweep 9
# f : 1040000000.0
#  ended at 2018-10-12 16:32:46.906000
#  taking 74 seonds
# Sweep 10
# f : 1050000000.0
#  began at 2018-10-12 16:32:46.906000
# Writing to AWG Began at 2018-10-12 16:32:46.916000
# Measuring on VNA  Began at 2018-10-12 16:32:48.984000
# Measuring on Scope  Began at 2018-10-12 16:32:54.281000
# Writing to AWG Began at 2018-10-12 16:32:54.391000
# Measuring on VNA  Began at 2018-10-12 16:32:56.450000
# Measuring on Scope  Began at 2018-10-12 16:33:01.748000
# Writing to AWG Began at 2018-10-12 16:33:01.868000
# Measuring on VNA  Began at 2018-10-12 16:33:03.998000
# Measuring on Scope  Began at 2018-10-12 16:33:09.258000
# Writing to AWG Began at 2018-10-12 16:33:09.378000
# Measuring on VNA  Began at 2018-10-12 16:33:11.464000
# Measuring on Scope  Began at 2018-10-12 16:33:16.805000
# Writing to AWG Began at 2018-10-12 16:33:16.925000
# Measuring on VNA  Began at 2018-10-12 16:33:19.008000
# Measuring on Scope  Began at 2018-10-12 16:33:24.255000
# Writing to AWG Began at 2018-10-12 16:33:24.375000
# Measuring on VNA  Began at 2018-10-12 16:33:26.445000
# Measuring on Scope  Began at 2018-10-12 16:33:32.258000
# Writing to AWG Began at 2018-10-12 16:33:32.378000
# Measuring on VNA  Began at 2018-10-12 16:33:34.432000
# Measuring on Scope  Began at 2018-10-12 16:33:39.658000
# Writing to AWG Began at 2018-10-12 16:33:39.778000
# Measuring on VNA  Began at 2018-10-12 16:33:41.855000
# Measuring on Scope  Began at 2018-10-12 16:33:47.150000
# Writing to AWG Began at 2018-10-12 16:33:47.270000
# Measuring on VNA  Began at 2018-10-12 16:33:49.339000
# Measuring on Scope  Began at 2018-10-12 16:33:54.593000
# Writing to AWG Began at 2018-10-12 16:33:54.713000
# Measuring on VNA  Began at 2018-10-12 16:33:56.822000
# Measuring on Scope  Began at 2018-10-12 16:34:02.026000
# Sweep 10
# f : 1050000000.0
#  ended at 2018-10-12 16:34:02.166000
#  taking 75 seonds
# Calibration Began at 2018-10-12 16:34:04.210000
# Sweep 0
# f : 975000000.0
#  began at 2018-10-12 16:34:04.210000
# Writing to AWG Began at 2018-10-12 16:34:04.240000
# Measuring on VNA  Began at 2018-10-12 16:34:06.354000
# Measuring on Scope  Began at 2018-10-12 16:34:11.728000
# Writing to AWG Began at 2018-10-12 16:34:11.838000
# Measuring on VNA  Began at 2018-10-12 16:34:13.957000
# Measuring on Scope  Began at 2018-10-12 16:34:19.230000
# Writing to AWG Began at 2018-10-12 16:34:19.370000
# Measuring on VNA  Began at 2018-10-12 16:34:21.463000
# Measuring on Scope  Began at 2018-10-12 16:34:26.687000
# Writing to AWG Began at 2018-10-12 16:34:26.817000
# Measuring on VNA  Began at 2018-10-12 16:34:28.904000
# Measuring on Scope  Began at 2018-10-12 16:34:34.250000
# Writing to AWG Began at 2018-10-12 16:34:34.380000
# Measuring on VNA  Began at 2018-10-12 16:34:36.460000
# Measuring on Scope  Began at 2018-10-12 16:34:41.719000
# Writing to AWG Began at 2018-10-12 16:34:41.849000
# Measuring on VNA  Began at 2018-10-12 16:34:43.961000
# Measuring on Scope  Began at 2018-10-12 16:34:49.247000
# Writing to AWG Began at 2018-10-12 16:34:49.377000
# Measuring on VNA  Began at 2018-10-12 16:34:51.474000
# Measuring on Scope  Began at 2018-10-12 16:34:56.765000
# Writing to AWG Began at 2018-10-12 16:34:56.895000
# Measuring on VNA  Began at 2018-10-12 16:34:59.008000
# Measuring on Scope  Began at 2018-10-12 16:35:04.348000
# Writing to AWG Began at 2018-10-12 16:35:04.488000
# Measuring on VNA  Began at 2018-10-12 16:35:06.581000
# Measuring on Scope  Began at 2018-10-12 16:35:11.869000
# Writing to AWG Began at 2018-10-12 16:35:11.999000
# Measuring on VNA  Began at 2018-10-12 16:35:14.118000
# Measuring on Scope  Began at 2018-10-12 16:35:19.462000
# Sweep 0
# f : 975000000.0
#  ended at 2018-10-12 16:35:19.582000
#  taking 75 seonds
# Sweep 1
# f : 980000000.0
#  began at 2018-10-12 16:35:19.582000
# Writing to AWG Began at 2018-10-12 16:35:19.592000
# Measuring on VNA  Began at 2018-10-12 16:35:21.648000
# Measuring on Scope  Began at 2018-10-12 16:35:26.929000
# Writing to AWG Began at 2018-10-12 16:35:27.059000
# Measuring on VNA  Began at 2018-10-12 16:35:29.165000
# Measuring on Scope  Began at 2018-10-12 16:35:34.444000
# Writing to AWG Began at 2018-10-12 16:35:34.574000
# Measuring on VNA  Began at 2018-10-12 16:35:36.692000
# Measuring on Scope  Began at 2018-10-12 16:35:42.009000
# Writing to AWG Began at 2018-10-12 16:35:42.139000
# Measuring on VNA  Began at 2018-10-12 16:35:44.223000
# Measuring on Scope  Began at 2018-10-12 16:35:49.530000
# Writing to AWG Began at 2018-10-12 16:35:49.660000
# Measuring on VNA  Began at 2018-10-12 16:35:51.799000
# Measuring on Scope  Began at 2018-10-12 16:35:57.068000
# Writing to AWG Began at 2018-10-12 16:35:57.188000
# Measuring on VNA  Began at 2018-10-12 16:35:59.271000
# Measuring on Scope  Began at 2018-10-12 16:36:04.561000
# Writing to AWG Began at 2018-10-12 16:36:04.691000
# Measuring on VNA  Began at 2018-10-12 16:36:06.823000
# Measuring on Scope  Began at 2018-10-12 16:36:12.089000
# Writing to AWG Began at 2018-10-12 16:36:12.219000
# Measuring on VNA  Began at 2018-10-12 16:36:14.365000
# Measuring on Scope  Began at 2018-10-12 16:36:19.581000
# Writing to AWG Began at 2018-10-12 16:36:19.701000
# Measuring on VNA  Began at 2018-10-12 16:36:21.818000
# Measuring on Scope  Began at 2018-10-12 16:36:27.121000
# Writing to AWG Began at 2018-10-12 16:36:27.251000
# Measuring on VNA  Began at 2018-10-12 16:36:29.349000
# Measuring on Scope  Began at 2018-10-12 16:36:34.691000
# Sweep 1
# f : 980000000.0
#  ended at 2018-10-12 16:36:34.811000
#  taking 75 seonds
# Sweep 2
# f : 985000000.0
#  began at 2018-10-12 16:36:34.811000
# Writing to AWG Began at 2018-10-12 16:36:34.821000
# Measuring on VNA  Began at 2018-10-12 16:36:36.919000
# Measuring on Scope  Began at 2018-10-12 16:36:42.222000
# Writing to AWG Began at 2018-10-12 16:36:42.352000
# Measuring on VNA  Began at 2018-10-12 16:36:44.429000
# Measuring on Scope  Began at 2018-10-12 16:36:49.663000
# Writing to AWG Began at 2018-10-12 16:36:49.783000
# Measuring on VNA  Began at 2018-10-12 16:36:51.835000
# Measuring on Scope  Began at 2018-10-12 16:36:57.214000
# Writing to AWG Began at 2018-10-12 16:36:57.344000
# Measuring on VNA  Began at 2018-10-12 16:36:59.415000
# Measuring on Scope  Began at 2018-10-12 16:37:04.742000
# Writing to AWG Began at 2018-10-12 16:37:04.882000
# Measuring on VNA  Began at 2018-10-12 16:37:06.979000
# Measuring on Scope  Began at 2018-10-12 16:37:12.863000
# Writing to AWG Began at 2018-10-12 16:37:12.993000
# Measuring on VNA  Began at 2018-10-12 16:37:15.069000
# Measuring on Scope  Began at 2018-10-12 16:37:20.376000
# Writing to AWG Began at 2018-10-12 16:37:20.516000
# Measuring on VNA  Began at 2018-10-12 16:37:22.582000
# Measuring on Scope  Began at 2018-10-12 16:37:27.866000
# Writing to AWG Began at 2018-10-12 16:37:28.016000
# Measuring on VNA  Began at 2018-10-12 16:37:30.094000
# Measuring on Scope  Began at 2018-10-12 16:37:35.444000
# Writing to AWG Began at 2018-10-12 16:37:35.574000
# Measuring on VNA  Began at 2018-10-12 16:37:37.711000
# Measuring on Scope  Began at 2018-10-12 16:37:42.977000
# Writing to AWG Began at 2018-10-12 16:37:43.107000
# Measuring on VNA  Began at 2018-10-12 16:37:45.179000
# Measuring on Scope  Began at 2018-10-12 16:37:50.444000
# Sweep 2
# f : 985000000.0
#  ended at 2018-10-12 16:37:50.564000
#  taking 75 seonds
# Sweep 3
# f : 990000000.0
#  began at 2018-10-12 16:37:50.564000
# Writing to AWG Began at 2018-10-12 16:37:50.584000
# Measuring on VNA  Began at 2018-10-12 16:37:52.661000
# Measuring on Scope  Began at 2018-10-12 16:37:57.898000
# Writing to AWG Began at 2018-10-12 16:37:58.018000
# Measuring on VNA  Began at 2018-10-12 16:38:00.132000
# Measuring on Scope  Began at 2018-10-12 16:38:05.434000
# Writing to AWG Began at 2018-10-12 16:38:05.574000
# Measuring on VNA  Began at 2018-10-12 16:38:07.733000
# Measuring on Scope  Began at 2018-10-12 16:38:12.976000
# Writing to AWG Began at 2018-10-12 16:38:13.106000
# Measuring on VNA  Began at 2018-10-12 16:38:15.155000
# Measuring on Scope  Began at 2018-10-12 16:38:20.460000
# Writing to AWG Began at 2018-10-12 16:38:20.580000
# Measuring on VNA  Began at 2018-10-12 16:38:22.679000
# Measuring on Scope  Began at 2018-10-12 16:38:27.986000
# Writing to AWG Began at 2018-10-12 16:38:28.116000
# Measuring on VNA  Began at 2018-10-12 16:38:30.212000
# Measuring on Scope  Began at 2018-10-12 16:38:35.496000
# Writing to AWG Began at 2018-10-12 16:38:35.626000
# Measuring on VNA  Began at 2018-10-12 16:38:37.753000
# Measuring on Scope  Began at 2018-10-12 16:38:43.014000
# Writing to AWG Began at 2018-10-12 16:38:43.134000
# Measuring on VNA  Began at 2018-10-12 16:38:45.270000
# Measuring on Scope  Began at 2018-10-12 16:38:50.531000
# Writing to AWG Began at 2018-10-12 16:38:50.661000
# Measuring on VNA  Began at 2018-10-12 16:38:52.767000
# Measuring on Scope  Began at 2018-10-12 16:38:58.069000
# Writing to AWG Began at 2018-10-12 16:38:58.189000
# Measuring on VNA  Began at 2018-10-12 16:39:00.286000
# Measuring on Scope  Began at 2018-10-12 16:39:05.607000
# Sweep 3
# f : 990000000.0
#  ended at 2018-10-12 16:39:05.737000
#  taking 75 seonds
# Sweep 4
# f : 995000000.0
#  began at 2018-10-12 16:39:05.737000
# Writing to AWG Began at 2018-10-12 16:39:05.747000
# Measuring on VNA  Began at 2018-10-12 16:39:07.805000
# Measuring on Scope  Began at 2018-10-12 16:39:13.124000
# Writing to AWG Began at 2018-10-12 16:39:13.264000
# Measuring on VNA  Began at 2018-10-12 16:39:15.320000
# Measuring on Scope  Began at 2018-10-12 16:39:20.619000
# Writing to AWG Began at 2018-10-12 16:39:20.759000
# Measuring on VNA  Began at 2018-10-12 16:39:22.844000
# Measuring on Scope  Began at 2018-10-12 16:39:28.135000
# Writing to AWG Began at 2018-10-12 16:39:28.284000
# Measuring on VNA  Began at 2018-10-12 16:39:30.404000
# Measuring on Scope  Began at 2018-10-12 16:39:35.694000
# Writing to AWG Began at 2018-10-12 16:39:35.824000
# Measuring on VNA  Began at 2018-10-12 16:39:37.906000
# Measuring on Scope  Began at 2018-10-12 16:39:43.196000
# Writing to AWG Began at 2018-10-12 16:39:43.336000
# Measuring on VNA  Began at 2018-10-12 16:39:45.455000
# Measuring on Scope  Began at 2018-10-12 16:39:50.719000
# Writing to AWG Began at 2018-10-12 16:39:50.849000
# Measuring on VNA  Began at 2018-10-12 16:39:52.942000
# Measuring on Scope  Began at 2018-10-12 16:39:58.140000
# Writing to AWG Began at 2018-10-12 16:39:58.270000
# Measuring on VNA  Began at 2018-10-12 16:40:00.360000
# Measuring on Scope  Began at 2018-10-12 16:40:05.602000
# Writing to AWG Began at 2018-10-12 16:40:05.732000
# Measuring on VNA  Began at 2018-10-12 16:40:07.865000
# Measuring on Scope  Began at 2018-10-12 16:40:13.089000
# Writing to AWG Began at 2018-10-12 16:40:13.219000
# Measuring on VNA  Began at 2018-10-12 16:40:15.269000
# Measuring on Scope  Began at 2018-10-12 16:40:20.563000
# Sweep 4
# f : 995000000.0
#  ended at 2018-10-12 16:40:20.698000
#  taking 74 seonds
# Sweep 5
# f : 1000000000.0
#  began at 2018-10-12 16:40:20.699000
# Writing to AWG Began at 2018-10-12 16:40:20.710000
# Measuring on VNA  Began at 2018-10-12 16:40:22.814000
# Measuring on Scope  Began at 2018-10-12 16:40:28.114000
# Writing to AWG Began at 2018-10-12 16:40:28.244000
# Measuring on VNA  Began at 2018-10-12 16:40:30.363000
# Measuring on Scope  Began at 2018-10-12 16:40:35.584000
# Writing to AWG Began at 2018-10-12 16:40:35.714000
# Measuring on VNA  Began at 2018-10-12 16:40:37.800000
# Measuring on Scope  Began at 2018-10-12 16:40:43.088000
# Writing to AWG Began at 2018-10-12 16:40:43.218000
# Measuring on VNA  Began at 2018-10-12 16:40:45.331000
# Measuring on Scope  Began at 2018-10-12 16:40:50.641000
# Writing to AWG Began at 2018-10-12 16:40:50.761000
# Measuring on VNA  Began at 2018-10-12 16:40:52.860000
# Measuring on Scope  Began at 2018-10-12 16:40:58.164000
# Writing to AWG Began at 2018-10-12 16:40:58.284000
# Measuring on VNA  Began at 2018-10-12 16:41:00.408000
# Measuring on Scope  Began at 2018-10-12 16:41:05.636000
# Writing to AWG Began at 2018-10-12 16:41:05.756000
# Measuring on VNA  Began at 2018-10-12 16:41:07.811000
# Measuring on Scope  Began at 2018-10-12 16:41:13.105000
# Writing to AWG Began at 2018-10-12 16:41:13.245000
# Measuring on VNA  Began at 2018-10-12 16:41:15.315000
# Measuring on Scope  Began at 2018-10-12 16:41:20.575000
# Writing to AWG Began at 2018-10-12 16:41:20.695000
# Measuring on VNA  Began at 2018-10-12 16:41:22.787000
# Measuring on Scope  Began at 2018-10-12 16:41:28.076000
# Writing to AWG Began at 2018-10-12 16:41:28.196000
# Measuring on VNA  Began at 2018-10-12 16:41:30.326000
# Measuring on Scope  Began at 2018-10-12 16:41:35.658000
# Sweep 5
# f : 1000000000.0
#  ended at 2018-10-12 16:41:35.778000
#  taking 75 seonds
# Sweep 6
# f : 1005000000.0
#  began at 2018-10-12 16:41:35.778000
# Writing to AWG Began at 2018-10-12 16:41:35.788000
# Measuring on VNA  Began at 2018-10-12 16:41:37.893000
# Measuring on Scope  Began at 2018-10-12 16:41:43.919000
# Writing to AWG Began at 2018-10-12 16:41:44.049000
# Measuring on VNA  Began at 2018-10-12 16:41:46.137000
# Measuring on Scope  Began at 2018-10-12 16:41:51.429000
# Writing to AWG Began at 2018-10-12 16:41:51.570000
# Measuring on VNA  Began at 2018-10-12 16:41:53.636000
# Measuring on Scope  Began at 2018-10-12 16:41:58.872000
# Writing to AWG Began at 2018-10-12 16:41:59.012000
# Measuring on VNA  Began at 2018-10-12 16:42:01.076000
# Measuring on Scope  Began at 2018-10-12 16:42:06.333000
# Writing to AWG Began at 2018-10-12 16:42:06.473000
# Measuring on VNA  Began at 2018-10-12 16:42:08.564000
# Measuring on Scope  Began at 2018-10-12 16:42:13.802000
# Writing to AWG Began at 2018-10-12 16:42:13.932000
# Measuring on VNA  Began at 2018-10-12 16:42:16.041000
# Measuring on Scope  Began at 2018-10-12 16:42:21.354000
# Writing to AWG Began at 2018-10-12 16:42:21.494000
# Measuring on VNA  Began at 2018-10-12 16:42:23.591000
# Measuring on Scope  Began at 2018-10-12 16:42:28.883000
# Writing to AWG Began at 2018-10-12 16:42:29.023000
# Measuring on VNA  Began at 2018-10-12 16:42:31.075000
# Measuring on Scope  Began at 2018-10-12 16:42:36.296000
# Writing to AWG Began at 2018-10-12 16:42:36.426000
# Measuring on VNA  Began at 2018-10-12 16:42:38.497000
# Measuring on Scope  Began at 2018-10-12 16:42:43.711000
# Writing to AWG Began at 2018-10-12 16:42:43.841000
# Measuring on VNA  Began at 2018-10-12 16:42:45.958000
# Measuring on Scope  Began at 2018-10-12 16:42:51.206000
# Sweep 6
# f : 1005000000.0
#  ended at 2018-10-12 16:42:51.326000
#  taking 75 seonds
# Sweep 7
# f : 1010000000.0
#  began at 2018-10-12 16:42:51.326000
# Writing to AWG Began at 2018-10-12 16:42:51.346000
# Measuring on VNA  Began at 2018-10-12 16:42:53.402000
# Measuring on Scope  Began at 2018-10-12 16:42:58.723000
# Writing to AWG Began at 2018-10-12 16:42:58.853000
# Measuring on VNA  Began at 2018-10-12 16:43:00.948000
# Measuring on Scope  Began at 2018-10-12 16:43:06.303000
# Writing to AWG Began at 2018-10-12 16:43:06.413000
# Measuring on VNA  Began at 2018-10-12 16:43:08.502000
# Measuring on Scope  Began at 2018-10-12 16:43:13.743000
# Writing to AWG Began at 2018-10-12 16:43:13.863000
# Measuring on VNA  Began at 2018-10-12 16:43:15.983000
# Measuring on Scope  Began at 2018-10-12 16:43:21.296000
# Writing to AWG Began at 2018-10-12 16:43:21.426000
# Measuring on VNA  Began at 2018-10-12 16:43:23.493000
# Measuring on Scope  Began at 2018-10-12 16:43:28.783000
# Writing to AWG Began at 2018-10-12 16:43:28.913000
# Measuring on VNA  Began at 2018-10-12 16:43:31.061000
# Measuring on Scope  Began at 2018-10-12 16:43:36.341000
# Writing to AWG Began at 2018-10-12 16:43:36.471000
# Measuring on VNA  Began at 2018-10-12 16:43:38.588000
# Measuring on Scope  Began at 2018-10-12 16:43:43.830000
# Writing to AWG Began at 2018-10-12 16:43:43.960000
# Measuring on VNA  Began at 2018-10-12 16:43:46.061000
# Measuring on Scope  Began at 2018-10-12 16:43:51.314000
# Writing to AWG Began at 2018-10-12 16:43:51.424000
# Measuring on VNA  Began at 2018-10-12 16:43:53.474000
# Measuring on Scope  Began at 2018-10-12 16:43:58.774000
# Writing to AWG Began at 2018-10-12 16:43:58.894000
# Measuring on VNA  Began at 2018-10-12 16:44:01.012000
# Measuring on Scope  Began at 2018-10-12 16:44:06.324000
# Sweep 7
# f : 1010000000.0
#  ended at 2018-10-12 16:44:06.464000
#  taking 75 seonds
# Sweep 8
# f : 1015000000.0
#  began at 2018-10-12 16:44:06.464000
# Writing to AWG Began at 2018-10-12 16:44:06.484000
# Measuring on VNA  Began at 2018-10-12 16:44:08.561000
# Measuring on Scope  Began at 2018-10-12 16:44:13.884000
# Writing to AWG Began at 2018-10-12 16:44:14.014000
# Measuring on VNA  Began at 2018-10-12 16:44:16.106000
# Measuring on Scope  Began at 2018-10-12 16:44:21.384000
# Writing to AWG Began at 2018-10-12 16:44:21.514000
# Measuring on VNA  Began at 2018-10-12 16:44:23.621000
# Measuring on Scope  Began at 2018-10-12 16:44:28.936000
# Writing to AWG Began at 2018-10-12 16:44:29.066000
# Measuring on VNA  Began at 2018-10-12 16:44:31.174000
# Measuring on Scope  Began at 2018-10-12 16:44:36.449000
# Writing to AWG Began at 2018-10-12 16:44:36.579000
# Measuring on VNA  Began at 2018-10-12 16:44:38.650000
# Measuring on Scope  Began at 2018-10-12 16:44:43.977000
# Writing to AWG Began at 2018-10-12 16:44:44.087000
# Measuring on VNA  Began at 2018-10-12 16:44:46.133000
# Measuring on Scope  Began at 2018-10-12 16:44:51.329000
# Writing to AWG Began at 2018-10-12 16:44:51.459000
# Measuring on VNA  Began at 2018-10-12 16:44:53.574000
# Measuring on Scope  Began at 2018-10-12 16:44:58.903000
# Writing to AWG Began at 2018-10-12 16:44:59.043000
# Measuring on VNA  Began at 2018-10-12 16:45:01.153000
# Measuring on Scope  Began at 2018-10-12 16:45:06.426000
# Writing to AWG Began at 2018-10-12 16:45:06.566000
# Measuring on VNA  Began at 2018-10-12 16:45:08.653000
# Measuring on Scope  Began at 2018-10-12 16:45:13.947000
# Writing to AWG Began at 2018-10-12 16:45:14.077000
# Measuring on VNA  Began at 2018-10-12 16:45:16.180000
# Measuring on Scope  Began at 2018-10-12 16:45:21.495000
# Sweep 8
# f : 1015000000.0
#  ended at 2018-10-12 16:45:21.635000
#  taking 75 seonds
# Sweep 9
# f : 1020000000.0
#  began at 2018-10-12 16:45:21.635000
# Writing to AWG Began at 2018-10-12 16:45:21.655000
# Measuring on VNA  Began at 2018-10-12 16:45:23.730000
# Measuring on Scope  Began at 2018-10-12 16:45:28.981000
# Writing to AWG Began at 2018-10-12 16:45:29.101000
# Measuring on VNA  Began at 2018-10-12 16:45:31.166000
# Measuring on Scope  Began at 2018-10-12 16:45:36.412000
# Writing to AWG Began at 2018-10-12 16:45:36.542000
# Measuring on VNA  Began at 2018-10-12 16:45:38.622000
# Measuring on Scope  Began at 2018-10-12 16:45:43.915000
# Writing to AWG Began at 2018-10-12 16:45:44.045000
# Measuring on VNA  Began at 2018-10-12 16:45:46.128000
# Measuring on Scope  Began at 2018-10-12 16:45:51.375000
# Writing to AWG Began at 2018-10-12 16:45:51.495000
# Measuring on VNA  Began at 2018-10-12 16:45:53.588000
# Measuring on Scope  Began at 2018-10-12 16:45:58.902000
# Writing to AWG Began at 2018-10-12 16:45:59.032000
# Measuring on VNA  Began at 2018-10-12 16:46:01.085000
# Measuring on Scope  Began at 2018-10-12 16:46:06.356000
# Writing to AWG Began at 2018-10-12 16:46:06.486000
# Measuring on VNA  Began at 2018-10-12 16:46:08.559000
# Measuring on Scope  Began at 2018-10-12 16:46:13.889000
# Writing to AWG Began at 2018-10-12 16:46:14.019000
# Measuring on VNA  Began at 2018-10-12 16:46:16.085000
# Measuring on Scope  Began at 2018-10-12 16:46:21.444000
# Writing to AWG Began at 2018-10-12 16:46:21.574000
# Measuring on VNA  Began at 2018-10-12 16:46:23.632000
# Measuring on Scope  Began at 2018-10-12 16:46:28.863000
# Writing to AWG Began at 2018-10-12 16:46:28.983000
# Measuring on VNA  Began at 2018-10-12 16:46:31.040000
# Measuring on Scope  Began at 2018-10-12 16:46:36.388000
# Sweep 9
# f : 1020000000.0
#  ended at 2018-10-12 16:46:36.528000
#  taking 74 seonds
# Sweep 10
# f : 1025000000.0
#  began at 2018-10-12 16:46:36.528000
# Writing to AWG Began at 2018-10-12 16:46:36.548000
# Measuring on VNA  Began at 2018-10-12 16:46:38.633000
# Measuring on Scope  Began at 2018-10-12 16:46:43.907000
# Writing to AWG Began at 2018-10-12 16:46:44.047000
# Measuring on VNA  Began at 2018-10-12 16:46:46.140000
# Measuring on Scope  Began at 2018-10-12 16:46:51.374000
# Writing to AWG Began at 2018-10-12 16:46:51.514000
# Measuring on VNA  Began at 2018-10-12 16:46:53.587000
# Measuring on Scope  Began at 2018-10-12 16:46:58.899000
# Writing to AWG Began at 2018-10-12 16:46:59.039000
# Measuring on VNA  Began at 2018-10-12 16:47:01.109000
# Measuring on Scope  Began at 2018-10-12 16:47:06.391000
# Writing to AWG Began at 2018-10-12 16:47:06.501000
# Measuring on VNA  Began at 2018-10-12 16:47:08.557000
# Measuring on Scope  Began at 2018-10-12 16:47:14.743000
# Writing to AWG Began at 2018-10-12 16:47:14.883000
# Measuring on VNA  Began at 2018-10-12 16:47:16.975000
# Measuring on Scope  Began at 2018-10-12 16:47:22.260000
# Writing to AWG Began at 2018-10-12 16:47:22.400000
# Measuring on VNA  Began at 2018-10-12 16:47:24.500000
# Measuring on Scope  Began at 2018-10-12 16:47:29.782000
# Writing to AWG Began at 2018-10-12 16:47:29.922000
# Measuring on VNA  Began at 2018-10-12 16:47:32.039000
# Measuring on Scope  Began at 2018-10-12 16:47:37.239000
# Writing to AWG Began at 2018-10-12 16:47:37.379000
# Measuring on VNA  Began at 2018-10-12 16:47:39.461000
# Measuring on Scope  Began at 2018-10-12 16:47:44.748000
# Writing to AWG Began at 2018-10-12 16:47:44.898000
# Measuring on VNA  Began at 2018-10-12 16:47:46.985000
# Measuring on Scope  Began at 2018-10-12 16:47:52.291000
# Sweep 10
# f : 1025000000.0
#  ended at 2018-10-12 16:47:52.431000
#  taking 75 seonds
# Calibration Began at 2018-10-12 16:47:54.529000
# Sweep 0
# f : 987500000.0
#  began at 2018-10-12 16:47:54.529000
# Writing to AWG Began at 2018-10-12 16:47:54.569000
# Measuring on VNA  Began at 2018-10-12 16:47:56.706000
# Measuring on Scope  Began at 2018-10-12 16:48:02.063000
# Writing to AWG Began at 2018-10-12 16:48:02.203000
# Measuring on VNA  Began at 2018-10-12 16:48:04.403000
# Measuring on Scope  Began at 2018-10-12 16:48:09.704000
# Writing to AWG Began at 2018-10-12 16:48:09.844000
# Measuring on VNA  Began at 2018-10-12 16:48:11.966000
# Measuring on Scope  Began at 2018-10-12 16:48:17.254000
# Writing to AWG Began at 2018-10-12 16:48:17.404000
# Measuring on VNA  Began at 2018-10-12 16:48:19.517000
# Measuring on Scope  Began at 2018-10-12 16:48:24.750000
# Writing to AWG Began at 2018-10-12 16:48:24.870000
# Measuring on VNA  Began at 2018-10-12 16:48:26.981000
# Measuring on Scope  Began at 2018-10-12 16:48:32.241000
# Writing to AWG Began at 2018-10-12 16:48:32.401000
# Measuring on VNA  Began at 2018-10-12 16:48:34.541000
# Measuring on Scope  Began at 2018-10-12 16:48:39.912000
# Writing to AWG Began at 2018-10-12 16:48:40.062000
# Measuring on VNA  Began at 2018-10-12 16:48:42.188000
# Measuring on Scope  Began at 2018-10-12 16:48:47.467000
# Writing to AWG Began at 2018-10-12 16:48:47.617000
# Measuring on VNA  Began at 2018-10-12 16:48:49.685000
# Measuring on Scope  Began at 2018-10-12 16:48:54.972000
# Writing to AWG Began at 2018-10-12 16:48:55.122000
# Measuring on VNA  Began at 2018-10-12 16:48:57.291000
# Measuring on Scope  Began at 2018-10-12 16:49:02.552000
# Writing to AWG Began at 2018-10-12 16:49:02.712000
# Measuring on VNA  Began at 2018-10-12 16:49:04.795000
# Measuring on Scope  Began at 2018-10-12 16:49:09.998000
# Sweep 0
# f : 987500000.0
#  ended at 2018-10-12 16:49:10.108000
#  taking 75 seonds
# Sweep 1
# f : 990000000.0
#  began at 2018-10-12 16:49:10.108000
# Writing to AWG Began at 2018-10-12 16:49:10.128000
# Measuring on VNA  Began at 2018-10-12 16:49:12.262000
# Measuring on Scope  Began at 2018-10-12 16:49:17.521000
# Writing to AWG Began at 2018-10-12 16:49:17.661000
# Measuring on VNA  Began at 2018-10-12 16:49:19.805000
# Measuring on Scope  Began at 2018-10-12 16:49:24.986000
# Writing to AWG Began at 2018-10-12 16:49:25.126000
# Measuring on VNA  Began at 2018-10-12 16:49:27.263000
# Measuring on Scope  Began at 2018-10-12 16:49:32.563000
# Writing to AWG Began at 2018-10-12 16:49:32.693000
# Measuring on VNA  Began at 2018-10-12 16:49:34.790000
# Measuring on Scope  Began at 2018-10-12 16:49:40.084000
# Writing to AWG Began at 2018-10-12 16:49:40.224000
# Measuring on VNA  Began at 2018-10-12 16:49:42.293000
# Measuring on Scope  Began at 2018-10-12 16:49:47.578000
# Writing to AWG Began at 2018-10-12 16:49:47.728000
# Measuring on VNA  Began at 2018-10-12 16:49:49.854000
# Measuring on Scope  Began at 2018-10-12 16:49:55.085000
# Writing to AWG Began at 2018-10-12 16:49:55.225000
# Measuring on VNA  Began at 2018-10-12 16:49:57.335000
# Measuring on Scope  Began at 2018-10-12 16:50:02.622000
# Writing to AWG Began at 2018-10-12 16:50:02.762000
# Measuring on VNA  Began at 2018-10-12 16:50:04.870000
# Measuring on Scope  Began at 2018-10-12 16:50:10.128000
# Writing to AWG Began at 2018-10-12 16:50:10.258000
# Measuring on VNA  Began at 2018-10-12 16:50:12.384000
# Measuring on Scope  Began at 2018-10-12 16:50:17.672000
# Writing to AWG Began at 2018-10-12 16:50:17.812000
# Measuring on VNA  Began at 2018-10-12 16:50:20.593000
# Measuring on Scope  Began at 2018-10-12 16:50:25.873000
# Sweep 1
# f : 990000000.0
#  ended at 2018-10-12 16:50:25.993000
#  taking 75 seonds
# Sweep 2
# f : 992500000.0
#  began at 2018-10-12 16:50:25.993000
# Writing to AWG Began at 2018-10-12 16:50:26.013000
# Measuring on VNA  Began at 2018-10-12 16:50:28.098000
# Measuring on Scope  Began at 2018-10-12 16:50:33.391000
# Writing to AWG Began at 2018-10-12 16:50:33.521000
# Measuring on VNA  Began at 2018-10-12 16:50:35.601000
# Measuring on Scope  Began at 2018-10-12 16:50:40.907000
# Writing to AWG Began at 2018-10-12 16:50:41.057000
# Measuring on VNA  Began at 2018-10-12 16:50:43.153000
# Measuring on Scope  Began at 2018-10-12 16:50:48.439000
# Writing to AWG Began at 2018-10-12 16:50:48.599000
# Measuring on VNA  Began at 2018-10-12 16:50:50.741000
# Measuring on Scope  Began at 2018-10-12 16:50:55.989000
# Writing to AWG Began at 2018-10-12 16:50:56.139000
# Measuring on VNA  Began at 2018-10-12 16:50:58.291000
# Measuring on Scope  Began at 2018-10-12 16:51:03.528000
# Writing to AWG Began at 2018-10-12 16:51:03.678000
# Measuring on VNA  Began at 2018-10-12 16:51:05.804000
# Measuring on Scope  Began at 2018-10-12 16:51:11.138000
# Writing to AWG Began at 2018-10-12 16:51:11.288000
# Measuring on VNA  Began at 2018-10-12 16:51:13.432000
# Measuring on Scope  Began at 2018-10-12 16:51:18.745000
# Writing to AWG Began at 2018-10-12 16:51:18.885000
# Measuring on VNA  Began at 2018-10-12 16:51:20.992000
# Measuring on Scope  Began at 2018-10-12 16:51:26.305000
# Writing to AWG Began at 2018-10-12 16:51:26.425000
# Measuring on VNA  Began at 2018-10-12 16:51:28.539000
# Measuring on Scope  Began at 2018-10-12 16:51:33.792000
# Writing to AWG Began at 2018-10-12 16:51:33.922000
# Measuring on VNA  Began at 2018-10-12 16:51:36.041000
# Measuring on Scope  Began at 2018-10-12 16:51:41.294000
# Sweep 2
# f : 992500000.0
#  ended at 2018-10-12 16:51:41.424000
#  taking 75 seonds
# Sweep 3
# f : 995000000.0
#  began at 2018-10-12 16:51:41.424000
# Writing to AWG Began at 2018-10-12 16:51:41.464000
# Measuring on VNA  Began at 2018-10-12 16:51:43.581000
# Measuring on Scope  Began at 2018-10-12 16:51:48.834000
# Writing to AWG Began at 2018-10-12 16:51:48.984000
# Measuring on VNA  Began at 2018-10-12 16:51:51.125000
# Measuring on Scope  Began at 2018-10-12 16:51:56.408000
# Writing to AWG Began at 2018-10-12 16:51:56.558000
# Measuring on VNA  Began at 2018-10-12 16:51:58.677000
# Measuring on Scope  Began at 2018-10-12 16:52:03.984000
# Writing to AWG Began at 2018-10-12 16:52:04.124000
# Measuring on VNA  Began at 2018-10-12 16:52:06.258000
# Measuring on Scope  Began at 2018-10-12 16:52:11.578000
# Writing to AWG Began at 2018-10-12 16:52:11.718000
# Measuring on VNA  Began at 2018-10-12 16:52:13.866000
# Measuring on Scope  Began at 2018-10-12 16:52:19.097000
# Writing to AWG Began at 2018-10-12 16:52:19.247000
# Measuring on VNA  Began at 2018-10-12 16:52:21.401000
# Measuring on Scope  Began at 2018-10-12 16:52:26.680000
# Writing to AWG Began at 2018-10-12 16:52:26.820000
# Measuring on VNA  Began at 2018-10-12 16:52:28.944000
# Measuring on Scope  Began at 2018-10-12 16:52:34.153000
# Writing to AWG Began at 2018-10-12 16:52:34.293000
# Measuring on VNA  Began at 2018-10-12 16:52:36.411000
# Measuring on Scope  Began at 2018-10-12 16:52:41.642000
# Writing to AWG Began at 2018-10-12 16:52:41.772000
# Measuring on VNA  Began at 2018-10-12 16:52:43.855000
# Measuring on Scope  Began at 2018-10-12 16:52:49.168000
# Writing to AWG Began at 2018-10-12 16:52:49.318000
# Measuring on VNA  Began at 2018-10-12 16:52:51.428000
# Measuring on Scope  Began at 2018-10-12 16:52:56.714000
# Sweep 3
# f : 995000000.0
#  ended at 2018-10-12 16:52:56.854000
#  taking 75 seonds
# Sweep 4
# f : 997500000.0
#  began at 2018-10-12 16:52:56.854000
# Writing to AWG Began at 2018-10-12 16:52:56.904000
# Measuring on VNA  Began at 2018-10-12 16:52:59.041000
# Measuring on Scope  Began at 2018-10-12 16:53:04.286000
# Writing to AWG Began at 2018-10-12 16:53:04.436000
# Measuring on VNA  Began at 2018-10-12 16:53:06.554000
# Measuring on Scope  Began at 2018-10-12 16:53:11.857000
# Writing to AWG Began at 2018-10-12 16:53:12.027000
# Measuring on VNA  Began at 2018-10-12 16:53:14.114000
# Measuring on Scope  Began at 2018-10-12 16:53:19.405000
# Writing to AWG Began at 2018-10-12 16:53:19.565000
# Measuring on VNA  Began at 2018-10-12 16:53:21.681000
# Measuring on Scope  Began at 2018-10-12 16:53:26.974000
# Writing to AWG Began at 2018-10-12 16:53:27.124000
# Measuring on VNA  Began at 2018-10-12 16:53:29.273000
# Measuring on Scope  Began at 2018-10-12 16:53:34.538000
# Writing to AWG Began at 2018-10-12 16:53:34.688000
# Measuring on VNA  Began at 2018-10-12 16:53:36.821000
# Measuring on Scope  Began at 2018-10-12 16:53:42.005000
# Writing to AWG Began at 2018-10-12 16:53:42.145000
# Measuring on VNA  Began at 2018-10-12 16:53:44.255000
# Measuring on Scope  Began at 2018-10-12 16:53:49.507000
# Writing to AWG Began at 2018-10-12 16:53:49.648000
# Measuring on VNA  Began at 2018-10-12 16:53:51.740000
# Measuring on Scope  Began at 2018-10-12 16:53:57.042000
# Writing to AWG Began at 2018-10-12 16:53:57.192000
# ...
# Measuring on VNA  Began at 2018-10-12 17:21:52.504000
# Measuring on Scope  Began at 2018-10-12 17:21:57.757000
# Writing to AWG Began at 2018-10-12 17:21:59.996000
# Measuring on VNA  Began at 2018-10-12 17:22:04.114000
# Measuring on Scope  Began at 2018-10-12 17:22:09.328000
# Writing to AWG Began at 2018-10-12 17:22:11.594000
# Measuring on VNA  Began at 2018-10-12 17:22:15.687000
# Measuring on Scope  Began at 2018-10-12 17:22:20.969000
# Writing to AWG Began at 2018-10-12 17:22:23.207000
# Measuring on VNA  Began at 2018-10-12 17:22:27.318000
# Measuring on Scope  Began at 2018-10-12 17:22:32.538000
# Writing to AWG Began at 2018-10-12 17:22:34.798000
# Measuring on VNA  Began at 2018-10-12 17:22:38.841000
# Measuring on Scope  Began at 2018-10-12 17:22:43.982000
# Writing to AWG Began at 2018-10-12 17:22:46.178000
# Measuring on VNA  Began at 2018-10-12 17:22:50.281000
# Measuring on Scope  Began at 2018-10-12 17:22:55.528000
# Writing to AWG Began at 2018-10-12 17:22:57.757000
# Measuring on VNA  Began at 2018-10-12 17:23:01.857000
# Measuring on Scope  Began at 2018-10-12 17:23:07.132000
# Writing to AWG Began at 2018-10-12 17:23:09.355000
# Measuring on VNA  Began at 2018-10-12 17:23:13.465000
# Measuring on Scope  Began at 2018-10-12 17:23:18.651000
# Writing to AWG Began at 2018-10-12 17:23:20.945000
# Measuring on VNA  Began at 2018-10-12 17:23:25.058000
# Measuring on Scope  Began at 2018-10-12 17:23:30.318000
# Writing to AWG Began at 2018-10-12 17:23:32.576000
# Measuring on VNA  Began at 2018-10-12 17:23:36.708000
# Measuring on Scope  Began at 2018-10-12 17:23:41.962000
# Sweep 2
# f : 999925000.0
#  ended at 2018-10-12 17:23:42.082000
#  taking 115 seonds
# Sweep 3
# f : 999950000.0
#  began at 2018-10-12 17:23:42.082000
# Writing to AWG Began at 2018-10-12 17:23:44.201000
# Measuring on VNA  Began at 2018-10-12 17:23:48.339000
# Measuring on Scope  Began at 2018-10-12 17:23:53.634000
# Writing to AWG Began at 2018-10-12 17:23:55.944000
# Measuring on VNA  Began at 2018-10-12 17:24:00.097000
# Measuring on Scope  Began at 2018-10-12 17:24:05.383000
# Writing to AWG Began at 2018-10-12 17:24:07.661000
# Measuring on VNA  Began at 2018-10-12 17:24:11.781000
# Measuring on Scope  Began at 2018-10-12 17:24:17.064000
# Writing to AWG Began at 2018-10-12 17:24:19.308000
# Measuring on VNA  Began at 2018-10-12 17:24:23.391000
# Measuring on Scope  Began at 2018-10-12 17:24:28.575000
# Writing to AWG Began at 2018-10-12 17:24:30.844000
# Measuring on VNA  Began at 2018-10-12 17:24:34.966000
# Measuring on Scope  Began at 2018-10-12 17:24:40.219000
# Writing to AWG Began at 2018-10-12 17:24:42.468000
# Measuring on VNA  Began at 2018-10-12 17:24:46.670000
# Measuring on Scope  Began at 2018-10-12 17:24:51.908000
# Writing to AWG Began at 2018-10-12 17:24:54.194000
# Measuring on VNA  Began at 2018-10-12 17:24:58.251000
# Measuring on Scope  Began at 2018-10-12 17:25:03.510000
# Writing to AWG Began at 2018-10-12 17:25:05.790000
# Measuring on VNA  Began at 2018-10-12 17:25:09.904000
# Measuring on Scope  Began at 2018-10-12 17:25:15.159000
# Writing to AWG Began at 2018-10-12 17:25:17.470000
# Measuring on VNA  Began at 2018-10-12 17:25:21.587000
# Measuring on Scope  Began at 2018-10-12 17:25:26.881000
# Writing to AWG Began at 2018-10-12 17:25:29.153000
# Measuring on VNA  Began at 2018-10-12 17:25:33.253000
# Measuring on Scope  Began at 2018-10-12 17:25:38.561000
# Sweep 3
# f : 999950000.0
#  ended at 2018-10-12 17:25:38.691000
#  taking 116 seonds
# Sweep 4
# f : 999975000.0
#  began at 2018-10-12 17:25:38.691000
# Writing to AWG Began at 2018-10-12 17:25:40.822000
# Measuring on VNA  Began at 2018-10-12 17:25:44.995000
# Measuring on Scope  Began at 2018-10-12 17:25:50.294000
# Writing to AWG Began at 2018-10-12 17:25:52.547000
# Measuring on VNA  Began at 2018-10-12 17:25:56.691000
# Measuring on Scope  Began at 2018-10-12 17:26:01.995000
# Writing to AWG Began at 2018-10-12 17:26:04.229000
# Measuring on VNA  Began at 2018-10-12 17:26:08.357000
# Measuring on Scope  Began at 2018-10-12 17:26:13.557000
# Writing to AWG Began at 2018-10-12 17:26:15.821000
# Measuring on VNA  Began at 2018-10-12 17:26:19.953000
# Measuring on Scope  Began at 2018-10-12 17:26:25.237000
# Writing to AWG Began at 2018-10-12 17:26:27.427000
# Measuring on VNA  Began at 2018-10-12 17:26:31.510000
# Measuring on Scope  Began at 2018-10-12 17:26:36.841000
# Writing to AWG Began at 2018-10-12 17:26:39.083000
# Measuring on VNA  Began at 2018-10-12 17:26:43.180000
# Measuring on Scope  Began at 2018-10-12 17:26:48.370000
# Writing to AWG Began at 2018-10-12 17:26:50.587000
# Measuring on VNA  Began at 2018-10-12 17:26:54.680000
# Measuring on Scope  Began at 2018-10-12 17:26:59.963000
# Writing to AWG Began at 2018-10-12 17:27:02.189000
# Measuring on VNA  Began at 2018-10-12 17:27:06.323000
# Measuring on Scope  Began at 2018-10-12 17:27:11.583000
# Writing to AWG Began at 2018-10-12 17:27:13.814000
# Measuring on VNA  Began at 2018-10-12 17:27:17.964000
# Measuring on Scope  Began at 2018-10-12 17:27:23.227000
# Writing to AWG Began at 2018-10-12 17:27:25.467000
# Measuring on VNA  Began at 2018-10-12 17:27:29.576000
# Measuring on Scope  Began at 2018-10-12 17:27:34.747000
# Sweep 4
# f : 999975000.0
#  ended at 2018-10-12 17:27:34.877000
#  taking 116 seonds
# Sweep 5
# f : 1000000000.0
#  began at 2018-10-12 17:27:34.877000
# Writing to AWG Began at 2018-10-12 17:27:37.014000
# Measuring on VNA  Began at 2018-10-12 17:27:41.137000
# Measuring on Scope  Began at 2018-10-12 17:27:46.388000
# Writing to AWG Began at 2018-10-12 17:27:48.694000
# Measuring on VNA  Began at 2018-10-12 17:27:52.946000
# Measuring on Scope  Began at 2018-10-12 17:27:58.215000
# Writing to AWG Began at 2018-10-12 17:28:00.539000
# Measuring on VNA  Began at 2018-10-12 17:28:04.734000
# Measuring on Scope  Began at 2018-10-12 17:28:09.943000
# Writing to AWG Began at 2018-10-12 17:28:12.190000
# Measuring on VNA  Began at 2018-10-12 17:28:16.338000
# Measuring on Scope  Began at 2018-10-12 17:28:21.623000
# Writing to AWG Began at 2018-10-12 17:28:23.827000
# Measuring on VNA  Began at 2018-10-12 17:28:27.962000
# Measuring on Scope  Began at 2018-10-12 17:28:33.266000
# Writing to AWG Began at 2018-10-12 17:28:35.479000
# Measuring on VNA  Began at 2018-10-12 17:28:39.634000
# Measuring on Scope  Began at 2018-10-12 17:28:44.853000
# Writing to AWG Began at 2018-10-12 17:28:47.109000
# Measuring on VNA  Began at 2018-10-12 17:28:51.210000
# Measuring on Scope  Began at 2018-10-12 17:28:56.506000
# Writing to AWG Began at 2018-10-12 17:28:58.740000
# Measuring on VNA  Began at 2018-10-12 17:29:02.871000
# Measuring on Scope  Began at 2018-10-12 17:29:08.196000
# Writing to AWG Began at 2018-10-12 17:29:10.466000
# Measuring on VNA  Began at 2018-10-12 17:29:14.652000
# Measuring on Scope  Began at 2018-10-12 17:29:19.869000
# Writing to AWG Began at 2018-10-12 17:29:22.077000
# Measuring on VNA  Began at 2018-10-12 17:29:26.293000
# Measuring on Scope  Began at 2018-10-12 17:29:31.594000
# Sweep 5
# f : 1000000000.0
#  ended at 2018-10-12 17:29:31.734000
#  taking 116 seonds
# Sweep 6
# f : 1000025000.0
#  began at 2018-10-12 17:29:31.734000
# Writing to AWG Began at 2018-10-12 17:29:33.873000
# Measuring on VNA  Began at 2018-10-12 17:29:37.998000
# Measuring on Scope  Began at 2018-10-12 17:29:43.260000
# Writing to AWG Began at 2018-10-12 17:29:45.532000
# Measuring on VNA  Began at 2018-10-12 17:29:49.790000
# Measuring on Scope  Began at 2018-10-12 17:29:55.040000
# Writing to AWG Began at 2018-10-12 17:29:57.253000
# Measuring on VNA  Began at 2018-10-12 17:30:01.509000
# Measuring on Scope  Began at 2018-10-12 17:30:06.751000
# Writing to AWG Began at 2018-10-12 17:30:08.970000
# Measuring on VNA  Began at 2018-10-12 17:30:13.211000
# Measuring on Scope  Began at 2018-10-12 17:30:18.471000
# Writing to AWG Began at 2018-10-12 17:30:20.676000
# Measuring on VNA  Began at 2018-10-12 17:30:24.823000
# Measuring on Scope  Began at 2018-10-12 17:30:30.016000
# Writing to AWG Began at 2018-10-12 17:30:32.227000
# Measuring on VNA  Began at 2018-10-12 17:30:36.382000
# Measuring on Scope  Began at 2018-10-12 17:30:41.603000
# Writing to AWG Began at 2018-10-12 17:30:43.862000
# Measuring on VNA  Began at 2018-10-12 17:30:48.166000
# Measuring on Scope  Began at 2018-10-12 17:30:53.359000
# Writing to AWG Began at 2018-10-12 17:30:55.571000
# Measuring on VNA  Began at 2018-10-12 17:30:59.820000
# Measuring on Scope  Began at 2018-10-12 17:31:05.086000
# Writing to AWG Began at 2018-10-12 17:31:07.319000
# Measuring on VNA  Began at 2018-10-12 17:31:11.600000
# Measuring on Scope  Began at 2018-10-12 17:31:16.860000
# Writing to AWG Began at 2018-10-12 17:31:19.107000
# Measuring on VNA  Began at 2018-10-12 17:31:23.384000
# Measuring on Scope  Began at 2018-10-12 17:31:28.639000
# Sweep 6
# f : 1000025000.0
#  ended at 2018-10-12 17:31:28.769000
#  taking 117 seonds
# Sweep 7
# f : 1000050000.0
#  began at 2018-10-12 17:31:28.769000
# Writing to AWG Began at 2018-10-12 17:31:30.903000
# Measuring on VNA  Began at 2018-10-12 17:31:35.133000
# Measuring on Scope  Began at 2018-10-12 17:31:40.412000
# Writing to AWG Began at 2018-10-12 17:31:42.700000
# Measuring on VNA  Began at 2018-10-12 17:31:46.950000
# Measuring on Scope  Began at 2018-10-12 17:31:52.219000
# Writing to AWG Began at 2018-10-12 17:31:54.517000
# Measuring on VNA  Began at 2018-10-12 17:31:58.757000
# Measuring on Scope  Began at 2018-10-12 17:32:03.999000
# Writing to AWG Began at 2018-10-12 17:32:06.285000
# Measuring on VNA  Began at 2018-10-12 17:32:10.479000
# Measuring on Scope  Began at 2018-10-12 17:32:15.782000
# Writing to AWG Began at 2018-10-12 17:32:18.033000
# Measuring on VNA  Began at 2018-10-12 17:32:22.246000
# Measuring on Scope  Began at 2018-10-12 17:32:27.479000
# Writing to AWG Began at 2018-10-12 17:32:29.796000
# Measuring on VNA  Began at 2018-10-12 17:32:34.196000
# Measuring on Scope  Began at 2018-10-12 17:32:39.453000
# Writing to AWG Began at 2018-10-12 17:32:41.727000
# Measuring on VNA  Began at 2018-10-12 17:32:45.992000
# Measuring on Scope  Began at 2018-10-12 17:32:51.191000
# Writing to AWG Began at 2018-10-12 17:32:53.413000
# Measuring on VNA  Began at 2018-10-12 17:32:57.615000
# Measuring on Scope  Began at 2018-10-12 17:33:02.891000
# Writing to AWG Began at 2018-10-12 17:33:05.152000
# Measuring on VNA  Began at 2018-10-12 17:33:09.320000
# Measuring on Scope  Began at 2018-10-12 17:33:14.566000
# Writing to AWG Began at 2018-10-12 17:33:16.852000
# Measuring on VNA  Began at 2018-10-12 17:33:21.164000
# Measuring on Scope  Began at 2018-10-12 17:33:26.385000
# Sweep 7
# f : 1000050000.0
#  ended at 2018-10-12 17:33:26.525000
#  taking 117 seonds
# Sweep 8
# f : 1000075000.0
#  began at 2018-10-12 17:33:26.525000
# Writing to AWG Began at 2018-10-12 17:33:28.672000
# Measuring on VNA  Began at 2018-10-12 17:33:32.948000
# Measuring on Scope  Began at 2018-10-12 17:33:38.263000
# Writing to AWG Began at 2018-10-12 17:33:40.536000
# Measuring on VNA  Began at 2018-10-12 17:33:44.758000
# Measuring on Scope  Began at 2018-10-12 17:33:50.052000
# Writing to AWG Began at 2018-10-12 17:33:52.293000
# Measuring on VNA  Began at 2018-10-12 17:33:56.585000
# Measuring on Scope  Began at 2018-10-12 17:34:01.883000
# Writing to AWG Began at 2018-10-12 17:34:04.115000
# Measuring on VNA  Began at 2018-10-12 17:34:08.270000
# Measuring on Scope  Began at 2018-10-12 17:34:13.536000
# Writing to AWG Began at 2018-10-12 17:34:15.832000
# Measuring on VNA  Began at 2018-10-12 17:34:20.083000
# Measuring on Scope  Began at 2018-10-12 17:34:25.352000
# Writing to AWG Began at 2018-10-12 17:34:27.627000
# Measuring on VNA  Began at 2018-10-12 17:34:31.773000
# Measuring on Scope  Began at 2018-10-12 17:34:39.262000
# Writing to AWG Began at 2018-10-12 17:34:41.499000
# Measuring on VNA  Began at 2018-10-12 17:34:45.618000
# Measuring on Scope  Began at 2018-10-12 17:34:50.913000
# Writing to AWG Began at 2018-10-12 17:34:53.159000
# Measuring on VNA  Began at 2018-10-12 17:34:57.268000
# Measuring on Scope  Began at 2018-10-12 17:35:02.522000
# Writing to AWG Began at 2018-10-12 17:35:04.823000
# Measuring on VNA  Began at 2018-10-12 17:35:08.945000
# Measuring on Scope  Began at 2018-10-12 17:35:14.149000
# Writing to AWG Began at 2018-10-12 17:35:16.444000
# Measuring on VNA  Began at 2018-10-12 17:35:20.568000
# Measuring on Scope  Began at 2018-10-12 17:35:25.839000
# Sweep 8
# f : 1000075000.0
#  ended at 2018-10-12 17:35:25.989000
#  taking 119 seonds
# Sweep 9
# f : 1000100000.0
#  began at 2018-10-12 17:35:25.989000
# Writing to AWG Began at 2018-10-12 17:35:28.106000
# Measuring on VNA  Began at 2018-10-12 17:35:32.303000
# Measuring on Scope  Began at 2018-10-12 17:35:37.558000
# Writing to AWG Began at 2018-10-12 17:35:39.827000
# Measuring on VNA  Began at 2018-10-12 17:35:44.131000
# Measuring on Scope  Began at 2018-10-12 17:35:49.401000
# Writing to AWG Began at 2018-10-12 17:35:51.638000
# Measuring on VNA  Began at 2018-10-12 17:35:55.929000
# Measuring on Scope  Began at 2018-10-12 17:36:01.172000
# Writing to AWG Began at 2018-10-12 17:36:03.467000
# Measuring on VNA  Began at 2018-10-12 17:36:07.693000
# Measuring on Scope  Began at 2018-10-12 17:36:12.977000
# Writing to AWG Began at 2018-10-12 17:36:15.211000
# Measuring on VNA  Began at 2018-10-12 17:36:19.308000
# Measuring on Scope  Began at 2018-10-12 17:36:24.545000
# Writing to AWG Began at 2018-10-12 17:36:26.835000
# Measuring on VNA  Began at 2018-10-12 17:36:31.067000
# Measuring on Scope  Began at 2018-10-12 17:36:36.317000
# Writing to AWG Began at 2018-10-12 17:36:38.588000
# Measuring on VNA  Began at 2018-10-12 17:36:42.738000
# Measuring on Scope  Began at 2018-10-12 17:36:47.951000
# Writing to AWG Began at 2018-10-12 17:36:50.227000
# Measuring on VNA  Began at 2018-10-12 17:36:54.472000
# Measuring on Scope  Began at 2018-10-12 17:36:59.745000
# Writing to AWG Began at 2018-10-12 17:37:02.051000
# Measuring on VNA  Began at 2018-10-12 17:37:06.172000
# Measuring on Scope  Began at 2018-10-12 17:37:11.471000
# Writing to AWG Began at 2018-10-12 17:37:13.817000
# Measuring on VNA  Began at 2018-10-12 17:37:18.095000
# Measuring on Scope  Began at 2018-10-12 17:37:23.322000
# Sweep 9
# f : 1000100000.0
#  ended at 2018-10-12 17:37:23.452000
#  taking 117 seonds
# Sweep 10
# f : 1000125000.0
#  began at 2018-10-12 17:37:23.452000
# Writing to AWG Began at 2018-10-12 17:37:25.701000
# Measuring on VNA  Began at 2018-10-12 17:37:30.048000
# Measuring on Scope  Began at 2018-10-12 17:37:35.348000
# Writing to AWG Began at 2018-10-12 17:37:37.616000
# Measuring on VNA  Began at 2018-10-12 17:37:41.758000
# Measuring on Scope  Began at 2018-10-12 17:37:47.055000
# Writing to AWG Began at 2018-10-12 17:37:49.345000
# Measuring on VNA  Began at 2018-10-12 17:37:53.532000
# Measuring on Scope  Began at 2018-10-12 17:37:58.828000
# Writing to AWG Began at 2018-10-12 17:38:01.074000
# Measuring on VNA  Began at 2018-10-12 17:38:05.202000
# Measuring on Scope  Began at 2018-10-12 17:38:10.394000
# Writing to AWG Began at 2018-10-12 17:38:12.705000
# Measuring on VNA  Began at 2018-10-12 17:38:16.834000
# Measuring on Scope  Began at 2018-10-12 17:38:22.144000
# Writing to AWG Began at 2018-10-12 17:38:24.491000
# Measuring on VNA  Began at 2018-10-12 17:38:28.555000
# Measuring on Scope  Began at 2018-10-12 17:38:33.767000
# Writing to AWG Began at 2018-10-12 17:38:36.025000
# Measuring on VNA  Began at 2018-10-12 17:38:40.145000
# Measuring on Scope  Began at 2018-10-12 17:38:45.495000
# Writing to AWG Began at 2018-10-12 17:38:47.752000
# Measuring on VNA  Began at 2018-10-12 17:38:51.867000
# Measuring on Scope  Began at 2018-10-12 17:38:57.135000
# Writing to AWG Began at 2018-10-12 17:38:59.362000
# Measuring on VNA  Began at 2018-10-12 17:39:03.468000
# Measuring on Scope  Began at 2018-10-12 17:39:08.701000
# Writing to AWG Began at 2018-10-12 17:39:10.947000
# Measuring on VNA  Began at 2018-10-12 17:39:15.031000
# Measuring on Scope  Began at 2018-10-12 17:39:20.282000
# Sweep 10
# f : 1000125000.0
#  ended at 2018-10-12 17:39:20.425000
#  taking 116 seonds
