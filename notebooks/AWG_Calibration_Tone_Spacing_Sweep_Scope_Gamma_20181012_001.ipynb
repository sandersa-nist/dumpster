# %% [markdown]
# # A sweep of tone spacing for the AWG calibration

# %%
# import the pyMez packages default API
from pyMez import *
# import the Fitting module for Signal Generation and Fitting, note the namespace Code.Analysis.Fitting also works
from pyMez.Code.Analysis.Fitting import *
# Out:
# Importing pyMez, this should take roughly 30 seconds
# Importing Code.DataHandlers.GeneralModels
# It took 1.492 s to import Code.DataHandlers.GeneralModels
# Importing Code.DataHandlers.HTMLModels
# It took 0.33 s to import Code.DataHandlers.HTMLModels
# Importing Code.DataHandlers.NISTModels
# The module smithplot was not found,please put it on the python path
# It took 2.36 s to import Code.DataHandlers.NISTModels
# Importing Code.DataHandlers.TouchstoneModels
# The module smithplot was not found,please put it on the python path
# It took 0.02 s to import Code.DataHandlers.TouchstoneModels
# Importing Code.DataHandlers.XMLModels
# It took 0.41 s to import Code.DataHandlers.XMLModels
# Importing Code.DataHandlers.ZipModels
# It took 0.039 s to import Code.DataHandlers.ZipModels
# Importing Code.InstrumentControl.Experiments
# It took 5.614 s to import Code.InstrumentControl.Experiments
# Importing Code.InstrumentControl.Instruments
# It took 0.01 s to import Code.InstrumentControl.Instruments
# Importing Code.Utils.Names
# It took 0.01 s to import Code.Utils.Names
# It took 10.285 s to import all of the active modules

# %% [markdown]
# ## Setup Variables that do not change with tone spacing

# %%
# none of these instruments have xml instrument sheets, need to add them
psg_address="GPIB1::19"
vna_address="GPIB1::16"
awg_address="GPIB1::10"
scope_address="GPIB1::7::INSTR"
pm_address="GPIB1::13"
# ----------------------
vna=VNA(vna_address)
scope=HighSpeedOscope(scope_address)
awg=VisaInstrument(awg_address)
pm=PowerMeter(pm_address)
# ----------------


# this is local to the computer taking the data, the data should be copied to Q:\public\Aric\AWG_Phase_Calibration_20180927
data_directory=r'C:\Share\AWG_Phase_Calibration_20181001\Comb_Locked_PSG\Zero_Phase_Scope_Gamma'
# Experimental variables

# the psg frequency acts as the master clock
psg_amplitude=12. #psg amplitude in dBm
psg_frequency=10.*10.**9 # 10 GHz
time_step=1./psg_frequency # time step for the awg
fundamental_frequency = 1.*10.**9 # Center of the passband or fundemental frequency in Hz
number_tones = 11 # Number of tones in the modulation bandwidth including the fundamental, should be odd
number_harmonics = 1# Number of harmonics to use. The frequency grid will be n*(f-df), n*f, n*(f+df), etc
# Select the phase for the multisine    
multisine_phase="zero"
#multisine_phase="schroeder"
number_envelopes=1.

# Measurement Phase Reference Setup 
round_multisine_before_writing=True # Rounds the multisine to a desired bitdepth before writing to AWG
bit_depth=8
waveform_name="Calibration_Phase_Reference" # name of the waveform to write to the 
bin_format=True # If the wave is in 16 bit bin format
marker_1=False # If marker one is to be set
marker_1_n_repeats=1 # the rep rate of the marker as a function of number of repeats per time sequence
marker_2=False
marker_2_n_repeats=1

# VNA setup 
vna_IFBW=10
comb_frequency = 2.5*10**6
number_phases=10
vna.set_IFBW(vna_IFBW)

# Power Meter Setup
# pm.set_units("W")
# Out:
# The information sheet was not found defaulting to address
# The information sheet was not found defaulting to address
# The information sheet was not found defaulting to address
# The information sheet was not found defaulting to address

# %%
# Setup the traces that we might want
# Delete all of the traces that we do not need, in this case I will delete  all of them it leaves one trace
trace_string=vna.query("CALC:PAR:CAT?")
trace_list=trace_string.replace("\n","").split(",")[0::3] #remove endline, split on , and then take every third one
for trace in trace_list:
    vna.write("CALC:PAR:DEL '{0}'".format(trace))
print("Existing traces are {0}".format(vna.query("CALC:PAR:CAT?")))
# set up the traces, we use drive_port=1 sense all of the inputs are turned off, there are combs on port 2, port 3

# first we add a trace for a each reference reciever (R1=a1)
for i in range(4):
    vna.add_trace(trace_name="a{0}".format(i+1),trace_parameter="R{0}".format(i+1),drive_port=1)
# now we add a trace for each b reciever (labelled A,B,C,D)
for i,receiver in enumerate(["A","B","C","D"]):
    vna.add_trace(trace_name="b{0}".format(i+1),trace_parameter="{0}".format(receiver),drive_port=1)
    
# now we want a ratio of R1R4 (a1/a4) <- this is the calibration phase reference / measurement phase reference
vna.add_trace(trace_name="ratio",trace_parameter="R1R4",drive_port="1")
vna.add_trace(trace_name="b_ratio",trace_parameter="b1a4",drive_port="1")

vna.add_trace(trace_name="comb_ratio",trace_parameter="a1b2",drive_port="1")
print("Existing traces are {0}".format(vna.query("CALC:PAR:CAT?")))
# Out:
# Existing traces are "a1,a1,1"
#
# Existing traces are "a1,a1,1,a2,R2,1,a3,R3,1,a4,R4,1,b1,A,1,b2,B,1,b3,C,1,b4,D,1,ratio,R1/R4,1,b_ratio,b1/a4,1,comb_ratio,a1/b2,1"

# %%
tone_spacings=[10*10**6,5*10**6,2.5*10**6,2.5*10**5,2.5*10**4]
comb_spacings=[10*10**6,5*10**6,2.5*10**6]

# %%
for tone_spacing in tone_spacings:
    comb_spacing=tone_spacing in comb_spacings
    print(comb_spacing)
# Out:
# True
# True
# True
# False
# False

# %%
for tone_spacing in tone_spacings:
    comb_spacing = tone_spacing in comb_spacings
    summary_data=[]
    # now calculate the frequency_list
    frequency_list=[]
    for harmonic in range(number_harmonics):
        frequency_array=np.linspace((harmonic+1)*(fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                    (harmonic+1)*(fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)
        frequency_list=frequency_list+frequency_array.tolist()
    time_max=number_envelopes/tone_spacing
    number_time_points=int(round(time_max/time_step))
    time_shift=0.*time_step
    sweep_wait_time=2.5*float(len(frequency_list))/float(vna_IFBW)
    sweep_directory=os.path.join(data_directory,"{0}_Tones_{1:.0f}KHz_Spacing".format(number_tones,10**-3*tone_spacing))
    os.mkdir(sweep_directory)
    # first create the multisine
    sine_function=FunctionalModel(parameters=["f","phi"],variables=["t"],equation="cos(2*pi*f*t+phi)")
    time_list=np.linspace(0.+time_shift,time_max+time_shift-time_step,number_time_points)

    # calculate the phases 
    phase_list = [0. for i in range(len(frequency_list))]
    if re.search("sch",multisine_phase,re.IGNORECASE):
        phase_list=[]
        for frequency_index,frequency in enumerate(frequency_list):
            k=(frequency_index+1)%number_tones
            schroeder_phase=-k*(k-1)*np.pi/number_tones
            phase_list.append(schroeder_phase)
    # initialize multisine to a set of zeros
    multisine=np.array([0 for i in range(number_time_points)])
    # add each component
    for frequency_index,frequency in enumerate(frequency_list):
        sine_function.set_parameters({"f":frequency,"phi":phase_list[frequency_index]})
        multisine_component=sine_function(time_list)
        multisine=multisine+multisine_component

    # substract the mean
    # multisine=multisine-np.mean(multisine)
    # normalize the multisine
    # multisine=1/max(multisine)*multisine

    # round the multisine to the nearest bitdepth before writing
    if round_multisine_before_writing:
        discrete_steps=np.linspace(min(multisine),max(multisine),2**bit_depth)
        rounded_multisine=[]
        int_multisine=[]
        for value in multisine:
            difference_array=abs(discrete_steps-value)
            minimum_location=np.argmin(difference_array)
            rounded_multisine.append(discrete_steps[minimum_location])
            int_multisine.append(minimum_location)
        if bin_format:
            multisine=np.array(int_multisine,dtype=np.uint16)
            # Shift, now to add the marker add + 2**14 or +2**15 at the desired location
            multisine=multisine*2**6
        else:
            multisine=rounded_multisine

    # now we add the marker. 
    if marker_1:

        distance=int(np.floor(float(len(multisine))/float(marker_1_n_repeats)))
        for i in range(marker_1_n_repeats):
            try:
                multisine[i*distance]=multisine[i*distance]+2**14
            except:
                pass
    # I am guessing that this has the possibility of kiling the oscope trigger
    if bin_format:
        # turn AWG's output 1 & 2 OFF
        awg.write(':OUTPUT1:STATE OFF')
        awg.write(':OUTPUT2:STATE OFF')
        # wait...
        time.sleep(0.1)
        # UNRUN state
        awg.write('AWGCONTROL:STOP')
        # wait...
        time.sleep(0.5)

        # delete any older waveform with the same name
        awg.write('WLISt:WAVeform:DELete "{0}"'.format(waveform_name))
        time.sleep(0.05)

        # create new waveform
        awg.write('WLISt:WAVeform:NEW "{0}", {1}, INT'.format(waveform_name,len(multisine)))
        # download data
        awg.resource.write_binary_values('WLISt:WAVeform:DATA "{0}",'.format(waveform_name), multisine, datatype='H', is_big_endian=False)
        time.sleep(.1)
        # assign new waveform to channel 1 & 2
        awg.write('SOURce1:WAVeform "{0}"'.format(waveform_name))
        awg.write('SOURce2:WAVeform "{0}"'.format(waveform_name))

        # check for errors
        error_str = awg.query('SYSTEM:ERROR:NEXT?')
        # wait...
        time.sleep(.1)
        # AWG on RUN state
        awg.write('AWGCONTROL:RUN')
        # wait...
        time.sleep(0.5)
        # check if there is any errors on AWG's buffer
        error_str = awg.query('SYSTEM:ERROR:NEXT?')
        if error_str == '0,"No error"\n':
            # turn AWG's output 1 OFF
            awg.write(':OUTPUT1:STATE ON')
            awg.write(':OUTPUT2:STATE ON')

    if number_harmonics is 1:    
        vna.set_frequency((fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                        (fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)  
    else:
        for harmonic in range(number_harmonics):
            vna.add_segment((harmonic+1)*(fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                        (harmonic+1)*(fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)

    single_cosine=FunctionalModel(variables=["t"],parameters=["f","phi"],equation="cos(2*pi*f*t+phi)")

    phase_sweep_list=[2*np.pi*i/number_phases for i in range(number_phases)]
    # Loop to measure the phase
    start_timer=datetime.datetime.now()
    print("Calibration Began at {0}".format(start_timer))
    for frequency_index,frequency in enumerate(frequency_list[:]):
        begin_sweep_timer=datetime.datetime.now()
        print("Sweep {0} \nf : {1}\n began at {2} ".format(frequency_index,frequency,begin_sweep_timer))
        for phase_index,phase in enumerate(phase_sweep_list):

             #create the sine to write
            # ----------------------------------------------------------------------------------------------------------
            single_cosine.set_parameters({"f":frequency,"phi":phase})
            tone_data=single_cosine(time_list)

            # round the multisine to the nearest bitdepth before writing
            if round_multisine_before_writing:
                discrete_steps=np.linspace(min(tone_data),max(tone_data),2**bit_depth)
                rounded_tone_data=[]
                int_tone_data=[]
                for value in tone_data:
                    difference_array=abs(discrete_steps-value)
                    minimum_location=np.argmin(difference_array)
                    rounded_tone_data.append(discrete_steps[minimum_location])
                    int_tone_data.append(minimum_location)
                if bin_format:
                    tone_data=np.array(int_tone_data,dtype=np.uint16)
                    # Shift, now to add the marker add + 2**14 or +2**15 at the desired location
                    tone_data=tone_data*2**6
                else:
                    tone_data=rounded_tone_data

            timer=datetime.datetime.now()
            print("Writing to AWG Began at {0} ".format(timer))
            # write tone to AWG
            # --------------------------------------------------------
            tone_waveform_name="Tone_{0}_Phase_{1:.0f}_Calibration".format(frequency_index,phase*180/np.pi)
            # save the wave for good measure
            out_file=open(os.path.join(sweep_directory,"{0}.bin".format(tone_waveform_name)),"wb")
            out_file.write(tone_data)
            out_file.close()
            # plot 
            plt.close()
            plt.plot(time_list,tone_data)
            plt.xlabel("Time (s)")
            plt.ylabel("Amplitude (arb)")
            plt.title(tone_waveform_name)
            plt.savefig(os.path.join(sweep_directory,"{0}.png".format(tone_waveform_name)))
            #plt.show();

            if bin_format:
                # turn AWG's output 1 
                awg.write(':OUTPUT1:STATE OFF')
                time.sleep(0.1)
                # UNRUN state
                awg.write('AWGCONTROL:STOP')
                # wait...
                time.sleep(0.5)

                # delete any older waveform with the same name
                awg.write('WLISt:WAVeform:DELete "{0}"'.format(tone_waveform_name))
                time.sleep(0.05)

                # create new waveform
                awg.write('WLISt:WAVeform:NEW "{0}", {1}, INT'.format(tone_waveform_name,len(tone_data)))
                # download data
                awg.resource.write_binary_values('WLISt:WAVeform:DATA "{0}",'.format(tone_waveform_name), 
                                                 tone_data, datatype='H', is_big_endian=False)
                time.sleep(0.1)
                # assign new waveform to channel 1 
                awg.write('SOURce1:WAVeform "{0}"'.format(tone_waveform_name))


                # check for errors
                error_str = awg.query('SYSTEM:ERROR:NEXT?')
                # wait...
                time.sleep(.1)
                # AWG on RUN state
                awg.write('AWGCONTROL:RUN')
                # wait...
                time.sleep(0.5)
                # check if there is any errors on AWG's buffer
                error_str = awg.query('SYSTEM:ERROR:NEXT?')
                if error_str == '0,"No error"\n':
                    # turn AWG's output 1 ON
                    awg.write(':OUTPUT1:STATE ON')
                    
            timer=datetime.datetime.now()
            print("Measuring on VNA  Began at {0} ".format(timer))                
            # Measure on VNA
            # ---------------------------------------------------------------------------------------------------------
            # now the measured trace should be the multisine we can trigger and display the ratio to be sure
            vna.trigger_sweep()
            time.sleep(sweep_wait_time)
            # read_trace needs to have some work
            # Here we read a1/a4, a1, a4
            #------------------------------------------------------------------------------------
            vna.write("CALC:PAR:SEL '{0}'".format("ratio"))
            ratio_trace_string = vna.query("CALC:DATA? SDATA")
            ratio_trace = ratio_trace_string.replace("\n","").split(",")
            ratio_real = ratio_trace[0::2]
            ratio_imaginary = ratio_trace[1::2]
            complex_ratio =np.array([complex(float(real_value),
                                             float(ratio_imaginary[index])) for index,real_value in enumerate(ratio_real)])
                 
            vna.write("CALC:PAR:SEL '{0}'".format("b_ratio"))    
            b_ratio_trace_string = vna.query("CALC:DATA? SDATA")
            b_ratio_trace = b_ratio_trace_string.replace("\n","").split(",")
            b_ratio_real = b_ratio_trace[0::2]
            b_ratio_imaginary = b_ratio_trace[1::2]
            b_complex_ratio =np.array([complex(float(real_value),
                                             float(b_ratio_imaginary[index])) for index,real_value in enumerate(b_ratio_real)])

            vna.write("CALC:PAR:SEL '{0}'".format("a1"))
            a1_trace_string = vna.query("CALC:DATA? SDATA")
            a1_trace = a1_trace_string.replace("\n","").split(",")
            a1_real = a1_trace[0::2]
            a1_imaginary = a1_trace[1::2]
            complex_a1 =np.array([complex(float(real_value),
                                             float(a1_imaginary[index])) for index,real_value in enumerate(a1_real)])
            
            vna.write("CALC:PAR:SEL '{0}'".format("b1"))
            b1_trace_string = vna.query("CALC:DATA? SDATA")
            b1_trace = b1_trace_string.replace("\n","").split(",")
            b1_real = b1_trace[0::2]
            b1_imaginary = b1_trace[1::2]
            complex_b1 =np.array([complex(float(real_value),
                                             float(b1_imaginary[index])) for index,real_value in enumerate(b1_real)])

            vna.write("CALC:PAR:SEL '{0}'".format("a4"))
            a4_trace_string = vna.query("CALC:DATA? SDATA")
            a4_trace = a4_trace_string.replace("\n","").split(",")
            a4_real = a4_trace[0::2]
            a4_imaginary = a4_trace[1::2]
            complex_a4 =np.array([complex(float(real_value),
                                             float(a4_imaginary[index])) for index,real_value in enumerate(a4_real)])
            # If the tone spacing is on the comb grid, we want a1/b2, b2, b3
            if comb_spacing:
                # this block should be replaced with vna.read_trace
                vna.write("CALC:PAR:SEL '{0}'".format("b2"))
                b2_trace_string = vna.query("CALC:DATA? SDATA")
                b2_trace = b2_trace_string.replace("\n","").split(",")
                b2_real = b2_trace[0::2]
                b2_imaginary = b2_trace[1::2]
                complex_b2 =np.array([complex(float(real_value),
                                                 float(b2_imaginary[index])) for index,real_value in enumerate(b2_real)])                

                vna.write("CALC:PAR:SEL '{0}'".format("b3"))
                b3_trace_string = vna.query("CALC:DATA? SDATA")
                b3_trace = b3_trace_string.replace("\n","").split(",")
                b3_real = b3_trace[0::2]
                b3_imaginary = b3_trace[1::2]
                complex_b3 =np.array([complex(float(real_value),
                                                 float(b3_imaginary[index])) for index,real_value in enumerate(b3_real)])                
                             
                vna.write("CALC:PAR:SEL '{0}'".format("comb_ratio"))
                comb_ratio_trace_string = vna.query("CALC:DATA? SDATA")
                comb_ratio_trace = comb_ratio_trace_string.replace("\n","").split(",")
                comb_ratio_real = comb_ratio_trace[0::2]
                comb_ratio_imaginary = comb_ratio_trace[1::2]
                complex_comb_ratio =np.array([complex(float(real_value),
                                                 float(comb_ratio_imaginary[index])) for index,real_value in enumerate(comb_ratio_real)])                
                             

                vna_data=[map(lambda x:float(x),[frequency_list[index],
                           real_value,
                           ratio_imaginary[index],
                           b_ratio_real[index],b_ratio_imaginary[index],
                           a1_real[index],a1_imaginary[index],
                           b1_real[index],b1_imaginary[index],
                           a4_real[index],a4_imaginary[index],
                           comb_ratio_real[index],comb_ratio_imaginary[index],
                           b2_real[index],b2_imaginary[index],
                           b3_real[index],b3_imaginary[index]]) for index,real_value in enumerate(ratio_real)]
                
                
                column_names=["Frequency",
                                         "reA1_Div_A4","imA1_Div_A4",
                                         "reB1_Div_A4","imB1_Div_A4",
                                         "reA1","imA1","reB1","imB1",
                                         "reA4","imA4",
                                         "reA1_Div_B2","imA1_Div_B2",
                                         "reB2","imB2","reB3","imB3"]
                options={"column_names":column_names,
                         "column_types":["float" for i in range(len(column_names))],
                         "directory":sweep_directory,"specific_descriptor":tone_waveform_name,
                         "general_descriptor":"Vna_Reciever_Values","extension":"txt","data":vna_data}                    
            else:
                
                vna_data=[map(lambda x:float(x),[frequency_list[index],
                           real_value,
                           ratio_imaginary[index],
                           b_ratio_real[index],b_ratio_imaginary[index],
                           a1_real[index],a1_imaginary[index],
                           b1_real[index],b1_imaginary[index],                      
                           a4_real[index],a4_imaginary[index]]) for index,real_value in enumerate(ratio_real)]
                column_names=["Frequency","reA1_Div_A4","imA1_Div_A4",
                              "reB1_Div_A4","imB1_Div_A4",
                              "reA1","imA1","reB1","imB1","reA4","imA4"]
                options={"column_names":column_names,
                         "column_types":["float" for i in range(len(column_names))],
                         "directory":sweep_directory,"specific_descriptor":tone_waveform_name,
                         "general_descriptor":"Vna_Reciever_Values","extension":"txt","data":vna_data}
            ratio_data_table=AsciiDataTable(None,**options)
            ratio_data_table.save()
            ratio_data_table.save_schema(change_extension(ratio_data_table.path,new_extension="schema"))
            plt.close()
            plt.plot(frequency_list,abs(complex_ratio),'b-o')
            plt.xlabel("Frequency (Hz)")
            plt.ylabel("Linear Magnitude")
            plt.title("Magnitude Measured on VNA")
            plt.savefig(os.path.join(sweep_directory,"Magnitude_Plot_Ratio_{0}.png".format(tone_waveform_name)))
            #plt.show();
            plt.close()
            plt.plot(np.array(frequency_list),np.angle(complex_ratio,deg=1),"b-o")
            plt.xlabel("Frequency(Hz)")
            plt.ylabel("Phase (Degrees)")
            plt.title("Phase Measured on VNA")
            plt.savefig(os.path.join(sweep_directory,"Phase_Plot_Ratio_{0}.png".format(tone_waveform_name)))
            #plt.show();
            timer=datetime.datetime.now()
            print("Measuring on Scope  Began at {0} ".format(timer))
            time.sleep(.1)
            # Measure on Power Meter
            # ---------------------------------------------------------------------------------------------------------
#             pm.set_frequency(frequency)
#             power_reading=pm.get_reading()
            
            
            
            
            
#             wave_trace=scope.measure_waves()
#             time.sleep(.1)
#             plt.close()            
#             plt.plot(wave_trace["Time"],wave_trace["CHAN2"],label="SUT")
#             plt.plot(wave_trace["Time"],wave_trace["CHAN3"],label="I")
#             plt.plot(wave_trace["Time"],wave_trace["CHAN4"],label="Q")
#             plt.legend()
#             plt.savefig(os.path.join(sweep_directory,"Scope_{0}.png".format(tone_waveform_name)))
#             #plt.show();
#             fit_cosine=FunctionalModel(variables=["t"],parameters=["A","phi"],equation="A*cos(2*pi*t*{0}+phi)".format(frequency))
#             x_data=10**-9*np.array(map(lambda x:float(x),wave_trace["Time"]))
#             y_data=np.array(map(lambda x:float(x),wave_trace["CHAN2"]))
#             fit_cosine.fit_data(x_data=x_data,y_data=y_data)
#             plt.close()
#             plt.plot(x_data,fit_cosine(x_data),label="Fit")
#             plt.plot(x_data,y_data,label="CHAN2")
#             fit_parameters=fit_cosine.parameter_values
#             plt.title("Amplitude: {A} Phase: {phi}".format(**fit_parameters))
#             plt.legend()
#             plt.savefig(os.path.join(sweep_directory,"Scope_Fit_{0}.png".format(tone_waveform_name)))
#             #plt.show();
#             wave_trace.options["fit_equation"]="{0}".format(fit_cosine)
#             wave_trace.options["fit_parameters"]=fit_parameters
#             wave_trace.save(os.path.join(sweep_directory,"{0}_Scope_Measurement.txt".format(tone_waveform_name)))
#             wave_trace.save_schema(change_extension(wave_trace.path,new_extension="schema"))

            
            # Calculate the Summary Row, A table of Tone Index, Frequency, AWG Set Amplitude, AWG Set Phase, Scope Measured Amp
            # Scope MEasured Phase, VNA Measured Amp, VNA Measured Phase and optional values if comb_spacing
            tone_index=frequency_index+1 # starts at 1
            summary_frequency=frequency  # I know it is not needed just a reminder
            AWG_set_amplitude = .5 # set by the awg after the write of the binary wave
            AWG_set_phase=phase*180/np.pi 
            
            vna_measured_amplitude=abs(complex_ratio[frequency_index])
            vna_measured_phase=np.angle(complex_ratio[frequency_index],deg=True)
            reflected_vna_measured_amplitude=abs(b_complex_ratio[frequency_index])
            reflected_vna_measured_phase=np.angle(b_complex_ratio[frequency_index],deg=True)
            if comb_spacing:
                vna_measured_amplitude_comb=abs(complex_comb_ratio[frequency_index])
                vna_measured_phase_comb=np.angle(complex_comb_ratio[frequency_index],deg=True)
                summary_row=[tone_index,summary_frequency,
                             AWG_set_amplitude,AWG_set_phase,
                             vna_measured_amplitude,vna_measured_phase,
                             reflected_vna_measured_amplitude,reflected_vna_measured_phase,
                             vna_measured_amplitude_comb,vna_measured_phase_comb]
            else:
                summary_row=[tone_index,summary_frequency,
                                 AWG_set_amplitude,AWG_set_phase,
                                 vna_measured_amplitude,vna_measured_phase,
                                 reflected_vna_measured_amplitude,reflected_vna_measured_phase]
            # Delete last waveform
            if phase_index>0:
                awg.write('WLISt:WAVeform:DELete "{0}"'.format(last_waveform_name))
            last_waveform_name=tone_waveform_name
            summary_data.append(summary_row)
            
        if comb_spacing:
            summary_column_names=["Tone","Frequency","AWG_Set_Amplitude","AWG_Set_Phase",
                                  "Vna_Amplitude","Vna_Phase","B1_Vna_Amplitude","B1_Vna_Phase",
                                  "Vna_Comb_Referenced_Amplitude","Vna_Comb_Referenced_Phase"]
            summary_column_units=[None,"Hz","Volts","Degrees",
                                  "Volts","Degrees",
                                  "Volts","Degrees",
                                  "Volts","Degrees"]
        else:
            summary_column_names=["Tone","Frequency","AWG_Set_Amplitude","AWG_Set_Phase",
                                  "Vna_Amplitude","Vna_Phase","B1_Vna_Amplitude","B1_Vna_Phase"]
            summary_column_units=[None,"Hz","Volts","Degrees",
                                  "Volts","Degrees"
                                  "Volts","Degrees"]
            
        summary_options={"column_names":summary_column_names,
                         "column_types":["float" for i in range(len(summary_column_names))],
                         "column_units":summary_column_units,
                         "directory":sweep_directory,
                         "specific_descriptor":"{0}_Tones_{1:.0f}KHz_Spacing".format(number_tones,10**3*tone_spacing),
                         "general_descriptor":"Summary","extension":"txt","data":summary_data,
                         "metadata":{"Timestamp":"{0}".format(datetime.datetime.now()),
                                     "sweep":"{0}_Tones_{1:.0f}KHz_Spacing".format(number_tones,10**3*tone_spacing),
                                    "tone_spacing":tone_spacing,"number_tones":number_tones,
                                     "multisine_phase":multisine_phase,"number_harmonics":number_harmonics,
                                    "frequnecy_list":frequency_list}} 
        summary_table=AsciiDataTable(None,**summary_options)
        summary_table.save()
        summary_table.save_schema(change_extension(summary_table.path,new_extension="schema"))
        end_sweep_timer=datetime.datetime.now()
        difference=end_sweep_timer-begin_sweep_timer
        print("Sweep {0} \nf : {1}\n ended at {2}\n taking {3} seonds ".format(frequency_index,
                                                                               frequency,
                                                                               end_sweep_timer,
                                                                               difference.seconds))
# Out:
# Calibration Began at 2018-10-12 17:48:41.524000
# Sweep 0
# f : 950000000.0
#  began at 2018-10-12 17:48:41.524000
# Writing to AWG Began at 2018-10-12 17:48:41.524000
# Measuring on VNA  Began at 2018-10-12 17:48:43.761000
# Measuring on Scope  Began at 2018-10-12 17:48:48.989000
# Writing to AWG Began at 2018-10-12 17:48:49.099000
# Measuring on VNA  Began at 2018-10-12 17:48:51.158000
# Measuring on Scope  Began at 2018-10-12 17:48:56.385000
# Writing to AWG Began at 2018-10-12 17:48:56.495000
# Measuring on VNA  Began at 2018-10-12 17:48:58.538000
# Measuring on Scope  Began at 2018-10-12 17:49:03.819000
# Writing to AWG Began at 2018-10-12 17:49:03.939000
# Measuring on VNA  Began at 2018-10-12 17:49:06.053000
# Measuring on Scope  Began at 2018-10-12 17:49:11.342000
# Writing to AWG Began at 2018-10-12 17:49:11.462000
# Measuring on VNA  Began at 2018-10-12 17:49:13.540000
# Measuring on Scope  Began at 2018-10-12 17:49:18.767000
# Writing to AWG Began at 2018-10-12 17:49:18.887000
# Measuring on VNA  Began at 2018-10-12 17:49:20.979000
# Measuring on Scope  Began at 2018-10-12 17:49:26.282000
# Writing to AWG Began at 2018-10-12 17:49:26.402000
# Measuring on VNA  Began at 2018-10-12 17:49:28.509000
# Measuring on Scope  Began at 2018-10-12 17:49:33.837000
# Writing to AWG Began at 2018-10-12 17:49:33.957000
# Measuring on VNA  Began at 2018-10-12 17:49:36.053000
# Measuring on Scope  Began at 2018-10-12 17:49:41.328000
# Writing to AWG Began at 2018-10-12 17:49:41.448000
# Measuring on VNA  Began at 2018-10-12 17:49:43.520000
# Measuring on Scope  Began at 2018-10-12 17:49:48.843000
# Writing to AWG Began at 2018-10-12 17:49:48.963000
# Measuring on VNA  Began at 2018-10-12 17:49:51.023000
# Measuring on Scope  Began at 2018-10-12 17:49:56.223000
# Sweep 0
# f : 950000000.0
#  ended at 2018-10-12 17:49:56.343000
#  taking 74 seonds
# Sweep 1
# f : 960000000.0
#  began at 2018-10-12 17:49:56.343000
# Writing to AWG Began at 2018-10-12 17:49:56.363000
# Measuring on VNA  Began at 2018-10-12 17:49:58.423000
# Measuring on Scope  Began at 2018-10-12 17:50:03.731000
# Writing to AWG Began at 2018-10-12 17:50:03.851000
# Measuring on VNA  Began at 2018-10-12 17:50:05.930000
# Measuring on Scope  Began at 2018-10-12 17:50:11.256000
# Writing to AWG Began at 2018-10-12 17:50:11.386000
# Measuring on VNA  Began at 2018-10-12 17:50:13.494000
# Measuring on Scope  Began at 2018-10-12 17:50:18.849000
# Writing to AWG Began at 2018-10-12 17:50:18.969000
# Measuring on VNA  Began at 2018-10-12 17:50:21.008000
# Measuring on Scope  Began at 2018-10-12 17:50:26.275000
# Writing to AWG Began at 2018-10-12 17:50:26.395000
# Measuring on VNA  Began at 2018-10-12 17:50:28.466000
# Measuring on Scope  Began at 2018-10-12 17:50:33.755000
# Writing to AWG Began at 2018-10-12 17:50:33.875000
# Measuring on VNA  Began at 2018-10-12 17:50:36.676000
# Measuring on Scope  Began at 2018-10-12 17:50:42.042000
# Writing to AWG Began at 2018-10-12 17:50:42.172000
# Measuring on VNA  Began at 2018-10-12 17:50:44.262000
# Measuring on Scope  Began at 2018-10-12 17:50:49.585000
# Writing to AWG Began at 2018-10-12 17:50:49.705000
# Measuring on VNA  Began at 2018-10-12 17:50:51.793000
# Measuring on Scope  Began at 2018-10-12 17:50:57.091000
# Writing to AWG Began at 2018-10-12 17:50:57.211000
# Measuring on VNA  Began at 2018-10-12 17:50:59.323000
# Measuring on Scope  Began at 2018-10-12 17:51:04.626000
# Writing to AWG Began at 2018-10-12 17:51:04.746000
# Measuring on VNA  Began at 2018-10-12 17:51:06.896000
# Measuring on Scope  Began at 2018-10-12 17:51:12.220000
# Sweep 1
# f : 960000000.0
#  ended at 2018-10-12 17:51:12.351000
#  taking 76 seonds
# Sweep 2
# f : 970000000.0
#  began at 2018-10-12 17:51:12.351000
# Writing to AWG Began at 2018-10-12 17:51:12.361000
# Measuring on VNA  Began at 2018-10-12 17:51:14.450000
# Measuring on Scope  Began at 2018-10-12 17:51:19.730000
# Writing to AWG Began at 2018-10-12 17:51:19.850000
# Measuring on VNA  Began at 2018-10-12 17:51:21.918000
# Measuring on Scope  Began at 2018-10-12 17:51:27.137000
# Writing to AWG Began at 2018-10-12 17:51:27.257000
# Measuring on VNA  Began at 2018-10-12 17:51:29.354000
# Measuring on Scope  Began at 2018-10-12 17:51:34.552000
# Writing to AWG Began at 2018-10-12 17:51:34.672000
# Measuring on VNA  Began at 2018-10-12 17:51:36.762000
# Measuring on Scope  Began at 2018-10-12 17:51:42.204000
# Writing to AWG Began at 2018-10-12 17:51:42.326000
# Measuring on VNA  Began at 2018-10-12 17:51:44.372000
# Measuring on Scope  Began at 2018-10-12 17:51:49.630000
# Writing to AWG Began at 2018-10-12 17:51:49.750000
# Measuring on VNA  Began at 2018-10-12 17:51:51.822000
# Measuring on Scope  Began at 2018-10-12 17:51:57.138000
# Writing to AWG Began at 2018-10-12 17:51:57.258000
# Measuring on VNA  Began at 2018-10-12 17:51:59.351000
# Measuring on Scope  Began at 2018-10-12 17:52:04.613000
# Writing to AWG Began at 2018-10-12 17:52:04.733000
# Measuring on VNA  Began at 2018-10-12 17:52:06.802000
# Measuring on Scope  Began at 2018-10-12 17:52:12.092000
# Writing to AWG Began at 2018-10-12 17:52:12.212000
# Measuring on VNA  Began at 2018-10-12 17:52:14.286000
# Measuring on Scope  Began at 2018-10-12 17:52:19.549000
# Writing to AWG Began at 2018-10-12 17:52:19.669000
# Measuring on VNA  Began at 2018-10-12 17:52:21.763000
# Measuring on Scope  Began at 2018-10-12 17:52:27.013000
# Sweep 2
# f : 970000000.0
#  ended at 2018-10-12 17:52:27.143000
#  taking 74 seonds
# Sweep 3
# f : 980000000.0
#  began at 2018-10-12 17:52:27.143000
# Writing to AWG Began at 2018-10-12 17:52:27.163000
# Measuring on VNA  Began at 2018-10-12 17:52:29.243000
# Measuring on Scope  Began at 2018-10-12 17:52:34.547000
# Writing to AWG Began at 2018-10-12 17:52:34.657000
# Measuring on VNA  Began at 2018-10-12 17:52:36.757000
# Measuring on Scope  Began at 2018-10-12 17:52:42
# Writing to AWG Began at 2018-10-12 17:52:42.110000
# Measuring on VNA  Began at 2018-10-12 17:52:44.168000
# Measuring on Scope  Began at 2018-10-12 17:52:49.430000
# Writing to AWG Began at 2018-10-12 17:52:49.550000
# Measuring on VNA  Began at 2018-10-12 17:52:51.611000
# Measuring on Scope  Began at 2018-10-12 17:52:57.171000
# Writing to AWG Began at 2018-10-12 17:52:57.291000
# Measuring on VNA  Began at 2018-10-12 17:52:59.371000
# Measuring on Scope  Began at 2018-10-12 17:53:04.670000
# Writing to AWG Began at 2018-10-12 17:53:04.790000
# Measuring on VNA  Began at 2018-10-12 17:53:06.900000
# Measuring on Scope  Began at 2018-10-12 17:53:12.164000
# Writing to AWG Began at 2018-10-12 17:53:12.284000
# Measuring on VNA  Began at 2018-10-12 17:53:14.385000
# Measuring on Scope  Began at 2018-10-12 17:53:19.640000
# Writing to AWG Began at 2018-10-12 17:53:19.760000
# Measuring on VNA  Began at 2018-10-12 17:53:21.847000
# Measuring on Scope  Began at 2018-10-12 17:53:27.131000
# Writing to AWG Began at 2018-10-12 17:53:27.251000
# Measuring on VNA  Began at 2018-10-12 17:53:29.319000
# Measuring on Scope  Began at 2018-10-12 17:53:34.583000
# Writing to AWG Began at 2018-10-12 17:53:34.703000
# Measuring on VNA  Began at 2018-10-12 17:53:36.839000
# Measuring on Scope  Began at 2018-10-12 17:53:42.099000
# Sweep 3
# f : 980000000.0
#  ended at 2018-10-12 17:53:42.239000
#  taking 75 seonds
# Sweep 4
# f : 990000000.0
#  began at 2018-10-12 17:53:42.239000
# Writing to AWG Began at 2018-10-12 17:53:42.260000
# Measuring on VNA  Began at 2018-10-12 17:53:44.340000
# Measuring on Scope  Began at 2018-10-12 17:53:49.651000
# Writing to AWG Began at 2018-10-12 17:53:49.771000
# Measuring on VNA  Began at 2018-10-12 17:53:51.847000
# Measuring on Scope  Began at 2018-10-12 17:53:57.177000
# Writing to AWG Began at 2018-10-12 17:53:57.297000
# Measuring on VNA  Began at 2018-10-12 17:53:59.383000
# Measuring on Scope  Began at 2018-10-12 17:54:04.669000
# Writing to AWG Began at 2018-10-12 17:54:04.789000
# Measuring on VNA  Began at 2018-10-12 17:54:06.916000
# Measuring on Scope  Began at 2018-10-12 17:54:12.213000
# Writing to AWG Began at 2018-10-12 17:54:12.333000
# Measuring on VNA  Began at 2018-10-12 17:54:14.427000
# Measuring on Scope  Began at 2018-10-12 17:54:19.771000
# Writing to AWG Began at 2018-10-12 17:54:19.891000
# Measuring on VNA  Began at 2018-10-12 17:54:22.004000
# Measuring on Scope  Began at 2018-10-12 17:54:27.257000
# Writing to AWG Began at 2018-10-12 17:54:27.377000
# Measuring on VNA  Began at 2018-10-12 17:54:29.489000
# Measuring on Scope  Began at 2018-10-12 17:54:34.918000
# Writing to AWG Began at 2018-10-12 17:54:35.038000
# Measuring on VNA  Began at 2018-10-12 17:54:37.130000
# Measuring on Scope  Began at 2018-10-12 17:54:42.415000
# Writing to AWG Began at 2018-10-12 17:54:42.535000
# Measuring on VNA  Began at 2018-10-12 17:54:44.628000
# Measuring on Scope  Began at 2018-10-12 17:54:49.902000
# Writing to AWG Began at 2018-10-12 17:54:50.022000
# Measuring on VNA  Began at 2018-10-12 17:54:52.131000
# Measuring on Scope  Began at 2018-10-12 17:54:57.374000
# Sweep 4
# f : 990000000.0
#  ended at 2018-10-12 17:54:57.504000
#  taking 75 seonds
# Sweep 5
# f : 1000000000.0
#  began at 2018-10-12 17:54:57.504000
# Writing to AWG Began at 2018-10-12 17:54:57.514000
# Measuring on VNA  Began at 2018-10-12 17:54:59.585000
# Measuring on Scope  Began at 2018-10-12 17:55:04.856000
# Writing to AWG Began at 2018-10-12 17:55:04.976000
# Measuring on VNA  Began at 2018-10-12 17:55:07.023000
# Measuring on Scope  Began at 2018-10-12 17:55:12.326000
# Writing to AWG Began at 2018-10-12 17:55:12.446000
# Measuring on VNA  Began at 2018-10-12 17:55:14.524000
# Measuring on Scope  Began at 2018-10-12 17:55:19.810000
# Writing to AWG Began at 2018-10-12 17:55:19.920000
# Measuring on VNA  Began at 2018-10-12 17:55:21.962000
# Measuring on Scope  Began at 2018-10-12 17:55:27.289000
# Writing to AWG Began at 2018-10-12 17:55:27.399000
# Measuring on VNA  Began at 2018-10-12 17:55:29.487000
# Measuring on Scope  Began at 2018-10-12 17:55:34.764000
# Writing to AWG Began at 2018-10-12 17:55:34.884000
# Measuring on VNA  Began at 2018-10-12 17:55:36.991000
# Measuring on Scope  Began at 2018-10-12 17:55:42.383000
# Writing to AWG Began at 2018-10-12 17:55:42.513000
# Measuring on VNA  Began at 2018-10-12 17:55:44.600000
# Measuring on Scope  Began at 2018-10-12 17:55:49.833000
# Writing to AWG Began at 2018-10-12 17:55:49.953000
# Measuring on VNA  Began at 2018-10-12 17:55:52.053000
# Measuring on Scope  Began at 2018-10-12 17:55:57.355000
# Writing to AWG Began at 2018-10-12 17:55:57.475000
# Measuring on VNA  Began at 2018-10-12 17:55:59.570000
# Measuring on Scope  Began at 2018-10-12 17:56:04.881000
# Writing to AWG Began at 2018-10-12 17:56:05.001000
# Measuring on VNA  Began at 2018-10-12 17:56:07.101000
# Measuring on Scope  Began at 2018-10-12 17:56:12.364000
# Sweep 5
# f : 1000000000.0
#  ended at 2018-10-12 17:56:12.504000
#  taking 75 seonds
# Sweep 6
# f : 1010000000.0
#  began at 2018-10-12 17:56:12.504000
# Writing to AWG Began at 2018-10-12 17:56:12.514000
# Measuring on VNA  Began at 2018-10-12 17:56:14.602000
# Measuring on Scope  Began at 2018-10-12 17:56:19.924000
# Writing to AWG Began at 2018-10-12 17:56:20.044000
# Measuring on VNA  Began at 2018-10-12 17:56:22.153000
# Measuring on Scope  Began at 2018-10-12 17:56:27.411000
# Writing to AWG Began at 2018-10-12 17:56:27.531000
# Measuring on VNA  Began at 2018-10-12 17:56:29.912000
# Measuring on Scope  Began at 2018-10-12 17:56:35.215000
# Writing to AWG Began at 2018-10-12 17:56:35.335000
# Measuring on VNA  Began at 2018-10-12 17:56:37.445000
# Measuring on Scope  Began at 2018-10-12 17:56:42.767000
# Writing to AWG Began at 2018-10-12 17:56:42.877000
# Measuring on VNA  Began at 2018-10-12 17:56:44.938000
# Measuring on Scope  Began at 2018-10-12 17:56:50.259000
# Writing to AWG Began at 2018-10-12 17:56:50.379000
# Measuring on VNA  Began at 2018-10-12 17:56:52.455000
# Measuring on Scope  Began at 2018-10-12 17:56:57.783000
# Writing to AWG Began at 2018-10-12 17:56:57.903000
# Measuring on VNA  Began at 2018-10-12 17:57:00.021000
# Measuring on Scope  Began at 2018-10-12 17:57:05.253000
# Writing to AWG Began at 2018-10-12 17:57:05.373000
# Measuring on VNA  Began at 2018-10-12 17:57:07.487000
# Measuring on Scope  Began at 2018-10-12 17:57:12.790000
# Writing to AWG Began at 2018-10-12 17:57:12.900000
# Measuring on VNA  Began at 2018-10-12 17:57:15.004000
# Measuring on Scope  Began at 2018-10-12 17:57:20.287000
# Writing to AWG Began at 2018-10-12 17:57:20.407000
# Measuring on VNA  Began at 2018-10-12 17:57:22.501000
# Measuring on Scope  Began at 2018-10-12 17:57:27.733000
# Sweep 6
# f : 1010000000.0
#  ended at 2018-10-12 17:57:27.863000
#  taking 75 seonds
# Sweep 7
# f : 1020000000.0
#  began at 2018-10-12 17:57:27.863000
# Writing to AWG Began at 2018-10-12 17:57:27.883000
# Measuring on VNA  Began at 2018-10-12 17:57:29.971000
# Measuring on Scope  Began at 2018-10-12 17:57:35.251000
# Writing to AWG Began at 2018-10-12 17:57:35.361000
# Measuring on VNA  Began at 2018-10-12 17:57:37.424000
# Measuring on Scope  Began at 2018-10-12 17:57:42.738000
# Writing to AWG Began at 2018-10-12 17:57:42.858000
# Measuring on VNA  Began at 2018-10-12 17:57:44.920000
# Measuring on Scope  Began at 2018-10-12 17:57:50.212000
# Writing to AWG Began at 2018-10-12 17:57:50.332000
# Measuring on VNA  Began at 2018-10-12 17:57:52.485000
# Measuring on Scope  Began at 2018-10-12 17:57:57.803000
# Writing to AWG Began at 2018-10-12 17:57:57.923000
# Measuring on VNA  Began at 2018-10-12 17:57:59.998000
# Measuring on Scope  Began at 2018-10-12 17:58:05.287000
# Writing to AWG Began at 2018-10-12 17:58:05.407000
# Measuring on VNA  Began at 2018-10-12 17:58:07.502000
# Measuring on Scope  Began at 2018-10-12 17:58:12.794000
# Writing to AWG Began at 2018-10-12 17:58:12.914000
# Measuring on VNA  Began at 2018-10-12 17:58:14.999000
# Measuring on Scope  Began at 2018-10-12 17:58:20.289000
# Writing to AWG Began at 2018-10-12 17:58:20.409000
# Measuring on VNA  Began at 2018-10-12 17:58:22.512000
# Measuring on Scope  Began at 2018-10-12 17:58:27.813000
# Writing to AWG Began at 2018-10-12 17:58:27.933000
# Measuring on VNA  Began at 2018-10-12 17:58:30.030000
# Measuring on Scope  Began at 2018-10-12 17:58:35.323000
# Writing to AWG Began at 2018-10-12 17:58:35.443000
# Measuring on VNA  Began at 2018-10-12 17:58:37.529000
# Measuring on Scope  Began at 2018-10-12 17:58:42.906000
# Sweep 7
# f : 1020000000.0
#  ended at 2018-10-12 17:58:43.046000
#  taking 75 seonds
# Sweep 8
# f : 1030000000.0
#  began at 2018-10-12 17:58:43.046000
# Writing to AWG Began at 2018-10-12 17:58:43.056000
# Measuring on VNA  Began at 2018-10-12 17:58:45.130000
# Measuring on Scope  Began at 2018-10-12 17:58:50.425000
# Writing to AWG Began at 2018-10-12 17:58:50.545000
# Measuring on VNA  Began at 2018-10-12 17:58:52.594000
# Measuring on Scope  Began at 2018-10-12 17:58:58.323000
# Writing to AWG Began at 2018-10-12 17:58:58.443000
# Measuring on VNA  Began at 2018-10-12 17:59:00.497000
# Measuring on Scope  Began at 2018-10-12 17:59:05.821000
# Writing to AWG Began at 2018-10-12 17:59:05.941000
# Measuring on VNA  Began at 2018-10-12 17:59:08.037000
# Measuring on Scope  Began at 2018-10-12 17:59:13.330000
# Writing to AWG Began at 2018-10-12 17:59:13.450000
# Measuring on VNA  Began at 2018-10-12 17:59:15.501000
# Measuring on Scope  Began at 2018-10-12 17:59:20.744000
# Writing to AWG Began at 2018-10-12 17:59:20.864000
# Measuring on VNA  Began at 2018-10-12 17:59:22.930000
# Measuring on Scope  Began at 2018-10-12 17:59:28.105000
# Writing to AWG Began at 2018-10-12 17:59:28.225000
# Measuring on VNA  Began at 2018-10-12 17:59:30.288000
# Measuring on Scope  Began at 2018-10-12 17:59:35.504000
# Writing to AWG Began at 2018-10-12 17:59:35.639000
# Measuring on VNA  Began at 2018-10-12 17:59:37.756000
# Measuring on Scope  Began at 2018-10-12 17:59:43.032000
# Writing to AWG Began at 2018-10-12 17:59:43.153000
# Measuring on VNA  Began at 2018-10-12 17:59:45.280000
# Measuring on Scope  Began at 2018-10-12 17:59:50.645000
# Writing to AWG Began at 2018-10-12 17:59:50.765000
# Measuring on VNA  Began at 2018-10-12 17:59:52.825000
# Measuring on Scope  Began at 2018-10-12 17:59:58.055000
# Sweep 8
# f : 1030000000.0
#  ended at 2018-10-12 17:59:58.195000
#  taking 75 seonds
# Sweep 9
# f : 1040000000.0
#  began at 2018-10-12 17:59:58.195000
# Writing to AWG Began at 2018-10-12 17:59:58.215000
# Measuring on VNA  Began at 2018-10-12 18:00:00.285000
# Measuring on Scope  Began at 2018-10-12 18:00:05.626000
# Writing to AWG Began at 2018-10-12 18:00:05.746000
# Measuring on VNA  Began at 2018-10-12 18:00:07.797000
# Measuring on Scope  Began at 2018-10-12 18:00:13.113000
# Writing to AWG Began at 2018-10-12 18:00:13.233000
# Measuring on VNA  Began at 2018-10-12 18:00:15.306000
# Measuring on Scope  Began at 2018-10-12 18:00:20.583000
# Writing to AWG Began at 2018-10-12 18:00:20.703000
# Measuring on VNA  Began at 2018-10-12 18:00:22.767000
# Measuring on Scope  Began at 2018-10-12 18:00:28.060000
# Writing to AWG Began at 2018-10-12 18:00:28.170000
# Measuring on VNA  Began at 2018-10-12 18:00:30.255000
# Measuring on Scope  Began at 2018-10-12 18:00:35.464000
# Writing to AWG Began at 2018-10-12 18:00:35.574000
# Measuring on VNA  Began at 2018-10-12 18:00:37.644000
# Measuring on Scope  Began at 2018-10-12 18:00:42.935000
# Writing to AWG Began at 2018-10-12 18:00:43.055000
# Measuring on VNA  Began at 2018-10-12 18:00:45.107000
# Measuring on Scope  Began at 2018-10-12 18:00:50.425000
# Writing to AWG Began at 2018-10-12 18:00:50.545000
# Measuring on VNA  Began at 2018-10-12 18:00:52.661000
# Measuring on Scope  Began at 2018-10-12 18:00:57.905000
# Writing to AWG Began at 2018-10-12 18:00:58.025000
# Measuring on VNA  Began at 2018-10-12 18:01:00.098000
# Measuring on Scope  Began at 2018-10-12 18:01:05.355000
# Writing to AWG Began at 2018-10-12 18:01:05.475000
# Measuring on VNA  Began at 2018-10-12 18:01:07.575000
# Measuring on Scope  Began at 2018-10-12 18:01:12.772000
# Sweep 9
# f : 1040000000.0
#  ended at 2018-10-12 18:01:12.912000
#  taking 74 seonds
# Sweep 10
# f : 1050000000.0
#  began at 2018-10-12 18:01:12.912000
# Writing to AWG Began at 2018-10-12 18:01:12.922000
# Measuring on VNA  Began at 2018-10-12 18:01:15.028000
# Measuring on Scope  Began at 2018-10-12 18:01:20.403000
# Writing to AWG Began at 2018-10-12 18:01:20.523000
# Measuring on VNA  Began at 2018-10-12 18:01:22.580000
# Measuring on Scope  Began at 2018-10-12 18:01:27.842000
# Writing to AWG Began at 2018-10-12 18:01:27.962000
# Measuring on VNA  Began at 2018-10-12 18:01:30.029000
# Measuring on Scope  Began at 2018-10-12 18:01:35.326000
# Writing to AWG Began at 2018-10-12 18:01:35.456000
# Measuring on VNA  Began at 2018-10-12 18:01:37.566000
# Measuring on Scope  Began at 2018-10-12 18:01:42.857000
# Writing to AWG Began at 2018-10-12 18:01:42.987000
# Measuring on VNA  Began at 2018-10-12 18:01:45.076000
# Measuring on Scope  Began at 2018-10-12 18:01:50.364000
# Writing to AWG Began at 2018-10-12 18:01:50.484000
# Measuring on VNA  Began at 2018-10-12 18:01:52.557000
# Measuring on Scope  Began at 2018-10-12 18:01:58.241000
# Writing to AWG Began at 2018-10-12 18:01:58.371000
# Measuring on VNA  Began at 2018-10-12 18:02:00.441000
# Measuring on Scope  Began at 2018-10-12 18:02:05.716000
# Writing to AWG Began at 2018-10-12 18:02:05.836000
# Measuring on VNA  Began at 2018-10-12 18:02:07.944000
# Measuring on Scope  Began at 2018-10-12 18:02:13.232000
# Writing to AWG Began at 2018-10-12 18:02:13.352000
# Measuring on VNA  Began at 2018-10-12 18:02:15.420000
# Measuring on Scope  Began at 2018-10-12 18:02:20.625000
# Writing to AWG Began at 2018-10-12 18:02:20.745000
# Measuring on VNA  Began at 2018-10-12 18:02:22.864000
# Measuring on Scope  Began at 2018-10-12 18:02:28.144000
# Sweep 10
# f : 1050000000.0
#  ended at 2018-10-12 18:02:28.274000
#  taking 75 seonds
# Calibration Began at 2018-10-12 18:02:30.321000
# Sweep 0
# f : 975000000.0
#  began at 2018-10-12 18:02:30.321000
# Writing to AWG Began at 2018-10-12 18:02:30.361000
# Measuring on VNA  Began at 2018-10-12 18:02:32.458000
# Measuring on Scope  Began at 2018-10-12 18:02:37.723000
# Writing to AWG Began at 2018-10-12 18:02:37.843000
# Measuring on VNA  Began at 2018-10-12 18:02:39.909000
# Measuring on Scope  Began at 2018-10-12 18:02:45.158000
# Writing to AWG Began at 2018-10-12 18:02:45.278000
# Measuring on VNA  Began at 2018-10-12 18:02:47.349000
# Measuring on Scope  Began at 2018-10-12 18:02:52.542000
# Writing to AWG Began at 2018-10-12 18:02:52.662000
# Measuring on VNA  Began at 2018-10-12 18:02:54.746000
# Measuring on Scope  Began at 2018-10-12 18:03:00.002000
# Writing to AWG Began at 2018-10-12 18:03:00.122000
# Measuring on VNA  Began at 2018-10-12 18:03:02.124000
# Measuring on Scope  Began at 2018-10-12 18:03:07.377000
# Writing to AWG Began at 2018-10-12 18:03:07.497000
# Measuring on VNA  Began at 2018-10-12 18:03:09.573000
# Measuring on Scope  Began at 2018-10-12 18:03:14.791000
# Writing to AWG Began at 2018-10-12 18:03:14.911000
# Measuring on VNA  Began at 2018-10-12 18:03:16.983000
# Measuring on Scope  Began at 2018-10-12 18:03:22.207000
# Writing to AWG Began at 2018-10-12 18:03:22.317000
# Measuring on VNA  Began at 2018-10-12 18:03:24.404000
# Measuring on Scope  Began at 2018-10-12 18:03:29.554000
# Writing to AWG Began at 2018-10-12 18:03:29.684000
# Measuring on VNA  Began at 2018-10-12 18:03:31.733000
# Measuring on Scope  Began at 2018-10-12 18:03:36.961000
# Writing to AWG Began at 2018-10-12 18:03:37.078000
# Measuring on VNA  Began at 2018-10-12 18:03:39.125000
# Measuring on Scope  Began at 2018-10-12 18:03:44.401000
# Sweep 0
# f : 975000000.0
#  ended at 2018-10-12 18:03:44.531000
#  taking 74 seonds
# Sweep 1
# f : 980000000.0
#  began at 2018-10-12 18:03:44.531000
# Writing to AWG Began at 2018-10-12 18:03:44.551000
# Measuring on VNA  Began at 2018-10-12 18:03:46.621000
# Measuring on Scope  Began at 2018-10-12 18:03:51.883000
# Writing to AWG Began at 2018-10-12 18:03:51.993000
# Measuring on VNA  Began at 2018-10-12 18:03:54.050000
# Measuring on Scope  Began at 2018-10-12 18:03:59.275000
# Writing to AWG Began at 2018-10-12 18:03:59.405000
# Measuring on VNA  Began at 2018-10-12 18:04:01.450000
# Measuring on Scope  Began at 2018-10-12 18:04:06.706000
# Writing to AWG Began at 2018-10-12 18:04:06.836000
# Measuring on VNA  Began at 2018-10-12 18:04:08.958000
# Measuring on Scope  Began at 2018-10-12 18:04:14.223000
# Writing to AWG Began at 2018-10-12 18:04:14.333000
# Measuring on VNA  Began at 2018-10-12 18:04:16.439000
# Measuring on Scope  Began at 2018-10-12 18:04:21.651000
# Writing to AWG Began at 2018-10-12 18:04:21.781000
# Measuring on VNA  Began at 2018-10-12 18:04:23.847000
# Measuring on Scope  Began at 2018-10-12 18:04:29.137000
# Writing to AWG Began at 2018-10-12 18:04:29.267000
# Measuring on VNA  Began at 2018-10-12 18:04:31.361000
# Measuring on Scope  Began at 2018-10-12 18:04:36.637000
# Writing to AWG Began at 2018-10-12 18:04:36.767000
# Measuring on VNA  Began at 2018-10-12 18:04:38.861000
# Measuring on Scope  Began at 2018-10-12 18:04:44.118000
# Writing to AWG Began at 2018-10-12 18:04:44.228000
# Measuring on VNA  Began at 2018-10-12 18:04:46.324000
# Measuring on Scope  Began at 2018-10-12 18:04:51.555000
# Writing to AWG Began at 2018-10-12 18:04:51.665000
# Measuring on VNA  Began at 2018-10-12 18:04:53.748000
# Measuring on Scope  Began at 2018-10-12 18:04:58.948000
# Sweep 1
# f : 980000000.0
#  ended at 2018-10-12 18:04:59.068000
#  taking 74 seonds
# Sweep 2
# f : 985000000.0
#  began at 2018-10-12 18:04:59.068000
# Writing to AWG Began at 2018-10-12 18:04:59.108000
# Measuring on VNA  Began at 2018-10-12 18:05:01.248000
# Measuring on Scope  Began at 2018-10-12 18:05:06.538000
# Writing to AWG Began at 2018-10-12 18:05:06.678000
# Measuring on VNA  Began at 2018-10-12 18:05:08.732000
# Measuring on Scope  Began at 2018-10-12 18:05:13.978000
# Writing to AWG Began at 2018-10-12 18:05:14.088000
# Measuring on VNA  Began at 2018-10-12 18:05:16.182000
# Measuring on Scope  Began at 2018-10-12 18:05:21.436000
# Writing to AWG Began at 2018-10-12 18:05:21.546000
# Measuring on VNA  Began at 2018-10-12 18:05:23.642000
# Measuring on Scope  Began at 2018-10-12 18:05:28.923000
# Writing to AWG Began at 2018-10-12 18:05:29.033000
# Measuring on VNA  Began at 2018-10-12 18:05:31.126000
# Measuring on Scope  Began at 2018-10-12 18:05:36.959000
# Writing to AWG Began at 2018-10-12 18:05:37.079000
# Measuring on VNA  Began at 2018-10-12 18:05:39.150000
# Measuring on Scope  Began at 2018-10-12 18:05:44.438000
# Writing to AWG Began at 2018-10-12 18:05:44.578000
# Measuring on VNA  Began at 2018-10-12 18:05:46.733000
# Measuring on Scope  Began at 2018-10-12 18:05:52.004000
# Writing to AWG Began at 2018-10-12 18:05:52.114000
# Measuring on VNA  Began at 2018-10-12 18:05:54.230000
# Measuring on Scope  Began at 2018-10-12 18:05:59.474000
# Writing to AWG Began at 2018-10-12 18:05:59.614000
# Measuring on VNA  Began at 2018-10-12 18:06:01.738000
# Measuring on Scope  Began at 2018-10-12 18:06:07.019000
# Writing to AWG Began at 2018-10-12 18:06:07.129000
# Measuring on VNA  Began at 2018-10-12 18:06:09.249000
# Measuring on Scope  Began at 2018-10-12 18:06:14.516000
# Sweep 2
# f : 985000000.0
#  ended at 2018-10-12 18:06:14.646000
#  taking 75 seonds
# Sweep 3
# f : 990000000.0
#  began at 2018-10-12 18:06:14.646000
# Writing to AWG Began at 2018-10-12 18:06:14.656000
# Measuring on VNA  Began at 2018-10-12 18:06:16.772000
# Measuring on Scope  Began at 2018-10-12 18:06:22.032000
# Writing to AWG Began at 2018-10-12 18:06:22.142000
# Measuring on VNA  Began at 2018-10-12 18:06:24.229000
# Measuring on Scope  Began at 2018-10-12 18:06:29.478000
# Writing to AWG Began at 2018-10-12 18:06:29.588000
# Measuring on VNA  Began at 2018-10-12 18:06:31.688000
# Measuring on Scope  Began at 2018-10-12 18:06:36.950000
# Writing to AWG Began at 2018-10-12 18:06:37.060000
# Measuring on VNA  Began at 2018-10-12 18:06:39.143000
# Measuring on Scope  Began at 2018-10-12 18:06:44.426000
# Writing to AWG Began at 2018-10-12 18:06:44.556000
# Measuring on VNA  Began at 2018-10-12 18:06:46.643000
# Measuring on Scope  Began at 2018-10-12 18:06:51.905000
# Writing to AWG Began at 2018-10-12 18:06:52.025000
# Measuring on VNA  Began at 2018-10-12 18:06:54.122000
# Measuring on Scope  Began at 2018-10-12 18:06:59.369000
# Writing to AWG Began at 2018-10-12 18:06:59.489000
# Measuring on VNA  Began at 2018-10-12 18:07:01.564000
# Measuring on Scope  Began at 2018-10-12 18:07:06.823000
# Writing to AWG Began at 2018-10-12 18:07:06.943000
# Measuring on VNA  Began at 2018-10-12 18:07:09.027000
# Measuring on Scope  Began at 2018-10-12 18:07:14.321000
# Writing to AWG Began at 2018-10-12 18:07:14.441000
# Measuring on VNA  Began at 2018-10-12 18:07:16.500000
# Measuring on Scope  Began at 2018-10-12 18:07:21.760000
# Writing to AWG Began at 2018-10-12 18:07:21.870000
# Measuring on VNA  Began at 2018-10-12 18:07:23.954000
# Measuring on Scope  Began at 2018-10-12 18:07:29.187000
# Sweep 3
# f : 990000000.0
#  ended at 2018-10-12 18:07:29.307000
#  taking 74 seonds
# Sweep 4
# f : 995000000.0
#  began at 2018-10-12 18:07:29.307000
# Writing to AWG Began at 2018-10-12 18:07:29.317000
# Measuring on VNA  Began at 2018-10-12 18:07:31.378000
# Measuring on Scope  Began at 2018-10-12 18:07:36.568000
# Writing to AWG Began at 2018-10-12 18:07:36.691000
# Measuring on VNA  Began at 2018-10-12 18:07:38.748000
# Measuring on Scope  Began at 2018-10-12 18:07:44.017000
# Writing to AWG Began at 2018-10-12 18:07:44.147000
# Measuring on VNA  Began at 2018-10-12 18:07:46.252000
# Measuring on Scope  Began at 2018-10-12 18:07:51.486000
# Writing to AWG Began at 2018-10-12 18:07:51.616000
# Measuring on VNA  Began at 2018-10-12 18:07:53.731000
# Measuring on Scope  Began at 2018-10-12 18:07:59.001000
# Writing to AWG Began at 2018-10-12 18:07:59.131000
# Measuring on VNA  Began at 2018-10-12 18:08:01.195000
# Measuring on Scope  Began at 2018-10-12 18:08:06.469000
# Writing to AWG Began at 2018-10-12 18:08:06.579000
# Measuring on VNA  Began at 2018-10-12 18:08:08.645000
# Measuring on Scope  Began at 2018-10-12 18:08:13.923000
# Writing to AWG Began at 2018-10-12 18:08:14.043000
# Measuring on VNA  Began at 2018-10-12 18:08:16.101000
# Measuring on Scope  Began at 2018-10-12 18:08:21.371000
# Writing to AWG Began at 2018-10-12 18:08:21.501000
# Measuring on VNA  Began at 2018-10-12 18:08:23.571000
# Measuring on Scope  Began at 2018-10-12 18:08:28.842000
# Writing to AWG Began at 2018-10-12 18:08:28.972000
# Measuring on VNA  Began at 2018-10-12 18:08:31.022000
# Measuring on Scope  Began at 2018-10-12 18:08:36.288000
# Writing to AWG Began at 2018-10-12 18:08:36.428000
# Measuring on VNA  Began at 2018-10-12 18:08:38.512000
# Measuring on Scope  Began at 2018-10-12 18:08:43.796000
# Sweep 4
# f : 995000000.0
#  ended at 2018-10-12 18:08:43.916000
#  taking 74 seonds
# Sweep 5
# f : 1000000000.0
#  began at 2018-10-12 18:08:43.916000
# Writing to AWG Began at 2018-10-12 18:08:43.926000
# Measuring on VNA  Began at 2018-10-12 18:08:45.992000
# Measuring on Scope  Began at 2018-10-12 18:08:51.189000
# Writing to AWG Began at 2018-10-12 18:08:51.299000
# Measuring on VNA  Began at 2018-10-12 18:08:53.372000
# Measuring on Scope  Began at 2018-10-12 18:08:58.571000
# Writing to AWG Began at 2018-10-12 18:08:58.691000
# Measuring on VNA  Began at 2018-10-12 18:09:00.773000
# Measuring on Scope  Began at 2018-10-12 18:09:06.034000
# Writing to AWG Began at 2018-10-12 18:09:06.164000
# Measuring on VNA  Began at 2018-10-12 18:09:08.244000
# Measuring on Scope  Began at 2018-10-12 18:09:13.480000
# Writing to AWG Began at 2018-10-12 18:09:13.600000
# Measuring on VNA  Began at 2018-10-12 18:09:15.684000
# Measuring on Scope  Began at 2018-10-12 18:09:20.924000
# Writing to AWG Began at 2018-10-12 18:09:21.044000
# Measuring on VNA  Began at 2018-10-12 18:09:23.086000
# Measuring on Scope  Began at 2018-10-12 18:09:28.320000
# Writing to AWG Began at 2018-10-12 18:09:28.430000
# Measuring on VNA  Began at 2018-10-12 18:09:30.507000
# Measuring on Scope  Began at 2018-10-12 18:09:35.697000
# Writing to AWG Began at 2018-10-12 18:09:35.809000
# Measuring on VNA  Began at 2018-10-12 18:09:37.867000
# Measuring on Scope  Began at 2018-10-12 18:09:43.039000
# Writing to AWG Began at 2018-10-12 18:09:43.149000
# Measuring on VNA  Began at 2018-10-12 18:09:45.234000
# Measuring on Scope  Began at 2018-10-12 18:09:50.451000
# Writing to AWG Began at 2018-10-12 18:09:50.561000
# Measuring on VNA  Began at 2018-10-12 18:09:52.641000
# Measuring on Scope  Began at 2018-10-12 18:09:57.917000
# Sweep 5
# f : 1000000000.0
#  ended at 2018-10-12 18:09:58.057000
#  taking 74 seonds
# Sweep 6
# f : 1005000000.0
#  began at 2018-10-12 18:09:58.057000
# Writing to AWG Began at 2018-10-12 18:09:58.067000
# Measuring on VNA  Began at 2018-10-12 18:10:00.138000
# Measuring on Scope  Began at 2018-10-12 18:10:06.144000
# Writing to AWG Began at 2018-10-12 18:10:06.274000
# Measuring on VNA  Began at 2018-10-12 18:10:08.342000
# Measuring on Scope  Began at 2018-10-12 18:10:13.585000
# Writing to AWG Began at 2018-10-12 18:10:13.705000
# Measuring on VNA  Began at 2018-10-12 18:10:15.795000
# Measuring on Scope  Began at 2018-10-12 18:10:21.063000
# Writing to AWG Began at 2018-10-12 18:10:21.183000
# Measuring on VNA  Began at 2018-10-12 18:10:23.309000
# Measuring on Scope  Began at 2018-10-12 18:10:28.547000
# Writing to AWG Began at 2018-10-12 18:10:28.667000
# Measuring on VNA  Began at 2018-10-12 18:10:30.742000
# Measuring on Scope  Began at 2018-10-12 18:10:35.953000
# Writing to AWG Began at 2018-10-12 18:10:36.063000
# Measuring on VNA  Began at 2018-10-12 18:10:38.142000
# Measuring on Scope  Began at 2018-10-12 18:10:43.430000
# Writing to AWG Began at 2018-10-12 18:10:43.560000
# Measuring on VNA  Began at 2018-10-12 18:10:45.637000
# Measuring on Scope  Began at 2018-10-12 18:10:50.836000
# Writing to AWG Began at 2018-10-12 18:10:50.946000
# Measuring on VNA  Began at 2018-10-12 18:10:53.026000
# Measuring on Scope  Began at 2018-10-12 18:10:58.316000
# Writing to AWG Began at 2018-10-12 18:10:58.446000
# Measuring on VNA  Began at 2018-10-12 18:11:00.520000
# Measuring on Scope  Began at 2018-10-12 18:11:05.811000
# Writing to AWG Began at 2018-10-12 18:11:05.921000
# Measuring on VNA  Began at 2018-10-12 18:11:07.990000
# Measuring on Scope  Began at 2018-10-12 18:11:13.254000
# Sweep 6
# f : 1005000000.0
#  ended at 2018-10-12 18:11:13.394000
#  taking 75 seonds
# Sweep 7
# f : 1010000000.0
#  began at 2018-10-12 18:11:13.394000
# Writing to AWG Began at 2018-10-12 18:11:13.414000
# Measuring on VNA  Began at 2018-10-12 18:11:15.493000
# Measuring on Scope  Began at 2018-10-12 18:11:20.775000
# Writing to AWG Began at 2018-10-12 18:11:20.915000
# Measuring on VNA  Began at 2018-10-12 18:11:22.987000
# Measuring on Scope  Began at 2018-10-12 18:11:28.208000
# Writing to AWG Began at 2018-10-12 18:11:28.318000
# Measuring on VNA  Began at 2018-10-12 18:11:30.414000
# Measuring on Scope  Began at 2018-10-12 18:11:35.591000
# Writing to AWG Began at 2018-10-12 18:11:35.718000
# Measuring on VNA  Began at 2018-10-12 18:11:37.776000
# Measuring on Scope  Began at 2018-10-12 18:11:43.008000
# Writing to AWG Began at 2018-10-12 18:11:43.128000
# Measuring on VNA  Began at 2018-10-12 18:11:45.225000
# Measuring on Scope  Began at 2018-10-12 18:11:50.473000
# Writing to AWG Began at 2018-10-12 18:11:50.593000
# Measuring on VNA  Began at 2018-10-12 18:11:52.696000
# Measuring on Scope  Began at 2018-10-12 18:11:57.956000
# Writing to AWG Began at 2018-10-12 18:11:58.066000
# Measuring on VNA  Began at 2018-10-12 18:12:00.136000
# Measuring on Scope  Began at 2018-10-12 18:12:05.393000
# Writing to AWG Began at 2018-10-12 18:12:05.523000
# Measuring on VNA  Began at 2018-10-12 18:12:07.619000
# Measuring on Scope  Began at 2018-10-12 18:12:12.873000
# Writing to AWG Began at 2018-10-12 18:12:12.993000
# Measuring on VNA  Began at 2018-10-12 18:12:15.033000
# Measuring on Scope  Began at 2018-10-12 18:12:20.239000
# Writing to AWG Began at 2018-10-12 18:12:20.359000
# Measuring on VNA  Began at 2018-10-12 18:12:22.430000
# Measuring on Scope  Began at 2018-10-12 18:12:27.680000
# Sweep 7
# f : 1010000000.0
#  ended at 2018-10-12 18:12:27.820000
#  taking 74 seonds
# Sweep 8
# f : 1015000000.0
#  began at 2018-10-12 18:12:27.820000
# Writing to AWG Began at 2018-10-12 18:12:27.840000
# Measuring on VNA  Began at 2018-10-12 18:12:29.903000
# Measuring on Scope  Began at 2018-10-12 18:12:35.190000
# Writing to AWG Began at 2018-10-12 18:12:35.320000
# Measuring on VNA  Began at 2018-10-12 18:12:37.404000
# Measuring on Scope  Began at 2018-10-12 18:12:42.677000
# Writing to AWG Began at 2018-10-12 18:12:42.807000
# Measuring on VNA  Began at 2018-10-12 18:12:44.871000
# Measuring on Scope  Began at 2018-10-12 18:12:50.158000
# Writing to AWG Began at 2018-10-12 18:12:50.298000
# Measuring on VNA  Began at 2018-10-12 18:12:52.368000
# Measuring on Scope  Began at 2018-10-12 18:12:57.608000
# Writing to AWG Began at 2018-10-12 18:12:57.738000
# Measuring on VNA  Began at 2018-10-12 18:12:59.812000
# Measuring on Scope  Began at 2018-10-12 18:13:04.965000
# Writing to AWG Began at 2018-10-12 18:13:05.075000
# Measuring on VNA  Began at 2018-10-12 18:13:07.129000
# Measuring on Scope  Began at 2018-10-12 18:13:12.395000
# Writing to AWG Began at 2018-10-12 18:13:12.535000
# Measuring on VNA  Began at 2018-10-12 18:13:14.639000
# Measuring on Scope  Began at 2018-10-12 18:13:19.892000
# Writing to AWG Began at 2018-10-12 18:13:20.022000
# Measuring on VNA  Began at 2018-10-12 18:13:22.089000
# Measuring on Scope  Began at 2018-10-12 18:13:27.333000
# Writing to AWG Began at 2018-10-12 18:13:27.453000
# Measuring on VNA  Began at 2018-10-12 18:13:29.534000
# Measuring on Scope  Began at 2018-10-12 18:13:34.813000
# Writing to AWG Began at 2018-10-12 18:13:34.943000
# Measuring on VNA  Began at 2018-10-12 18:13:37.019000
# Measuring on Scope  Began at 2018-10-12 18:13:42.208000
# Sweep 8
# f : 1015000000.0
#  ended at 2018-10-12 18:13:42.318000
#  taking 74 seonds
# Sweep 9
# f : 1020000000.0
#  began at 2018-10-12 18:13:42.318000
# Writing to AWG Began at 2018-10-12 18:13:42.338000
# Measuring on VNA  Began at 2018-10-12 18:13:44.400000
# Measuring on Scope  Began at 2018-10-12 18:13:49.643000
# Writing to AWG Began at 2018-10-12 18:13:49.763000
# Measuring on VNA  Began at 2018-10-12 18:13:51.854000
# Measuring on Scope  Began at 2018-10-12 18:13:57.112000
# Writing to AWG Began at 2018-10-12 18:13:57.222000
# Measuring on VNA  Began at 2018-10-12 18:13:59.271000
# Measuring on Scope  Began at 2018-10-12 18:14:04.495000
# Writing to AWG Began at 2018-10-12 18:14:04.605000
# Measuring on VNA  Began at 2018-10-12 18:14:06.677000
# Measuring on Scope  Began at 2018-10-12 18:14:11.943000
# Writing to AWG Began at 2018-10-12 18:14:12.053000
# Measuring on VNA  Began at 2018-10-12 18:14:14.134000
# Measuring on Scope  Began at 2018-10-12 18:14:19.434000
# Writing to AWG Began at 2018-10-12 18:14:19.564000
# Measuring on VNA  Began at 2018-10-12 18:14:21.695000
# Measuring on Scope  Began at 2018-10-12 18:14:26.882000
# Writing to AWG Began at 2018-10-12 18:14:26.992000
# Measuring on VNA  Began at 2018-10-12 18:14:29.048000
# Measuring on Scope  Began at 2018-10-12 18:14:34.389000
# Writing to AWG Began at 2018-10-12 18:14:34.519000
# Measuring on VNA  Began at 2018-10-12 18:14:36.583000
# Measuring on Scope  Began at 2018-10-12 18:14:41.875000
# Writing to AWG Began at 2018-10-12 18:14:42.005000
# Measuring on VNA  Began at 2018-10-12 18:14:44.119000
# Measuring on Scope  Began at 2018-10-12 18:14:49.410000
# Writing to AWG Began at 2018-10-12 18:14:49.540000
# Measuring on VNA  Began at 2018-10-12 18:14:51.629000
# Measuring on Scope  Began at 2018-10-12 18:14:56.897000
# Sweep 9
# f : 1020000000.0
#  ended at 2018-10-12 18:14:57.037000
#  taking 74 seonds
# Sweep 10
# f : 1025000000.0
#  began at 2018-10-12 18:14:57.037000
# Writing to AWG Began at 2018-10-12 18:14:57.057000
# Measuring on VNA  Began at 2018-10-12 18:14:59.113000
# Measuring on Scope  Began at 2018-10-12 18:15:04.434000
# Writing to AWG Began at 2018-10-12 18:15:04.564000
# Measuring on VNA  Began at 2018-10-12 18:15:06.637000
# Measuring on Scope  Began at 2018-10-12 18:15:11.941000
# Writing to AWG Began at 2018-10-12 18:15:12.081000
# Measuring on VNA  Began at 2018-10-12 18:15:14.136000
# Measuring on Scope  Began at 2018-10-12 18:15:19.412000
# Writing to AWG Began at 2018-10-12 18:15:19.552000
# Measuring on VNA  Began at 2018-10-12 18:15:21.634000
# Measuring on Scope  Began at 2018-10-12 18:15:26.912000
# Writing to AWG Began at 2018-10-12 18:15:27.052000
# Measuring on VNA  Began at 2018-10-12 18:15:29.119000
# Measuring on Scope  Began at 2018-10-12 18:15:35.467000
# Writing to AWG Began at 2018-10-12 18:15:35.597000
# Measuring on VNA  Began at 2018-10-12 18:15:37.675000
# Measuring on Scope  Began at 2018-10-12 18:15:42.976000
# Writing to AWG Began at 2018-10-12 18:15:43.096000
# Measuring on VNA  Began at 2018-10-12 18:15:45.166000
# Measuring on Scope  Began at 2018-10-12 18:15:50.466000
# Writing to AWG Began at 2018-10-12 18:15:50.596000
# Measuring on VNA  Began at 2018-10-12 18:15:52.692000
# Measuring on Scope  Began at 2018-10-12 18:15:57.999000
# Writing to AWG Began at 2018-10-12 18:15:58.119000
# Measuring on VNA  Began at 2018-10-12 18:16:00.179000
# Measuring on Scope  Began at 2018-10-12 18:16:05.433000
# Writing to AWG Began at 2018-10-12 18:16:05.543000
# Measuring on VNA  Began at 2018-10-12 18:16:07.614000
# Measuring on Scope  Began at 2018-10-12 18:16:12.933000
# Sweep 10
# f : 1025000000.0
#  ended at 2018-10-12 18:16:13.073000
#  taking 76 seonds
# Calibration Began at 2018-10-12 18:16:15.095000
# Sweep 0
# f : 987500000.0
#  began at 2018-10-12 18:16:15.095000
# Writing to AWG Began at 2018-10-12 18:16:15.125000
# Measuring on VNA  Began at 2018-10-12 18:16:17.257000
# Measuring on Scope  Began at 2018-10-12 18:16:22.537000
# Writing to AWG Began at 2018-10-12 18:16:22.677000
# Measuring on VNA  Began at 2018-10-12 18:16:24.785000
# Measuring on Scope  Began at 2018-10-12 18:16:30.131000
# Writing to AWG Began at 2018-10-12 18:16:30.271000
# Measuring on VNA  Began at 2018-10-12 18:16:32.393000
# Measuring on Scope  Began at 2018-10-12 18:16:37.620000
# Writing to AWG Began at 2018-10-12 18:16:37.750000
# Measuring on VNA  Began at 2018-10-12 18:16:39.947000
# Measuring on Scope  Began at 2018-10-12 18:16:45.190000
# Writing to AWG Began at 2018-10-12 18:16:45.340000
# Measuring on VNA  Began at 2018-10-12 18:16:47.425000
# Measuring on Scope  Began at 2018-10-12 18:16:52.654000
# Writing to AWG Began at 2018-10-12 18:16:52.804000
# Measuring on VNA  Began at 2018-10-12 18:16:54.908000
# Measuring on Scope  Began at 2018-10-12 18:17:00.192000
# Writing to AWG Began at 2018-10-12 18:17:00.312000
# Measuring on VNA  Began at 2018-10-12 18:17:02.455000
# Measuring on Scope  Began at 2018-10-12 18:17:07.712000
# Writing to AWG Began at 2018-10-12 18:17:07.862000
# Measuring on VNA  Began at 2018-10-12 18:17:09.958000
# Measuring on Scope  Began at 2018-10-12 18:17:15.308000
# Writing to AWG Began at 2018-10-12 18:17:15.448000
# Measuring on VNA  Began at 2018-10-12 18:17:17.609000
# Measuring on Scope  Began at 2018-10-12 18:17:22.992000
# Writing to AWG Began at 2018-10-12 18:17:23.152000
# Measuring on VNA  Began at 2018-10-12 18:17:25.318000
# Measuring on Scope  Began at 2018-10-12 18:17:30.616000
# Sweep 0
# f : 987500000.0
#  ended at 2018-10-12 18:17:30.736000
#  taking 75 seonds
# Sweep 1
# f : 990000000.0
#  began at 2018-10-12 18:17:30.736000
# Writing to AWG Began at 2018-10-12 18:17:30.756000
# Measuring on VNA  Began at 2018-10-12 18:17:32.880000
# Measuring on Scope  Began at 2018-10-12 18:17:38.159000
# Writing to AWG Began at 2018-10-12 18:17:38.299000
# Measuring on VNA  Began at 2018-10-12 18:17:40.408000
# Measuring on Scope  Began at 2018-10-12 18:17:45.720000
# Writing to AWG Began at 2018-10-12 18:17:45.870000
# Measuring on VNA  Began at 2018-10-12 18:17:47.990000
# Measuring on Scope  Began at 2018-10-12 18:17:53.268000
# Writing to AWG Began at 2018-10-12 18:17:53.388000
# Measuring on VNA  Began at 2018-10-12 18:17:55.531000
# Measuring on Scope  Began at 2018-10-12 18:18:00.751000
# Writing to AWG Began at 2018-10-12 18:18:00.901000
# Measuring on VNA  Began at 2018-10-12 18:18:03.024000
# Measuring on Scope  Began at 2018-10-12 18:18:08.242000
# Writing to AWG Began at 2018-10-12 18:18:08.372000
# Measuring on VNA  Began at 2018-10-12 18:18:10.492000
# Measuring on Scope  Began at 2018-10-12 18:18:15.824000
# Writing to AWG Began at 2018-10-12 18:18:15.964000
# Measuring on VNA  Began at 2018-10-12 18:18:18.111000
# Measuring on Scope  Began at 2018-10-12 18:18:23.341000
# Writing to AWG Began at 2018-10-12 18:18:23.481000
# Measuring on VNA  Began at 2018-10-12 18:18:25.584000
# Measuring on Scope  Began at 2018-10-12 18:18:30.890000
# Writing to AWG Began at 2018-10-12 18:18:31.020000
# Measuring on VNA  Began at 2018-10-12 18:18:33.205000
# Measuring on Scope  Began at 2018-10-12 18:18:38.495000
# Writing to AWG Began at 2018-10-12 18:18:38.646000
# Measuring on VNA  Began at 2018-10-12 18:18:40.768000
# Measuring on Scope  Began at 2018-10-12 18:18:46.066000
# Sweep 1
# f : 990000000.0
#  ended at 2018-10-12 18:18:46.186000
#  taking 75 seonds
# Sweep 2
# f : 992500000.0
#  began at 2018-10-12 18:18:46.186000
# Writing to AWG Began at 2018-10-12 18:18:46.226000
# Measuring on VNA  Began at 2018-10-12 18:18:48.363000
# Measuring on Scope  Began at 2018-10-12 18:18:53.627000
# Writing to AWG Began at 2018-10-12 18:18:53.787000
# Measuring on VNA  Began at 2018-10-12 18:18:55.925000
# Measuring on Scope  Began at 2018-10-12 18:19:01.168000
# Writing to AWG Began at 2018-10-12 18:19:01.318000
# Measuring on VNA  Began at 2018-10-12 18:19:03.472000
# Measuring on Scope  Began at 2018-10-12 18:19:08.693000
# Writing to AWG Began at 2018-10-12 18:19:08.853000
# Measuring on VNA  Began at 2018-10-12 18:19:10.970000
# Measuring on Scope  Began at 2018-10-12 18:19:16.273000
# Writing to AWG Began at 2018-10-12 18:19:16.423000
# Measuring on VNA  Began at 2018-10-12 18:19:18.554000
# Measuring on Scope  Began at 2018-10-12 18:19:23.807000
# Writing to AWG Began at 2018-10-12 18:19:23.947000
# Measuring on VNA  Began at 2018-10-12 18:19:26.048000
# Measuring on Scope  Began at 2018-10-12 18:19:31.271000
# Writing to AWG Began at 2018-10-12 18:19:31.421000
# Measuring on VNA  Began at 2018-10-12 18:19:33.563000
# Measuring on Scope  Began at 2018-10-12 18:19:38.898000
# Writing to AWG Began at 2018-10-12 18:19:39.048000
# Measuring on VNA  Began at 2018-10-12 18:19:41.101000
# Measuring on Scope  Began at 2018-10-12 18:19:46.379000
# Writing to AWG Began at 2018-10-12 18:19:46.519000
# Measuring on VNA  Began at 2018-10-12 18:19:48.631000
# Measuring on Scope  Began at 2018-10-12 18:19:53.862000
# Writing to AWG Began at 2018-10-12 18:19:54.012000
# Measuring on VNA  Began at 2018-10-12 18:19:56.172000
# Measuring on Scope  Began at 2018-10-12 18:20:01.544000
# Sweep 2
# f : 992500000.0
#  ended at 2018-10-12 18:20:01.674000
#  taking 75 seonds
# Sweep 3
# f : 995000000.0
#  began at 2018-10-12 18:20:01.674000
# Writing to AWG Began at 2018-10-12 18:20:01.704000
# Measuring on VNA  Began at 2018-10-12 18:20:03.852000
# Measuring on Scope  Began at 2018-10-12 18:20:09.159000
# Writing to AWG Began at 2018-10-12 18:20:09.299000
# Measuring on VNA  Began at 2018-10-12 18:20:11.408000
# Measuring on Scope  Began at 2018-10-12 18:20:16.708000
# Writing to AWG Began at 2018-10-12 18:20:16.858000
# Measuring on VNA  Began at 2018-10-12 18:20:18.968000
# Measuring on Scope  Began at 2018-10-12 18:20:24.246000
# Writing to AWG Began at 2018-10-12 18:20:24.386000
# Measuring on VNA  Began at 2018-10-12 18:20:26.532000
# Measuring on Scope  Began at 2018-10-12 18:20:31.762000
# Writing to AWG Began at 2018-10-12 18:20:31.902000
# Measuring on VNA  Began at 2018-10-12 18:20:34.055000
# Measuring on Scope  Began at 2018-10-12 18:20:39.396000
# Writing to AWG Began at 2018-10-12 18:20:39.536000
# Measuring on VNA  Began at 2018-10-12 18:20:42.224000
# Measuring on Scope  Began at 2018-10-12 18:20:47.446000
# Writing to AWG Began at 2018-10-12 18:20:47.586000
# Measuring on VNA  Began at 2018-10-12 18:20:49.733000
# Measuring on Scope  Began at 2018-10-12 18:20:55.025000
# Writing to AWG Began at 2018-10-12 18:20:55.175000
# Measuring on VNA  Began at 2018-10-12 18:20:57.314000
# Measuring on Scope  Began at 2018-10-12 18:21:02.617000
# Writing to AWG Began at 2018-10-12 18:21:02.757000
# Measuring on VNA  Began at 2018-10-12 18:21:04.907000
# Measuring on Scope  Began at 2018-10-12 18:21:10.195000
# Writing to AWG Began at 2018-10-12 18:21:10.335000
# Measuring on VNA  Began at 2018-10-12 18:21:12.465000
# Measuring on Scope  Began at 2018-10-12 18:21:17.789000
# Sweep 3
# f : 995000000.0
#  ended at 2018-10-12 18:21:17.919000
#  taking 76 seonds
# Sweep 4
# f : 997500000.0
#  began at 2018-10-12 18:21:17.919000
# Writing to AWG Began at 2018-10-12 18:21:17.949000
# Measuring on VNA  Began at 2018-10-12 18:21:20.109000
# Measuring on Scope  Began at 2018-10-12 18:21:25.429000
# Writing to AWG Began at 2018-10-12 18:21:25.569000
# Measuring on VNA  Began at 2018-10-12 18:21:27.734000
# Measuring on Scope  Began at 2018-10-12 18:21:33.025000
# Writing to AWG Began at 2018-10-12 18:21:33.175000
# Measuring on VNA  Began at 2018-10-12 18:21:35.288000
# Measuring on Scope  Began at 2018-10-12 18:21:40.598000
# Writing to AWG Began at 2018-10-12 18:21:40.738000
# Measuring on VNA  Began at 2018-10-12 18:21:42.862000
# Measuring on Scope  Began at 2018-10-12 18:21:48.178000
# Writing to AWG Began at 2018-10-12 18:21:48.318000
# Measuring on VNA  Began at 2018-10-12 18:21:50.429000
# Measuring on Scope  Began at 2018-10-12 18:21:55.669000
# Writing to AWG Began at 2018-10-12 18:21:55.819000
# Measuring on VNA  Began at 2018-10-12 18:21:57.929000
# Measuring on Scope  Began at 2018-10-12 18:22:03.179000
# Writing to AWG Began at 2018-10-12 18:22:03.329000
# Measuring on VNA  Began at 2018-10-12 18:22:05.449000
# Measuring on Scope  Began at 2018-10-12 18:22:10.754000
# Writing to AWG Began at 2018-10-12 18:22:10.904000
# Measuring on VNA  Began at 2018-10-12 18:22:13.053000
# Measuring on Scope  Began at 2018-10-12 18:22:18.334000
# Writing to AWG Began at 2018-10-12 18:22:18.484000
# ...
# Measuring on VNA  Began at 2018-10-12 18:50:26.981000
# Measuring on Scope  Began at 2018-10-12 18:50:32.214000
# Writing to AWG Began at 2018-10-12 18:50:34.375000
# Measuring on VNA  Began at 2018-10-12 18:50:38.514000
# Measuring on Scope  Began at 2018-10-12 18:50:43.696000
# Writing to AWG Began at 2018-10-12 18:50:45.852000
# Measuring on VNA  Began at 2018-10-12 18:50:50.732000
# Measuring on Scope  Began at 2018-10-12 18:50:56.044000
# Writing to AWG Began at 2018-10-12 18:50:58.175000
# Measuring on VNA  Began at 2018-10-12 18:51:02.369000
# Measuring on Scope  Began at 2018-10-12 18:51:07.647000
# Writing to AWG Began at 2018-10-12 18:51:09.801000
# Measuring on VNA  Began at 2018-10-12 18:51:14.043000
# Measuring on Scope  Began at 2018-10-12 18:51:19.258000
# Writing to AWG Began at 2018-10-12 18:51:21.420000
# Measuring on VNA  Began at 2018-10-12 18:51:25.604000
# Measuring on Scope  Began at 2018-10-12 18:51:30.818000
# Writing to AWG Began at 2018-10-12 18:51:32.951000
# Measuring on VNA  Began at 2018-10-12 18:51:37.230000
# Measuring on Scope  Began at 2018-10-12 18:51:42.457000
# Writing to AWG Began at 2018-10-12 18:51:44.675000
# Measuring on VNA  Began at 2018-10-12 18:51:48.945000
# Measuring on Scope  Began at 2018-10-12 18:51:54.102000
# Writing to AWG Began at 2018-10-12 18:51:56.264000
# Measuring on VNA  Began at 2018-10-12 18:52:00.554000
# Measuring on Scope  Began at 2018-10-12 18:52:05.725000
# Writing to AWG Began at 2018-10-12 18:52:07.899000
# Measuring on VNA  Began at 2018-10-12 18:52:12.230000
# Measuring on Scope  Began at 2018-10-12 18:52:17.447000
# Sweep 2
# f : 999925000.0
#  ended at 2018-10-12 18:52:17.577000
#  taking 116 seonds
# Sweep 3
# f : 999950000.0
#  began at 2018-10-12 18:52:17.577000
# Writing to AWG Began at 2018-10-12 18:52:19.610000
# Measuring on VNA  Began at 2018-10-12 18:52:23.966000
# Measuring on Scope  Began at 2018-10-12 18:52:29.178000
# Writing to AWG Began at 2018-10-12 18:52:31.404000
# Measuring on VNA  Began at 2018-10-12 18:52:35.743000
# Measuring on Scope  Began at 2018-10-12 18:52:40.946000
# Writing to AWG Began at 2018-10-12 18:52:43.184000
# Measuring on VNA  Began at 2018-10-12 18:52:47.537000
# Measuring on Scope  Began at 2018-10-12 18:52:52.764000
# Writing to AWG Began at 2018-10-12 18:52:54.918000
# Measuring on VNA  Began at 2018-10-12 18:52:59.211000
# Measuring on Scope  Began at 2018-10-12 18:53:04.444000
# Writing to AWG Began at 2018-10-12 18:53:06.622000
# Measuring on VNA  Began at 2018-10-12 18:53:10.884000
# Measuring on Scope  Began at 2018-10-12 18:53:16.068000
# Writing to AWG Began at 2018-10-12 18:53:18.210000
# Measuring on VNA  Began at 2018-10-12 18:53:22.457000
# Measuring on Scope  Began at 2018-10-12 18:53:27.765000
# Writing to AWG Began at 2018-10-12 18:53:30.046000
# Measuring on VNA  Began at 2018-10-12 18:53:34.333000
# Measuring on Scope  Began at 2018-10-12 18:53:39.590000
# Writing to AWG Began at 2018-10-12 18:53:41.783000
# Measuring on VNA  Began at 2018-10-12 18:53:45.963000
# Measuring on Scope  Began at 2018-10-12 18:53:51.217000
# Writing to AWG Began at 2018-10-12 18:53:53.376000
# Measuring on VNA  Began at 2018-10-12 18:53:57.554000
# Measuring on Scope  Began at 2018-10-12 18:54:02.726000
# Writing to AWG Began at 2018-10-12 18:54:04.938000
# Measuring on VNA  Began at 2018-10-12 18:54:09.199000
# Measuring on Scope  Began at 2018-10-12 18:54:14.463000
# Sweep 3
# f : 999950000.0
#  ended at 2018-10-12 18:54:14.593000
#  taking 117 seonds
# Sweep 4
# f : 999975000.0
#  began at 2018-10-12 18:54:14.593000
# Writing to AWG Began at 2018-10-12 18:54:16.683000
# Measuring on VNA  Began at 2018-10-12 18:54:20.918000
# Measuring on Scope  Began at 2018-10-12 18:54:26.179000
# Writing to AWG Began at 2018-10-12 18:54:28.358000
# Measuring on VNA  Began at 2018-10-12 18:54:32.512000
# Measuring on Scope  Began at 2018-10-12 18:54:37.767000
# Writing to AWG Began at 2018-10-12 18:54:39.936000
# Measuring on VNA  Began at 2018-10-12 18:54:44.164000
# Measuring on Scope  Began at 2018-10-12 18:54:49.442000
# Writing to AWG Began at 2018-10-12 18:54:51.703000
# Measuring on VNA  Began at 2018-10-12 18:54:55.897000
# Measuring on Scope  Began at 2018-10-12 18:55:01.197000
# Writing to AWG Began at 2018-10-12 18:55:03.426000
# Measuring on VNA  Began at 2018-10-12 18:55:07.553000
# Measuring on Scope  Began at 2018-10-12 18:55:12.821000
# Writing to AWG Began at 2018-10-12 18:55:15.053000
# Measuring on VNA  Began at 2018-10-12 18:55:19.229000
# Measuring on Scope  Began at 2018-10-12 18:55:24.433000
# Writing to AWG Began at 2018-10-12 18:55:26.704000
# Measuring on VNA  Began at 2018-10-12 18:55:30.944000
# Measuring on Scope  Began at 2018-10-12 18:55:36.163000
# Writing to AWG Began at 2018-10-12 18:55:38.386000
# Measuring on VNA  Began at 2018-10-12 18:55:42.585000
# Measuring on Scope  Began at 2018-10-12 18:55:47.791000
# Writing to AWG Began at 2018-10-12 18:55:50.010000
# Measuring on VNA  Began at 2018-10-12 18:55:54.301000
# Measuring on Scope  Began at 2018-10-12 18:55:59.561000
# Writing to AWG Began at 2018-10-12 18:56:01.851000
# Measuring on VNA  Began at 2018-10-12 18:56:06.116000
# Measuring on Scope  Began at 2018-10-12 18:56:11.416000
# Sweep 4
# f : 999975000.0
#  ended at 2018-10-12 18:56:11.546000
#  taking 116 seonds
# Sweep 5
# f : 1000000000.0
#  began at 2018-10-12 18:56:11.546000
# Writing to AWG Began at 2018-10-12 18:56:13.643000
# Measuring on VNA  Began at 2018-10-12 18:56:17.805000
# Measuring on Scope  Began at 2018-10-12 18:56:23.056000
# Writing to AWG Began at 2018-10-12 18:56:25.250000
# Measuring on VNA  Began at 2018-10-12 18:56:29.602000
# Measuring on Scope  Began at 2018-10-12 18:56:34.774000
# Writing to AWG Began at 2018-10-12 18:56:36.936000
# Measuring on VNA  Began at 2018-10-12 18:56:41.230000
# Measuring on Scope  Began at 2018-10-12 18:56:46.493000
# Writing to AWG Began at 2018-10-12 18:56:48.717000
# Measuring on VNA  Began at 2018-10-12 18:56:53.067000
# Measuring on Scope  Began at 2018-10-12 18:56:58.298000
# Writing to AWG Began at 2018-10-12 18:57:00.477000
# Measuring on VNA  Began at 2018-10-12 18:57:04.662000
# Measuring on Scope  Began at 2018-10-12 18:57:09.988000
# Writing to AWG Began at 2018-10-12 18:57:12.161000
# Measuring on VNA  Began at 2018-10-12 18:57:16.472000
# Measuring on Scope  Began at 2018-10-12 18:57:21.763000
# Writing to AWG Began at 2018-10-12 18:57:23.948000
# Measuring on VNA  Began at 2018-10-12 18:57:28.160000
# Measuring on Scope  Began at 2018-10-12 18:57:33.512000
# Writing to AWG Began at 2018-10-12 18:57:35.724000
# Measuring on VNA  Began at 2018-10-12 18:57:39.909000
# Measuring on Scope  Began at 2018-10-12 18:57:45.220000
# Writing to AWG Began at 2018-10-12 18:57:47.466000
# Measuring on VNA  Began at 2018-10-12 18:57:51.742000
# Measuring on Scope  Began at 2018-10-12 18:57:56.990000
# Writing to AWG Began at 2018-10-12 18:57:59.299000
# Measuring on VNA  Began at 2018-10-12 18:58:03.548000
# Measuring on Scope  Began at 2018-10-12 18:58:08.800000
# Sweep 5
# f : 1000000000.0
#  ended at 2018-10-12 18:58:08.930000
#  taking 117 seonds
# Sweep 6
# f : 1000025000.0
#  began at 2018-10-12 18:58:08.930000
# Writing to AWG Began at 2018-10-12 18:58:11.022000
# Measuring on VNA  Began at 2018-10-12 18:58:15.235000
# Measuring on Scope  Began at 2018-10-12 18:58:20.477000
# Writing to AWG Began at 2018-10-12 18:58:22.666000
# Measuring on VNA  Began at 2018-10-12 18:58:26.896000
# Measuring on Scope  Began at 2018-10-12 18:58:32.133000
# Writing to AWG Began at 2018-10-12 18:58:34.307000
# Measuring on VNA  Began at 2018-10-12 18:58:38.597000
# Measuring on Scope  Began at 2018-10-12 18:58:43.824000
# Writing to AWG Began at 2018-10-12 18:58:46.073000
# Measuring on VNA  Began at 2018-10-12 18:58:50.316000
# Measuring on Scope  Began at 2018-10-12 18:58:55.577000
# Writing to AWG Began at 2018-10-12 18:58:57.756000
# Measuring on VNA  Began at 2018-10-12 18:59:01.971000
# Measuring on Scope  Began at 2018-10-12 18:59:07.235000
# Writing to AWG Began at 2018-10-12 18:59:09.465000
# Measuring on VNA  Began at 2018-10-12 18:59:13.649000
# Measuring on Scope  Began at 2018-10-12 18:59:18.900000
# Writing to AWG Began at 2018-10-12 18:59:21.109000
# Measuring on VNA  Began at 2018-10-12 18:59:25.360000
# Measuring on Scope  Began at 2018-10-12 18:59:30.626000
# Writing to AWG Began at 2018-10-12 18:59:32.805000
# Measuring on VNA  Began at 2018-10-12 18:59:37.115000
# Measuring on Scope  Began at 2018-10-12 18:59:42.336000
# Writing to AWG Began at 2018-10-12 18:59:44.572000
# Measuring on VNA  Began at 2018-10-12 18:59:48.832000
# Measuring on Scope  Began at 2018-10-12 18:59:54.113000
# Writing to AWG Began at 2018-10-12 18:59:56.375000
# Measuring on VNA  Began at 2018-10-12 19:00:00.614000
# Measuring on Scope  Began at 2018-10-12 19:00:05.865000
# Sweep 6
# f : 1000025000.0
#  ended at 2018-10-12 19:00:05.995000
#  taking 117 seonds
# Sweep 7
# f : 1000050000.0
#  began at 2018-10-12 19:00:05.995000
# Writing to AWG Began at 2018-10-12 19:00:08.105000
# Measuring on VNA  Began at 2018-10-12 19:00:12.319000
# Measuring on Scope  Began at 2018-10-12 19:00:17.604000
# Writing to AWG Began at 2018-10-12 19:00:19.848000
# Measuring on VNA  Began at 2018-10-12 19:00:24.078000
# Measuring on Scope  Began at 2018-10-12 19:00:29.402000
# Writing to AWG Began at 2018-10-12 19:00:31.773000
# Measuring on VNA  Began at 2018-10-12 19:00:36.032000
# Measuring on Scope  Began at 2018-10-12 19:00:41.254000
# Writing to AWG Began at 2018-10-12 19:00:43.563000
# Measuring on VNA  Began at 2018-10-12 19:00:47.880000
# Measuring on Scope  Began at 2018-10-12 19:00:53.095000
# Writing to AWG Began at 2018-10-12 19:00:55.331000
# Measuring on VNA  Began at 2018-10-12 19:00:59.599000
# Measuring on Scope  Began at 2018-10-12 19:01:04.798000
# Writing to AWG Began at 2018-10-12 19:01:07.058000
# Measuring on VNA  Began at 2018-10-12 19:01:11.312000
# Measuring on Scope  Began at 2018-10-12 19:01:16.529000
# Writing to AWG Began at 2018-10-12 19:01:18.745000
# Measuring on VNA  Began at 2018-10-12 19:01:22.942000
# Measuring on Scope  Began at 2018-10-12 19:01:28.148000
# Writing to AWG Began at 2018-10-12 19:01:30.427000
# Measuring on VNA  Began at 2018-10-12 19:01:34.611000
# Measuring on Scope  Began at 2018-10-12 19:01:39.814000
# Writing to AWG Began at 2018-10-12 19:01:42.047000
# Measuring on VNA  Began at 2018-10-12 19:01:46.327000
# Measuring on Scope  Began at 2018-10-12 19:01:51.532000
# Writing to AWG Began at 2018-10-12 19:01:53.845000
# Measuring on VNA  Began at 2018-10-12 19:01:58.143000
# Measuring on Scope  Began at 2018-10-12 19:02:03.356000
# Sweep 7
# f : 1000050000.0
#  ended at 2018-10-12 19:02:03.476000
#  taking 117 seonds
# Sweep 8
# f : 1000075000.0
#  began at 2018-10-12 19:02:03.486000
# Writing to AWG Began at 2018-10-12 19:02:05.607000
# Measuring on VNA  Began at 2018-10-12 19:02:09.922000
# Measuring on Scope  Began at 2018-10-12 19:02:15.125000
# Writing to AWG Began at 2018-10-12 19:02:17.412000
# Measuring on VNA  Began at 2018-10-12 19:02:21.705000
# Measuring on Scope  Began at 2018-10-12 19:02:26.917000
# Writing to AWG Began at 2018-10-12 19:02:29.205000
# Measuring on VNA  Began at 2018-10-12 19:02:33.482000
# Measuring on Scope  Began at 2018-10-12 19:02:38.619000
# Writing to AWG Began at 2018-10-12 19:02:40.896000
# Measuring on VNA  Began at 2018-10-12 19:02:45.190000
# Measuring on Scope  Began at 2018-10-12 19:02:50.487000
# Writing to AWG Began at 2018-10-12 19:02:52.721000
# Measuring on VNA  Began at 2018-10-12 19:02:57.005000
# Measuring on Scope  Began at 2018-10-12 19:03:04.534000
# Writing to AWG Began at 2018-10-12 19:03:06.776000
# Measuring on VNA  Began at 2018-10-12 19:03:11.018000
# Measuring on Scope  Began at 2018-10-12 19:03:16.315000
# Writing to AWG Began at 2018-10-12 19:03:18.575000
# Measuring on VNA  Began at 2018-10-12 19:03:22.748000
# Measuring on Scope  Began at 2018-10-12 19:03:27.932000
# Writing to AWG Began at 2018-10-12 19:03:30.162000
# Measuring on VNA  Began at 2018-10-12 19:03:34.452000
# Measuring on Scope  Began at 2018-10-12 19:03:39.727000
# Writing to AWG Began at 2018-10-12 19:03:41.968000
# Measuring on VNA  Began at 2018-10-12 19:03:46.186000
# Measuring on Scope  Began at 2018-10-12 19:03:51.342000
# Writing to AWG Began at 2018-10-12 19:03:53.588000
# Measuring on VNA  Began at 2018-10-12 19:03:57.921000
# Measuring on Scope  Began at 2018-10-12 19:04:03.139000
# Sweep 8
# f : 1000075000.0
#  ended at 2018-10-12 19:04:03.279000
#  taking 119 seonds
# Sweep 9
# f : 1000100000.0
#  began at 2018-10-12 19:04:03.279000
# Writing to AWG Began at 2018-10-12 19:04:05.462000
# Measuring on VNA  Began at 2018-10-12 19:04:09.628000
# Measuring on Scope  Began at 2018-10-12 19:04:14.896000
# Writing to AWG Began at 2018-10-12 19:04:17.156000
# Measuring on VNA  Began at 2018-10-12 19:04:21.441000
# Measuring on Scope  Began at 2018-10-12 19:04:26.715000
# Writing to AWG Began at 2018-10-12 19:04:28.955000
# Measuring on VNA  Began at 2018-10-12 19:04:33.169000
# Measuring on Scope  Began at 2018-10-12 19:04:38.386000
# Writing to AWG Began at 2018-10-12 19:04:40.662000
# Measuring on VNA  Began at 2018-10-12 19:04:44.967000
# Measuring on Scope  Began at 2018-10-12 19:04:50.207000
# Writing to AWG Began at 2018-10-12 19:04:52.541000
# Measuring on VNA  Began at 2018-10-12 19:04:56.683000
# Measuring on Scope  Began at 2018-10-12 19:05:01.950000
# Writing to AWG Began at 2018-10-12 19:05:04.221000
# Measuring on VNA  Began at 2018-10-12 19:05:08.481000
# Measuring on Scope  Began at 2018-10-12 19:05:13.771000
# Writing to AWG Began at 2018-10-12 19:05:16.082000
# Measuring on VNA  Began at 2018-10-12 19:05:20.248000
# Measuring on Scope  Began at 2018-10-12 19:05:25.496000
# Writing to AWG Began at 2018-10-12 19:05:27.790000
# Measuring on VNA  Began at 2018-10-12 19:05:32.060000
# Measuring on Scope  Began at 2018-10-12 19:05:37.384000
# Writing to AWG Began at 2018-10-12 19:05:39.704000
# Measuring on VNA  Began at 2018-10-12 19:05:43.953000
# Measuring on Scope  Began at 2018-10-12 19:05:49.193000
# Writing to AWG Began at 2018-10-12 19:05:51.421000
# Measuring on VNA  Began at 2018-10-12 19:05:55.752000
# Measuring on Scope  Began at 2018-10-12 19:06:00.946000
# Sweep 9
# f : 1000100000.0
#  ended at 2018-10-12 19:06:01.076000
#  taking 117 seonds
# Sweep 10
# f : 1000125000.0
#  began at 2018-10-12 19:06:01.076000
# Writing to AWG Began at 2018-10-12 19:06:03.179000
# Measuring on VNA  Began at 2018-10-12 19:06:07.358000
# Measuring on Scope  Began at 2018-10-12 19:06:12.641000
# Writing to AWG Began at 2018-10-12 19:06:14.770000
# Measuring on VNA  Began at 2018-10-12 19:06:19.093000
# Measuring on Scope  Began at 2018-10-12 19:06:24.395000
# Writing to AWG Began at 2018-10-12 19:06:26.591000
# Measuring on VNA  Began at 2018-10-12 19:06:30.827000
# Measuring on Scope  Began at 2018-10-12 19:06:36.081000
# Writing to AWG Began at 2018-10-12 19:06:38.220000
# Measuring on VNA  Began at 2018-10-12 19:06:42.387000
# Measuring on Scope  Began at 2018-10-12 19:06:47.670000
# Writing to AWG Began at 2018-10-12 19:06:49.804000
# Measuring on VNA  Began at 2018-10-12 19:06:54.027000
# Measuring on Scope  Began at 2018-10-12 19:06:59.290000
# Writing to AWG Began at 2018-10-12 19:07:01.572000
# Measuring on VNA  Began at 2018-10-12 19:07:05.744000
# Measuring on Scope  Began at 2018-10-12 19:07:11.012000
# Writing to AWG Began at 2018-10-12 19:07:13.222000
# Measuring on VNA  Began at 2018-10-12 19:07:17.370000
# Measuring on Scope  Began at 2018-10-12 19:07:22.661000
# Writing to AWG Began at 2018-10-12 19:07:24.804000
# Measuring on VNA  Began at 2018-10-12 19:07:28.981000
# Measuring on Scope  Began at 2018-10-12 19:07:34.155000
# Writing to AWG Began at 2018-10-12 19:07:36.316000
# Measuring on VNA  Began at 2018-10-12 19:07:40.526000
# Measuring on Scope  Began at 2018-10-12 19:07:45.701000
# Writing to AWG Began at 2018-10-12 19:07:47.841000
# Measuring on VNA  Began at 2018-10-12 19:07:52.013000
# Measuring on Scope  Began at 2018-10-12 19:07:57.212000
# Sweep 10
# f : 1000125000.0
#  ended at 2018-10-12 19:07:57.352000
#  taking 116 seonds
