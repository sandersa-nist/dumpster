# %% [markdown]
# # A sweep of tone spacing for the AWG calibration

# %%
# import the pyMez packages default API
from pyMez import *
# import the Fitting module for Signal Generation and Fitting, note the namespace Code.Analysis.Fitting also works
from pyMez.Code.Analysis.Fitting import *
# Out:
# Importing pyMez, this should take roughly 30 seconds
# Importing Code.DataHandlers.GeneralModels
# It took 0.857 s to import Code.DataHandlers.GeneralModels
# Importing Code.DataHandlers.HTMLModels
# It took 0.13 s to import Code.DataHandlers.HTMLModels
# Importing Code.DataHandlers.NISTModels
# The module smithplot was not found,please put it on the python path
# It took 1.373 s to import Code.DataHandlers.NISTModels
# Importing Code.DataHandlers.TouchstoneModels
# The module smithplot was not found,please put it on the python path
# It took 0.02 s to import Code.DataHandlers.TouchstoneModels
# Importing Code.DataHandlers.XMLModels
# It took 0.163 s to import Code.DataHandlers.XMLModels
# Importing Code.DataHandlers.ZipModels
# It took 0.023 s to import Code.DataHandlers.ZipModels
# Importing Code.InstrumentControl.Experiments
# It took 2.794 s to import Code.InstrumentControl.Experiments
# Importing Code.InstrumentControl.Instruments
# It took 0.01 s to import Code.InstrumentControl.Instruments
# Importing Code.Utils.Names
# It took 0.01 s to import Code.Utils.Names
# It took 5.38 s to import all of the active modules

# %% [markdown]
# ## Setup Variables that do not change with tone spacing

# %%
# none of these instruments have xml instrument sheets, need to add them
psg_address="GPIB1::19"
vna_address="GPIB1::16"
awg_address="GPIB1::10"
scope_address="GPIB1::7::INSTR"
pm_address="GPIB1::13"
# ----------------------
vna=VNA(vna_address)
scope=HighSpeedOscope(scope_address)
awg=VisaInstrument(awg_address)
# ----------------


# this is local to the computer taking the data, the data should be copied to Q:\public\Aric\AWG_Phase_Calibration_20180927
data_directory=r'C:\Share\AWG_Full_Calibration_20181022\Schroeder_Phase\TBC_Scope_Measurements'
# Experimental variables

# the psg frequency acts as the master clock
psg_amplitude=12. #psg amplitude in dBm
psg_frequency=10.*10.**9 # 10 GHz
time_step=1./psg_frequency # time step for the awg
fundamental_frequency = 1.*10.**9 # Center of the passband or fundemental frequency in Hz
number_tones = 11 # Number of tones in the modulation bandwidth including the fundamental, should be odd
number_harmonics = 1# Number of harmonics to use. The frequency grid will be n*(f-df), n*f, n*(f+df), etc
# Select the phase for the multisine    
#multisine_phase="zero"
multisine_phase="schroeder"
number_envelopes=1.

# Measurement Phase Reference Setup 
round_multisine_before_writing=True # Rounds the multisine to a desired bitdepth before writing to AWG
bit_depth=8
waveform_name="Calibration_Phase_Reference" # name of the waveform to write to the 
bin_format=True # If the wave is in 16 bit bin format
marker_1=True # If marker one is to be set
marker_1_n_repeats=1 # the rep rate of the marker as a function of number of repeats per time sequence
marker_2=False
marker_2_n_repeats=1

# VNA setup 
vna_IFBW=10
comb_frequency = 2.5*10**6
number_phases=1
vna.set_IFBW(vna_IFBW)
# Out:
# The information sheet was not found defaulting to address
# The information sheet was not found defaulting to address
# The information sheet was not found defaulting to address

# %%
# Setup the traces that we might want
# Delete all of the traces that we do not need, in this case I will delete  all of them it leaves one trace
trace_string=vna.query("CALC:PAR:CAT?")
trace_list=trace_string.replace("\n","").split(",")[0::3] #remove endline, split on , and then take every third one
for trace in trace_list:
    vna.write("CALC:PAR:DEL '{0}'".format(trace))
print("Existing traces are {0}".format(vna.query("CALC:PAR:CAT?")))
# set up the traces, we use drive_port=1 sense all of the inputs are turned off, there are combs on port 2, port 3

# first we add a trace for a each reference reciever (R1=a1)
for i in range(4):
    vna.add_trace(trace_name="a{0}".format(i+1),trace_parameter="R{0}".format(i+1),drive_port=1)
# now we add a trace for each b reciever (labelled A,B,C,D)
for i,receiver in enumerate(["A","B","C","D"]):
    vna.add_trace(trace_name="b{0}".format(i+1),trace_parameter="{0}".format(receiver),drive_port=1)
    
# now we want a ratio of R1R4 (a1/a4) <- this is the calibration phase reference / measurement phase reference
vna.add_trace(trace_name="ratio",trace_parameter="R1R4",drive_port="1")
vna.add_trace(trace_name="comb_ratio",trace_parameter="a1b2",drive_port="1")
print("Existing traces are {0}".format(vna.query("CALC:PAR:CAT?")))
# Out:
# Existing traces are "a1,a1,1"
#
# Existing traces are "a1,a1,1,a2,R2,1,a3,R3,1,a4,R4,1,b1,A,1,b2,B,1,b3,C,1,b4,D,1,ratio,R1/R4,1,comb_ratio,a1/b2,1"

# %%
tone_spacings=[10*10**6,5*10**6,2.5*10**6,2.5*10**5,2.5*10**4]
comb_spacings=[10*10**6,5*10**6,2.5*10**6]

# %%
for tone_spacing in tone_spacings:
    comb_spacing=tone_spacing in comb_spacings
    print(comb_spacing)
# Out:
# True
# True
# True
# False
# False

# %%
for tone_spacing in tone_spacings:
    comb_spacing = tone_spacing in comb_spacings
    summary_data=[]
    # now calculate the frequency_list
    frequency_list=[]
    for harmonic in range(number_harmonics):
        frequency_array=np.linspace((harmonic+1)*(fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                    (harmonic+1)*(fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)
        frequency_list=frequency_list+frequency_array.tolist()
    time_max=number_envelopes/tone_spacing
    number_time_points=int(round(time_max/time_step))
    time_shift=0.*time_step
    sweep_wait_time=2.5*float(len(frequency_list))/float(vna_IFBW)
    sweep_directory=os.path.join(data_directory,"{0}_Tones_{1:.0f}KHz_Spacing".format(number_tones,10**-3*tone_spacing))
    os.mkdir(sweep_directory)
    # first create the multisine
    sine_function=FunctionalModel(parameters=["f","phi"],variables=["t"],equation="cos(2*pi*f*t+phi)")
    time_list=np.linspace(0.+time_shift,time_max+time_shift-time_step,number_time_points)

    # calculate the phases 
    phase_list = [0. for i in range(len(frequency_list))]
    if re.search("sch",multisine_phase,re.IGNORECASE):
        phase_list=[]
        for frequency_index,frequency in enumerate(frequency_list):
            k=(frequency_index+1)%number_tones
            schroeder_phase=-k*(k-1)*np.pi/number_tones
            phase_list.append(schroeder_phase)
    # initialize multisine to a set of zeros
    multisine=np.array([0 for i in range(number_time_points)])
    # add each component
    for frequency_index,frequency in enumerate(frequency_list):
        sine_function.set_parameters({"f":frequency,"phi":phase_list[frequency_index]})
        multisine_component=sine_function(time_list)
        multisine=multisine+multisine_component

    # substract the mean
    # multisine=multisine-np.mean(multisine)
    # normalize the multisine
    # multisine=1/max(multisine)*multisine

    # round the multisine to the nearest bitdepth before writing
    if round_multisine_before_writing:
        discrete_steps=np.linspace(min(multisine),max(multisine),2**bit_depth)
        rounded_multisine=[]
        int_multisine=[]
        for value in multisine:
            difference_array=abs(discrete_steps-value)
            minimum_location=np.argmin(difference_array)
            rounded_multisine.append(discrete_steps[minimum_location])
            int_multisine.append(minimum_location)
        if bin_format:
            multisine=np.array(int_multisine,dtype=np.uint16)
            # Shift, now to add the marker add + 2**14 or +2**15 at the desired location
            multisine=multisine*2**6
        else:
            multisine=rounded_multisine

    # now we add the marker. 
    if marker_1:

        distance=int(np.floor(float(len(multisine))/float(marker_1_n_repeats)))
        for i in range(marker_1_n_repeats):
            try:
                multisine[i*distance]=multisine[i*distance]+2**14
            except:
                pass
    # I am guessing that this has the possibility of kiling the oscope trigger
    if bin_format:
        # turn AWG's output 1 & 2 OFF
        awg.write(':OUTPUT1:STATE OFF')
        awg.write(':OUTPUT2:STATE OFF')
        # wait...
        time.sleep(0.1)
        # UNRUN state
        awg.write('AWGCONTROL:STOP')
        # wait...
        time.sleep(0.5)

        # delete any older waveform with the same name
        awg.write('WLISt:WAVeform:DELete "{0}"'.format(waveform_name))
        time.sleep(0.05)

        # create new waveform
        awg.write('WLISt:WAVeform:NEW "{0}", {1}, INT'.format(waveform_name,len(multisine)))
        # download data
        awg.resource.write_binary_values('WLISt:WAVeform:DATA "{0}",'.format(waveform_name), multisine, datatype='H', is_big_endian=False)
        time.sleep(.1)
        # assign new waveform to channel 1 & 2
        awg.write('SOURce1:WAVeform "{0}"'.format(waveform_name))
        awg.write('SOURce2:WAVeform "{0}"'.format(waveform_name))

        # check for errors
        error_str = awg.query('SYSTEM:ERROR:NEXT?')
        # wait...
        time.sleep(.1)
        # AWG on RUN state
        awg.write('AWGCONTROL:RUN')
        # wait...
        time.sleep(0.5)
        # check if there is any errors on AWG's buffer
        error_str = awg.query('SYSTEM:ERROR:NEXT?')
        if error_str == '0,"No error"\n':
            # turn AWG's output 1 OFF
            awg.write(':OUTPUT1:STATE ON')
            awg.write(':OUTPUT2:STATE ON')

    if number_harmonics is 1:    
        vna.set_frequency((fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                        (fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)  
    else:
        for harmonic in range(number_harmonics):
            vna.add_segment((harmonic+1)*(fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                        (harmonic+1)*(fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)
            
    #-------------------------------- Measurement of Multisine on Port 1-------------------------------
    # VNA Measurement -----------------------------------------------------
    vna.write("CALC:PAR:SEL '{0}'".format("ratio"))
    ratio_trace_string = vna.query("CALC:DATA? SDATA")
    ratio_trace = ratio_trace_string.replace("\n","").split(",")
    ratio_real = ratio_trace[0::2]
    ratio_imaginary = ratio_trace[1::2]
    complex_ratio =np.array([complex(float(real_value),
                                     float(ratio_imaginary[index])) for index,real_value in enumerate(ratio_real)])

    vna.write("CALC:PAR:SEL '{0}'".format("a1"))
    a1_trace_string = vna.query("CALC:DATA? SDATA")
    a1_trace = a1_trace_string.replace("\n","").split(",")
    a1_real = a1_trace[0::2]
    a1_imaginary = a1_trace[1::2]
    complex_a1 =np.array([complex(float(real_value),
                                     float(a1_imaginary[index])) for index,real_value in enumerate(a1_real)])

    vna.write("CALC:PAR:SEL '{0}'".format("b1"))
    b1_trace_string = vna.query("CALC:DATA? SDATA")
    b1_trace = b1_trace_string.replace("\n","").split(",")
    b1_real = b1_trace[0::2]
    b1_imaginary = b1_trace[1::2]
    complex_b1 =np.array([complex(float(real_value),
                                     float(b1_imaginary[index])) for index,real_value in enumerate(b1_real)])

    vna.write("CALC:PAR:SEL '{0}'".format("a4"))
    a4_trace_string = vna.query("CALC:DATA? SDATA")
    a4_trace = a4_trace_string.replace("\n","").split(",")
    a4_real = a4_trace[0::2]
    a4_imaginary = a4_trace[1::2]
    complex_a4 =np.array([complex(float(real_value),
                                     float(a4_imaginary[index])) for index,real_value in enumerate(a4_real)])
    # If the tone spacing is on the comb grid, we want a1/b2, b2, b3
    if comb_spacing:
        # this block should be replaced with vna.read_trace
        vna.write("CALC:PAR:SEL '{0}'".format("b2"))
        b2_trace_string = vna.query("CALC:DATA? SDATA")
        b2_trace = b2_trace_string.replace("\n","").split(",")
        b2_real = b2_trace[0::2]
        b2_imaginary = b2_trace[1::2]
        complex_b2 =np.array([complex(float(real_value),
                                         float(b2_imaginary[index])) for index,real_value in enumerate(b2_real)])                

        vna.write("CALC:PAR:SEL '{0}'".format("b3"))
        b3_trace_string = vna.query("CALC:DATA? SDATA")
        b3_trace = b3_trace_string.replace("\n","").split(",")
        b3_real = b3_trace[0::2]
        b3_imaginary = b3_trace[1::2]
        complex_b3 =np.array([complex(float(real_value),
                                         float(b3_imaginary[index])) for index,real_value in enumerate(b3_real)])                

        vna.write("CALC:PAR:SEL '{0}'".format("comb_ratio"))
        comb_ratio_trace_string = vna.query("CALC:DATA? SDATA")
        comb_ratio_trace = comb_ratio_trace_string.replace("\n","").split(",")
        comb_ratio_real = comb_ratio_trace[0::2]
        comb_ratio_imaginary = comb_ratio_trace[1::2]
        complex_comb_ratio =np.array([complex(float(real_value),
                                         float(comb_ratio_imaginary[index])) for index,real_value in enumerate(comb_ratio_real)])                


        vna_data=[map(lambda x:float(x),[frequency_list[index],
                   real_value,
                   ratio_imaginary[index],
                   a1_real[index],a1_imaginary[index],
                   b1_real[index],b1_imaginary[index],                      
                   a4_real[index],a4_imaginary[index],
                   comb_ratio_real[index],comb_ratio_imaginary[index],
                   b2_real[index],b2_imaginary[index],
                   b3_real[index],b3_imaginary[index]]) for index,real_value in enumerate(ratio_real)]


        column_names=["Frequency",
                                 "reA1_Div_A4","imA1_Div_A4",
                                 "reA1","imA1","reB1","imB1",
                                 "reA4","imA4",
                                 "reA1_Div_B2","imA1_Div_B2",
                                 "reB2","imB2","reB3","imB3"]
        options={"column_names":column_names,
                 "column_types":["float" for i in range(len(column_names))],
                 "directory":sweep_directory,"specific_descriptor":waveform_name,
                 "general_descriptor":"Vna_Reciever_Values","extension":"txt","data":vna_data}                    
    else:

        vna_data=[map(lambda x:float(x),[frequency_list[index],
                   real_value,
                   ratio_imaginary[index],
                   a1_real[index],a1_imaginary[index],
                   b1_real[index],b1_imaginary[index],                      
                   a4_real[index],a4_imaginary[index]]) for index,real_value in enumerate(ratio_real)]

        column_names=["Frequency","reA1_Div_A4","imA1_Div_A4",
                      "reA1","imA1","reB1","imB1","reA4","imA4"]

        options={"column_names":column_names,
                 "column_types":["float" for i in range(len(column_names))],
                 "directory":sweep_directory,"specific_descriptor":waveform_name,
                 "general_descriptor":"Vna_Reciever_Values","extension":"txt","data":vna_data}

    ratio_data_table=AsciiDataTable(None,**options)
    ratio_data_table.save()
    ratio_data_table.save_schema(change_extension(ratio_data_table.path,new_extension="schema"))
  # Scope Measurement --------------------------------------------------------------------------          
    number_frames=int(np.ceil(4/(tone_spacing*10*32.768*10-9)))
    scope.set_number_points()
    wave_trace=scope.measure_waves(number_frames=number_frames,timebase_scale=32.768)
    wave_trace.options["metadata"]=scope.measure_options
    wave_trace.save(os.path.join(sweep_directory,"{0}_Scope_Measurement.txt".format(waveform_name)))
    wave_trace.save_schema(change_extension(wave_trace.path,new_extension="schema"))
    plt.close()            
    plt.plot(wave_trace["Time"],wave_trace["CHAN2"],label="SUT")
    plt.plot(wave_trace["Time"],wave_trace["CHAN3"],label="I")
    plt.plot(wave_trace["Time"],wave_trace["CHAN4"],label="Q")
    plt.legend()
    plt.savefig(os.path.join(sweep_directory,"Scope_{0}.png".format(waveform_name)))
  # ----------------------------------------------------------------------------------------------------  
    
    
    
    
    

    single_cosine=FunctionalModel(variables=["t"],parameters=["f","phi"],equation="cos(2*pi*f*t+phi)")

    phase_sweep_list=[2*np.pi*i/number_phases for i in range(number_phases)]
    # Loop to measure the phase
    start_timer=datetime.datetime.now()
    print("Calibration Began at {0}".format(start_timer))
    for frequency_index,frequency in enumerate(frequency_list[:]):
        begin_sweep_timer=datetime.datetime.now()
        print("Sweep {0} \nf : {1}\n began at {2} ".format(frequency_index,frequency,begin_sweep_timer))
        for phase_index,phase in enumerate(phase_sweep_list):

             #create the sine to write
            # ----------------------------------------------------------------------------------------------------------
            single_cosine.set_parameters({"f":frequency,"phi":phase})
            tone_data=single_cosine(time_list)

            # round the multisine to the nearest bitdepth before writing
            if round_multisine_before_writing:
                discrete_steps=np.linspace(min(tone_data),max(tone_data),2**bit_depth)
                rounded_tone_data=[]
                int_tone_data=[]
                for value in tone_data:
                    difference_array=abs(discrete_steps-value)
                    minimum_location=np.argmin(difference_array)
                    rounded_tone_data.append(discrete_steps[minimum_location])
                    int_tone_data.append(minimum_location)
                if bin_format:
                    tone_data=np.array(int_tone_data,dtype=np.uint16)
                    # Shift, now to add the marker add + 2**14 or +2**15 at the desired location
                    tone_data=tone_data*2**6
                else:
                    tone_data=rounded_tone_data

            timer=datetime.datetime.now()
            print("Writing to AWG Began at {0} ".format(timer))
            # write tone to AWG
            # --------------------------------------------------------
            tone_waveform_name="Tone_{0}_Phase_{1:03.0f}_Calibration".format(frequency_index,phase*180/np.pi)
            # save the wave for good measure
            out_file=open(os.path.join(sweep_directory,"{0}.bin".format(tone_waveform_name)),"wb")
            out_file.write(tone_data)
            out_file.close()
            # plot 
            plt.close()
            plt.plot(time_list,tone_data)
            plt.xlabel("Time (s)")
            plt.ylabel("Amplitude (arb)")
            plt.title(tone_waveform_name)
            plt.savefig(os.path.join(sweep_directory,"{0}.png".format(tone_waveform_name)))
            #plt.show();

            if bin_format:
                # turn AWG's output 1 
                awg.write(':OUTPUT1:STATE OFF')
                time.sleep(0.1)
                # UNRUN state
                awg.write('AWGCONTROL:STOP')
                # wait...
                time.sleep(0.5)

                # delete any older waveform with the same name
                awg.write('WLISt:WAVeform:DELete "{0}"'.format(tone_waveform_name))
                time.sleep(0.05)

                # create new waveform
                awg.write('WLISt:WAVeform:NEW "{0}", {1}, INT'.format(tone_waveform_name,len(tone_data)))
                # download data
                awg.resource.write_binary_values('WLISt:WAVeform:DATA "{0}",'.format(tone_waveform_name), 
                                                 tone_data, datatype='H', is_big_endian=False)
                time.sleep(0.1)
                # assign new waveform to channel 1 
                awg.write('SOURce1:WAVeform "{0}"'.format(tone_waveform_name))


                # check for errors
                error_str = awg.query('SYSTEM:ERROR:NEXT?')
                # wait...
                time.sleep(.1)
                # AWG on RUN state
                awg.write('AWGCONTROL:RUN')
                # wait...
                time.sleep(0.5)
                # check if there is any errors on AWG's buffer
                error_str = awg.query('SYSTEM:ERROR:NEXT?')
                if error_str == '0,"No error"\n':
                    # turn AWG's output 1 ON
                    awg.write(':OUTPUT1:STATE ON')
                    
            timer=datetime.datetime.now()
            print("Measuring on VNA  Began at {0} ".format(timer))                
            # Measure on VNA
            # ---------------------------------------------------------------------------------------------------------
            # now the measured trace should be the multisine we can trigger and display the ratio to be sure
            vna.trigger_sweep()
            time.sleep(sweep_wait_time)
            # read_trace needs to have some work
            # Here we read a1/a4, a1, a4
            #------------------------------------------------------------------------------------
            vna.write("CALC:PAR:SEL '{0}'".format("ratio"))
            ratio_trace_string = vna.query("CALC:DATA? SDATA")
            ratio_trace = ratio_trace_string.replace("\n","").split(",")
            ratio_real = ratio_trace[0::2]
            ratio_imaginary = ratio_trace[1::2]
            complex_ratio =np.array([complex(float(real_value),
                                             float(ratio_imaginary[index])) for index,real_value in enumerate(ratio_real)])

            vna.write("CALC:PAR:SEL '{0}'".format("a1"))
            a1_trace_string = vna.query("CALC:DATA? SDATA")
            a1_trace = a1_trace_string.replace("\n","").split(",")
            a1_real = a1_trace[0::2]
            a1_imaginary = a1_trace[1::2]
            complex_a1 =np.array([complex(float(real_value),
                                             float(a1_imaginary[index])) for index,real_value in enumerate(a1_real)])
            
            vna.write("CALC:PAR:SEL '{0}'".format("b1"))
            b1_trace_string = vna.query("CALC:DATA? SDATA")
            b1_trace = b1_trace_string.replace("\n","").split(",")
            b1_real = b1_trace[0::2]
            b1_imaginary = b1_trace[1::2]
            complex_b1 =np.array([complex(float(real_value),
                                             float(b1_imaginary[index])) for index,real_value in enumerate(b1_real)])

            vna.write("CALC:PAR:SEL '{0}'".format("a4"))
            a4_trace_string = vna.query("CALC:DATA? SDATA")
            a4_trace = a4_trace_string.replace("\n","").split(",")
            a4_real = a4_trace[0::2]
            a4_imaginary = a4_trace[1::2]
            complex_a4 =np.array([complex(float(real_value),
                                             float(a4_imaginary[index])) for index,real_value in enumerate(a4_real)])
            # If the tone spacing is on the comb grid, we want a1/b2, b2, b3
            if comb_spacing:
                # this block should be replaced with vna.read_trace
                vna.write("CALC:PAR:SEL '{0}'".format("b2"))
                b2_trace_string = vna.query("CALC:DATA? SDATA")
                b2_trace = b2_trace_string.replace("\n","").split(",")
                b2_real = b2_trace[0::2]
                b2_imaginary = b2_trace[1::2]
                complex_b2 =np.array([complex(float(real_value),
                                                 float(b2_imaginary[index])) for index,real_value in enumerate(b2_real)])                

                vna.write("CALC:PAR:SEL '{0}'".format("b3"))
                b3_trace_string = vna.query("CALC:DATA? SDATA")
                b3_trace = b3_trace_string.replace("\n","").split(",")
                b3_real = b3_trace[0::2]
                b3_imaginary = b3_trace[1::2]
                complex_b3 =np.array([complex(float(real_value),
                                                 float(b3_imaginary[index])) for index,real_value in enumerate(b3_real)])                
                             
                vna.write("CALC:PAR:SEL '{0}'".format("comb_ratio"))
                comb_ratio_trace_string = vna.query("CALC:DATA? SDATA")
                comb_ratio_trace = comb_ratio_trace_string.replace("\n","").split(",")
                comb_ratio_real = comb_ratio_trace[0::2]
                comb_ratio_imaginary = comb_ratio_trace[1::2]
                complex_comb_ratio =np.array([complex(float(real_value),
                                                 float(comb_ratio_imaginary[index])) for index,real_value in enumerate(comb_ratio_real)])                
                             

                vna_data=[map(lambda x:float(x),[frequency_list[index],
                           real_value,
                           ratio_imaginary[index],
                           a1_real[index],a1_imaginary[index],
                           b1_real[index],b1_imaginary[index],                      
                           a4_real[index],a4_imaginary[index],
                           comb_ratio_real[index],comb_ratio_imaginary[index],
                           b2_real[index],b2_imaginary[index],
                           b3_real[index],b3_imaginary[index]]) for index,real_value in enumerate(ratio_real)]
                
                
                column_names=["Frequency","reA1_Div_A4","imA1_Div_A4",
                                         "reA1","imA1","reB1","imB1",
                                         "reA4","imA4",
                                         "reA1_Div_B2","imA1_Div_B2",
                                         "reB2","imB2","reB3","imB3"]
            
                print("len({0}) is {1}".format("vna_data",len(vna_data)))
                print("len({0}) is {1}".format("column_names",len(column_names)))
                print("len({0}) is {1}".format("['float' for i in range(len(column_names))]",
                                               len(["float" for i in range(len(column_names))])))
                options={"column_names":column_names,
                         "column_types":["float" for i in range(len(column_names))],
                         "directory":sweep_directory,"specific_descriptor":tone_waveform_name,
                         "general_descriptor":"Vna_Reciever_Values","extension":"txt","data":vna_data}                    
            else:
                
                vna_data=[map(lambda x:float(x),[frequency_list[index],
                           real_value,
                           ratio_imaginary[index],
                           a1_real[index],a1_imaginary[index],
                           b1_real[index],b1_imaginary[index],                      
                           a4_real[index],a4_imaginary[index]]) for index,real_value in enumerate(ratio_real)]
                
                column_names=["Frequency","reA1_Div_A4","imA1_Div_A4",
                              "reA1","imA1","reB1","imB1","reA4","imA4"]
                
                options={"column_names":column_names,
                         "column_types":["float" for i in range(len(column_names))],
                         "directory":sweep_directory,"specific_descriptor":tone_waveform_name,
                         "general_descriptor":"Vna_Reciever_Values","extension":"txt","data":vna_data}
                
            ratio_data_table=AsciiDataTable(None,**options)
            ratio_data_table.save()
            ratio_data_table.save_schema(change_extension(ratio_data_table.path,new_extension="schema"))
            plt.close()
            plt.plot(frequency_list,abs(complex_ratio),'b-o')
            plt.xlabel("Frequency (Hz)")
            plt.ylabel("Linear Magnitude")
            plt.title("Magnitude Measured on VNA")
            plt.savefig(os.path.join(sweep_directory,"Magnitude_Plot_Ratio_{0}.png".format(tone_waveform_name)))
            #plt.show();
            plt.close()
            plt.plot(np.array(frequency_list),np.angle(complex_ratio,deg=1),"b-o")
            plt.xlabel("Frequency(Hz)")
            plt.ylabel("Phase (Degrees)")
            plt.title("Phase Measured on VNA")
            plt.savefig(os.path.join(sweep_directory,"Phase_Plot_Ratio_{0}.png".format(tone_waveform_name)))
            #plt.show();
            timer=datetime.datetime.now()
            print("Measuring on Scope  Began at {0} ".format(timer))
            time.sleep(.1)
            # Measure on Oscope
            # ---------------------------------------------------------------------------------------------------------
            wave_trace=scope.measure_waves(number_frames=1)
            time.sleep(.1)
            plt.close()            
            plt.plot(wave_trace["Time"],wave_trace["CHAN2"],label="SUT")
            plt.plot(wave_trace["Time"],wave_trace["CHAN3"],label="I")
            plt.plot(wave_trace["Time"],wave_trace["CHAN4"],label="Q")
            plt.legend()
            plt.savefig(os.path.join(sweep_directory,"Scope_{0}.png".format(tone_waveform_name)))
            #plt.show();
            fit_cosine=FunctionalModel(variables=["t"],parameters=["A","phi"],equation="A*cos(2*pi*t*{0}+phi)".format(frequency))
            x_data=10**-9*np.array(map(lambda x:float(x),wave_trace["Time"]))
            y_data=np.array(map(lambda x:float(x),wave_trace["CHAN2"]))
            fit_cosine.fit_data(x_data=x_data,y_data=y_data)
            plt.close()
            plt.plot(x_data,fit_cosine(x_data),label="Fit")
            plt.plot(x_data,y_data,label="CHAN2")
            fit_parameters=fit_cosine.parameter_values
            plt.title("Amplitude: {A} Phase: {phi}".format(**fit_parameters))
            plt.legend()
            plt.savefig(os.path.join(sweep_directory,"Scope_Fit_{0}.png".format(tone_waveform_name)))
            #plt.show();
            wave_trace.options["fit_equation"]="{0}".format(fit_cosine)
            wave_trace.options["fit_parameters"]=fit_parameters
            wave_trace.save(os.path.join(sweep_directory,"{0}_Scope_Measurement.txt".format(tone_waveform_name)))
            wave_trace.save_schema(change_extension(wave_trace.path,new_extension="schema"))

            
            # Calculate the Summary Row, A table of Tone Index, Frequency, AWG Set Amplitude, AWG Set Phase, Scope Measured Amp
            # Scope MEasured Phase, VNA Measured Amp, VNA Measured Phase and optional values if comb_spacing
            tone_index=frequency_index+1 # starts at 1
            summary_frequency=frequency  # I know it is not needed just a reminder
            AWG_set_amplitude = .5 # set by the awg after the write of the binary wave
            AWG_set_phase=phase*180/np.pi 
            scope_measured_amplitude=fit_parameters["A"]
            scope_measured_phase=fit_parameters["phi"]*180/np.pi 
            vna_measured_amplitude=abs(complex_ratio[frequency_index])
            vna_measured_phase=np.angle(complex_ratio[frequency_index],deg=True)
            if comb_spacing:
                vna_measured_amplitude_comb=abs(complex_comb_ratio[frequency_index])
                vna_measured_phase_comb=np.angle(complex_comb_ratio[frequency_index],deg=True)
                summary_row=[tone_index,summary_frequency,
                             AWG_set_amplitude,AWG_set_phase,
                             scope_measured_amplitude,scope_measured_phase,
                             vna_measured_amplitude,vna_measured_phase,
                            vna_measured_amplitude_comb,vna_measured_phase_comb]
            else:
                summary_row=[tone_index,summary_frequency,
                                 AWG_set_amplitude,AWG_set_phase,
                                 scope_measured_amplitude,scope_measured_phase,
                                 vna_measured_amplitude,vna_measured_phase]
            # Delete last waveform
            if phase_index>0:
                awg.write('WLISt:WAVeform:DELete "{0}"'.format(last_waveform_name))
            last_waveform_name=tone_waveform_name
            summary_data.append(summary_row)
            
        if comb_spacing:
            summary_column_names=["Tone","Frequency","AWG_Set_Amplitude","AWG_Set_Phase",
                                  "Scope_Amplitude","Scope_Phase","Vna_Amplitude","Vna_Phase",
                                  "Vna_Comb_Referenced_Amplitude","Vna_Comb_Referenced_Phase"]
            summary_column_units=[None,"Hz","Volts","Degrees",
                                  "Volts","Degrees",
                                  "Volts","Degrees",
                                  "Volts","Degrees"]
        else:
            summary_column_names=["Tone","Frequency","AWG_Set_Amplitude","AWG_Set_Phase",
                                  "Scope_Amplitude","Scope_Phase","Vna_Amplitude","Vna_Phase"]
            summary_column_units=[None,"Hz","Volts","Degrees",
                                  "Volts","Degrees",
                                  "Volts","Degrees"]
            
        summary_options={"column_names":summary_column_names,
                         "column_types":["float" for i in range(len(summary_column_names))],
                         "column_units":summary_column_units,
                         "directory":sweep_directory,
                         "specific_descriptor":"{0}_Tones_{1:05.0f}KHz_Spacing".format(number_tones,10**3*tone_spacing),
                         "general_descriptor":"Summary","extension":"txt","data":summary_data,
                         "metadata":{"Timestamp":"{0}".format(datetime.datetime.now()),
                                     "sweep":"{0}_Tones_{1:05.0f}KHz_Spacing".format(number_tones,10**3*tone_spacing),
                                    "tone_spacing":tone_spacing,"number_tones":number_tones,
                                     "multisine_phase":multisine_phase,"number_harmonics":number_harmonics,
                                    "frequnecy_list":frequency_list}} 
        summary_table=AsciiDataTable(None,**summary_options)
        summary_table.save()
        summary_table.save_schema(change_extension(summary_table.path,new_extension="schema"))
        end_sweep_timer=datetime.datetime.now()
        difference=end_sweep_timer-begin_sweep_timer
        print("Sweep {0} \nf : {1}\n ended at {2}\n taking {3} seonds ".format(frequency_index,
                                                                               frequency,
                                                                               end_sweep_timer,
                                                                               difference.seconds))
# Out:
# Calibration Began at 2018-10-22 13:37:18.357000
# Sweep 0
# f : 950000000.0
#  began at 2018-10-22 13:37:18.357000
# Writing to AWG Began at 2018-10-22 13:37:18.367000
# Measuring on VNA  Began at 2018-10-22 13:37:20.410000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:37:25.710000
# Writing to AWG Began at 2018-10-22 13:37:30.040000
# Measuring on VNA  Began at 2018-10-22 13:37:32.053000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:37:37.273000
# Writing to AWG Began at 2018-10-22 13:37:41.554000
# Measuring on VNA  Began at 2018-10-22 13:37:43.624000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:37:48.949000
# Writing to AWG Began at 2018-10-22 13:37:53.257000
# Measuring on VNA  Began at 2018-10-22 13:37:55.301000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:38:00.531000
# Writing to AWG Began at 2018-10-22 13:38:04.916000
# Measuring on VNA  Began at 2018-10-22 13:38:06.965000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:38:12.283000
# Writing to AWG Began at 2018-10-22 13:38:16.769000
# Measuring on VNA  Began at 2018-10-22 13:38:18.802000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:38:24.096000
# Writing to AWG Began at 2018-10-22 13:38:28.545000
# Measuring on VNA  Began at 2018-10-22 13:38:30.789000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:38:36.053000
# Writing to AWG Began at 2018-10-22 13:38:40.455000
# Measuring on VNA  Began at 2018-10-22 13:38:42.485000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:38:47.800000
# Writing to AWG Began at 2018-10-22 13:38:52.349000
# Measuring on VNA  Began at 2018-10-22 13:38:54.406000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:38:59.650000
# Writing to AWG Began at 2018-10-22 13:39:04.146000
# Measuring on VNA  Began at 2018-10-22 13:39:06.207000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:39:11.468000
# Sweep 0
# f : 950000000.0
#  ended at 2018-10-22 13:39:15.881000
#  taking 117 seonds
# Sweep 1
# f : 960000000.0
#  began at 2018-10-22 13:39:15.881000
# Writing to AWG Began at 2018-10-22 13:39:15.891000
# Measuring on VNA  Began at 2018-10-22 13:39:17.934000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:39:23.212000
# Writing to AWG Began at 2018-10-22 13:39:27.765000
# Measuring on VNA  Began at 2018-10-22 13:39:29.799000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:39:35.148000
# Writing to AWG Began at 2018-10-22 13:39:39.671000
# Measuring on VNA  Began at 2018-10-22 13:39:41.704000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:39:47.015000
# Writing to AWG Began at 2018-10-22 13:39:51.464000
# Measuring on VNA  Began at 2018-10-22 13:39:53.526000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:39:58.846000
# Writing to AWG Began at 2018-10-22 13:40:03.379000
# Measuring on VNA  Began at 2018-10-22 13:40:05.410000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:40:10.704000
# Writing to AWG Began at 2018-10-22 13:40:15.141000
# Measuring on VNA  Began at 2018-10-22 13:40:17.190000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:40:22.455000
# Writing to AWG Began at 2018-10-22 13:40:26.955000
# Measuring on VNA  Began at 2018-10-22 13:40:28.996000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:40:34.223000
# Writing to AWG Began at 2018-10-22 13:40:38.617000
# Measuring on VNA  Began at 2018-10-22 13:40:40.688000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:40:45.994000
# Writing to AWG Began at 2018-10-22 13:40:50.591000
# Measuring on VNA  Began at 2018-10-22 13:40:52.685000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:40:58.030000
# Writing to AWG Began at 2018-10-22 13:41:02.562000
# Measuring on VNA  Began at 2018-10-22 13:41:04.641000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:41:09.948000
# Sweep 1
# f : 960000000.0
#  ended at 2018-10-22 13:41:14.582000
#  taking 118 seonds
# Sweep 2
# f : 970000000.0
#  began at 2018-10-22 13:41:14.582000
# Writing to AWG Began at 2018-10-22 13:41:14.592000
# Measuring on VNA  Began at 2018-10-22 13:41:16.675000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:41:21.982000
# Writing to AWG Began at 2018-10-22 13:41:26.362000
# Measuring on VNA  Began at 2018-10-22 13:41:28.400000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:41:33.684000
# Writing to AWG Began at 2018-10-22 13:41:38.096000
# Measuring on VNA  Began at 2018-10-22 13:41:40.173000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:41:45.526000
# Writing to AWG Began at 2018-10-22 13:41:50.126000
# Measuring on VNA  Began at 2018-10-22 13:41:52.185000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:41:57.454000
# Writing to AWG Began at 2018-10-22 13:42:01.934000
# Measuring on VNA  Began at 2018-10-22 13:42:03.937000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:42:09.187000
# Writing to AWG Began at 2018-10-22 13:42:13.840000
# Measuring on VNA  Began at 2018-10-22 13:42:15.907000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:42:21.254000
# Writing to AWG Began at 2018-10-22 13:42:25.654000
# Measuring on VNA  Began at 2018-10-22 13:42:27.705000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:42:32.996000
# Writing to AWG Began at 2018-10-22 13:42:37.430000
# Measuring on VNA  Began at 2018-10-22 13:42:39.439000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:42:44.717000
# Writing to AWG Began at 2018-10-22 13:42:49.323000
# Measuring on VNA  Began at 2018-10-22 13:42:51.388000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:42:56.679000
# Writing to AWG Began at 2018-10-22 13:43:01.079000
# Measuring on VNA  Began at 2018-10-22 13:43:03.169000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:43:08.459000
# Sweep 2
# f : 970000000.0
#  ended at 2018-10-22 13:43:13.066000
#  taking 118 seonds
# Sweep 3
# f : 980000000.0
#  began at 2018-10-22 13:43:13.076000
# Writing to AWG Began at 2018-10-22 13:43:13.086000
# Measuring on VNA  Began at 2018-10-22 13:43:15.403000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:43:20.679000
# Writing to AWG Began at 2018-10-22 13:43:25.103000
# Measuring on VNA  Began at 2018-10-22 13:43:27.170000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:43:32.478000
# Writing to AWG Began at 2018-10-22 13:43:36.847000
# Measuring on VNA  Began at 2018-10-22 13:43:38.890000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:43:44.193000
# Writing to AWG Began at 2018-10-22 13:43:48.930000
# Measuring on VNA  Began at 2018-10-22 13:43:50.969000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:43:56.278000
# Writing to AWG Began at 2018-10-22 13:44:00.704000
# Measuring on VNA  Began at 2018-10-22 13:44:02.749000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:44:08.061000
# Writing to AWG Began at 2018-10-22 13:44:12.608000
# Measuring on VNA  Began at 2018-10-22 13:44:14.688000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:44:20.015000
# Writing to AWG Began at 2018-10-22 13:44:24.495000
# Measuring on VNA  Began at 2018-10-22 13:44:26.858000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:44:32.216000
# Writing to AWG Began at 2018-10-22 13:44:36.600000
# Measuring on VNA  Began at 2018-10-22 13:44:38.715000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:44:43.962000
# Writing to AWG Began at 2018-10-22 13:44:48.349000
# Measuring on VNA  Began at 2018-10-22 13:44:50.405000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:44:55.708000
# Writing to AWG Began at 2018-10-22 13:45:00.169000
# Measuring on VNA  Began at 2018-10-22 13:45:02.230000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:45:07.466000
# Sweep 3
# f : 980000000.0
#  ended at 2018-10-22 13:45:12.177000
#  taking 119 seonds
# Sweep 4
# f : 990000000.0
#  began at 2018-10-22 13:45:12.177000
# Writing to AWG Began at 2018-10-22 13:45:12.187000
# Measuring on VNA  Began at 2018-10-22 13:45:14.236000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:45:19.566000
# Writing to AWG Began at 2018-10-22 13:45:24.044000
# Measuring on VNA  Began at 2018-10-22 13:45:26.088000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:45:31.310000
# Writing to AWG Began at 2018-10-22 13:45:35.797000
# Measuring on VNA  Began at 2018-10-22 13:45:37.844000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:45:43.168000
# Writing to AWG Began at 2018-10-22 13:45:47.909000
# Measuring on VNA  Began at 2018-10-22 13:45:49.951000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:45:55.177000
# Writing to AWG Began at 2018-10-22 13:45:59.746000
# Measuring on VNA  Began at 2018-10-22 13:46:01.782000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:46:07.074000
# Writing to AWG Began at 2018-10-22 13:46:11.612000
# Measuring on VNA  Began at 2018-10-22 13:46:13.685000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:46:18.906000
# Writing to AWG Began at 2018-10-22 13:46:23.433000
# Measuring on VNA  Began at 2018-10-22 13:46:25.510000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:46:30.816000
# Writing to AWG Began at 2018-10-22 13:46:35.694000
# Measuring on VNA  Began at 2018-10-22 13:46:37.728000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:46:43.024000
# Writing to AWG Began at 2018-10-22 13:46:47.544000
# Measuring on VNA  Began at 2018-10-22 13:46:49.546000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:46:54.850000
# Writing to AWG Began at 2018-10-22 13:46:59.257000
# Measuring on VNA  Began at 2018-10-22 13:47:01.307000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:47:06.572000
# Sweep 4
# f : 990000000.0
#  ended at 2018-10-22 13:47:11.054000
#  taking 118 seonds
# Sweep 5
# f : 1000000000.0
#  began at 2018-10-22 13:47:11.054000
# Writing to AWG Began at 2018-10-22 13:47:11.074000
# Measuring on VNA  Began at 2018-10-22 13:47:13.164000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:47:18.488000
# Writing to AWG Began at 2018-10-22 13:47:23.381000
# Measuring on VNA  Began at 2018-10-22 13:47:25.401000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:47:30.690000
# Writing to AWG Began at 2018-10-22 13:47:35.212000
# Measuring on VNA  Began at 2018-10-22 13:47:37.226000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:47:42.553000
# Writing to AWG Began at 2018-10-22 13:47:47.098000
# Measuring on VNA  Began at 2018-10-22 13:47:49.179000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:47:54.507000
# Writing to AWG Began at 2018-10-22 13:47:59.012000
# Measuring on VNA  Began at 2018-10-22 13:48:01.087000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:48:06.361000
# Writing to AWG Began at 2018-10-22 13:48:10.836000
# Measuring on VNA  Began at 2018-10-22 13:48:12.880000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:48:18.180000
# Writing to AWG Began at 2018-10-22 13:48:23.080000
# Measuring on VNA  Began at 2018-10-22 13:48:25.163000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:48:30.411000
# Writing to AWG Began at 2018-10-22 13:48:35.035000
# Measuring on VNA  Began at 2018-10-22 13:48:37.098000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:48:42.425000
# Writing to AWG Began at 2018-10-22 13:48:47.064000
# Measuring on VNA  Began at 2018-10-22 13:48:49.117000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:48:54.430000
# Writing to AWG Began at 2018-10-22 13:48:59.073000
# Measuring on VNA  Began at 2018-10-22 13:49:01.119000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:49:06.432000
# Sweep 5
# f : 1000000000.0
#  ended at 2018-10-22 13:49:11.461000
#  taking 120 seonds
# Sweep 6
# f : 1010000000.0
#  began at 2018-10-22 13:49:11.461000
# Writing to AWG Began at 2018-10-22 13:49:11.471000
# Measuring on VNA  Began at 2018-10-22 13:49:13.523000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:49:18.833000
# Writing to AWG Began at 2018-10-22 13:49:23.384000
# Measuring on VNA  Began at 2018-10-22 13:49:25.426000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:49:30.729000
# Writing to AWG Began at 2018-10-22 13:49:35.193000
# Measuring on VNA  Began at 2018-10-22 13:49:37.246000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:49:42.540000
# Writing to AWG Began at 2018-10-22 13:49:47.086000
# Measuring on VNA  Began at 2018-10-22 13:49:49.161000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:49:54.423000
# Writing to AWG Began at 2018-10-22 13:49:58.982000
# Measuring on VNA  Began at 2018-10-22 13:50:01.008000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:50:06.354000
# Writing to AWG Began at 2018-10-22 13:50:11.415000
# Measuring on VNA  Began at 2018-10-22 13:50:13.442000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:50:18.744000
# Writing to AWG Began at 2018-10-22 13:50:23.339000
# Measuring on VNA  Began at 2018-10-22 13:50:25.402000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:50:30.694000
# Writing to AWG Began at 2018-10-22 13:50:35.404000
# Measuring on VNA  Began at 2018-10-22 13:50:37.463000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:50:42.752000
# Writing to AWG Began at 2018-10-22 13:50:47.300000
# Measuring on VNA  Began at 2018-10-22 13:50:49.352000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:50:54.669000
# Writing to AWG Began at 2018-10-22 13:50:59.222000
# Measuring on VNA  Began at 2018-10-22 13:51:01.272000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:51:06.544000
# Sweep 6
# f : 1010000000.0
#  ended at 2018-10-22 13:51:11.094000
#  taking 119 seonds
# Sweep 7
# f : 1020000000.0
#  began at 2018-10-22 13:51:11.094000
# Writing to AWG Began at 2018-10-22 13:51:11.104000
# Measuring on VNA  Began at 2018-10-22 13:51:13.160000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:51:19.103000
# Writing to AWG Began at 2018-10-22 13:51:23.654000
# Measuring on VNA  Began at 2018-10-22 13:51:25.707000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:51:31.046000
# Writing to AWG Began at 2018-10-22 13:51:35.620000
# Measuring on VNA  Began at 2018-10-22 13:51:37.675000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:51:43.005000
# Writing to AWG Began at 2018-10-22 13:51:47.680000
# Measuring on VNA  Began at 2018-10-22 13:51:49.727000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:51:55.014000
# Writing to AWG Began at 2018-10-22 13:51:59.731000
# Measuring on VNA  Began at 2018-10-22 13:52:01.785000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:52:07.088000
# Writing to AWG Began at 2018-10-22 13:52:11.720000
# Measuring on VNA  Began at 2018-10-22 13:52:13.759000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:52:19.073000
# Writing to AWG Began at 2018-10-22 13:52:24.283000
# Measuring on VNA  Began at 2018-10-22 13:52:26.321000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:52:31.626000
# Writing to AWG Began at 2018-10-22 13:52:36.223000
# Measuring on VNA  Began at 2018-10-22 13:52:38.286000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:52:43.617000
# Writing to AWG Began at 2018-10-22 13:52:48.250000
# Measuring on VNA  Began at 2018-10-22 13:52:50.284000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:52:55.598000
# Writing to AWG Began at 2018-10-22 13:53:00.215000
# Measuring on VNA  Began at 2018-10-22 13:53:02.274000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:53:07.506000
# Sweep 7
# f : 1020000000.0
#  ended at 2018-10-22 13:53:12.130000
#  taking 121 seonds
# Sweep 8
# f : 1030000000.0
#  began at 2018-10-22 13:53:12.130000
# Writing to AWG Began at 2018-10-22 13:53:12.140000
# Measuring on VNA  Began at 2018-10-22 13:53:14.194000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:53:19.458000
# Writing to AWG Began at 2018-10-22 13:53:24.333000
# Measuring on VNA  Began at 2018-10-22 13:53:26.394000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:53:31.742000
# Writing to AWG Began at 2018-10-22 13:53:37.005000
# Measuring on VNA  Began at 2018-10-22 13:53:39.039000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:53:44.359000
# Writing to AWG Began at 2018-10-22 13:53:48.992000
# Measuring on VNA  Began at 2018-10-22 13:53:51.005000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:53:56.316000
# Writing to AWG Began at 2018-10-22 13:54:00.881000
# Measuring on VNA  Began at 2018-10-22 13:54:02.930000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:54:08.216000
# Writing to AWG Began at 2018-10-22 13:54:12.764000
# Measuring on VNA  Began at 2018-10-22 13:54:14.783000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:54:20.093000
# Writing to AWG Began at 2018-10-22 13:54:24.783000
# Measuring on VNA  Began at 2018-10-22 13:54:26.814000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:54:32.180000
# Writing to AWG Began at 2018-10-22 13:54:36.788000
# Measuring on VNA  Began at 2018-10-22 13:54:38.826000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:54:44.150000
# Writing to AWG Began at 2018-10-22 13:54:48.734000
# Measuring on VNA  Began at 2018-10-22 13:54:51.394000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:54:56.717000
# Writing to AWG Began at 2018-10-22 13:55:01.325000
# Measuring on VNA  Began at 2018-10-22 13:55:03.396000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:55:08.690000
# Sweep 8
# f : 1030000000.0
#  ended at 2018-10-22 13:55:13.352000
#  taking 121 seonds
# Sweep 9
# f : 1040000000.0
#  began at 2018-10-22 13:55:13.352000
# Writing to AWG Began at 2018-10-22 13:55:13.362000
# Measuring on VNA  Began at 2018-10-22 13:55:15.398000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:55:20.742000
# Writing to AWG Began at 2018-10-22 13:55:25.312000
# Measuring on VNA  Began at 2018-10-22 13:55:27.346000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:55:32.663000
# Writing to AWG Began at 2018-10-22 13:55:37.393000
# Measuring on VNA  Began at 2018-10-22 13:55:39.423000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:55:44.747000
# Writing to AWG Began at 2018-10-22 13:55:49.313000
# Measuring on VNA  Began at 2018-10-22 13:55:51.350000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:55:56.695000
# Writing to AWG Began at 2018-10-22 13:56:01.413000
# Measuring on VNA  Began at 2018-10-22 13:56:03.427000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:56:08.757000
# Writing to AWG Began at 2018-10-22 13:56:14.127000
# Measuring on VNA  Began at 2018-10-22 13:56:16.148000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:56:21.450000
# Writing to AWG Began at 2018-10-22 13:56:26.112000
# Measuring on VNA  Began at 2018-10-22 13:56:28.177000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:56:33.468000
# Writing to AWG Began at 2018-10-22 13:56:38.169000
# Measuring on VNA  Began at 2018-10-22 13:56:40.228000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:56:45.526000
# Writing to AWG Began at 2018-10-22 13:56:50.318000
# Measuring on VNA  Began at 2018-10-22 13:56:52.375000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:56:57.702000
# Writing to AWG Began at 2018-10-22 13:57:02.492000
# Measuring on VNA  Began at 2018-10-22 13:57:04.537000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:57:09.876000
# Sweep 9
# f : 1040000000.0
#  ended at 2018-10-22 13:57:14.516000
#  taking 121 seonds
# Sweep 10
# f : 1050000000.0
#  began at 2018-10-22 13:57:14.516000
# Writing to AWG Began at 2018-10-22 13:57:14.526000
# Measuring on VNA  Began at 2018-10-22 13:57:16.593000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:57:21.904000
# Writing to AWG Began at 2018-10-22 13:57:26.713000
# Measuring on VNA  Began at 2018-10-22 13:57:28.760000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:57:34.073000
# Writing to AWG Began at 2018-10-22 13:57:39.481000
# Measuring on VNA  Began at 2018-10-22 13:57:41.528000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:57:46.867000
# Writing to AWG Began at 2018-10-22 13:57:51.628000
# Measuring on VNA  Began at 2018-10-22 13:57:53.659000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:57:58.950000
# Writing to AWG Began at 2018-10-22 13:58:03.648000
# Measuring on VNA  Began at 2018-10-22 13:58:05.678000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:58:10.947000
# Writing to AWG Began at 2018-10-22 13:58:15.606000
# Measuring on VNA  Began at 2018-10-22 13:58:17.694000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:58:23
# Writing to AWG Began at 2018-10-22 13:58:27.621000
# Measuring on VNA  Began at 2018-10-22 13:58:29.685000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:58:35.013000
# Writing to AWG Began at 2018-10-22 13:58:39.746000
# Measuring on VNA  Began at 2018-10-22 13:58:41.786000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:58:47.133000
# Writing to AWG Began at 2018-10-22 13:58:51.883000
# Measuring on VNA  Began at 2018-10-22 13:58:53.920000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:58:59.224000
# Writing to AWG Began at 2018-10-22 13:59:03.949000
# Measuring on VNA  Began at 2018-10-22 13:59:05.974000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:59:11.283000
# Sweep 10
# f : 1050000000.0
#  ended at 2018-10-22 13:59:16.710000
#  taking 122 seonds
# Calibration Began at 2018-10-22 13:59:23.465000
# Sweep 0
# f : 975000000.0
#  began at 2018-10-22 13:59:23.465000
# Writing to AWG Began at 2018-10-22 13:59:23.485000
# Measuring on VNA  Began at 2018-10-22 13:59:25.514000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:59:30.803000
# Writing to AWG Began at 2018-10-22 13:59:35.844000
# Measuring on VNA  Began at 2018-10-22 13:59:37.889000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:59:43.188000
# Writing to AWG Began at 2018-10-22 13:59:47.980000
# Measuring on VNA  Began at 2018-10-22 13:59:50.026000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 13:59:55.284000
# Writing to AWG Began at 2018-10-22 13:59:59.939000
# Measuring on VNA  Began at 2018-10-22 14:00:02.019000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:00:07.304000
# Writing to AWG Began at 2018-10-22 14:00:12.267000
# Measuring on VNA  Began at 2018-10-22 14:00:14.318000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:00:19.676000
# Writing to AWG Began at 2018-10-22 14:00:24.438000
# Measuring on VNA  Began at 2018-10-22 14:00:26.503000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:00:31.829000
# Writing to AWG Began at 2018-10-22 14:00:36.575000
# Measuring on VNA  Began at 2018-10-22 14:00:38.653000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:00:44.007000
# Writing to AWG Began at 2018-10-22 14:00:49.787000
# Measuring on VNA  Began at 2018-10-22 14:00:51.844000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:00:57.195000
# Writing to AWG Began at 2018-10-22 14:01:01.827000
# Measuring on VNA  Began at 2018-10-22 14:01:03.892000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:01:09.212000
# Writing to AWG Began at 2018-10-22 14:01:13.905000
# Measuring on VNA  Began at 2018-10-22 14:01:15.965000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:01:21.273000
# Sweep 0
# f : 975000000.0
#  ended at 2018-10-22 14:01:26.052000
#  taking 122 seonds
# Sweep 1
# f : 980000000.0
#  began at 2018-10-22 14:01:26.052000
# Writing to AWG Began at 2018-10-22 14:01:26.062000
# Measuring on VNA  Began at 2018-10-22 14:01:28.155000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:01:33.453000
# Writing to AWG Began at 2018-10-22 14:01:38.212000
# Measuring on VNA  Began at 2018-10-22 14:01:40.266000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:01:45.577000
# Writing to AWG Began at 2018-10-22 14:01:50.249000
# Measuring on VNA  Began at 2018-10-22 14:01:52.296000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:01:57.543000
# Writing to AWG Began at 2018-10-22 14:02:02.234000
# Measuring on VNA  Began at 2018-10-22 14:02:04.301000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:02:09.638000
# Writing to AWG Began at 2018-10-22 14:02:14.472000
# Measuring on VNA  Began at 2018-10-22 14:02:16.524000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:02:21.760000
# Writing to AWG Began at 2018-10-22 14:02:26.588000
# Measuring on VNA  Began at 2018-10-22 14:02:28.667000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:02:33.964000
# Writing to AWG Began at 2018-10-22 14:02:39.559000
# Measuring on VNA  Began at 2018-10-22 14:02:41.609000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:02:46.918000
# Writing to AWG Began at 2018-10-22 14:02:51.659000
# Measuring on VNA  Began at 2018-10-22 14:02:53.731000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:02:59.034000
# Writing to AWG Began at 2018-10-22 14:03:03.694000
# Measuring on VNA  Began at 2018-10-22 14:03:05.749000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:03:11.039000
# Writing to AWG Began at 2018-10-22 14:03:15.722000
# Measuring on VNA  Began at 2018-10-22 14:03:17.776000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:03:23.072000
# Sweep 1
# f : 980000000.0
#  ended at 2018-10-22 14:03:27.863000
#  taking 121 seonds
# Sweep 2
# f : 985000000.0
#  began at 2018-10-22 14:03:27.863000
# Writing to AWG Began at 2018-10-22 14:03:27.883000
# Measuring on VNA  Began at 2018-10-22 14:03:29.930000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:03:35.248000
# Writing to AWG Began at 2018-10-22 14:03:40.013000
# Measuring on VNA  Began at 2018-10-22 14:03:42.091000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:03:47.395000
# Writing to AWG Began at 2018-10-22 14:03:52.222000
# Measuring on VNA  Began at 2018-10-22 14:03:54.292000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:03:59.600000
# Writing to AWG Began at 2018-10-22 14:04:04.462000
# Measuring on VNA  Began at 2018-10-22 14:04:06.508000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:04:11.878000
# Writing to AWG Began at 2018-10-22 14:04:16.675000
# Measuring on VNA  Began at 2018-10-22 14:04:18.728000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:04:24.065000
# Writing to AWG Began at 2018-10-22 14:04:29.918000
# Measuring on VNA  Began at 2018-10-22 14:04:31.969000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:04:37.308000
# Writing to AWG Began at 2018-10-22 14:04:42.275000
# Measuring on VNA  Began at 2018-10-22 14:04:44.345000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:04:49.666000
# Writing to AWG Began at 2018-10-22 14:04:54.322000
# Measuring on VNA  Began at 2018-10-22 14:04:56.384000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:05:01.640000
# Writing to AWG Began at 2018-10-22 14:05:06.366000
# Measuring on VNA  Began at 2018-10-22 14:05:08.420000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:05:13.740000
# Writing to AWG Began at 2018-10-22 14:05:18.454000
# Measuring on VNA  Began at 2018-10-22 14:05:20.507000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:05:25.791000
# Sweep 2
# f : 985000000.0
#  ended at 2018-10-22 14:05:30.558000
#  taking 122 seonds
# Sweep 3
# f : 990000000.0
#  began at 2018-10-22 14:05:30.558000
# Writing to AWG Began at 2018-10-22 14:05:30.578000
# Measuring on VNA  Began at 2018-10-22 14:05:32.652000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:05:37.975000
# Writing to AWG Began at 2018-10-22 14:05:42.755000
# Measuring on VNA  Began at 2018-10-22 14:05:44.831000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:05:50.141000
# Writing to AWG Began at 2018-10-22 14:05:55.503000
# Measuring on VNA  Began at 2018-10-22 14:05:57.538000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:06:02.864000
# Writing to AWG Began at 2018-10-22 14:06:07.882000
# Measuring on VNA  Began at 2018-10-22 14:06:09.930000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:06:15.242000
# Writing to AWG Began at 2018-10-22 14:06:20.086000
# Measuring on VNA  Began at 2018-10-22 14:06:22.183000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:06:27.420000
# Writing to AWG Began at 2018-10-22 14:06:33.401000
# Measuring on VNA  Began at 2018-10-22 14:06:35.443000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:06:40.738000
# Writing to AWG Began at 2018-10-22 14:06:45.506000
# Measuring on VNA  Began at 2018-10-22 14:06:47.573000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:06:52.876000
# Writing to AWG Began at 2018-10-22 14:06:58.220000
# Measuring on VNA  Began at 2018-10-22 14:07:00.265000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:07:05.568000
# Writing to AWG Began at 2018-10-22 14:07:10.563000
# Measuring on VNA  Began at 2018-10-22 14:07:12.668000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:07:17.941000
# Writing to AWG Began at 2018-10-22 14:07:22.706000
# Measuring on VNA  Began at 2018-10-22 14:07:24.758000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:07:30.078000
# Sweep 3
# f : 990000000.0
#  ended at 2018-10-22 14:07:34.965000
#  taking 124 seonds
# Sweep 4
# f : 995000000.0
#  began at 2018-10-22 14:07:34.965000
# Writing to AWG Began at 2018-10-22 14:07:34.985000
# Measuring on VNA  Began at 2018-10-22 14:07:37.029000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:07:42.323000
# Writing to AWG Began at 2018-10-22 14:07:47.310000
# Measuring on VNA  Began at 2018-10-22 14:07:49.380000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:07:54.668000
# Writing to AWG Began at 2018-10-22 14:07:59.552000
# Measuring on VNA  Began at 2018-10-22 14:08:01.650000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:08:06.980000
# Writing to AWG Began at 2018-10-22 14:08:11.948000
# Measuring on VNA  Began at 2018-10-22 14:08:14.004000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:08:19.254000
# Writing to AWG Began at 2018-10-22 14:08:24.069000
# Measuring on VNA  Began at 2018-10-22 14:08:26.068000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:08:31.360000
# Writing to AWG Began at 2018-10-22 14:08:37.225000
# Measuring on VNA  Began at 2018-10-22 14:08:39.288000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:08:44.587000
# Writing to AWG Began at 2018-10-22 14:08:49.350000
# Measuring on VNA  Began at 2018-10-22 14:08:51.386000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:08:56.614000
# Writing to AWG Began at 2018-10-22 14:09:01.583000
# Measuring on VNA  Began at 2018-10-22 14:09:03.662000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:09:09.003000
# Writing to AWG Began at 2018-10-22 14:09:13.833000
# Measuring on VNA  Began at 2018-10-22 14:09:15.885000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:09:21.152000
# Writing to AWG Began at 2018-10-22 14:09:27.005000
# Measuring on VNA  Began at 2018-10-22 14:09:29.153000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:09:34.456000
# Sweep 4
# f : 995000000.0
#  ended at 2018-10-22 14:09:39.620000
#  taking 124 seonds
# Sweep 5
# f : 1000000000.0
#  began at 2018-10-22 14:09:39.620000
# Writing to AWG Began at 2018-10-22 14:09:39.630000
# Measuring on VNA  Began at 2018-10-22 14:09:41.697000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:09:47.014000
# Writing to AWG Began at 2018-10-22 14:09:51.945000
# Measuring on VNA  Began at 2018-10-22 14:09:54.619000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:09:59.926000
# Writing to AWG Began at 2018-10-22 14:10:04.857000
# Measuring on VNA  Began at 2018-10-22 14:10:06.910000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:10:12.259000
# Writing to AWG Began at 2018-10-22 14:10:17.129000
# Measuring on VNA  Began at 2018-10-22 14:10:19.185000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:10:24.512000
# Writing to AWG Began at 2018-10-22 14:10:29.661000
# Measuring on VNA  Began at 2018-10-22 14:10:31.730000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:10:36.976000
# Writing to AWG Began at 2018-10-22 14:10:41.955000
# Measuring on VNA  Began at 2018-10-22 14:10:44.019000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:10:49.325000
# Writing to AWG Began at 2018-10-22 14:10:55.366000
# Measuring on VNA  Began at 2018-10-22 14:10:57.423000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:11:02.764000
# Writing to AWG Began at 2018-10-22 14:11:07.737000
# Measuring on VNA  Began at 2018-10-22 14:11:09.792000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:11:15.103000
# Writing to AWG Began at 2018-10-22 14:11:20.088000
# Measuring on VNA  Began at 2018-10-22 14:11:22.196000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:11:27.533000
# Writing to AWG Began at 2018-10-22 14:11:32.493000
# Measuring on VNA  Began at 2018-10-22 14:11:34.510000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:11:39.806000
# Sweep 5
# f : 1000000000.0
#  ended at 2018-10-22 14:11:44.933000
#  taking 125 seonds
# Sweep 6
# f : 1005000000.0
#  began at 2018-10-22 14:11:44.933000
# Writing to AWG Began at 2018-10-22 14:11:44.943000
# Measuring on VNA  Began at 2018-10-22 14:11:47.009000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:11:52.293000
# Writing to AWG Began at 2018-10-22 14:11:57.315000
# Measuring on VNA  Began at 2018-10-22 14:11:59.376000
# len(vna_data) is 11
# len(column_names) is 15
# len(['float' for i in range(len(column_names))]) is 15
# Measuring on Scope  Began at 2018-10-22 14:12:04.664000
# Writing to AWG Began at 2018-10-22 14:12:09.606000
# Measuring on VNA  Began at 2018-10-22 14:12:11.660000
# len(vna_data) is 11
# ...
# Measuring on VNA  Began at 2018-10-22 15:20:54.561000
# Measuring on Scope  Began at 2018-10-22 15:20:59.888000
# Writing to AWG Began at 2018-10-22 15:21:10.138000
# Measuring on VNA  Began at 2018-10-22 15:21:14.593000
# Measuring on Scope  Began at 2018-10-22 15:21:19.804000
# Writing to AWG Began at 2018-10-22 15:21:28.771000
# Measuring on VNA  Began at 2018-10-22 15:21:33.198000
# Measuring on Scope  Began at 2018-10-22 15:21:38.466000
# Writing to AWG Began at 2018-10-22 15:21:50.729000
# Measuring on VNA  Began at 2018-10-22 15:21:55.217000
# Measuring on Scope  Began at 2018-10-22 15:22:00.467000
# Writing to AWG Began at 2018-10-22 15:22:09.697000
# Measuring on VNA  Began at 2018-10-22 15:22:14.109000
# Measuring on Scope  Began at 2018-10-22 15:22:19.395000
# Writing to AWG Began at 2018-10-22 15:22:28.536000
# Measuring on VNA  Began at 2018-10-22 15:22:32.886000
# Measuring on Scope  Began at 2018-10-22 15:22:38.165000
# Writing to AWG Began at 2018-10-22 15:22:47.678000
# Measuring on VNA  Began at 2018-10-22 15:22:52.079000
# Measuring on Scope  Began at 2018-10-22 15:22:57.336000
# Writing to AWG Began at 2018-10-22 15:23:07.938000
# Measuring on VNA  Began at 2018-10-22 15:23:12.293000
# Measuring on Scope  Began at 2018-10-22 15:23:17.591000
# Writing to AWG Began at 2018-10-22 15:23:26.461000
# Measuring on VNA  Began at 2018-10-22 15:23:30.852000
# Measuring on Scope  Began at 2018-10-22 15:23:36.159000
# Writing to AWG Began at 2018-10-22 15:23:45.361000
# Measuring on VNA  Began at 2018-10-22 15:23:49.777000
# Measuring on Scope  Began at 2018-10-22 15:23:55.096000
# Sweep 2
# f : 999925000.0
#  ended at 2018-10-22 15:24:03.116000
#  taking 194 seonds
# Sweep 3
# f : 999950000.0
#  began at 2018-10-22 15:24:03.116000
# Writing to AWG Began at 2018-10-22 15:24:05.257000
# Measuring on VNA  Began at 2018-10-22 15:24:09.730000
# Measuring on Scope  Began at 2018-10-22 15:24:15.036000
# Writing to AWG Began at 2018-10-22 15:24:24.152000
# Measuring on VNA  Began at 2018-10-22 15:24:28.666000
# Measuring on Scope  Began at 2018-10-22 15:24:33.973000
# Writing to AWG Began at 2018-10-22 15:24:43.950000
# Measuring on VNA  Began at 2018-10-22 15:24:48.436000
# Measuring on Scope  Began at 2018-10-22 15:24:53.691000
# Writing to AWG Began at 2018-10-22 15:25:02.739000
# Measuring on VNA  Began at 2018-10-22 15:25:07.172000
# Measuring on Scope  Began at 2018-10-22 15:25:12.483000
# Writing to AWG Began at 2018-10-22 15:25:22.674000
# Measuring on VNA  Began at 2018-10-22 15:25:27.091000
# Measuring on Scope  Began at 2018-10-22 15:25:32.384000
# Writing to AWG Began at 2018-10-22 15:25:42.992000
# Measuring on VNA  Began at 2018-10-22 15:25:47.396000
# Measuring on Scope  Began at 2018-10-22 15:25:52.681000
# Writing to AWG Began at 2018-10-22 15:26:02.282000
# Measuring on VNA  Began at 2018-10-22 15:26:06.680000
# Measuring on Scope  Began at 2018-10-22 15:26:12.010000
# Writing to AWG Began at 2018-10-22 15:26:21.339000
# Measuring on VNA  Began at 2018-10-22 15:26:25.759000
# Measuring on Scope  Began at 2018-10-22 15:26:31.055000
# Writing to AWG Began at 2018-10-22 15:26:40.178000
# Measuring on VNA  Began at 2018-10-22 15:26:44.588000
# Measuring on Scope  Began at 2018-10-22 15:26:49.872000
# Writing to AWG Began at 2018-10-22 15:26:58.942000
# Measuring on VNA  Began at 2018-10-22 15:27:03.324000
# Measuring on Scope  Began at 2018-10-22 15:27:08.599000
# Sweep 3
# f : 999950000.0
#  ended at 2018-10-22 15:27:16.479000
#  taking 193 seonds
# Sweep 4
# f : 999975000.0
#  began at 2018-10-22 15:27:16.479000
# Writing to AWG Began at 2018-10-22 15:27:18.576000
# Measuring on VNA  Began at 2018-10-22 15:27:23.006000
# Measuring on Scope  Began at 2018-10-22 15:27:28.263000
# Writing to AWG Began at 2018-10-22 15:27:38.820000
# Measuring on VNA  Began at 2018-10-22 15:27:43.294000
# Measuring on Scope  Began at 2018-10-22 15:27:48.560000
# Writing to AWG Began at 2018-10-22 15:27:57.676000
# Measuring on VNA  Began at 2018-10-22 15:28:02.099000
# Measuring on Scope  Began at 2018-10-22 15:28:07.380000
# Writing to AWG Began at 2018-10-22 15:28:16.567000
# Measuring on VNA  Began at 2018-10-22 15:28:20.958000
# Measuring on Scope  Began at 2018-10-22 15:28:26.269000
# Writing to AWG Began at 2018-10-22 15:28:40.107000
# Measuring on VNA  Began at 2018-10-22 15:28:44.521000
# Measuring on Scope  Began at 2018-10-22 15:28:49.846000
# Writing to AWG Began at 2018-10-22 15:28:59.132000
# Measuring on VNA  Began at 2018-10-22 15:29:03.378000
# Measuring on Scope  Began at 2018-10-22 15:29:08.673000
# Writing to AWG Began at 2018-10-22 15:29:19.278000
# Measuring on VNA  Began at 2018-10-22 15:29:23.741000
# Measuring on Scope  Began at 2018-10-22 15:29:29.059000
# Writing to AWG Began at 2018-10-22 15:29:38.210000
# Measuring on VNA  Began at 2018-10-22 15:29:42.615000
# Measuring on Scope  Began at 2018-10-22 15:29:47.893000
# Writing to AWG Began at 2018-10-22 15:30:00.945000
# Measuring on VNA  Began at 2018-10-22 15:30:05.375000
# Measuring on Scope  Began at 2018-10-22 15:30:10.644000
# Writing to AWG Began at 2018-10-22 15:30:20.099000
# Measuring on VNA  Began at 2018-10-22 15:30:24.470000
# Measuring on Scope  Began at 2018-10-22 15:30:29.745000
# Sweep 4
# f : 999975000.0
#  ended at 2018-10-22 15:30:37.246000
#  taking 200 seonds
# Sweep 5
# f : 1000000000.0
#  began at 2018-10-22 15:30:37.246000
# Writing to AWG Began at 2018-10-22 15:30:39.352000
# Measuring on VNA  Began at 2018-10-22 15:30:43.808000
# Measuring on Scope  Began at 2018-10-22 15:30:49.092000
# Writing to AWG Began at 2018-10-22 15:31:00.141000
# Measuring on VNA  Began at 2018-10-22 15:31:04.692000
# Measuring on Scope  Began at 2018-10-22 15:31:09.981000
# Writing to AWG Began at 2018-10-22 15:31:20.263000
# Measuring on VNA  Began at 2018-10-22 15:31:24.802000
# Measuring on Scope  Began at 2018-10-22 15:31:30.118000
# Writing to AWG Began at 2018-10-22 15:31:40.874000
# Measuring on VNA  Began at 2018-10-22 15:31:45.409000
# Measuring on Scope  Began at 2018-10-22 15:31:50.627000
# Writing to AWG Began at 2018-10-22 15:32:00.582000
# Measuring on VNA  Began at 2018-10-22 15:32:05.073000
# Measuring on Scope  Began at 2018-10-22 15:32:10.288000
# Writing to AWG Began at 2018-10-22 15:32:20.321000
# Measuring on VNA  Began at 2018-10-22 15:32:24.812000
# Measuring on Scope  Began at 2018-10-22 15:32:30.170000
# Writing to AWG Began at 2018-10-22 15:32:39.436000
# Measuring on VNA  Began at 2018-10-22 15:32:43.754000
# Measuring on Scope  Began at 2018-10-22 15:32:49.038000
# Writing to AWG Began at 2018-10-22 15:32:59.342000
# Measuring on VNA  Began at 2018-10-22 15:33:03.759000
# Measuring on Scope  Began at 2018-10-22 15:33:09.046000
# Writing to AWG Began at 2018-10-22 15:33:20.943000
# Measuring on VNA  Began at 2018-10-22 15:33:25.407000
# Measuring on Scope  Began at 2018-10-22 15:33:30.716000
# Writing to AWG Began at 2018-10-22 15:33:40.056000
# Measuring on VNA  Began at 2018-10-22 15:33:44.578000
# Measuring on Scope  Began at 2018-10-22 15:33:49.872000
# Sweep 5
# f : 1000000000.0
#  ended at 2018-10-22 15:33:57.025000
#  taking 199 seonds
# Sweep 6
# f : 1000025000.0
#  began at 2018-10-22 15:33:57.025000
# Writing to AWG Began at 2018-10-22 15:33:59.132000
# Measuring on VNA  Began at 2018-10-22 15:34:03.613000
# Measuring on Scope  Began at 2018-10-22 15:34:08.904000
# Writing to AWG Began at 2018-10-22 15:34:19.054000
# Measuring on VNA  Began at 2018-10-22 15:34:23.561000
# Measuring on Scope  Began at 2018-10-22 15:34:28.820000
# Writing to AWG Began at 2018-10-22 15:34:38.171000
# Measuring on VNA  Began at 2018-10-22 15:34:42.614000
# Measuring on Scope  Began at 2018-10-22 15:34:47.902000
# Writing to AWG Began at 2018-10-22 15:34:58.568000
# Measuring on VNA  Began at 2018-10-22 15:35:02.990000
# Measuring on Scope  Began at 2018-10-22 15:35:08.277000
# Writing to AWG Began at 2018-10-22 15:35:17.671000
# Measuring on VNA  Began at 2018-10-22 15:35:22.003000
# Measuring on Scope  Began at 2018-10-22 15:35:27.308000
# Writing to AWG Began at 2018-10-22 15:35:37.552000
# Measuring on VNA  Began at 2018-10-22 15:35:41.872000
# Measuring on Scope  Began at 2018-10-22 15:35:47.193000
# Writing to AWG Began at 2018-10-22 15:35:56.830000
# Measuring on VNA  Began at 2018-10-22 15:36:01.234000
# Measuring on Scope  Began at 2018-10-22 15:36:06.534000
# Writing to AWG Began at 2018-10-22 15:36:16.144000
# Measuring on VNA  Began at 2018-10-22 15:36:20.599000
# Measuring on Scope  Began at 2018-10-22 15:36:25.881000
# Writing to AWG Began at 2018-10-22 15:36:35.626000
# Measuring on VNA  Began at 2018-10-22 15:36:40.035000
# Measuring on Scope  Began at 2018-10-22 15:36:45.300000
# Writing to AWG Began at 2018-10-22 15:36:54.848000
# Measuring on VNA  Began at 2018-10-22 15:36:59.219000
# Measuring on Scope  Began at 2018-10-22 15:37:04.524000
# Sweep 6
# f : 1000025000.0
#  ended at 2018-10-22 15:37:14.486000
#  taking 197 seonds
# Sweep 7
# f : 1000050000.0
#  began at 2018-10-22 15:37:14.486000
# Writing to AWG Began at 2018-10-22 15:37:16.614000
# Measuring on VNA  Began at 2018-10-22 15:37:20.950000
# Measuring on Scope  Began at 2018-10-22 15:37:26.300000
# Writing to AWG Began at 2018-10-22 15:37:38.214000
# Measuring on VNA  Began at 2018-10-22 15:37:42.768000
# Measuring on Scope  Began at 2018-10-22 15:37:48.076000
# Writing to AWG Began at 2018-10-22 15:37:58.258000
# Measuring on VNA  Began at 2018-10-22 15:38:02.717000
# Measuring on Scope  Began at 2018-10-22 15:38:08.034000
# Writing to AWG Began at 2018-10-22 15:38:17.553000
# Measuring on VNA  Began at 2018-10-22 15:38:21.894000
# Measuring on Scope  Began at 2018-10-22 15:38:27.165000
# Writing to AWG Began at 2018-10-22 15:38:36.891000
# Measuring on VNA  Began at 2018-10-22 15:38:41.294000
# Measuring on Scope  Began at 2018-10-22 15:38:46.643000
# Writing to AWG Began at 2018-10-22 15:38:56.478000
# Measuring on VNA  Began at 2018-10-22 15:39:00.830000
# Measuring on Scope  Began at 2018-10-22 15:39:06.072000
# Writing to AWG Began at 2018-10-22 15:39:15.534000
# Measuring on VNA  Began at 2018-10-22 15:39:23.800000
# Measuring on Scope  Began at 2018-10-22 15:39:29.152000
# Writing to AWG Began at 2018-10-22 15:39:38.944000
# Measuring on VNA  Began at 2018-10-22 15:39:43.402000
# Measuring on Scope  Began at 2018-10-22 15:39:48.705000
# Writing to AWG Began at 2018-10-22 15:39:58.646000
# Measuring on VNA  Began at 2018-10-22 15:40:03.126000
# Measuring on Scope  Began at 2018-10-22 15:40:08.332000
# Writing to AWG Began at 2018-10-22 15:40:18.001000
# Measuring on VNA  Began at 2018-10-22 15:40:23.136000
# Measuring on Scope  Began at 2018-10-22 15:40:28.436000
# Sweep 7
# f : 1000050000.0
#  ended at 2018-10-22 15:40:36.780000
#  taking 202 seonds
# Sweep 8
# f : 1000075000.0
#  began at 2018-10-22 15:40:36.780000
# Writing to AWG Began at 2018-10-22 15:40:38.934000
# Measuring on VNA  Began at 2018-10-22 15:40:43.432000
# Measuring on Scope  Began at 2018-10-22 15:40:48.777000
# Writing to AWG Began at 2018-10-22 15:40:58.215000
# Measuring on VNA  Began at 2018-10-22 15:41:02.731000
# Measuring on Scope  Began at 2018-10-22 15:41:08.032000
# Writing to AWG Began at 2018-10-22 15:41:17.509000
# Measuring on VNA  Began at 2018-10-22 15:41:22.028000
# Measuring on Scope  Began at 2018-10-22 15:41:27.325000
# Writing to AWG Began at 2018-10-22 15:41:37.609000
# Measuring on VNA  Began at 2018-10-22 15:41:42.033000
# Measuring on Scope  Began at 2018-10-22 15:41:47.354000
# Writing to AWG Began at 2018-10-22 15:41:56.752000
# Measuring on VNA  Began at 2018-10-22 15:42:01.219000
# Measuring on Scope  Began at 2018-10-22 15:42:06.499000
# Writing to AWG Began at 2018-10-22 15:42:16.326000
# Measuring on VNA  Began at 2018-10-22 15:42:20.806000
# Measuring on Scope  Began at 2018-10-22 15:42:26.007000
# Writing to AWG Began at 2018-10-22 15:42:39.981000
# Measuring on VNA  Began at 2018-10-22 15:42:44.375000
# Measuring on Scope  Began at 2018-10-22 15:42:49.715000
# Writing to AWG Began at 2018-10-22 15:43:02.648000
# Measuring on VNA  Began at 2018-10-22 15:43:07.092000
# Measuring on Scope  Began at 2018-10-22 15:43:12.380000
# Writing to AWG Began at 2018-10-22 15:43:22.261000
# Measuring on VNA  Began at 2018-10-22 15:43:26.728000
# Measuring on Scope  Began at 2018-10-22 15:43:32.020000
# Writing to AWG Began at 2018-10-22 15:43:41.802000
# Measuring on VNA  Began at 2018-10-22 15:43:46.296000
# Measuring on Scope  Began at 2018-10-22 15:43:51.600000
# Sweep 8
# f : 1000075000.0
#  ended at 2018-10-22 15:44:00.050000
#  taking 203 seonds
# Sweep 9
# f : 1000100000.0
#  began at 2018-10-22 15:44:00.050000
# Writing to AWG Began at 2018-10-22 15:44:02.168000
# Measuring on VNA  Began at 2018-10-22 15:44:06.623000
# Measuring on Scope  Began at 2018-10-22 15:44:12.023000
# Writing to AWG Began at 2018-10-22 15:44:22.800000
# Measuring on VNA  Began at 2018-10-22 15:44:27.293000
# Measuring on Scope  Began at 2018-10-22 15:44:32.621000
# Writing to AWG Began at 2018-10-22 15:44:43.611000
# Measuring on VNA  Began at 2018-10-22 15:44:48.042000
# Measuring on Scope  Began at 2018-10-22 15:44:53.335000
# Writing to AWG Began at 2018-10-22 15:45:02.696000
# Measuring on VNA  Began at 2018-10-22 15:45:07.146000
# Measuring on Scope  Began at 2018-10-22 15:45:12.433000
# Writing to AWG Began at 2018-10-22 15:45:23.743000
# Measuring on VNA  Began at 2018-10-22 15:45:28.167000
# Measuring on Scope  Began at 2018-10-22 15:45:33.462000
# Writing to AWG Began at 2018-10-22 15:45:42.962000
# Measuring on VNA  Began at 2018-10-22 15:45:47.365000
# Measuring on Scope  Began at 2018-10-22 15:45:52.643000
# Writing to AWG Began at 2018-10-22 15:46:02.302000
# Measuring on VNA  Began at 2018-10-22 15:46:06.710000
# Measuring on Scope  Began at 2018-10-22 15:46:11.995000
# Writing to AWG Began at 2018-10-22 15:46:23.273000
# Measuring on VNA  Began at 2018-10-22 15:46:27.758000
# Measuring on Scope  Began at 2018-10-22 15:46:33.076000
# Writing to AWG Began at 2018-10-22 15:46:43.002000
# Measuring on VNA  Began at 2018-10-22 15:46:47.479000
# Measuring on Scope  Began at 2018-10-22 15:46:52.722000
# Writing to AWG Began at 2018-10-22 15:47:03.171000
# Measuring on VNA  Began at 2018-10-22 15:47:07.651000
# Measuring on Scope  Began at 2018-10-22 15:47:12.954000
# Sweep 9
# f : 1000100000.0
#  ended at 2018-10-22 15:47:23.407000
#  taking 203 seonds
# Sweep 10
# f : 1000125000.0
#  began at 2018-10-22 15:47:23.407000
# Writing to AWG Began at 2018-10-22 15:47:25.534000
# Measuring on VNA  Began at 2018-10-22 15:47:30.013000
# Measuring on Scope  Began at 2018-10-22 15:47:35.314000
# Writing to AWG Began at 2018-10-22 15:47:46.567000
# Measuring on VNA  Began at 2018-10-22 15:47:51.103000
# Measuring on Scope  Began at 2018-10-22 15:47:56.434000
# Writing to AWG Began at 2018-10-22 15:48:06.221000
# Measuring on VNA  Began at 2018-10-22 15:48:10.715000
# Measuring on Scope  Began at 2018-10-22 15:48:16.019000
# Writing to AWG Began at 2018-10-22 15:48:25.712000
# Measuring on VNA  Began at 2018-10-22 15:48:30.145000
# Measuring on Scope  Began at 2018-10-22 15:48:35.458000
# Writing to AWG Began at 2018-10-22 15:48:45.552000
# Measuring on VNA  Began at 2018-10-22 15:48:50.025000
# Measuring on Scope  Began at 2018-10-22 15:48:55.329000
# Writing to AWG Began at 2018-10-22 15:49:06.297000
# Measuring on VNA  Began at 2018-10-22 15:49:10.802000
# Measuring on Scope  Began at 2018-10-22 15:49:16.127000
# Writing to AWG Began at 2018-10-22 15:49:26.800000
# Measuring on VNA  Began at 2018-10-22 15:49:31.304000
# Measuring on Scope  Began at 2018-10-22 15:49:36.601000
# Writing to AWG Began at 2018-10-22 15:49:46.641000
# Measuring on VNA  Began at 2018-10-22 15:49:51.052000
# Measuring on Scope  Began at 2018-10-22 15:49:56.368000
# Writing to AWG Began at 2018-10-22 15:50:06.007000
# Measuring on VNA  Began at 2018-10-22 15:50:10.551000
# Measuring on Scope  Began at 2018-10-22 15:50:15.837000
# Writing to AWG Began at 2018-10-22 15:50:26.296000
# Measuring on VNA  Began at 2018-10-22 15:50:30.789000
# Measuring on Scope  Began at 2018-10-22 15:50:36.114000
# Sweep 10
# f : 1000125000.0
#  ended at 2018-10-22 15:50:44.107000
#  taking 200 seonds

# %%
vna.get_IFBW()
vna.set_IFBW(10)

# %%
vna.trigger_sweep()
time.sleep(30)

# %%
vna.write("CALC:PAR:SEL '{0}'".format("a4"))
a4_trace_string = vna.query("CALC:DATA? SDATA")
a4_trace = a4_trace_string.replace("\n","").split(",")
a4_real = a4_trace[0::2]
a4_imaginary = a4_trace[1::2]
complex_a4 =np.array([complex(float(real_value),
                                 float(a4_imaginary[index])) for index,real_value in enumerate(a4_real)])

# %%
complex_a4

# %%
vna.read_trace("b2")

# %%
vna.is_busy()

# %%
scope.measure_options
