# %% [markdown]
# # AWG Phase Calibration
# The goal of this experiment is to demonstrate phase calibration of a VNA on an arbitrary frequency grid using a arbitrary waveform generator. We do this by creating a phase reference signal on one port (port 4), and a series of sine waves on port 1. We then measure those sine waves with a calibrated oscilloscope.
#
# Notes:
# ------
# GPIB communication shutdown unexpectedly 10/03/2018 <br/>
# Trigger on Oscope seems to remain when changing the Multisine<br/>
# Something is weird about a1 wave recorded compared to on screen <- turned out to be wrong f grid<br/>

# %% [markdown]
# ## Imports

# %%
# import the pyMez packages default API
from pyMez import *
# import the Fitting module for Signal Generation and Fitting, note the namespace Code.Analysis.Fitting also works
from pyMez.Code.Analysis.Fitting import *
# Out:
# Importing pyMez, this should take roughly 30 seconds
# Importing Code.DataHandlers.GeneralModels
# It took 0.815 s to import Code.DataHandlers.GeneralModels
# Importing Code.DataHandlers.HTMLModels
# It took 0.13 s to import Code.DataHandlers.HTMLModels
# Importing Code.DataHandlers.NISTModels
# The module smithplot was not found,please put it on the python path
# It took 1.434 s to import Code.DataHandlers.NISTModels
# Importing Code.DataHandlers.TouchstoneModels
# The module smithplot was not found,please put it on the python path
# It took 0.022 s to import Code.DataHandlers.TouchstoneModels
# Importing Code.DataHandlers.XMLModels
# It took 0.165 s to import Code.DataHandlers.XMLModels
# Importing Code.DataHandlers.ZipModels
# It took 0.025 s to import Code.DataHandlers.ZipModels
# Importing Code.InstrumentControl.Experiments
# It took 2.785 s to import Code.InstrumentControl.Experiments
# Importing Code.InstrumentControl.Instruments
# It took 0.01 s to import Code.InstrumentControl.Instruments
# Importing Code.Utils.Names
# It took 0.0 s to import Code.Utils.Names
# It took 5.386 s to import all of the active modules

# %% [markdown]
# ## Global Variable Declaration
# This experiment involves the PSG, VNA, AWG,power meter, Scope and 2 combs. The addresses of the instruments and the top level data directory are assumed to be fixed throughout the course of the experiment.

# %%
# none of these instruments have xml instrument sheets, need to add them
psg_address="GPIB0::19"
vna_address="GPIB0::16"
awg_address="GPIB0::10"
scope_address="GPIB0::7::INSTR"
pm_address="GPIB0::13"
# this is local to the computer taking the data, the data should be copied to Q:\public\Aric\AWG_Phase_Calibration_20180927
data_directory=r'C:\Share\AWG_Phase_Calibration_20181001'

# %%
# Experimental variables

# the psg frequency acts as the master clock
psg_amplitude=12. #psg amplitude in dBm
psg_frequency=10.*10.**9 # 10 GHz
time_step=1./psg_frequency # time step for the awg

# Calculation of the frequency grid of interest
fundamental_frequency = 1.*10.**9 # Center of the passband or fundemental frequency in Hz
number_tones = 5 # Number of tones in the modulation bandwidth including the fundamental, should be odd
tone_spacing = 2.5*10**4 # Spacing of each tone. Combs can do 10 Mhz, 5 MHz, 2.5 MHz, 1.25 MHz and .625 MHz
number_harmonics = 1 # Number of harmonics to use. The frequency grid will be n*(f-df), n*f, n*(f+df), etc
# now calculate the frequency_list
frequency_list=[]
for harmonic in range(number_harmonics):
    frequency_array=np.linspace((harmonic+1)*(fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                (harmonic+1)*(fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)
    frequency_list=frequency_list+frequency_array.tolist()
# Select the phase for the multisine    
#multisine_phase="zero"
multisine_phase="schroeder"
# select the number of envelopes
number_envelopes=1.
time_max=number_envelopes/tone_spacing
number_time_points=int(round(time_max/time_step))
time_shift=0.*time_step
# Measurement Phase Reference Setup 
round_multisine_before_writing=True # Rounds the multisine to a desired bitdepth before writing to AWG
bit_depth=8
waveform_name="Calibration_Phase_Reference" # name of the waveform to write to the 
bin_format=True # If the wave is in 16 bit bin format
marker_1=True # If marker one is to be set
marker_1_n_repeats=1 # the rep rate of the marker as a function of number of repeats per time sequence
marker_2=False
marker_2_n_repeats=1

# VNA setup 
vna_IFBW=10
comb_frequency = 2.5*10**6
sweep_wait_time=2.*float(len(frequency_list))/float(vna_IFBW)

# %%
sweep_wait_time
# Out:
# 1.0

# %%
frequency_list
# Out:
# [999950000.0, 999975000.0, 1000000000.0, 1000025000.0, 1000050000.0]

# %% [markdown]
# ## Instrument Control Verification
# This verifies that the instruments are attached and responding properly

# %%
whos_there()
# Out:
#  is at address GPIB0::7::INSTR
# TEKTRONIX,AWG7122B,B020393,SCPI:99.0 FW:4.6.0.7  is at address GPIB0::13::INSTR
# Agilent Technologies,86100C,MY47440684,A.08.00
# o is at address GPIB0::10::INSTR
# Agilent Technologies,N5245A,SG49151009,A.10.64.03
#  is at address GPIB0::19::INSTR
# Agilent Technologies,E4417A,SG55376002,A2.05.04
#  is at address GPIB0::16::INSTR

# %% [markdown]
# ## PSG Setup
# The PSG is a vector signal generator manufactured by Agilent (model number 8267D). It is directly used as the clock for the AWG and inputs for IQ on the oscilloscope. It has to remain at the specified frequency for the duration of the experiment. In the first attempts we are using a 10 GHz sine wave with an amplitude of 12 dBm.

# %%
# first intialize a class to talk with the psg
psg=VisaInstrument(psg_address)
# verify that it is properly connected
print("The psg IDN is {0}".format(psg.query("*IDN?")))
# Make sure the mode is CW
print("The psg is in the {0} mode".format(psg.query("FREQ:MODE?")))
# Out:
# The information sheet was not found defaulting to address
# The psg IDN is CW
#
# The psg is in the Agi mode

# %%
psg.query("FREQ:MODE?")
# Out:
# u'CW\n'

# %%
# Only run this if the PSG was not already setup using the front panel
# This can be done in a single step if there is a saved xml state by using psg.load_state(path_to_xml_state)
# set the psg mode
psg.write("FREQ:MODE CW")
# set the amplitude
psg.write("POW:AMPL {0}".format(psg_amplitude))
# set the frequency
psg.write("FREQ:CW {0}".format(psg_frequency))
# turn the output on
psg.write("OUTP 1")
# Out:
# (8L, <StatusCode.success: 0>)

# %%
#Now get the state and save it
# We can do this one at a time or all at once
psg_state_name=auto_name(directory=data_directory,specific_descriptor="psg",general_descriptor="state",extension="xml")
psg_state_query_dictionary={"FREQ:MODE":"FREQ:MODE?","POW:AMPL":"POW:AMPL?","FREQ:CW":"FREQ:CW?","OUTP":"OUTP?"}
psg_state=psg.get_state(psg_state_query_dictionary)
state_path=os.path.join(data_directory,psg_state_name)
psg.save_state(state_path=state_path,state_dictionary=psg_state)
# Out:
#   File "<string>", line 1
# XMLSyntaxError: Char 0x0 out of allowed range, line 1, column 181

# %% [markdown]
# ## AWG setup
# Now that the PSG or master clock has been set up we must now setup the AWG (Tektronix Model AWG67122B). First we calculate the multi-sine used as a reference on port 4 of the VNA. It should contain all of the frequency components we expect to measure during the course of the experiment. The number of points required to faithfully represent this signal depends on the frequency grid and the master clock frequency set by the PSG. The length of the waveform chunk to be written is limited to 650 M Bytes where data written in Real format takes up 5 bytes. The fifth byte is the marker data.

# %%
# first create the multisine
sine_function=FunctionalModel(parameters=["f","phi"],variables=["t"],equation="cos(2*pi*f*t+phi)")
time_list=np.linspace(0.+time_shift,time_max+time_shift-time_step,number_time_points)

# calculate the phases 
phase_list = [0. for i in range(len(frequency_list))]
if re.search("sch",multisine_phase,re.IGNORECASE):
    phase_list=[]
    for frequency_index,frequency in enumerate(frequency_list):
        k=(frequency_index+1)%number_tones
        schroeder_phase=-k*(k-1)*np.pi/number_tones
        phase_list.append(schroeder_phase)
# initialize multisine to a set of zeros
multisine=np.array([0 for i in range(number_time_points)])
# add each component
for frequency_index,frequency in enumerate(frequency_list):
    sine_function.set_parameters({"f":frequency,"phi":phase_list[frequency_index]})
    multisine_component=sine_function(time_list)
    multisine=multisine+multisine_component
    
# substract the mean
# multisine=multisine-np.mean(multisine)
# normalize the multisine
# multisine=1/max(multisine)*multisine

# round the multisine to the nearest bitdepth before writing
if round_multisine_before_writing:
    discrete_steps=np.linspace(min(multisine),max(multisine),2**bit_depth)
    rounded_multisine=[]
    int_multisine=[]
    for value in multisine:
        difference_array=abs(discrete_steps-value)
        minimum_location=np.argmin(difference_array)
        rounded_multisine.append(discrete_steps[minimum_location])
        int_multisine.append(minimum_location)
    if bin_format:
        multisine=np.array(int_multisine,dtype=np.uint16)
        # Shift, now to add the marker add + 2**14 or +2**15 at the desired location
        multisine=multisine*2**6
    else:
        multisine=rounded_multisine
        
# now we add the marker. 
if marker_1:
    
    distance=int(np.floor(float(len(multisine))/float(marker_1_n_repeats)))
    for i in range(marker_1_n_repeats):
        try:
            multisine[i*distance]=multisine[i*distance]+2**14
        except:
            pass

# %%
multisine[0]
# Out:
# 29760

# %%
print("Length of discrete steps: {0}".format(len(discrete_steps)))
print("Max value of int_multisine: {0}".format(max(int_multisine)))
# Out:
# Length of discrete steps: 256
# Max value of int_multisine: 255

# %% [markdown]
# ## Verify the Multisine before writing to the AWG

# %%
# Time Domain Plot
plt.plot(time_list,multisine,label="Multisine")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (arb)")
plt.title("Reference Multisine")
print("Mean Value : {0}".format(np.mean(multisine)))
print("Length of Waveform: {0}".format(len(multisine)))
plt.show()
# Out:
# Mean Value : 8160.04352
# Length of Waveform: 400000

# %%
# Power Spectrum
plt.close()
multisine_fft=np.fft.fft(multisine)
fft_frequency_list=np.linspace(0,1/(2*time_step),number_time_points//2)
plt.loglog(fft_frequency_list,abs(multisine_fft[0:number_time_points//2]))
plt.xlabel("Frequency")
plt.ylabel("Intensity (arb)")
plt.title("Reference Multisine FFT")
#plt.xlim([min(frequency_list)-2*tone_spacing,max(frequency_list)+2*tone_spacing])
plt.show()

# %%
# Power Spectrum Zoomed In 
plt.close()
multisine_fft=np.fft.fft(multisine)
fft_frequency_list=np.linspace(0,1/(2*time_step),number_time_points//2)
plt.loglog(fft_frequency_list,abs(multisine_fft[0:number_time_points//2]))
plt.xlabel("Frequency")
plt.ylabel("Intensity (arb)")
plt.title("Reference Multisine FFT")
plt.xlim([min(frequency_list)-2*tone_spacing,max(frequency_list)+2*tone_spacing])
plt.show()

# %% [markdown]
# ## Write Measurement Phase Reference to the AWG

# %%
# create a control class for the awg
awg=VisaInstrument(awg_address)
# verify it is connected and working properly
awg.query("*IDN?")
# Out:
# The information sheet was not found defaulting to address
# u'TEKTRONIX,AWG7122B,B020393,SCPI:99.0 FW:4.6.0.7 \n'

# %% [markdown]
# ## Write to Channel 1 and Channel 2 of the AWG
# The waveform on Channel 1 and Channel 2 have to be the same length before running the AWG, so we define them both as the measurement reference waveform at first

# %%
# I am guessing that this has the possibility of kiling the oscope trigger
if bin_format:
    # turn AWG's output 1 & 2 OFF
    awg.write(':OUTPUT1:STATE OFF')
    awg.write(':OUTPUT2:STATE OFF')
    # wait...
    time.sleep(0.1)
    # UNRUN state
    awg.write('AWGCONTROL:STOP')
    # wait...
    time.sleep(0.5)

    # delete any older waveform with the same name
    awg.write('WLISt:WAVeform:DELete "{0}"'.format(waveform_name))
    time.sleep(0.05)

    # create new waveform
    awg.write('WLISt:WAVeform:NEW "{0}", {1}, INT'.format(waveform_name,len(multisine)))
    # download data
    awg.resource.write_binary_values('WLISt:WAVeform:DATA "{0}",'.format(waveform_name), multisine, datatype='H', is_big_endian=False)
    time.sleep(.1)
    # assign new waveform to channel 1 & 2
    awg.write('SOURce1:WAVeform "{0}"'.format(waveform_name))
    awg.write('SOURce2:WAVeform "{0}"'.format(waveform_name))

    # check for errors
    error_str = awg.query('SYSTEM:ERROR:NEXT?')
    # wait...
    time.sleep(.1)
    # AWG on RUN state
    awg.write('AWGCONTROL:RUN')
    # wait...
    time.sleep(0.5)
    # check if there is any errors on AWG's buffer
    error_str = awg.query('SYSTEM:ERROR:NEXT?')
    if error_str == '0,"No error"\n':
        # turn AWG's output 1 OFF
        awg.write(':OUTPUT1:STATE ON')
        awg.write(':OUTPUT2:STATE ON')

# %%
awg.query('SYSTEM:ERROR:NEXT?')
# Out:
# u'0,"No error"\n'

# %% [markdown]
# ## Setting up the VNA

# %%
vna=VNA(vna_address)
vna.query("*IDN?")
# Out:
# The information sheet was not found defaulting to address
# u'LIN\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'

# %%
# for the the phase measurement we turn off the outputs
vna.set_source_output(0)
# now we need to set up the freq of the sweep, if there is 1 harmonic a linear frequency sweep will do
if number_harmonics==1:
    vna.set_frequency((fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                (fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)
else:
    for harmonic in range(number_harmonics):
        # I am not sure if this works
        vna.add_segment((harmonic+1)*(fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                (harmonic+1)*(fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)

# %%
# verify the frequency list
vna.get_frequency_list()
# Out:
# []

# %%
vna.set_IFBW(vna_IFBW)

# %%
# inspect the traces already set up on the instrument
vna.query("CALC:PAR:CAT?")
# Out:
# u'"a1,a1,1,a2,R2,1,a3,R3,1,a4,R4,1,b1,A,1,b2,B,1,b3,C,1,b4,D,1,ratio,R1/R4,1"\n'

# %%
vna.query("CALC:PAR:CAT?").replace("\n","").split(",")[0::3]
# Out:
# [u'"a1', u'a2', u'a3', u'a4', u'b1', u'b2', u'b3', u'b4', u'ratio']

# %%
# Delete all of the traces that we do not need, in this case I will delete  all of them it leaves one trace
trace_string=vna.query("CALC:PAR:CAT?")
trace_list=trace_string.replace("\n","").split(",")[0::3] #remove endline, split on , and then take every third one
for trace in trace_list:
    vna.write("CALC:PAR:DEL '{0}'".format(trace))
print("Existing traces are {0}".format(vna.query("CALC:PAR:CAT?")))
# Out:
# Existing traces are "a1,a1,1,a

# %%
# set up the traces, we use drive_port=1 sense all of the inputs are turned off, there are combs on port 2, port 3

# first we add a trace for a each reference reciever (R1=a1)
for i in range(4):
    vna.add_trace(trace_name="a{0}".format(i+1),trace_parameter="R{0}".format(i+1),drive_port=1)
# now we add a trace for each b reciever (labelled A,B,C,D)
for i,receiver in enumerate(["A","B","C","D"]):
    vna.add_trace(trace_name="b{0}".format(i+1),trace_parameter="{0}".format(receiver),drive_port=1)
    
# now we want a ratio of R1R4 (a1/a4) <- this is the calibration phase reference / measurement phase reference
vna.add_trace(trace_name="ratio",trace_parameter="R1R4",drive_port="1")
print("Existing traces are {0}".format(vna.query("CALC:PAR:CAT?")))
# Out:
# Existing traces are "a1,a1,1,a2,R2,1,a3,R3,1,a4,R4,1,b1,A,1,b2,B,1,b3,C,1,b4,D,1,ratio,R1/R4,1"

# %%
vna.get_IFBW()
# Out:
# 10.0

# %%
# now the measured trace should be the multisine we can trigger and display the ratio to be sure
vna.trigger_sweep()
time.sleep(sweep_wait_time)
# read_trace needs to have some work
vna.write("CALC:PAR:SEL '{0}'".format("ratio"))
ratio_trace_string = vna.query("CALC:DATA? SDATA")
ratio_trace = ratio_trace_string.replace("\n","").split(",")
ratio_real = ratio_trace[0::2]
ratio_imaginary = ratio_trace[1::2]
complex_ratio =np.array([complex(float(real_value),float(ratio_imaginary[index])) for index,real_value in enumerate(ratio_real)])

# %%
plt.plot(frequency_list,abs(complex_ratio),'b-o')
plt.xlabel("Frequency")
plt.ylabel("Linear Magnitude")
plt.title("Multisine Magnitude Measured on VNA")
plt.show();

# %%
plt.plot(np.array(frequency_list),np.angle(complex_ratio,deg=1),"b-o")
plt.xlabel("Tone Offset Frequency(Hz)")
plt.ylabel("Phase (Degrees)")
plt.title("Multisine Phase Measured on VNA")
plt.show();

# %%
trace_name="a1"
# To get a broad view we can extend the frequency range
vna.set_frequency((fundamental_frequency-2*tone_spacing*(number_tones-1)/2),
                                (fundamental_frequency+2*tone_spacing*(number_tones-1)/2),2*number_tones-1)
vna.set_IFBW(1000)
# now the measured trace should be the multisine we can trigger and display the ratio to be sure
complex_ratio_list=[]
for i in range(5):
    vna.trigger_sweep()
    time.sleep(3*sweep_wait_time)
    # read_trace needs to have some work
    vna.write("CALC:PAR:SEL '{0}'".format(trace_name))
    ratio_trace_string = vna.query("CALC:DATA? SDATA")
    ratio_trace = ratio_trace_string.replace("\n","").split(",")
    ratio_real = ratio_trace[0::2]
    ratio_imaginary = ratio_trace[1::2]
    complex_ratio =np.array([complex(float(real_value),
                                     float(ratio_imaginary[index])) for index,real_value in enumerate(ratio_real)])
    complex_ratio_list.append(complex_ratio)

# %%
f_list=vna.get_frequency_list()
for index,complex_ratio in enumerate(complex_ratio_list):
    plt.plot(f_list,abs(complex_ratio),label="{0} Measurement {1}".format(trace_name,index))
plt.xlabel("Frequency")
plt.ylabel("Linear Magnitude")
plt.title("Multisine Magnitude Measured on VNA")
plt.legend()
plt.show();

# %% [markdown]
# ## Setting up the Oscilloscope

# %%
scope=HighSpeedOscope(scope_address)
# Out:
# The information sheet was not found defaulting to address

# %%
scope.get_trigger_source()

# %%
scope.query("TRIG:SOUR?")
# Out:
# u'FPAN\n'

# %%
scope.set_trigger_source(source="FPAN")

# %%
scope.set_number_points(10000)
wave=scope.measure_waves(number_frames=1)

# %%
plt.plot(wave["Time"],wave["CHAN2"])
plt.show()

# %%
wave_fft=np.fft.fft(wave["CHAN2"])
delta_time=(wave["Time"][1]-wave["Time"][0])*10**-9
fft_frequency_list=np.linspace(0,1./(2.*delta_time),len(wave["Time"])//2)
plt.loglog(fft_frequency_list,abs(wave_fft[0:len(wave["Time"])//2]))
plt.show();

# %%
wave_fft=np.fft.fft(wave["CHAN2"])
delta_time=(wave["Time"][1]-wave["Time"][0])*10**-9
fft_frequency_list=np.linspace(0,1./(2.*delta_time),len(wave["Time"])//2)
plt.loglog(fft_frequency_list,abs(wave_fft[0:len(wave["Time"])//2]))
plt.xlim([9.8*10**8,.12*10**10])
plt.show();

# %%
wave_fft=np.fft.fft(wave["CHAN3"])
delta_time=(wave["Time"][1]-wave["Time"][0])*10**-9
fft_frequency_list=np.linspace(0,1./(2.*delta_time),len(wave["Time"])//2)
plt.loglog(fft_frequency_list,abs(wave_fft[0:len(wave["Time"])//2]))
plt.show();

# %%
wave_fft=np.fft.fft(wave["CHAN3"])
delta_time=(wave["Time"][1]-wave["Time"][0])*10**-9
fft_frequency_list=np.linspace(0,1./(2.*delta_time),len(wave["Time"])//2)
plt.loglog(fft_frequency_list,abs(wave_fft[0:len(wave["Time"])//2]))
plt.xlim([9.9*10**9,1.01*10**10])
plt.show();

# %% [markdown]
# ## Sweeping the sine wave to determine phase using the oscope

# %%
whos_there()
# Out:
# Agilent Technologies,86100C,MY47440684,A.08.00
#  is at address GPIB0::7::INSTR
# Agilent Technologies,E4417A,SG55376002,A2.05.04
#  is at address GPIB0::13::INSTR
# TEKTRONIX,AWG7122B,B020393,SCPI:99.0 FW:4.6.0.7
#  is at address GPIB0::10::INSTR
# Agilent Technologies, E8267D, US46470659, C.05.26
#  is at address GPIB0::19::INSTR
# Agilent Technologies,N5245A,SG49151009,A.10.64.03
#  is at address GPIB0::16::INSTR

# %%
1./(20.*10.**-12.)*10**-9
# Out:
# 50.0

# %%
scope.getNumberPoints()
# Out:
# 10000

# %%
scope.get_timebase_scale()
# Out:
# 0.1

# %%
help(scope.measure_waves)
# Out:
# Help on method measure_waves in module pyMez.Code.InstrumentControl.Instruments:
#
# measure_waves(self, **options) method of pyMez.Code.InstrumentControl.Instruments.HighSpeedOscope instance
#     Returns data for a measurement in an AsciiDataTable

# %%
timebase_scale=.02*scope.get_number_points()/10

# %%
timebase_scale
# Out:
# 0.2

# %%
scope.set_number_points()

# %%
timebase_scale=.02*scope.get_number_points()/10
print(timebase_scale)
# Out:
# 32.768

# %%
wave_trace=scope.measure_waves()
plt.plot(wave_trace["Time"],wave_trace["CHAN2"])
plt.show()

# %%
plt.plot(wave_trace["Time"],wave_trace["CHAN2"],label="SUT")
plt.plot(wave_trace["Time"],wave_trace["CHAN3"],label="I")
plt.plot(wave_trace["Time"],wave_trace["CHAN4"],label="Q")

plt.legend()
plt.show()

# %%
# for the the phase measurement we turn off the outputs
vna.set_source_output(0)
# now we need to set up the freq of the sweep, if there is 1 harmonic a linear frequency sweep will do
if number_harmonics==1:
    vna.set_frequency((fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                (fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)
else:
    for harmonic in range(number_harmonics):
        # I am not sure if this works
        vna.add_segment((harmonic+1)*(fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                (harmonic+1)*(fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)

# %%
sweep_directory=os.path.join(data_directory,"Sweep2")
single_cosine=FunctionalModel(variables=["t"],parameters=["f","phi"],equation="cos(2*pi*f*t+phi)")
number_phases=10
phase_sweep_list=[2*np.pi*i/number_phases for i in range(number_phases)]
# Loop to measure the phase
start_timer=datetime.datetime.now()
print("Calibration Began at {0}".format(start_timer))
for frequency_index,frequency in enumerate(frequency_list[:]):
    begin_sweep_timer=datetime.datetime.now()
    print("Sweep {0} \nf : {1}\n began at {2} ".format(frequency_index,frequency,begin_sweep_timer))
    for phase in phase_sweep_list:
        
         #create the sine to write
        # ----------------------------------------------------------------------------------------------------------
        single_cosine.set_parameters({"f":frequency,"phi":phase})
        tone_data=single_cosine(time_list)

        # round the multisine to the nearest bitdepth before writing
        if round_multisine_before_writing:
            discrete_steps=np.linspace(min(tone_data),max(tone_data),2**bit_depth)
            rounded_tone_data=[]
            int_tone_data=[]
            for value in tone_data:
                difference_array=abs(discrete_steps-value)
                minimum_location=np.argmin(difference_array)
                rounded_tone_data.append(discrete_steps[minimum_location])
                int_tone_data.append(minimum_location)
            if bin_format:
                tone_data=np.array(int_tone_data,dtype=np.uint16)
                # Shift, now to add the marker add + 2**14 or +2**15 at the desired location
                tone_data=tone_data*2**6
            else:
                tone_data=rounded_tone_data

        timer=datetime.datetime.now()
        print("Writing to AWG Began at {0} ".format(timer))
        # write tone to AWG
        # --------------------------------------------------------
        tone_waveform_name="Tone_{0}_Phase_{1:03.0f}_Calibration".format(frequency_index,phase*180/np.pi)
        # save the wave for good measure
        out_file=open(os.path.join(sweep_directory,"{0}.bin".format(tone_waveform_name)),"wb")
        out_file.write(tone_data)
        out_file.close()
        # plot 
        plt.close()
        plt.plot(time_list,tone_data)
        plt.xlabel("Time (s)")
        plt.ylabel("Amplitude (arb)")
        plt.title(tone_waveform_name)
        plt.savefig(os.path.join(sweep_directory,"{0}.png".format(tone_waveform_name)))
        plt.show();
        
        if bin_format:
            # turn AWG's output 1 
            awg.write(':OUTPUT1:STATE OFF')
            time.sleep(0.1)
            # UNRUN state
            awg.write('AWGCONTROL:STOP')
            # wait...
            time.sleep(0.5)

            # delete any older waveform with the same name
            awg.write('WLISt:WAVeform:DELete "{0}"'.format(tone_waveform_name))
            time.sleep(0.05)

            # create new waveform
            awg.write('WLISt:WAVeform:NEW "{0}", {1}, INT'.format(tone_waveform_name,len(tone_data)))
            # download data
            awg.resource.write_binary_values('WLISt:WAVeform:DATA "{0}",'.format(tone_waveform_name), 
                                             tone_data, datatype='H', is_big_endian=False)
            time.sleep(0.1)
            # assign new waveform to channel 1 
            awg.write('SOURce1:WAVeform "{0}"'.format(tone_waveform_name))


            # check for errors
            error_str = awg.query('SYSTEM:ERROR:NEXT?')
            # wait...
            time.sleep(.1)
            # AWG on RUN state
            awg.write('AWGCONTROL:RUN')
            # wait...
            time.sleep(0.5)
            # check if there is any errors on AWG's buffer
            error_str = awg.query('SYSTEM:ERROR:NEXT?')
            if error_str == '0,"No error"\n':
                # turn AWG's output 1 ON
                awg.write(':OUTPUT1:STATE ON')
        timer=datetime.datetime.now()
        print("Measuring on VNA  Began at {0} ".format(timer))                
        # Measure on VNA
        # ---------------------------------------------------------------------------------------------------------
        # now the measured trace should be the multisine we can trigger and display the ratio to be sure
        vna.trigger_sweep()
        time.sleep(sweep_wait_time)
        # read_trace needs to have some work
        vna.write("CALC:PAR:SEL '{0}'".format("ratio"))
        ratio_trace_string = vna.query("CALC:DATA? SDATA")
        ratio_trace = ratio_trace_string.replace("\n","").split(",")
        ratio_real = ratio_trace[0::2]
        ratio_imaginary = ratio_trace[1::2]
        complex_ratio =np.array([complex(float(real_value),
                                         float(ratio_imaginary[index])) for index,real_value in enumerate(ratio_real)])
        
        vna_data=[[frequency_list[index],
                   real_value,
                   ratio_imaginary[index]] for index,real_value in enumerate(ratio_real)]
        options={"column_names":["Frequency","reA1RA4","imA1RA4"],"column_types":["float","float","float"],
                 "directory":sweep_directory,"specific_descriptor":tone_waveform_name,
                 "general_descriptor":"Vna_Reciever_Values","extension":"txt","data":vna_data}
        ratio_data_table=AsciiDataTable(None,**options)
        ratio_data_table.save()
        plt.close()
        plt.plot(frequency_list,abs(complex_ratio),'b-o')
        plt.xlabel("Frequency")
        plt.ylabel("Linear Magnitude")
        plt.title("Multisine Magnitude Measured on VNA")
        plt.savefig(os.path.join(sweep_directory,"Magnitude_plot_ratio_{0}.png".format(tone_waveform_name)))
        plt.show();
        plt.close()
        plt.plot(np.array(frequency_list),np.angle(complex_ratio,deg=1),"b-o")
        plt.xlabel("Tone Offset Frequency(Hz)")
        plt.ylabel("Phase (Degrees)")
        plt.title("Multisine Phase Measured on VNA")
        plt.savefig(os.path.join(sweep_directory,"Phase_plot_ratio_{0}.png".format(tone_waveform_name)))
        plt.show();
        timer=datetime.datetime.now()
        print("Measuring on Scope  Began at {0} ".format(timer))         
        # Measure on Oscope
        # ---------------------------------------------------------------------------------------------------------
        wave_trace=scope.measure_waves()
        wave_trace.save(os.path.join(sweep_directory,"scope_{0}.txt".format(tone_waveform_name)))
        plt.close()            
        plt.plot(wave_trace["Time"],wave_trace["CHAN2"],label="SUT")
        plt.plot(wave_trace["Time"],wave_trace["CHAN3"],label="I")
        plt.plot(wave_trace["Time"],wave_trace["CHAN4"],label="Q")
        plt.legend()
        plt.savefig(os.path.join(sweep_directory,"Scope_{0}.png".format(tone_waveform_name)))
        plt.show();
    end_sweep_timer=datetime.datetime.now()
    difference=end_sweep_timer-begin_sweep_timer
    print("Sweep {0} \nf : {1}\n ended at {2}\n taking {3} seonds ".format(frequency_index,
                                                                           frequency,
                                                                           end_sweep_timer,
                                                                           difference.seconds))
# Out:
# Calibration Began at 2018-10-04 14:49:39.334000
# Sweep 0
# f : 995000000.0
#  began at 2018-10-04 14:49:39.334000
# Writing to AWG Began at 2018-10-04 14:49:39.364000
# Measuring on VNA  Began at 2018-10-04 14:49:42.261000
# Measuring on Scope  Began at 2018-10-04 14:49:43.686000
# Writing to AWG Began at 2018-10-04 14:49:47.656000
# Measuring on VNA  Began at 2018-10-04 14:49:49.885000
# Measuring on Scope  Began at 2018-10-04 14:49:51.293000
# Writing to AWG Began at 2018-10-04 14:49:55.205000
# Measuring on VNA  Began at 2018-10-04 14:49:57.419000
# Measuring on Scope  Began at 2018-10-04 14:49:58.770000
# Writing to AWG Began at 2018-10-04 14:50:02.599000
# Measuring on VNA  Began at 2018-10-04 14:50:04.851000
# Measuring on Scope  Began at 2018-10-04 14:50:06.335000
# Writing to AWG Began at 2018-10-04 14:50:10.207000
# Measuring on VNA  Began at 2018-10-04 14:50:12.491000
# Measuring on Scope  Began at 2018-10-04 14:50:13.966000
# Writing to AWG Began at 2018-10-04 14:50:17.949000
# Measuring on VNA  Began at 2018-10-04 14:50:20.210000
# Measuring on Scope  Began at 2018-10-04 14:50:21.565000
# Writing to AWG Began at 2018-10-04 14:50:25.425000
# Measuring on VNA  Began at 2018-10-04 14:50:27.742000
# Measuring on Scope  Began at 2018-10-04 14:50:29.185000
# Writing to AWG Began at 2018-10-04 14:50:33.036000
# Measuring on VNA  Began at 2018-10-04 14:50:35.295000
# Measuring on Scope  Began at 2018-10-04 14:50:36.707000
# Writing to AWG Began at 2018-10-04 14:50:40.677000
# Measuring on VNA  Began at 2018-10-04 14:50:42.992000
# Measuring on Scope  Began at 2018-10-04 14:50:44.384000
# Writing to AWG Began at 2018-10-04 14:50:48.301000
# Measuring on VNA  Began at 2018-10-04 14:50:50.545000
# Measuring on Scope  Began at 2018-10-04 14:50:52.016000
# Sweep 0
# f : 995000000.0
#  ended at 2018-10-04 14:50:55.905000
#  taking 76 seonds
# Sweep 1
# f : 997500000.0
#  began at 2018-10-04 14:50:55.905000
# Writing to AWG Began at 2018-10-04 14:50:55.929000
# Measuring on VNA  Began at 2018-10-04 14:50:58.161000
# Measuring on Scope  Began at 2018-10-04 14:50:59.625000
# Writing to AWG Began at 2018-10-04 14:51:03.557000
# Measuring on VNA  Began at 2018-10-04 14:51:05.821000
# Measuring on Scope  Began at 2018-10-04 14:51:07.192000
# Writing to AWG Began at 2018-10-04 14:51:11.113000
# Measuring on VNA  Began at 2018-10-04 14:51:13.378000
# Measuring on Scope  Began at 2018-10-04 14:51:14.758000
# Writing to AWG Began at 2018-10-04 14:51:18.660000
# Measuring on VNA  Began at 2018-10-04 14:51:20.901000
# Measuring on Scope  Began at 2018-10-04 14:51:22.313000
# Writing to AWG Began at 2018-10-04 14:51:26.200000
# Measuring on VNA  Began at 2018-10-04 14:51:28.431000
# Measuring on Scope  Began at 2018-10-04 14:51:29.901000
# Writing to AWG Began at 2018-10-04 14:51:33.713000
# Measuring on VNA  Began at 2018-10-04 14:51:35.991000
# Measuring on Scope  Began at 2018-10-04 14:51:37.412000
# Writing to AWG Began at 2018-10-04 14:51:41.389000
# Measuring on VNA  Began at 2018-10-04 14:51:43.624000
# Measuring on Scope  Began at 2018-10-04 14:51:45.051000
# Writing to AWG Began at 2018-10-04 14:51:48.841000
# Measuring on VNA  Began at 2018-10-04 14:51:51.205000
# Measuring on Scope  Began at 2018-10-04 14:51:52.628000
# Writing to AWG Began at 2018-10-04 14:51:56.474000
# Measuring on VNA  Began at 2018-10-04 14:51:58.690000
# Measuring on Scope  Began at 2018-10-04 14:52:00.134000
# Writing to AWG Began at 2018-10-04 14:52:04.001000
# Measuring on VNA  Began at 2018-10-04 14:52:06.286000
# Measuring on Scope  Began at 2018-10-04 14:52:07.679000
# Sweep 1
# f : 997500000.0
#  ended at 2018-10-04 14:52:11.568000
#  taking 75 seonds
# Sweep 2
# f : 1000000000.0
#  began at 2018-10-04 14:52:11.568000
# Writing to AWG Began at 2018-10-04 14:52:11.595000
# Measuring on VNA  Began at 2018-10-04 14:52:13.864000
# Measuring on Scope  Began at 2018-10-04 14:52:15.326000
# Writing to AWG Began at 2018-10-04 14:52:19.160000
# Measuring on VNA  Began at 2018-10-04 14:52:21.483000
# Measuring on Scope  Began at 2018-10-04 14:52:23.031000
# Writing to AWG Began at 2018-10-04 14:52:26.907000
# Measuring on VNA  Began at 2018-10-04 14:52:29.174000
# Measuring on Scope  Began at 2018-10-04 14:52:30.592000
# Writing to AWG Began at 2018-10-04 14:52:34.629000
# Measuring on VNA  Began at 2018-10-04 14:52:36.868000
# Measuring on Scope  Began at 2018-10-04 14:52:38.304000
# Writing to AWG Began at 2018-10-04 14:52:42.249000
# Measuring on VNA  Began at 2018-10-04 14:52:44.521000
# Measuring on Scope  Began at 2018-10-04 14:52:45.932000
# Writing to AWG Began at 2018-10-04 14:52:49.755000
# Measuring on VNA  Began at 2018-10-04 14:52:51.982000
# Measuring on Scope  Began at 2018-10-04 14:52:53.619000
# Writing to AWG Began at 2018-10-04 14:52:57.475000
# Measuring on VNA  Began at 2018-10-04 14:52:59.752000
# Measuring on Scope  Began at 2018-10-04 14:53:01.222000
# Writing to AWG Began at 2018-10-04 14:53:05.180000
# Measuring on VNA  Began at 2018-10-04 14:53:07.455000
# Measuring on Scope  Began at 2018-10-04 14:53:08.931000
# Writing to AWG Began at 2018-10-04 14:53:12.778000
# Measuring on VNA  Began at 2018-10-04 14:53:15.080000
# Measuring on Scope  Began at 2018-10-04 14:53:16.439000
# Writing to AWG Began at 2018-10-04 14:53:20.297000
# Measuring on VNA  Began at 2018-10-04 14:53:22.536000
# Measuring on Scope  Began at 2018-10-04 14:53:23.914000
# Sweep 2
# f : 1000000000.0
#  ended at 2018-10-04 14:53:27.854000
#  taking 76 seonds
# Sweep 3
# f : 1002500000.0
#  began at 2018-10-04 14:53:27.854000
# Writing to AWG Began at 2018-10-04 14:53:27.888000
# Measuring on VNA  Began at 2018-10-04 14:53:30.140000
# Measuring on Scope  Began at 2018-10-04 14:53:31.550000
# Writing to AWG Began at 2018-10-04 14:53:35.424000
# Measuring on VNA  Began at 2018-10-04 14:53:37.693000
# Measuring on Scope  Began at 2018-10-04 14:53:39.130000
# Writing to AWG Began at 2018-10-04 14:53:42.977000
# Measuring on VNA  Began at 2018-10-04 14:53:45.183000
# Measuring on Scope  Began at 2018-10-04 14:53:46.694000
# Writing to AWG Began at 2018-10-04 14:53:50.575000
# Measuring on VNA  Began at 2018-10-04 14:53:52.833000
# Measuring on Scope  Began at 2018-10-04 14:53:54.268000
# Writing to AWG Began at 2018-10-04 14:53:58.222000
# Measuring on VNA  Began at 2018-10-04 14:54:00.489000
# Measuring on Scope  Began at 2018-10-04 14:54:01.951000
# Writing to AWG Began at 2018-10-04 14:54:05.867000
# Measuring on VNA  Began at 2018-10-04 14:54:08.109000
# Measuring on Scope  Began at 2018-10-04 14:54:09.531000
# Writing to AWG Began at 2018-10-04 14:54:13.363000
# Measuring on VNA  Began at 2018-10-04 14:54:15.619000
# Measuring on Scope  Began at 2018-10-04 14:54:17.115000
# Writing to AWG Began at 2018-10-04 14:54:21.123000
# Measuring on VNA  Began at 2018-10-04 14:54:23.391000
# Measuring on Scope  Began at 2018-10-04 14:54:24.888000
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# <ipython-input-110-e25e93d86d25> in <module>()
#     129         # Measure on Oscope
#     130         # ---------------------------------------------------------------------------------------------------------
# --> 131         wave_trace=scope.measure_waves()
#     132         wave_trace.save(os.path.join(sweep_directory,"scope_{0}.txt".format(tone_waveform_name)))
#     133         plt.close()
#
# C:\ProgramData\Anaconda2\lib\site-packages\pyMez\Code\InstrumentControl\Instruments.pyc in measure_waves(self, **options)
#    1489                 # get data
#    1490                 if re.search("asc", self.measure_options["download_format"], re.IGNORECASE):
# -> 1491                     data_column = self.resource.query(':WAV:DATA?')
#    1492                     data_column = data_column.replace("\n", "").replace("1-", "-").split(",")
#    1493                 else:
#
# C:\ProgramData\Anaconda2\lib\site-packages\pyvisa\resources\messagebased.pyc in query(self, message, delay)
#     567         if delay > 0.0:
#     568             time.sleep(delay)
# --> 569         return self.read()
#     570
#     571     def ask(self, message, delay=None):
#
# C:\ProgramData\Anaconda2\lib\site-packages\pyvisa\resources\messagebased.pyc in read(self, termination, encoding)
#     411         if termination is None:
#     412             termination = self._read_termination
# --> 413             message = self._read_raw().decode(enco)
#     414         else:
#     415             with self.read_termination_context(termination):
#
# C:\ProgramData\Anaconda2\lib\site-packages\pyvisa\resources\messagebased.pyc in _read_raw(self, size)
#     384                     logger.debug('%s - reading %d bytes (last status %r)',
#     385                                  self._resource_name, size, status)
# --> 386                     chunk, status = self.visalib.read(self.session, size)
#     387                     ret.extend(chunk)
#     388             except errors.VisaIOError as e:
#
# C:\ProgramData\Anaconda2\lib\site-packages\pyvisa\ctwrapper\functions.pyc in read(library, session, count)
#    1582     buffer = create_string_buffer(count)
#    1583     return_count = ViUInt32()
# -> 1584     ret = library.viRead(session, buffer, count, byref(return_count))
#    1585     return buffer.raw[:return_count.value], ret
#    1586
#
# C:\ProgramData\Anaconda2\lib\site-packages\pyvisa\ctwrapper\highlevel.pyc in _return_handler(self, ret_value, func, arguments)
#     186
#     187         if ret_value < 0:
# --> 188             raise errors.VisaIOError(ret_value)
#     189
#     190         if ret_value in self.issue_warning_on:
#
# VisaIOError: VI_ERROR_INV_RSRC_NAME (-1073807342): Invalid resource reference specified. Parsing error.

# %%
error_str
# Out:
# u'0,"No error"\n'
