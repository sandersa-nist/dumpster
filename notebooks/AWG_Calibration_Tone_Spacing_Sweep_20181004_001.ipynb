# %% [markdown]
# # A sweep of tone spacing for the AWG calibration

# %%
# import the pyMez packages default API
from pyMez import *
# import the Fitting module for Signal Generation and Fitting, note the namespace Code.Analysis.Fitting also works
from pyMez.Code.Analysis.Fitting import *
# Out:
# Importing pyMez, this should take roughly 30 seconds
# Importing Code.DataHandlers.GeneralModels
# It took 1.273 s to import Code.DataHandlers.GeneralModels
# Importing Code.DataHandlers.HTMLModels
# It took 0.26 s to import Code.DataHandlers.HTMLModels
# Importing Code.DataHandlers.NISTModels
# The module smithplot was not found,please put it on the python path
# It took 2.058 s to import Code.DataHandlers.NISTModels
# Importing Code.DataHandlers.TouchstoneModels
# The module smithplot was not found,please put it on the python path
# It took 0.02 s to import Code.DataHandlers.TouchstoneModels
# Importing Code.DataHandlers.XMLModels
# It took 0.25 s to import Code.DataHandlers.XMLModels
# Importing Code.DataHandlers.ZipModels
# It took 0.039 s to import Code.DataHandlers.ZipModels
# Importing Code.InstrumentControl.Experiments
# It took 4.947 s to import Code.InstrumentControl.Experiments
# Importing Code.InstrumentControl.Instruments
# It took 0.01 s to import Code.InstrumentControl.Instruments
# Importing Code.Utils.Names
# It took 0.0 s to import Code.Utils.Names
# It took 8.857 s to import all of the active modules

# %% [markdown]
# ## Setup Variables that do not change with tone spacing

# %%
# none of these instruments have xml instrument sheets, need to add them
psg_address="GPIB1::19"
vna_address="GPIB1::16"
awg_address="GPIB1::10"
scope_address="GPIB1::7::INSTR"
pm_address="GPIB1::13"
# ----------------------
vna=VNA(vna_address)
scope=HighSpeedOscope(scope_address)
awg=VisaInstrument(awg_address)
# ----------------


# this is local to the computer taking the data, the data should be copied to Q:\public\Aric\AWG_Phase_Calibration_20180927
data_directory=r'C:\Share\AWG_Phase_Calibration_20181001\Comb_Locked_PSG\Zero_Phase_10Hz'
# Experimental variables

# the psg frequency acts as the master clock
psg_amplitude=12. #psg amplitude in dBm
psg_frequency=10.*10.**9 # 10 GHz
time_step=1./psg_frequency # time step for the awg
fundamental_frequency = 1.*10.**9 # Center of the passband or fundemental frequency in Hz
number_tones = 11 # Number of tones in the modulation bandwidth including the fundamental, should be odd
number_harmonics = 1# Number of harmonics to use. The frequency grid will be n*(f-df), n*f, n*(f+df), etc
# Select the phase for the multisine    
multisine_phase="zero"
#multisine_phase="schroeder"
number_envelopes=1.

# Measurement Phase Reference Setup 
round_multisine_before_writing=True # Rounds the multisine to a desired bitdepth before writing to AWG
bit_depth=8
waveform_name="Calibration_Phase_Reference" # name of the waveform to write to the 
bin_format=True # If the wave is in 16 bit bin format
marker_1=True # If marker one is to be set
marker_1_n_repeats=1 # the rep rate of the marker as a function of number of repeats per time sequence
marker_2=False
marker_2_n_repeats=1

# VNA setup 
vna_IFBW=10
comb_frequency = 2.5*10**6
number_phases=10
vna.set_IFBW(vna_IFBW)
# Out:
# The information sheet was not found defaulting to address
# The information sheet was not found defaulting to address
# The information sheet was not found defaulting to address

# %%
# Setup the traces that we might want
# Delete all of the traces that we do not need, in this case I will delete  all of them it leaves one trace
trace_string=vna.query("CALC:PAR:CAT?")
trace_list=trace_string.replace("\n","").split(",")[0::3] #remove endline, split on , and then take every third one
for trace in trace_list:
    vna.write("CALC:PAR:DEL '{0}'".format(trace))
print("Existing traces are {0}".format(vna.query("CALC:PAR:CAT?")))
# set up the traces, we use drive_port=1 sense all of the inputs are turned off, there are combs on port 2, port 3

# first we add a trace for a each reference reciever (R1=a1)
for i in range(4):
    vna.add_trace(trace_name="a{0}".format(i+1),trace_parameter="R{0}".format(i+1),drive_port=1)
# now we add a trace for each b reciever (labelled A,B,C,D)
for i,receiver in enumerate(["A","B","C","D"]):
    vna.add_trace(trace_name="b{0}".format(i+1),trace_parameter="{0}".format(receiver),drive_port=1)
    
# now we want a ratio of R1R4 (a1/a4) <- this is the calibration phase reference / measurement phase reference
vna.add_trace(trace_name="ratio",trace_parameter="R1R4",drive_port="1")
vna.add_trace(trace_name="comb_ratio",trace_parameter="a1b2",drive_port="1")
print("Existing traces are {0}".format(vna.query("CALC:PAR:CAT?")))
# Out:
# Existing traces are "a1,a1,1"
#
# Existing traces are "a1,a1,1,a2,R2,1,a3,R3,1,a4,R4,1,b1,A,1,b2,B,1,b3,C,1,b4,D,1,ratio,R1/R4,1,comb_ratio,a1/b2,1"

# %%
tone_spacings=[10*10**6,5*10**6,2.5*10**6,2.5*10**5,2.5*10**4]
comb_spacings=[10*10**6,5*10**6,2.5*10**6]

# %%
for tone_spacing in tone_spacings:
    comb_spacing=tone_spacing in comb_spacings
    print(comb_spacing)
# Out:
# True
# True
# True
# False
# False

# %%
for tone_spacing in tone_spacings:
    comb_spacing = tone_spacing in comb_spacings
    summary_data=[]
    # now calculate the frequency_list
    frequency_list=[]
    for harmonic in range(number_harmonics):
        frequency_array=np.linspace((harmonic+1)*(fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                    (harmonic+1)*(fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)
        frequency_list=frequency_list+frequency_array.tolist()
    time_max=number_envelopes/tone_spacing
    number_time_points=int(round(time_max/time_step))
    time_shift=0.*time_step
    sweep_wait_time=2.5*float(len(frequency_list))/float(vna_IFBW)
    sweep_directory=os.path.join(data_directory,"{0}_Tones_{1:.0f}KHz_Spacing".format(number_tones,10**-3*tone_spacing))
    os.mkdir(sweep_directory)
    # first create the multisine
    sine_function=FunctionalModel(parameters=["f","phi"],variables=["t"],equation="cos(2*pi*f*t+phi)")
    time_list=np.linspace(0.+time_shift,time_max+time_shift-time_step,number_time_points)

    # calculate the phases 
    phase_list = [0. for i in range(len(frequency_list))]
    if re.search("sch",multisine_phase,re.IGNORECASE):
        phase_list=[]
        for frequency_index,frequency in enumerate(frequency_list):
            k=(frequency_index+1)%number_tones
            schroeder_phase=-k*(k-1)*np.pi/number_tones
            phase_list.append(schroeder_phase)
    # initialize multisine to a set of zeros
    multisine=np.array([0 for i in range(number_time_points)])
    # add each component
    for frequency_index,frequency in enumerate(frequency_list):
        sine_function.set_parameters({"f":frequency,"phi":phase_list[frequency_index]})
        multisine_component=sine_function(time_list)
        multisine=multisine+multisine_component

    # substract the mean
    # multisine=multisine-np.mean(multisine)
    # normalize the multisine
    # multisine=1/max(multisine)*multisine

    # round the multisine to the nearest bitdepth before writing
    if round_multisine_before_writing:
        discrete_steps=np.linspace(min(multisine),max(multisine),2**bit_depth)
        rounded_multisine=[]
        int_multisine=[]
        for value in multisine:
            difference_array=abs(discrete_steps-value)
            minimum_location=np.argmin(difference_array)
            rounded_multisine.append(discrete_steps[minimum_location])
            int_multisine.append(minimum_location)
        if bin_format:
            multisine=np.array(int_multisine,dtype=np.uint16)
            # Shift, now to add the marker add + 2**14 or +2**15 at the desired location
            multisine=multisine*2**6
        else:
            multisine=rounded_multisine

    # now we add the marker. 
    if marker_1:

        distance=int(np.floor(float(len(multisine))/float(marker_1_n_repeats)))
        for i in range(marker_1_n_repeats):
            try:
                multisine[i*distance]=multisine[i*distance]+2**14
            except:
                pass
    # I am guessing that this has the possibility of kiling the oscope trigger
    if bin_format:
        # turn AWG's output 1 & 2 OFF
        awg.write(':OUTPUT1:STATE OFF')
        awg.write(':OUTPUT2:STATE OFF')
        # wait...
        time.sleep(0.1)
        # UNRUN state
        awg.write('AWGCONTROL:STOP')
        # wait...
        time.sleep(0.5)

        # delete any older waveform with the same name
        awg.write('WLISt:WAVeform:DELete "{0}"'.format(waveform_name))
        time.sleep(0.05)

        # create new waveform
        awg.write('WLISt:WAVeform:NEW "{0}", {1}, INT'.format(waveform_name,len(multisine)))
        # download data
        awg.resource.write_binary_values('WLISt:WAVeform:DATA "{0}",'.format(waveform_name), multisine, datatype='H', is_big_endian=False)
        time.sleep(.1)
        # assign new waveform to channel 1 & 2
        awg.write('SOURce1:WAVeform "{0}"'.format(waveform_name))
        awg.write('SOURce2:WAVeform "{0}"'.format(waveform_name))

        # check for errors
        error_str = awg.query('SYSTEM:ERROR:NEXT?')
        # wait...
        time.sleep(.1)
        # AWG on RUN state
        awg.write('AWGCONTROL:RUN')
        # wait...
        time.sleep(0.5)
        # check if there is any errors on AWG's buffer
        error_str = awg.query('SYSTEM:ERROR:NEXT?')
        if error_str == '0,"No error"\n':
            # turn AWG's output 1 OFF
            awg.write(':OUTPUT1:STATE ON')
            awg.write(':OUTPUT2:STATE ON')

    if number_harmonics is 1:    
        vna.set_frequency((fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                        (fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)  
    else:
        for harmonic in range(number_harmonics):
            vna.add_segment((harmonic+1)*(fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                        (harmonic+1)*(fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)

    single_cosine=FunctionalModel(variables=["t"],parameters=["f","phi"],equation="cos(2*pi*f*t+phi)")

    phase_sweep_list=[2*np.pi*i/number_phases for i in range(number_phases)]
    # Loop to measure the phase
    start_timer=datetime.datetime.now()
    print("Calibration Began at {0}".format(start_timer))
    for frequency_index,frequency in enumerate(frequency_list[:]):
        begin_sweep_timer=datetime.datetime.now()
        print("Sweep {0} \nf : {1}\n began at {2} ".format(frequency_index,frequency,begin_sweep_timer))
        for phase_index,phase in enumerate(phase_sweep_list):

             #create the sine to write
            # ----------------------------------------------------------------------------------------------------------
            single_cosine.set_parameters({"f":frequency,"phi":phase})
            tone_data=single_cosine(time_list)

            # round the multisine to the nearest bitdepth before writing
            if round_multisine_before_writing:
                discrete_steps=np.linspace(min(tone_data),max(tone_data),2**bit_depth)
                rounded_tone_data=[]
                int_tone_data=[]
                for value in tone_data:
                    difference_array=abs(discrete_steps-value)
                    minimum_location=np.argmin(difference_array)
                    rounded_tone_data.append(discrete_steps[minimum_location])
                    int_tone_data.append(minimum_location)
                if bin_format:
                    tone_data=np.array(int_tone_data,dtype=np.uint16)
                    # Shift, now to add the marker add + 2**14 or +2**15 at the desired location
                    tone_data=tone_data*2**6
                else:
                    tone_data=rounded_tone_data

            timer=datetime.datetime.now()
            print("Writing to AWG Began at {0} ".format(timer))
            # write tone to AWG
            # --------------------------------------------------------
            tone_waveform_name="Tone_{0}_Phase_{1:03.0f}_Calibration".format(frequency_index,phase*180/np.pi)
            # save the wave for good measure
            out_file=open(os.path.join(sweep_directory,"{0}.bin".format(tone_waveform_name)),"wb")
            out_file.write(tone_data)
            out_file.close()
            # plot 
            plt.close()
            plt.plot(time_list,tone_data)
            plt.xlabel("Time (s)")
            plt.ylabel("Amplitude (arb)")
            plt.title(tone_waveform_name)
            plt.savefig(os.path.join(sweep_directory,"{0}.png".format(tone_waveform_name)))
            #plt.show();

            if bin_format:
                # turn AWG's output 1 
                awg.write(':OUTPUT1:STATE OFF')
                time.sleep(0.1)
                # UNRUN state
                awg.write('AWGCONTROL:STOP')
                # wait...
                time.sleep(0.5)

                # delete any older waveform with the same name
                awg.write('WLISt:WAVeform:DELete "{0}"'.format(tone_waveform_name))
                time.sleep(0.05)

                # create new waveform
                awg.write('WLISt:WAVeform:NEW "{0}", {1}, INT'.format(tone_waveform_name,len(tone_data)))
                # download data
                awg.resource.write_binary_values('WLISt:WAVeform:DATA "{0}",'.format(tone_waveform_name), 
                                                 tone_data, datatype='H', is_big_endian=False)
                time.sleep(0.1)
                # assign new waveform to channel 1 
                awg.write('SOURce1:WAVeform "{0}"'.format(tone_waveform_name))


                # check for errors
                error_str = awg.query('SYSTEM:ERROR:NEXT?')
                # wait...
                time.sleep(.1)
                # AWG on RUN state
                awg.write('AWGCONTROL:RUN')
                # wait...
                time.sleep(0.5)
                # check if there is any errors on AWG's buffer
                error_str = awg.query('SYSTEM:ERROR:NEXT?')
                if error_str == '0,"No error"\n':
                    # turn AWG's output 1 ON
                    awg.write(':OUTPUT1:STATE ON')
                    
            timer=datetime.datetime.now()
            print("Measuring on VNA  Began at {0} ".format(timer))                
            # Measure on VNA
            # ---------------------------------------------------------------------------------------------------------
            # now the measured trace should be the multisine we can trigger and display the ratio to be sure
            vna.trigger_sweep()
            time.sleep(sweep_wait_time)
            # read_trace needs to have some work
            # Here we read a1/a4, a1, a4
            #------------------------------------------------------------------------------------
            vna.write("CALC:PAR:SEL '{0}'".format("ratio"))
            ratio_trace_string = vna.query("CALC:DATA? SDATA")
            ratio_trace = ratio_trace_string.replace("\n","").split(",")
            ratio_real = ratio_trace[0::2]
            ratio_imaginary = ratio_trace[1::2]
            complex_ratio =np.array([complex(float(real_value),
                                             float(ratio_imaginary[index])) for index,real_value in enumerate(ratio_real)])

            vna.write("CALC:PAR:SEL '{0}'".format("a1"))
            a1_trace_string = vna.query("CALC:DATA? SDATA")
            a1_trace = a1_trace_string.replace("\n","").split(",")
            a1_real = a1_trace[0::2]
            a1_imaginary = a1_trace[1::2]
            complex_a1 =np.array([complex(float(real_value),
                                             float(a1_imaginary[index])) for index,real_value in enumerate(a1_real)])

            vna.write("CALC:PAR:SEL '{0}'".format("a4"))
            a4_trace_string = vna.query("CALC:DATA? SDATA")
            a4_trace = a4_trace_string.replace("\n","").split(",")
            a4_real = a4_trace[0::2]
            a4_imaginary = a4_trace[1::2]
            complex_a4 =np.array([complex(float(real_value),
                                             float(a4_imaginary[index])) for index,real_value in enumerate(a4_real)])
            # If the tone spacing is on the comb grid, we want a1/b2, b2, b3
            if comb_spacing:
                # this block should be replaced with vna.read_trace
                vna.write("CALC:PAR:SEL '{0}'".format("b2"))
                b2_trace_string = vna.query("CALC:DATA? SDATA")
                b2_trace = b2_trace_string.replace("\n","").split(",")
                b2_real = b2_trace[0::2]
                b2_imaginary = b2_trace[1::2]
                complex_b2 =np.array([complex(float(real_value),
                                                 float(b2_imaginary[index])) for index,real_value in enumerate(b2_real)])                

                vna.write("CALC:PAR:SEL '{0}'".format("b3"))
                b3_trace_string = vna.query("CALC:DATA? SDATA")
                b3_trace = b3_trace_string.replace("\n","").split(",")
                b3_real = b3_trace[0::2]
                b3_imaginary = b3_trace[1::2]
                complex_b3 =np.array([complex(float(real_value),
                                                 float(b3_imaginary[index])) for index,real_value in enumerate(b3_real)])                
                             
                vna.write("CALC:PAR:SEL '{0}'".format("comb_ratio"))
                comb_ratio_trace_string = vna.query("CALC:DATA? SDATA")
                comb_ratio_trace = comb_ratio_trace_string.replace("\n","").split(",")
                comb_ratio_real = comb_ratio_trace[0::2]
                comb_ratio_imaginary = comb_ratio_trace[1::2]
                complex_comb_ratio =np.array([complex(float(real_value),
                                                 float(comb_ratio_imaginary[index])) for index,real_value in enumerate(comb_ratio_real)])                
                             

                vna_data=[map(lambda x:float(x),[frequency_list[index],
                           real_value,
                           ratio_imaginary[index],
                           a1_real[index],a1_imaginary[index],
                           a4_real[index],a4_imaginary[index],
                           comb_ratio_real[index],comb_ratio_imaginary[index],
                           b2_real[index],b2_imaginary[index],
                           b3_real[index],b3_imaginary[index]]) for index,real_value in enumerate(ratio_real)]
                
                
                column_names=["Frequency",
                                         "reA1_Div_A4","imA1_Div_A4",
                                         "reA1","imA1","reA4","imA4",
                                         "reA1_Div_B2","imA1_Div_B2",
                                         "reB2","imB2","reB3","imB3"]
                options={"column_names":column_names,
                         "column_types":["float" for i in range(len(column_names))],
                         "directory":sweep_directory,"specific_descriptor":tone_waveform_name,
                         "general_descriptor":"Vna_Reciever_Values","extension":"txt","data":vna_data}                    
            else:
                
                vna_data=[map(lambda x:float(x),[frequency_list[index],
                           real_value,
                           ratio_imaginary[index],
                           a1_real[index],a1_imaginary[index],
                           a4_real[index],a4_imaginary[index]]) for index,real_value in enumerate(ratio_real)]
                options={"column_names":["Frequency","reA1_Div_A4","imA1_Div_A4","reA1","imA1","reA4","imA4"],
                         "column_types":["float" for i in range(7)],
                         "directory":sweep_directory,"specific_descriptor":tone_waveform_name,
                         "general_descriptor":"Vna_Reciever_Values","extension":"txt","data":vna_data}
            ratio_data_table=AsciiDataTable(None,**options)
            ratio_data_table.save()
            ratio_data_table.save_schema(change_extension(ratio_data_table.path,new_extension="schema"))
            plt.close()
            plt.plot(frequency_list,abs(complex_ratio),'b-o')
            plt.xlabel("Frequency (Hz)")
            plt.ylabel("Linear Magnitude")
            plt.title("Magnitude Measured on VNA")
            plt.savefig(os.path.join(sweep_directory,"Magnitude_Plot_Ratio_{0}.png".format(tone_waveform_name)))
            #plt.show();
            plt.close()
            plt.plot(np.array(frequency_list),np.angle(complex_ratio,deg=1),"b-o")
            plt.xlabel("Frequency(Hz)")
            plt.ylabel("Phase (Degrees)")
            plt.title("Phase Measured on VNA")
            plt.savefig(os.path.join(sweep_directory,"Phase_Plot_Ratio_{0}.png".format(tone_waveform_name)))
            #plt.show();
            timer=datetime.datetime.now()
            print("Measuring on Scope  Began at {0} ".format(timer))
            time.sleep(.1)
            # Measure on Oscope
            # ---------------------------------------------------------------------------------------------------------
            wave_trace=scope.measure_waves()
            time.sleep(.1)
            plt.close()            
            plt.plot(wave_trace["Time"],wave_trace["CHAN2"],label="SUT")
            plt.plot(wave_trace["Time"],wave_trace["CHAN3"],label="I")
            plt.plot(wave_trace["Time"],wave_trace["CHAN4"],label="Q")
            plt.legend()
            plt.savefig(os.path.join(sweep_directory,"Scope_{0}.png".format(tone_waveform_name)))
            #plt.show();
            fit_cosine=FunctionalModel(variables=["t"],parameters=["A","phi"],equation="A*cos(2*pi*t*{0}+phi)".format(frequency))
            x_data=10**-9*np.array(map(lambda x:float(x),wave_trace["Time"]))
            y_data=np.array(map(lambda x:float(x),wave_trace["CHAN2"]))
            fit_cosine.fit_data(x_data=x_data,y_data=y_data)
            plt.close()
            plt.plot(x_data,fit_cosine(x_data),label="Fit")
            plt.plot(x_data,y_data,label="CHAN2")
            fit_parameters=fit_cosine.parameter_values
            plt.title("Amplitude: {A} Phase: {phi}".format(**fit_parameters))
            plt.legend()
            plt.savefig(os.path.join(sweep_directory,"Scope_Fit_{0}.png".format(tone_waveform_name)))
            #plt.show();
            wave_trace.options["fit_equation"]="{0}".format(fit_cosine)
            wave_trace.options["fit_parameters"]=fit_parameters
            wave_trace.save(os.path.join(sweep_directory,"{0}_Scope_Measurement.txt".format(tone_waveform_name)))
            wave_trace.save_schema(change_extension(wave_trace.path,new_extension="schema"))

            
            # Calculate the Summary Row, A table of Tone Index, Frequency, AWG Set Amplitude, AWG Set Phase, Scope Measured Amp
            # Scope MEasured Phase, VNA Measured Amp, VNA Measured Phase and optional values if comb_spacing
            tone_index=frequency_index+1 # starts at 1
            summary_frequency=frequency  # I know it is not needed just a reminder
            AWG_set_amplitude = .5 # set by the awg after the write of the binary wave
            AWG_set_phase=phase*180/np.pi 
            scope_measured_amplitude=fit_parameters["A"]
            scope_measured_phase=fit_parameters["phi"]*180/np.pi 
            vna_measured_amplitude=abs(complex_ratio[frequency_index])
            vna_measured_phase=np.angle(complex_ratio[frequency_index],deg=True)
            if comb_spacing:
                vna_measured_amplitude_comb=abs(complex_comb_ratio[frequency_index])
                vna_measured_phase_comb=np.angle(complex_comb_ratio[frequency_index],deg=True)
                summary_row=[tone_index,summary_frequency,
                             AWG_set_amplitude,AWG_set_phase,
                             scope_measured_amplitude,scope_measured_phase,
                             vna_measured_amplitude,vna_measured_phase,
                            vna_measured_amplitude_comb,vna_measured_phase_comb]
            else:
                summary_row=[tone_index,summary_frequency,
                                 AWG_set_amplitude,AWG_set_phase,
                                 scope_measured_amplitude,scope_measured_phase,
                                 vna_measured_amplitude,vna_measured_phase]
            # Delete last waveform
            if phase_index>0:
                awg.write('WLISt:WAVeform:DELete "{0}"'.format(last_waveform_name))
            last_waveform_name=tone_waveform_name
            summary_data.append(summary_row)
            
        if comb_spacing:
            summary_column_names=["Tone","Frequency","AWG_Set_Amplitude","AWG_Set_Phase",
                                  "Scope_Amplitude","Scope_Phase","Vna_Amplitude","Vna_Phase",
                                  "Vna_Comb_Referenced_Amplitude","Vna_Comb_Referenced_Phase"]
            summary_column_units=[None,"Hz","Volts","Degrees",
                                  "Volts","Degrees",
                                  "Volts","Degrees",
                                  "Volts","Degrees"]
        else:
            summary_column_names=["Tone","Frequency","AWG_Set_Amplitude","AWG_Set_Phase",
                                  "Scope_Amplitude","Scope_Phase","Vna_Amplitude","Vna_Phase"]
            summary_column_units=[None,"Hz","Volts","Degrees",
                                  "Volts","Degrees",
                                  "Volts","Degrees"]
            
        summary_options={"column_names":summary_column_names,
                         "column_types":["float" for i in range(len(summary_column_names))],
                         "column_units":summary_column_units,
                         "directory":sweep_directory,
                         "specific_descriptor":"{0}_Tones_{1:05.0f}KHz_Spacing".format(number_tones,10**3*tone_spacing),
                         "general_descriptor":"Summary","extension":"txt","data":summary_data,
                         "metadata":{"Timestamp":"{0}".format(datetime.datetime.now()),
                                     "sweep":"{0}_Tones_{1:05.0f}KHz_Spacing".format(number_tones,10**3*tone_spacing),
                                    "tone_spacing":tone_spacing,"number_tones":number_tones,
                                     "multisine_phase":multisine_phase,"number_harmonics":number_harmonics,
                                    "frequnecy_list":frequency_list}} 
        summary_table=AsciiDataTable(None,**summary_options)
        summary_table.save()
        summary_table.save_schema(change_extension(summary_table.path,new_extension="schema"))
        end_sweep_timer=datetime.datetime.now()
        difference=end_sweep_timer-begin_sweep_timer
        print("Sweep {0} \nf : {1}\n ended at {2}\n taking {3} seonds ".format(frequency_index,
                                                                               frequency,
                                                                               end_sweep_timer,
                                                                               difference.seconds))
# Out:
# Calibration Began at 2018-10-11 21:16:29.481000
# Sweep 0
# f : 950000000.0
#  began at 2018-10-11 21:16:29.481000
# Writing to AWG Began at 2018-10-11 21:16:29.491000
# Measuring on VNA  Began at 2018-10-11 21:16:31.842000
# Measuring on Scope  Began at 2018-10-11 21:16:37.162000
# Writing to AWG Began at 2018-10-11 21:16:40.083000
# Measuring on VNA  Began at 2018-10-11 21:16:42.131000
# Measuring on Scope  Began at 2018-10-11 21:16:47.482000
# Writing to AWG Began at 2018-10-11 21:16:50.363000
# Measuring on VNA  Began at 2018-10-11 21:16:52.406000
# Measuring on Scope  Began at 2018-10-11 21:16:57.670000
# Writing to AWG Began at 2018-10-11 21:17:00.725000
# Measuring on VNA  Began at 2018-10-11 21:17:02.756000
# Measuring on Scope  Began at 2018-10-11 21:17:07.960000
# Writing to AWG Began at 2018-10-11 21:17:10.875000
# Measuring on VNA  Began at 2018-10-11 21:17:12.941000
# Measuring on Scope  Began at 2018-10-11 21:17:18.193000
# Writing to AWG Began at 2018-10-11 21:17:21.221000
# Measuring on VNA  Began at 2018-10-11 21:17:23.243000
# Measuring on Scope  Began at 2018-10-11 21:17:28.429000
# Writing to AWG Began at 2018-10-11 21:17:31.405000
# Measuring on VNA  Began at 2018-10-11 21:17:33.534000
# Measuring on Scope  Began at 2018-10-11 21:17:38.774000
# Writing to AWG Began at 2018-10-11 21:17:41.732000
# Measuring on VNA  Began at 2018-10-11 21:17:43.758000
# Measuring on Scope  Began at 2018-10-11 21:17:49.041000
# Writing to AWG Began at 2018-10-11 21:17:52.132000
# Measuring on VNA  Began at 2018-10-11 21:17:54.130000
# Measuring on Scope  Began at 2018-10-11 21:17:59.400000
# Writing to AWG Began at 2018-10-11 21:18:02.354000
# Measuring on VNA  Began at 2018-10-11 21:18:04.381000
# Measuring on Scope  Began at 2018-10-11 21:18:09.696000
# Sweep 0
# f : 950000000.0
#  ended at 2018-10-11 21:18:12.763000
#  taking 103 seonds
# Sweep 1
# f : 960000000.0
#  began at 2018-10-11 21:18:12.763000
# Writing to AWG Began at 2018-10-11 21:18:12.773000
# Measuring on VNA  Began at 2018-10-11 21:18:14.833000
# Measuring on Scope  Began at 2018-10-11 21:18:20.114000
# Writing to AWG Began at 2018-10-11 21:18:23.042000
# Measuring on VNA  Began at 2018-10-11 21:18:25.074000
# Measuring on Scope  Began at 2018-10-11 21:18:30.329000
# Writing to AWG Began at 2018-10-11 21:18:33.460000
# Measuring on VNA  Began at 2018-10-11 21:18:35.510000
# Measuring on Scope  Began at 2018-10-11 21:18:40.768000
# Writing to AWG Began at 2018-10-11 21:18:43.747000
# Measuring on VNA  Began at 2018-10-11 21:18:45.803000
# Measuring on Scope  Began at 2018-10-11 21:18:51.135000
# Writing to AWG Began at 2018-10-11 21:18:54.041000
# Measuring on VNA  Began at 2018-10-11 21:18:56.254000
# Measuring on Scope  Began at 2018-10-11 21:19:01.541000
# Writing to AWG Began at 2018-10-11 21:19:04.482000
# Measuring on VNA  Began at 2018-10-11 21:19:06.542000
# Measuring on Scope  Began at 2018-10-11 21:19:11.843000
# Writing to AWG Began at 2018-10-11 21:19:14.786000
# Measuring on VNA  Began at 2018-10-11 21:19:16.822000
# Measuring on Scope  Began at 2018-10-11 21:19:22.084000
# Writing to AWG Began at 2018-10-11 21:19:25.343000
# Measuring on VNA  Began at 2018-10-11 21:19:27.401000
# Measuring on Scope  Began at 2018-10-11 21:19:32.667000
# Writing to AWG Began at 2018-10-11 21:19:35.608000
# Measuring on VNA  Began at 2018-10-11 21:19:37.648000
# Measuring on Scope  Began at 2018-10-11 21:19:42.977000
# Writing to AWG Began at 2018-10-11 21:19:45.963000
# Measuring on VNA  Began at 2018-10-11 21:19:48.223000
# Measuring on Scope  Began at 2018-10-11 21:19:53.514000
# Sweep 1
# f : 960000000.0
#  ended at 2018-10-11 21:19:56.507000
#  taking 103 seonds
# Sweep 2
# f : 970000000.0
#  began at 2018-10-11 21:19:56.507000
# Writing to AWG Began at 2018-10-11 21:19:56.517000
# Measuring on VNA  Began at 2018-10-11 21:19:58.548000
# Measuring on Scope  Began at 2018-10-11 21:20:03.856000
# Writing to AWG Began at 2018-10-11 21:20:06.779000
# Measuring on VNA  Began at 2018-10-11 21:20:08.829000
# Measuring on Scope  Began at 2018-10-11 21:20:14.100000
# Writing to AWG Began at 2018-10-11 21:20:17.361000
# Measuring on VNA  Began at 2018-10-11 21:20:19.399000
# Measuring on Scope  Began at 2018-10-11 21:20:24.676000
# Writing to AWG Began at 2018-10-11 21:20:27.655000
# Measuring on VNA  Began at 2018-10-11 21:20:29.696000
# Measuring on Scope  Began at 2018-10-11 21:20:34.905000
# Writing to AWG Began at 2018-10-11 21:20:37.840000
# Measuring on VNA  Began at 2018-10-11 21:20:39.871000
# Measuring on Scope  Began at 2018-10-11 21:20:45.077000
# Writing to AWG Began at 2018-10-11 21:20:48.366000
# Measuring on VNA  Began at 2018-10-11 21:20:50.399000
# Measuring on Scope  Began at 2018-10-11 21:20:55.661000
# Writing to AWG Began at 2018-10-11 21:20:58.625000
# Measuring on VNA  Began at 2018-10-11 21:21:00.707000
# Measuring on Scope  Began at 2018-10-11 21:21:05.923000
# Writing to AWG Began at 2018-10-11 21:21:08.761000
# Measuring on VNA  Began at 2018-10-11 21:21:10.821000
# Measuring on Scope  Began at 2018-10-11 21:21:16.104000
# Writing to AWG Began at 2018-10-11 21:21:19.036000
# Measuring on VNA  Began at 2018-10-11 21:21:21.102000
# Measuring on Scope  Began at 2018-10-11 21:21:26.387000
# Writing to AWG Began at 2018-10-11 21:21:29.633000
# Measuring on VNA  Began at 2018-10-11 21:21:31.687000
# Measuring on Scope  Began at 2018-10-11 21:21:36.938000
# Sweep 2
# f : 970000000.0
#  ended at 2018-10-11 21:21:39.892000
#  taking 103 seonds
# Sweep 3
# f : 980000000.0
#  began at 2018-10-11 21:21:39.902000
# Writing to AWG Began at 2018-10-11 21:21:39.902000
# Measuring on VNA  Began at 2018-10-11 21:21:41.938000
# Measuring on Scope  Began at 2018-10-11 21:21:47.226000
# Writing to AWG Began at 2018-10-11 21:21:50.132000
# Measuring on VNA  Began at 2018-10-11 21:21:52.196000
# Measuring on Scope  Began at 2018-10-11 21:21:57.457000
# Writing to AWG Began at 2018-10-11 21:22:00.425000
# Measuring on VNA  Began at 2018-10-11 21:22:02.456000
# Measuring on Scope  Began at 2018-10-11 21:22:08.027000
# Writing to AWG Began at 2018-10-11 21:22:11.014000
# Measuring on VNA  Began at 2018-10-11 21:22:13.064000
# Measuring on Scope  Began at 2018-10-11 21:22:18.314000
# Writing to AWG Began at 2018-10-11 21:22:21.259000
# Measuring on VNA  Began at 2018-10-11 21:22:23.304000
# Measuring on Scope  Began at 2018-10-11 21:22:28.568000
# Writing to AWG Began at 2018-10-11 21:22:31.639000
# Measuring on VNA  Began at 2018-10-11 21:22:33.660000
# Measuring on Scope  Began at 2018-10-11 21:22:38.875000
# Writing to AWG Began at 2018-10-11 21:22:41.757000
# Measuring on VNA  Began at 2018-10-11 21:22:43.783000
# Measuring on Scope  Began at 2018-10-11 21:22:49.320000
# Writing to AWG Began at 2018-10-11 21:22:52.238000
# Measuring on VNA  Began at 2018-10-11 21:22:54.280000
# Measuring on Scope  Began at 2018-10-11 21:22:59.558000
# Writing to AWG Began at 2018-10-11 21:23:02.653000
# Measuring on VNA  Began at 2018-10-11 21:23:04.688000
# Measuring on Scope  Began at 2018-10-11 21:23:09.951000
# Writing to AWG Began at 2018-10-11 21:23:12.895000
# Measuring on VNA  Began at 2018-10-11 21:23:14.907000
# Measuring on Scope  Began at 2018-10-11 21:23:20.212000
# Sweep 3
# f : 980000000.0
#  ended at 2018-10-11 21:23:23.201000
#  taking 103 seonds
# Sweep 4
# f : 990000000.0
#  began at 2018-10-11 21:23:23.201000
# Writing to AWG Began at 2018-10-11 21:23:23.201000
# Measuring on VNA  Began at 2018-10-11 21:23:25.178000
# Measuring on Scope  Began at 2018-10-11 21:23:30.538000
# Writing to AWG Began at 2018-10-11 21:23:33.992000
# Measuring on VNA  Began at 2018-10-11 21:23:36.052000
# Measuring on Scope  Began at 2018-10-11 21:23:41.348000
# Writing to AWG Began at 2018-10-11 21:23:44.287000
# Measuring on VNA  Began at 2018-10-11 21:23:46.321000
# Measuring on Scope  Began at 2018-10-11 21:23:51.575000
# Writing to AWG Began at 2018-10-11 21:23:54.615000
# Measuring on VNA  Began at 2018-10-11 21:23:56.649000
# Measuring on Scope  Began at 2018-10-11 21:24:01.973000
# Writing to AWG Began at 2018-10-11 21:24:04.954000
# Measuring on VNA  Began at 2018-10-11 21:24:07
# Measuring on Scope  Began at 2018-10-11 21:24:12.233000
# Writing to AWG Began at 2018-10-11 21:24:15.259000
# Measuring on VNA  Began at 2018-10-11 21:24:17.288000
# Measuring on Scope  Began at 2018-10-11 21:24:22.555000
# Writing to AWG Began at 2018-10-11 21:24:25.984000
# Measuring on VNA  Began at 2018-10-11 21:24:28.019000
# Measuring on Scope  Began at 2018-10-11 21:24:33.203000
# Writing to AWG Began at 2018-10-11 21:24:36.138000
# Measuring on VNA  Began at 2018-10-11 21:24:38.202000
# Measuring on Scope  Began at 2018-10-11 21:24:43.509000
# Writing to AWG Began at 2018-10-11 21:24:46.570000
# Measuring on VNA  Began at 2018-10-11 21:24:48.621000
# Measuring on Scope  Began at 2018-10-11 21:24:53.855000
# Writing to AWG Began at 2018-10-11 21:24:56.836000
# Measuring on VNA  Began at 2018-10-11 21:24:58.879000
# Measuring on Scope  Began at 2018-10-11 21:25:04.142000
# Sweep 4
# f : 990000000.0
#  ended at 2018-10-11 21:25:07.130000
#  taking 103 seonds
# Sweep 5
# f : 1000000000.0
#  began at 2018-10-11 21:25:07.130000
# Writing to AWG Began at 2018-10-11 21:25:07.140000
# Measuring on VNA  Began at 2018-10-11 21:25:09.171000
# Measuring on Scope  Began at 2018-10-11 21:25:14.372000
# Writing to AWG Began at 2018-10-11 21:25:17.354000
# Measuring on VNA  Began at 2018-10-11 21:25:19.802000
# Measuring on Scope  Began at 2018-10-11 21:25:25.104000
# Writing to AWG Began at 2018-10-11 21:25:28.086000
# Measuring on VNA  Began at 2018-10-11 21:25:30.120000
# Measuring on Scope  Began at 2018-10-11 21:25:35.410000
# Writing to AWG Began at 2018-10-11 21:25:38.353000
# Measuring on VNA  Began at 2018-10-11 21:25:40.411000
# Measuring on Scope  Began at 2018-10-11 21:25:45.772000
# Writing to AWG Began at 2018-10-11 21:25:48.706000
# Measuring on VNA  Began at 2018-10-11 21:25:50.749000
# Measuring on Scope  Began at 2018-10-11 21:25:56.032000
# Writing to AWG Began at 2018-10-11 21:25:59.009000
# Measuring on VNA  Began at 2018-10-11 21:26:01.050000
# Measuring on Scope  Began at 2018-10-11 21:26:06.351000
# Writing to AWG Began at 2018-10-11 21:26:09.335000
# Measuring on VNA  Began at 2018-10-11 21:26:11.365000
# Measuring on Scope  Began at 2018-10-11 21:26:16.649000
# Writing to AWG Began at 2018-10-11 21:26:20.124000
# Measuring on VNA  Began at 2018-10-11 21:26:22.146000
# Measuring on Scope  Began at 2018-10-11 21:26:27.372000
# Writing to AWG Began at 2018-10-11 21:26:30.329000
# Measuring on VNA  Began at 2018-10-11 21:26:32.358000
# Measuring on Scope  Began at 2018-10-11 21:26:37.691000
# Writing to AWG Began at 2018-10-11 21:26:40.750000
# Measuring on VNA  Began at 2018-10-11 21:26:42.798000
# Measuring on Scope  Began at 2018-10-11 21:26:48.049000
# Sweep 5
# f : 1000000000.0
#  ended at 2018-10-11 21:26:50.988000
#  taking 103 seonds
# Sweep 6
# f : 1010000000.0
#  began at 2018-10-11 21:26:50.988000
# Writing to AWG Began at 2018-10-11 21:26:50.998000
# Measuring on VNA  Began at 2018-10-11 21:26:53.040000
# Measuring on Scope  Began at 2018-10-11 21:26:58.256000
# Writing to AWG Began at 2018-10-11 21:27:01.181000
# Measuring on VNA  Began at 2018-10-11 21:27:03.278000
# Measuring on Scope  Began at 2018-10-11 21:27:08.486000
# Writing to AWG Began at 2018-10-11 21:27:11.465000
# Measuring on VNA  Began at 2018-10-11 21:27:13.499000
# Measuring on Scope  Began at 2018-10-11 21:27:18.774000
# Writing to AWG Began at 2018-10-11 21:27:21.951000
# Measuring on VNA  Began at 2018-10-11 21:27:23.998000
# Measuring on Scope  Began at 2018-10-11 21:27:29.769000
# Writing to AWG Began at 2018-10-11 21:27:32.711000
# Measuring on VNA  Began at 2018-10-11 21:27:34.769000
# Measuring on Scope  Began at 2018-10-11 21:27:40.054000
# Writing to AWG Began at 2018-10-11 21:27:43.079000
# Measuring on VNA  Began at 2018-10-11 21:27:45.127000
# Measuring on Scope  Began at 2018-10-11 21:27:50.317000
# Writing to AWG Began at 2018-10-11 21:27:53.253000
# Measuring on VNA  Began at 2018-10-11 21:27:55.298000
# Measuring on Scope  Began at 2018-10-11 21:28:00.489000
# Writing to AWG Began at 2018-10-11 21:28:03.492000
# Measuring on VNA  Began at 2018-10-11 21:28:05.526000
# Measuring on Scope  Began at 2018-10-11 21:28:10.693000
# Writing to AWG Began at 2018-10-11 21:28:13.711000
# Measuring on VNA  Began at 2018-10-11 21:28:15.783000
# Measuring on Scope  Began at 2018-10-11 21:28:21
# Writing to AWG Began at 2018-10-11 21:28:23.958000
# Measuring on VNA  Began at 2018-10-11 21:28:26.001000
# Measuring on Scope  Began at 2018-10-11 21:28:31.260000
# Sweep 6
# f : 1010000000.0
#  ended at 2018-10-11 21:28:34.771000
#  taking 103 seonds
# Sweep 7
# f : 1020000000.0
#  began at 2018-10-11 21:28:34.771000
# Writing to AWG Began at 2018-10-11 21:28:34.781000
# Measuring on VNA  Began at 2018-10-11 21:28:36.828000
# Measuring on Scope  Began at 2018-10-11 21:28:42.114000
# Writing to AWG Began at 2018-10-11 21:28:45.242000
# Measuring on VNA  Began at 2018-10-11 21:28:47.280000
# Measuring on Scope  Began at 2018-10-11 21:28:52.587000
# Writing to AWG Began at 2018-10-11 21:28:55.499000
# Measuring on VNA  Began at 2018-10-11 21:28:57.526000
# Measuring on Scope  Began at 2018-10-11 21:29:02.845000
# Writing to AWG Began at 2018-10-11 21:29:05.872000
# Measuring on VNA  Began at 2018-10-11 21:29:07.936000
# Measuring on Scope  Began at 2018-10-11 21:29:13.201000
# Writing to AWG Began at 2018-10-11 21:29:16.183000
# Measuring on VNA  Began at 2018-10-11 21:29:18.249000
# Measuring on Scope  Began at 2018-10-11 21:29:23.512000
# Writing to AWG Began at 2018-10-11 21:29:26.585000
# Measuring on VNA  Began at 2018-10-11 21:29:28.625000
# Measuring on Scope  Began at 2018-10-11 21:29:33.893000
# Writing to AWG Began at 2018-10-11 21:29:36.852000
# Measuring on VNA  Began at 2018-10-11 21:29:38.884000
# Measuring on Scope  Began at 2018-10-11 21:29:44.204000
# Writing to AWG Began at 2018-10-11 21:29:47.174000
# Measuring on VNA  Began at 2018-10-11 21:29:49.230000
# Measuring on Scope  Began at 2018-10-11 21:29:54.570000
# Writing to AWG Began at 2018-10-11 21:29:58.204000
# Measuring on VNA  Began at 2018-10-11 21:30:00.234000
# Measuring on Scope  Began at 2018-10-11 21:30:05.462000
# Writing to AWG Began at 2018-10-11 21:30:08.430000
# Measuring on VNA  Began at 2018-10-11 21:30:10.464000
# Measuring on Scope  Began at 2018-10-11 21:30:15.769000
# Sweep 7
# f : 1020000000.0
#  ended at 2018-10-11 21:30:18.749000
#  taking 103 seonds
# Sweep 8
# f : 1030000000.0
#  began at 2018-10-11 21:30:18.749000
# Writing to AWG Began at 2018-10-11 21:30:18.759000
# Measuring on VNA  Began at 2018-10-11 21:30:20.795000
# Measuring on Scope  Began at 2018-10-11 21:30:26.018000
# Writing to AWG Began at 2018-10-11 21:30:28.874000
# Measuring on VNA  Began at 2018-10-11 21:30:30.906000
# Measuring on Scope  Began at 2018-10-11 21:30:36.083000
# Writing to AWG Began at 2018-10-11 21:30:39.085000
# Measuring on VNA  Began at 2018-10-11 21:30:41.115000
# Measuring on Scope  Began at 2018-10-11 21:30:46.363000
# Writing to AWG Began at 2018-10-11 21:30:49.468000
# Measuring on VNA  Began at 2018-10-11 21:30:51.490000
# Measuring on Scope  Began at 2018-10-11 21:30:56.779000
# Writing to AWG Began at 2018-10-11 21:30:59.784000
# Measuring on VNA  Began at 2018-10-11 21:31:01.841000
# Measuring on Scope  Began at 2018-10-11 21:31:07.038000
# Writing to AWG Began at 2018-10-11 21:31:10.083000
# Measuring on VNA  Began at 2018-10-11 21:31:12.140000
# Measuring on Scope  Began at 2018-10-11 21:31:17.382000
# Writing to AWG Began at 2018-10-11 21:31:20.912000
# Measuring on VNA  Began at 2018-10-11 21:31:22.952000
# Measuring on Scope  Began at 2018-10-11 21:31:28.260000
# Writing to AWG Began at 2018-10-11 21:31:31.277000
# Measuring on VNA  Began at 2018-10-11 21:31:33.341000
# Measuring on Scope  Began at 2018-10-11 21:31:38.692000
# Writing to AWG Began at 2018-10-11 21:31:41.692000
# Measuring on VNA  Began at 2018-10-11 21:31:43.741000
# Measuring on Scope  Began at 2018-10-11 21:31:49.014000
# Writing to AWG Began at 2018-10-11 21:31:52.026000
# Measuring on VNA  Began at 2018-10-11 21:31:54.066000
# Measuring on Scope  Began at 2018-10-11 21:31:59.351000
# Sweep 8
# f : 1030000000.0
#  ended at 2018-10-11 21:32:02.315000
#  taking 103 seonds
# Sweep 9
# f : 1040000000.0
#  began at 2018-10-11 21:32:02.315000
# Writing to AWG Began at 2018-10-11 21:32:02.325000
# Measuring on VNA  Began at 2018-10-11 21:32:04.355000
# Measuring on Scope  Began at 2018-10-11 21:32:09.663000
# Writing to AWG Began at 2018-10-11 21:32:12.605000
# Measuring on VNA  Began at 2018-10-11 21:32:14.663000
# Measuring on Scope  Began at 2018-10-11 21:32:19.901000
# Writing to AWG Began at 2018-10-11 21:32:22.861000
# Measuring on VNA  Began at 2018-10-11 21:32:24.887000
# Measuring on Scope  Began at 2018-10-11 21:32:30.145000
# Writing to AWG Began at 2018-10-11 21:32:33.288000
# Measuring on VNA  Began at 2018-10-11 21:32:35.340000
# Measuring on Scope  Began at 2018-10-11 21:32:40.644000
# Writing to AWG Began at 2018-10-11 21:32:43.623000
# Measuring on VNA  Began at 2018-10-11 21:32:45.665000
# Measuring on Scope  Began at 2018-10-11 21:32:50.875000
# Writing to AWG Began at 2018-10-11 21:32:54.505000
# Measuring on VNA  Began at 2018-10-11 21:32:56.537000
# Measuring on Scope  Began at 2018-10-11 21:33:01.920000
# Writing to AWG Began at 2018-10-11 21:33:04.919000
# Measuring on VNA  Began at 2018-10-11 21:33:06.961000
# Measuring on Scope  Began at 2018-10-11 21:33:12.314000
# Writing to AWG Began at 2018-10-11 21:33:15.224000
# Measuring on VNA  Began at 2018-10-11 21:33:17.278000
# Measuring on Scope  Began at 2018-10-11 21:33:22.586000
# Writing to AWG Began at 2018-10-11 21:33:25.586000
# Measuring on VNA  Began at 2018-10-11 21:33:27.662000
# Measuring on Scope  Began at 2018-10-11 21:33:32.921000
# Writing to AWG Began at 2018-10-11 21:33:35.951000
# Measuring on VNA  Began at 2018-10-11 21:33:37.995000
# Measuring on Scope  Began at 2018-10-11 21:33:43.216000
# Sweep 9
# f : 1040000000.0
#  ended at 2018-10-11 21:33:46.224000
#  taking 103 seonds
# Sweep 10
# f : 1050000000.0
#  began at 2018-10-11 21:33:46.224000
# Writing to AWG Began at 2018-10-11 21:33:46.234000
# Measuring on VNA  Began at 2018-10-11 21:33:48.278000
# Measuring on Scope  Began at 2018-10-11 21:33:53.472000
# Writing to AWG Began at 2018-10-11 21:33:56.532000
# Measuring on VNA  Began at 2018-10-11 21:33:58.566000
# Measuring on Scope  Began at 2018-10-11 21:34:03.815000
# Writing to AWG Began at 2018-10-11 21:34:06.787000
# Measuring on VNA  Began at 2018-10-11 21:34:08.820000
# Measuring on Scope  Began at 2018-10-11 21:34:14.095000
# Writing to AWG Began at 2018-10-11 21:34:17.111000
# Measuring on VNA  Began at 2018-10-11 21:34:19.135000
# Measuring on Scope  Began at 2018-10-11 21:34:24.432000
# Writing to AWG Began at 2018-10-11 21:34:27.460000
# Measuring on VNA  Began at 2018-10-11 21:34:29.493000
# Measuring on Scope  Began at 2018-10-11 21:34:34.796000
# Writing to AWG Began at 2018-10-11 21:34:38.552000
# Measuring on VNA  Began at 2018-10-11 21:34:40.596000
# Measuring on Scope  Began at 2018-10-11 21:34:45.875000
# Writing to AWG Began at 2018-10-11 21:34:48.899000
# Measuring on VNA  Began at 2018-10-11 21:34:50.946000
# Measuring on Scope  Began at 2018-10-11 21:34:56.198000
# Writing to AWG Began at 2018-10-11 21:34:59.241000
# Measuring on VNA  Began at 2018-10-11 21:35:01.301000
# Measuring on Scope  Began at 2018-10-11 21:35:06.537000
# Writing to AWG Began at 2018-10-11 21:35:09.480000
# Measuring on VNA  Began at 2018-10-11 21:35:11.516000
# Measuring on Scope  Began at 2018-10-11 21:35:16.805000
# Writing to AWG Began at 2018-10-11 21:35:19.893000
# Measuring on VNA  Began at 2018-10-11 21:35:21.916000
# Measuring on Scope  Began at 2018-10-11 21:35:27.157000
# Sweep 10
# f : 1050000000.0
#  ended at 2018-10-11 21:35:30.115000
#  taking 103 seonds
# Calibration Began at 2018-10-11 21:35:32.130000
# Sweep 0
# f : 975000000.0
#  began at 2018-10-11 21:35:32.130000
# Writing to AWG Began at 2018-10-11 21:35:32.140000
# Measuring on VNA  Began at 2018-10-11 21:35:34.291000
# Measuring on Scope  Began at 2018-10-11 21:35:39.530000
# Writing to AWG Began at 2018-10-11 21:35:42.461000
# Measuring on VNA  Began at 2018-10-11 21:35:44.503000
# Measuring on Scope  Began at 2018-10-11 21:35:49.745000
# Writing to AWG Began at 2018-10-11 21:35:52.925000
# Measuring on VNA  Began at 2018-10-11 21:35:54.989000
# Measuring on Scope  Began at 2018-10-11 21:36:00.231000
# Writing to AWG Began at 2018-10-11 21:36:03.274000
# Measuring on VNA  Began at 2018-10-11 21:36:05.323000
# Measuring on Scope  Began at 2018-10-11 21:36:10.574000
# Writing to AWG Began at 2018-10-11 21:36:13.589000
# Measuring on VNA  Began at 2018-10-11 21:36:15.632000
# Measuring on Scope  Began at 2018-10-11 21:36:20.924000
# Writing to AWG Began at 2018-10-11 21:36:23.953000
# Measuring on VNA  Began at 2018-10-11 21:36:26.002000
# Measuring on Scope  Began at 2018-10-11 21:36:31.258000
# Writing to AWG Began at 2018-10-11 21:36:35.161000
# Measuring on VNA  Began at 2018-10-11 21:36:37.220000
# Measuring on Scope  Began at 2018-10-11 21:36:42.426000
# Writing to AWG Began at 2018-10-11 21:36:45.422000
# Measuring on VNA  Began at 2018-10-11 21:36:47.474000
# Measuring on Scope  Began at 2018-10-11 21:36:52.746000
# Writing to AWG Began at 2018-10-11 21:36:55.889000
# Measuring on VNA  Began at 2018-10-11 21:36:57.938000
# Measuring on Scope  Began at 2018-10-11 21:37:03.285000
# Writing to AWG Began at 2018-10-11 21:37:06.497000
# Measuring on VNA  Began at 2018-10-11 21:37:08.546000
# Measuring on Scope  Began at 2018-10-11 21:37:13.759000
# Sweep 0
# f : 975000000.0
#  ended at 2018-10-11 21:37:16.756000
#  taking 104 seonds
# Sweep 1
# f : 980000000.0
#  began at 2018-10-11 21:37:16.756000
# Writing to AWG Began at 2018-10-11 21:37:16.766000
# Measuring on VNA  Began at 2018-10-11 21:37:18.797000
# Measuring on Scope  Began at 2018-10-11 21:37:24.106000
# Writing to AWG Began at 2018-10-11 21:37:27.118000
# Measuring on VNA  Began at 2018-10-11 21:37:29.176000
# Measuring on Scope  Began at 2018-10-11 21:37:34.427000
# Writing to AWG Began at 2018-10-11 21:37:37.438000
# Measuring on VNA  Began at 2018-10-11 21:37:39.506000
# Measuring on Scope  Began at 2018-10-11 21:37:44.770000
# Writing to AWG Began at 2018-10-11 21:37:47.754000
# Measuring on VNA  Began at 2018-10-11 21:37:49.821000
# Measuring on Scope  Began at 2018-10-11 21:37:55.076000
# Writing to AWG Began at 2018-10-11 21:37:58.064000
# Measuring on VNA  Began at 2018-10-11 21:38:00.133000
# Measuring on Scope  Began at 2018-10-11 21:38:05.416000
# Writing to AWG Began at 2018-10-11 21:38:08.426000
# Measuring on VNA  Began at 2018-10-11 21:38:10.486000
# Measuring on Scope  Began at 2018-10-11 21:38:15.690000
# Writing to AWG Began at 2018-10-11 21:38:18.687000
# Measuring on VNA  Began at 2018-10-11 21:38:20.725000
# Measuring on Scope  Began at 2018-10-11 21:38:25.994000
# Writing to AWG Began at 2018-10-11 21:38:29.099000
# Measuring on VNA  Began at 2018-10-11 21:38:32.036000
# Measuring on Scope  Began at 2018-10-11 21:38:37.283000
# Writing to AWG Began at 2018-10-11 21:38:40.256000
# Measuring on VNA  Began at 2018-10-11 21:38:42.314000
# Measuring on Scope  Began at 2018-10-11 21:38:47.646000
# Writing to AWG Began at 2018-10-11 21:38:50.529000
# Measuring on VNA  Began at 2018-10-11 21:38:52.576000
# Measuring on Scope  Began at 2018-10-11 21:38:57.832000
# Sweep 1
# f : 980000000.0
#  ended at 2018-10-11 21:39:00.807000
#  taking 104 seonds
# Sweep 2
# f : 985000000.0
#  began at 2018-10-11 21:39:00.807000
# Writing to AWG Began at 2018-10-11 21:39:00.827000
# Measuring on VNA  Began at 2018-10-11 21:39:02.876000
# Measuring on Scope  Began at 2018-10-11 21:39:08.128000
# Writing to AWG Began at 2018-10-11 21:39:11.382000
# Measuring on VNA  Began at 2018-10-11 21:39:13.442000
# Measuring on Scope  Began at 2018-10-11 21:39:18.733000
# Writing to AWG Began at 2018-10-11 21:39:21.600000
# Measuring on VNA  Began at 2018-10-11 21:39:23.606000
# Measuring on Scope  Began at 2018-10-11 21:39:28.809000
# Writing to AWG Began at 2018-10-11 21:39:31.714000
# Measuring on VNA  Began at 2018-10-11 21:39:33.772000
# Measuring on Scope  Began at 2018-10-11 21:39:38.963000
# Writing to AWG Began at 2018-10-11 21:39:41.826000
# Measuring on VNA  Began at 2018-10-11 21:39:43.893000
# Measuring on Scope  Began at 2018-10-11 21:39:49.091000
# Writing to AWG Began at 2018-10-11 21:39:51.981000
# Measuring on VNA  Began at 2018-10-11 21:39:54.050000
# Measuring on Scope  Began at 2018-10-11 21:39:59.245000
# Writing to AWG Began at 2018-10-11 21:40:02.278000
# Measuring on VNA  Began at 2018-10-11 21:40:04.347000
# Measuring on Scope  Began at 2018-10-11 21:40:09.583000
# Writing to AWG Began at 2018-10-11 21:40:12.609000
# Measuring on VNA  Began at 2018-10-11 21:40:14.686000
# Measuring on Scope  Began at 2018-10-11 21:40:19.951000
# Writing to AWG Began at 2018-10-11 21:40:23.023000
# Measuring on VNA  Began at 2018-10-11 21:40:25.065000
# Measuring on Scope  Began at 2018-10-11 21:40:30.310000
# Writing to AWG Began at 2018-10-11 21:40:33.275000
# Measuring on VNA  Began at 2018-10-11 21:40:35.359000
# Measuring on Scope  Began at 2018-10-11 21:40:40.693000
# Sweep 2
# f : 985000000.0
#  ended at 2018-10-11 21:40:44.800000
#  taking 103 seonds
# Sweep 3
# f : 990000000.0
#  began at 2018-10-11 21:40:44.800000
# Writing to AWG Began at 2018-10-11 21:40:44.810000
# Measuring on VNA  Began at 2018-10-11 21:40:46.872000
# Measuring on Scope  Began at 2018-10-11 21:40:52.126000
# Writing to AWG Began at 2018-10-11 21:40:55.145000
# Measuring on VNA  Began at 2018-10-11 21:40:57.230000
# Measuring on Scope  Began at 2018-10-11 21:41:02.445000
# Writing to AWG Began at 2018-10-11 21:41:05.428000
# Measuring on VNA  Began at 2018-10-11 21:41:07.479000
# Measuring on Scope  Began at 2018-10-11 21:41:12.820000
# Writing to AWG Began at 2018-10-11 21:41:15.802000
# Measuring on VNA  Began at 2018-10-11 21:41:17.857000
# Measuring on Scope  Began at 2018-10-11 21:41:23.142000
# Writing to AWG Began at 2018-10-11 21:41:26.111000
# Measuring on VNA  Began at 2018-10-11 21:41:28.165000
# Measuring on Scope  Began at 2018-10-11 21:41:33.427000
# Writing to AWG Began at 2018-10-11 21:41:36.433000
# Measuring on VNA  Began at 2018-10-11 21:41:38.485000
# Measuring on Scope  Began at 2018-10-11 21:41:43.763000
# Writing to AWG Began at 2018-10-11 21:41:46.829000
# Measuring on VNA  Began at 2018-10-11 21:41:48.879000
# Measuring on Scope  Began at 2018-10-11 21:41:54.173000
# Writing to AWG Began at 2018-10-11 21:41:57.326000
# Measuring on VNA  Began at 2018-10-11 21:41:59.406000
# Measuring on Scope  Began at 2018-10-11 21:42:04.690000
# Writing to AWG Began at 2018-10-11 21:42:07.718000
# Measuring on VNA  Began at 2018-10-11 21:42:09.745000
# Measuring on Scope  Began at 2018-10-11 21:42:15.061000
# Writing to AWG Began at 2018-10-11 21:42:18.153000
# Measuring on VNA  Began at 2018-10-11 21:42:20.204000
# Measuring on Scope  Began at 2018-10-11 21:42:25.514000
# Sweep 3
# f : 990000000.0
#  ended at 2018-10-11 21:42:28.734000
#  taking 103 seonds
# Sweep 4
# f : 995000000.0
#  began at 2018-10-11 21:42:28.734000
# Writing to AWG Began at 2018-10-11 21:42:28.744000
# Measuring on VNA  Began at 2018-10-11 21:42:30.813000
# Measuring on Scope  Began at 2018-10-11 21:42:36.080000
# Writing to AWG Began at 2018-10-11 21:42:39.188000
# Measuring on VNA  Began at 2018-10-11 21:42:41.258000
# Measuring on Scope  Began at 2018-10-11 21:42:46.551000
# Writing to AWG Began at 2018-10-11 21:42:49.674000
# Measuring on VNA  Began at 2018-10-11 21:42:51.744000
# Measuring on Scope  Began at 2018-10-11 21:42:57.076000
# Writing to AWG Began at 2018-10-11 21:43:00.176000
# Measuring on VNA  Began at 2018-10-11 21:43:02.216000
# Measuring on Scope  Began at 2018-10-11 21:43:07.489000
# Writing to AWG Began at 2018-10-11 21:43:11.550000
# Measuring on VNA  Began at 2018-10-11 21:43:13.601000
# Measuring on Scope  Began at 2018-10-11 21:43:18.866000
# Writing to AWG Began at 2018-10-11 21:43:21.845000
# Measuring on VNA  Began at 2018-10-11 21:43:23.893000
# Measuring on Scope  Began at 2018-10-11 21:43:29.130000
# Writing to AWG Began at 2018-10-11 21:43:32.145000
# Measuring on VNA  Began at 2018-10-11 21:43:34.235000
# Measuring on Scope  Began at 2018-10-11 21:43:39.550000
# Writing to AWG Began at 2018-10-11 21:43:42.553000
# Measuring on VNA  Began at 2018-10-11 21:43:44.605000
# Measuring on Scope  Began at 2018-10-11 21:43:49.840000
# Writing to AWG Began at 2018-10-11 21:43:52.833000
# Measuring on VNA  Began at 2018-10-11 21:43:54.886000
# Measuring on Scope  Began at 2018-10-11 21:44:00.193000
# Writing to AWG Began at 2018-10-11 21:44:03.193000
# Measuring on VNA  Began at 2018-10-11 21:44:05.263000
# Measuring on Scope  Began at 2018-10-11 21:44:10.519000
# Sweep 4
# f : 995000000.0
#  ended at 2018-10-11 21:44:13.642000
#  taking 104 seonds
# Sweep 5
# f : 1000000000.0
#  began at 2018-10-11 21:44:13.652000
# Writing to AWG Began at 2018-10-11 21:44:13.662000
# Measuring on VNA  Began at 2018-10-11 21:44:15.729000
# Measuring on Scope  Began at 2018-10-11 21:44:20.996000
# Writing to AWG Began at 2018-10-11 21:44:24.049000
# Measuring on VNA  Began at 2018-10-11 21:44:26.116000
# Measuring on Scope  Began at 2018-10-11 21:44:31.382000
# Writing to AWG Began at 2018-10-11 21:44:34.409000
# Measuring on VNA  Began at 2018-10-11 21:44:36.474000
# Measuring on Scope  Began at 2018-10-11 21:44:41.700000
# Writing to AWG Began at 2018-10-11 21:44:44.720000
# Measuring on VNA  Began at 2018-10-11 21:44:46.801000
# Measuring on Scope  Began at 2018-10-11 21:44:52.148000
# Writing to AWG Began at 2018-10-11 21:44:55.175000
# Measuring on VNA  Began at 2018-10-11 21:44:57.233000
# Measuring on Scope  Began at 2018-10-11 21:45:02.561000
# Writing to AWG Began at 2018-10-11 21:45:05.634000
# Measuring on VNA  Began at 2018-10-11 21:45:07.727000
# Measuring on Scope  Began at 2018-10-11 21:45:13.028000
# Writing to AWG Began at 2018-10-11 21:45:15.991000
# Measuring on VNA  Began at 2018-10-11 21:45:18.028000
# Measuring on Scope  Began at 2018-10-11 21:45:23.308000
# Writing to AWG Began at 2018-10-11 21:45:26.404000
# Measuring on VNA  Began at 2018-10-11 21:45:28.458000
# Measuring on Scope  Began at 2018-10-11 21:45:33.728000
# Writing to AWG Began at 2018-10-11 21:45:36.733000
# Measuring on VNA  Began at 2018-10-11 21:45:38.791000
# Measuring on Scope  Began at 2018-10-11 21:45:44.065000
# Writing to AWG Began at 2018-10-11 21:45:48.217000
# Measuring on VNA  Began at 2018-10-11 21:45:50.289000
# Measuring on Scope  Began at 2018-10-11 21:45:55.589000
# Sweep 5
# f : 1000000000.0
#  ended at 2018-10-11 21:45:58.616000
#  taking 104 seonds
# Sweep 6
# f : 1005000000.0
#  began at 2018-10-11 21:45:58.616000
# Writing to AWG Began at 2018-10-11 21:45:58.626000
# Measuring on VNA  Began at 2018-10-11 21:46:00.724000
# Measuring on Scope  Began at 2018-10-11 21:46:06.038000
# Writing to AWG Began at 2018-10-11 21:46:09.042000
# Measuring on VNA  Began at 2018-10-11 21:46:11.101000
# Measuring on Scope  Began at 2018-10-11 21:46:16.331000
# Writing to AWG Began at 2018-10-11 21:46:19.401000
# Measuring on VNA  Began at 2018-10-11 21:46:21.458000
# Measuring on Scope  Began at 2018-10-11 21:46:26.716000
# Writing to AWG Began at 2018-10-11 21:46:29.712000
# Measuring on VNA  Began at 2018-10-11 21:46:32.410000
# Measuring on Scope  Began at 2018-10-11 21:46:37.731000
# Writing to AWG Began at 2018-10-11 21:46:40.808000
# Measuring on VNA  Began at 2018-10-11 21:46:42.883000
# Measuring on Scope  Began at 2018-10-11 21:46:48.167000
# Writing to AWG Began at 2018-10-11 21:46:51.154000
# Measuring on VNA  Began at 2018-10-11 21:46:53.228000
# Measuring on Scope  Began at 2018-10-11 21:46:58.526000
# Writing to AWG Began at 2018-10-11 21:47:01.613000
# Measuring on VNA  Began at 2018-10-11 21:47:03.714000
# Measuring on Scope  Began at 2018-10-11 21:47:08.922000
# Writing to AWG Began at 2018-10-11 21:47:11.912000
# Measuring on VNA  Began at 2018-10-11 21:47:13.974000
# Measuring on Scope  Began at 2018-10-11 21:47:19.238000
# Writing to AWG Began at 2018-10-11 21:47:22.266000
# Measuring on VNA  Began at 2018-10-11 21:47:24.324000
# Measuring on Scope  Began at 2018-10-11 21:47:29.592000
# Writing to AWG Began at 2018-10-11 21:47:32.651000
# Measuring on VNA  Began at 2018-10-11 21:47:34.742000
# Measuring on Scope  Began at 2018-10-11 21:47:40.048000
# Sweep 6
# f : 1005000000.0
#  ended at 2018-10-11 21:47:43.104000
#  taking 104 seonds
# Sweep 7
# f : 1010000000.0
#  began at 2018-10-11 21:47:43.104000
# Writing to AWG Began at 2018-10-11 21:47:43.114000
# Measuring on VNA  Began at 2018-10-11 21:47:45.160000
# Measuring on Scope  Began at 2018-10-11 21:47:50.492000
# Writing to AWG Began at 2018-10-11 21:47:53.452000
# Measuring on VNA  Began at 2018-10-11 21:47:55.487000
# Measuring on Scope  Began at 2018-10-11 21:48:00.751000
# Writing to AWG Began at 2018-10-11 21:48:03.787000
# Measuring on VNA  Began at 2018-10-11 21:48:05.849000
# Measuring on Scope  Began at 2018-10-11 21:48:11.082000
# Writing to AWG Began at 2018-10-11 21:48:14.110000
# Measuring on VNA  Began at 2018-10-11 21:48:16.164000
# Measuring on Scope  Began at 2018-10-11 21:48:21.464000
# Writing to AWG Began at 2018-10-11 21:48:24.482000
# Measuring on VNA  Began at 2018-10-11 21:48:26.517000
# Measuring on Scope  Began at 2018-10-11 21:48:31.869000
# Writing to AWG Began at 2018-10-11 21:48:34.867000
# Measuring on VNA  Began at 2018-10-11 21:48:36.911000
# Measuring on Scope  Began at 2018-10-11 21:48:42.205000
# Writing to AWG Began at 2018-10-11 21:48:46.685000
# Measuring on VNA  Began at 2018-10-11 21:48:48.756000
# Measuring on Scope  Began at 2018-10-11 21:48:54.037000
# Writing to AWG Began at 2018-10-11 21:48:57.223000
# Measuring on VNA  Began at 2018-10-11 21:48:59.286000
# Measuring on Scope  Began at 2018-10-11 21:49:04.544000
# Writing to AWG Began at 2018-10-11 21:49:07.505000
# Measuring on VNA  Began at 2018-10-11 21:49:09.561000
# Measuring on Scope  Began at 2018-10-11 21:49:14.800000
# Writing to AWG Began at 2018-10-11 21:49:17.804000
# Measuring on VNA  Began at 2018-10-11 21:49:19.859000
# Measuring on Scope  Began at 2018-10-11 21:49:25.082000
# Sweep 7
# f : 1010000000.0
#  ended at 2018-10-11 21:49:28.130000
#  taking 105 seonds
# Sweep 8
# f : 1015000000.0
#  began at 2018-10-11 21:49:28.130000
# Writing to AWG Began at 2018-10-11 21:49:28.140000
# Measuring on VNA  Began at 2018-10-11 21:49:30.225000
# Measuring on Scope  Began at 2018-10-11 21:49:35.476000
# Writing to AWG Began at 2018-10-11 21:49:38.545000
# Measuring on VNA  Began at 2018-10-11 21:49:40.607000
# Measuring on Scope  Began at 2018-10-11 21:49:45.914000
# Writing to AWG Began at 2018-10-11 21:49:48.995000
# Measuring on VNA  Began at 2018-10-11 21:49:51.045000
# Measuring on Scope  Began at 2018-10-11 21:49:56.311000
# Writing to AWG Began at 2018-10-11 21:49:59.399000
# Measuring on VNA  Began at 2018-10-11 21:50:01.472000
# Measuring on Scope  Began at 2018-10-11 21:50:06.672000
# Writing to AWG Began at 2018-10-11 21:50:09.630000
# Measuring on VNA  Began at 2018-10-11 21:50:11.676000
# Measuring on Scope  Began at 2018-10-11 21:50:16.945000
# Writing to AWG Began at 2018-10-11 21:50:19.978000
# Measuring on VNA  Began at 2018-10-11 21:50:21.999000
# Measuring on Scope  Began at 2018-10-11 21:50:27.285000
# Writing to AWG Began at 2018-10-11 21:50:30.243000
# Measuring on VNA  Began at 2018-10-11 21:50:32.311000
# Measuring on Scope  Began at 2018-10-11 21:50:37.630000
# Writing to AWG Began at 2018-10-11 21:50:40.668000
# Measuring on VNA  Began at 2018-10-11 21:50:42.719000
# Measuring on Scope  Began at 2018-10-11 21:50:47.988000
# Writing to AWG Began at 2018-10-11 21:50:51
# Measuring on VNA  Began at 2018-10-11 21:50:53.047000
# Measuring on Scope  Began at 2018-10-11 21:50:58.337000
# Writing to AWG Began at 2018-10-11 21:51:01.391000
# Measuring on VNA  Began at 2018-10-11 21:51:03.452000
# Measuring on Scope  Began at 2018-10-11 21:51:08.725000
# Sweep 8
# f : 1015000000.0
#  ended at 2018-10-11 21:51:11.768000
#  taking 103 seonds
# Sweep 9
# f : 1020000000.0
#  began at 2018-10-11 21:51:11.768000
# Writing to AWG Began at 2018-10-11 21:51:11.778000
# Measuring on VNA  Began at 2018-10-11 21:51:13.844000
# Measuring on Scope  Began at 2018-10-11 21:51:19.178000
# Writing to AWG Began at 2018-10-11 21:51:22.189000
# Measuring on VNA  Began at 2018-10-11 21:51:24.256000
# Measuring on Scope  Began at 2018-10-11 21:51:29.604000
# Writing to AWG Began at 2018-10-11 21:51:32.621000
# Measuring on VNA  Began at 2018-10-11 21:51:34.710000
# Measuring on Scope  Began at 2018-10-11 21:51:40.009000
# Writing to AWG Began at 2018-10-11 21:51:43.101000
# Measuring on VNA  Began at 2018-10-11 21:51:45.155000
# Measuring on Scope  Began at 2018-10-11 21:51:50.457000
# Writing to AWG Began at 2018-10-11 21:51:55.040000
# Measuring on VNA  Began at 2018-10-11 21:51:57.097000
# Measuring on Scope  Began at 2018-10-11 21:52:02.387000
# Writing to AWG Began at 2018-10-11 21:52:05.378000
# Measuring on VNA  Began at 2018-10-11 21:52:07.455000
# Measuring on Scope  Began at 2018-10-11 21:52:12.752000
# Writing to AWG Began at 2018-10-11 21:52:15.730000
# Measuring on VNA  Began at 2018-10-11 21:52:17.788000
# Measuring on Scope  Began at 2018-10-11 21:52:23.070000
# Writing to AWG Began at 2018-10-11 21:52:26.087000
# Measuring on VNA  Began at 2018-10-11 21:52:28.175000
# Measuring on Scope  Began at 2018-10-11 21:52:33.568000
# Writing to AWG Began at 2018-10-11 21:52:36.573000
# Measuring on VNA  Began at 2018-10-11 21:52:38.672000
# Measuring on Scope  Began at 2018-10-11 21:52:44.052000
# Writing to AWG Began at 2018-10-11 21:52:47.130000
# Measuring on VNA  Began at 2018-10-11 21:52:49.236000
# Measuring on Scope  Began at 2018-10-11 21:52:54.584000
# Sweep 9
# f : 1020000000.0
#  ended at 2018-10-11 21:52:57.646000
#  taking 105 seonds
# Sweep 10
# f : 1025000000.0
#  began at 2018-10-11 21:52:57.646000
# Writing to AWG Began at 2018-10-11 21:52:57.667000
# Measuring on VNA  Began at 2018-10-11 21:52:59.702000
# Measuring on Scope  Began at 2018-10-11 21:53:05.002000
# Writing to AWG Began at 2018-10-11 21:53:08.109000
# Measuring on VNA  Began at 2018-10-11 21:53:10.171000
# Measuring on Scope  Began at 2018-10-11 21:53:15.516000
# Writing to AWG Began at 2018-10-11 21:53:18.509000
# Measuring on VNA  Began at 2018-10-11 21:53:20.562000
# Measuring on Scope  Began at 2018-10-11 21:53:25.854000
# Writing to AWG Began at 2018-10-11 21:53:28.960000
# Measuring on VNA  Began at 2018-10-11 21:53:30.996000
# Measuring on Scope  Began at 2018-10-11 21:53:36.322000
# Writing to AWG Began at 2018-10-11 21:53:39.366000
# Measuring on VNA  Began at 2018-10-11 21:53:41.474000
# Measuring on Scope  Began at 2018-10-11 21:53:46.733000
# Writing to AWG Began at 2018-10-11 21:53:49.794000
# Measuring on VNA  Began at 2018-10-11 21:53:51.859000
# Measuring on Scope  Began at 2018-10-11 21:53:57.152000
# Writing to AWG Began at 2018-10-11 21:54:00.149000
# Measuring on VNA  Began at 2018-10-11 21:54:02.215000
# Measuring on Scope  Began at 2018-10-11 21:54:07.520000
# Writing to AWG Began at 2018-10-11 21:54:10.625000
# Measuring on VNA  Began at 2018-10-11 21:54:12.702000
# Measuring on Scope  Began at 2018-10-11 21:54:17.949000
# Writing to AWG Began at 2018-10-11 21:54:20.974000
# Measuring on VNA  Began at 2018-10-11 21:54:23.011000
# Measuring on Scope  Began at 2018-10-11 21:54:28.302000
# Writing to AWG Began at 2018-10-11 21:54:31.360000
# Measuring on VNA  Began at 2018-10-11 21:54:33.424000
# Measuring on Scope  Began at 2018-10-11 21:54:38.701000
# Sweep 10
# f : 1025000000.0
#  ended at 2018-10-11 21:54:41.715000
#  taking 104 seonds
# Calibration Began at 2018-10-11 21:54:43.774000
# Sweep 0
# f : 987500000.0
#  began at 2018-10-11 21:54:43.774000
# Writing to AWG Began at 2018-10-11 21:54:43.804000
# Measuring on VNA  Began at 2018-10-11 21:54:45.905000
# Measuring on Scope  Began at 2018-10-11 21:54:51.192000
# Writing to AWG Began at 2018-10-11 21:54:54.358000
# Measuring on VNA  Began at 2018-10-11 21:54:56.450000
# Measuring on Scope  Began at 2018-10-11 21:55:01.703000
# Writing to AWG Began at 2018-10-11 21:55:04.746000
# Measuring on VNA  Began at 2018-10-11 21:55:06.844000
# Measuring on Scope  Began at 2018-10-11 21:55:12.078000
# Writing to AWG Began at 2018-10-11 21:55:15.123000
# Measuring on VNA  Began at 2018-10-11 21:55:18.715000
# Measuring on Scope  Began at 2018-10-11 21:55:23.971000
# Writing to AWG Began at 2018-10-11 21:55:27.106000
# Measuring on VNA  Began at 2018-10-11 21:55:29.197000
# Measuring on Scope  Began at 2018-10-11 21:55:34.465000
# Writing to AWG Began at 2018-10-11 21:55:37.560000
# Measuring on VNA  Began at 2018-10-11 21:55:39.699000
# Measuring on Scope  Began at 2018-10-11 21:55:44.974000
# Writing to AWG Began at 2018-10-11 21:55:48.098000
# Measuring on VNA  Began at 2018-10-11 21:55:50.206000
# Measuring on Scope  Began at 2018-10-11 21:55:55.503000
# Writing to AWG Began at 2018-10-11 21:55:58.585000
# Measuring on VNA  Began at 2018-10-11 21:56:00.722000
# Measuring on Scope  Began at 2018-10-11 21:56:05.996000
# Writing to AWG Began at 2018-10-11 21:56:09.022000
# Measuring on VNA  Began at 2018-10-11 21:56:11.111000
# Measuring on Scope  Began at 2018-10-11 21:56:16.388000
# Writing to AWG Began at 2018-10-11 21:56:19.538000
# Measuring on VNA  Began at 2018-10-11 21:56:21.655000
# Measuring on Scope  Began at 2018-10-11 21:56:26.939000
# Sweep 0
# f : 987500000.0
#  ended at 2018-10-11 21:56:29.984000
#  taking 106 seonds
# Sweep 1
# f : 990000000.0
#  began at 2018-10-11 21:56:29.984000
# Writing to AWG Began at 2018-10-11 21:56:30.004000
# Measuring on VNA  Began at 2018-10-11 21:56:32.125000
# Measuring on Scope  Began at 2018-10-11 21:56:37.385000
# Writing to AWG Began at 2018-10-11 21:56:40.406000
# Measuring on VNA  Began at 2018-10-11 21:56:42.491000
# Measuring on Scope  Began at 2018-10-11 21:56:47.759000
# Writing to AWG Began at 2018-10-11 21:56:50.740000
# Measuring on VNA  Began at 2018-10-11 21:56:52.840000
# Measuring on Scope  Began at 2018-10-11 21:56:58.171000
# Writing to AWG Began at 2018-10-11 21:57:01.168000
# Measuring on VNA  Began at 2018-10-11 21:57:03.275000
# Measuring on Scope  Began at 2018-10-11 21:57:08.556000
# Writing to AWG Began at 2018-10-11 21:57:11.637000
# Measuring on VNA  Began at 2018-10-11 21:57:13.711000
# Measuring on Scope  Began at 2018-10-11 21:57:18.986000
# Writing to AWG Began at 2018-10-11 21:57:22.015000
# Measuring on VNA  Began at 2018-10-11 21:57:24.089000
# Measuring on Scope  Began at 2018-10-11 21:57:29.372000
# Writing to AWG Began at 2018-10-11 21:57:32.428000
# Measuring on VNA  Began at 2018-10-11 21:57:34.531000
# Measuring on Scope  Began at 2018-10-11 21:57:39.797000
# Writing to AWG Began at 2018-10-11 21:57:42.859000
# Measuring on VNA  Began at 2018-10-11 21:57:44.952000
# Measuring on Scope  Began at 2018-10-11 21:57:50.124000
# Writing to AWG Began at 2018-10-11 21:57:53.202000
# Measuring on VNA  Began at 2018-10-11 21:57:55.323000
# Measuring on Scope  Began at 2018-10-11 21:58:00.606000
# Writing to AWG Began at 2018-10-11 21:58:03.790000
# Measuring on VNA  Began at 2018-10-11 21:58:05.903000
# Measuring on Scope  Began at 2018-10-11 21:58:11.184000
# Sweep 1
# f : 990000000.0
#  ended at 2018-10-11 21:58:14.198000
#  taking 104 seonds
# Sweep 2
# f : 992500000.0
#  began at 2018-10-11 21:58:14.198000
# Writing to AWG Began at 2018-10-11 21:58:14.228000
# Measuring on VNA  Began at 2018-10-11 21:58:16.323000
# Measuring on Scope  Began at 2018-10-11 21:58:21.553000
# Writing to AWG Began at 2018-10-11 21:58:24.639000
# Measuring on VNA  Began at 2018-10-11 21:58:26.714000
# Measuring on Scope  Began at 2018-10-11 21:58:31.991000
# Writing to AWG Began at 2018-10-11 21:58:35.135000
# Measuring on VNA  Began at 2018-10-11 21:58:37.200000
# Measuring on Scope  Began at 2018-10-11 21:58:42.462000
# Writing to AWG Began at 2018-10-11 21:58:45.697000
# Measuring on VNA  Began at 2018-10-11 21:58:47.803000
# Measuring on Scope  Began at 2018-10-11 21:58:53.066000
# Writing to AWG Began at 2018-10-11 21:58:56.217000
# Measuring on VNA  Began at 2018-10-11 21:58:58.308000
# Measuring on Scope  Began at 2018-10-11 21:59:03.576000
# Writing to AWG Began at 2018-10-11 21:59:08.246000
# Measuring on VNA  Began at 2018-10-11 21:59:10.313000
# Measuring on Scope  Began at 2018-10-11 21:59:15.584000
# Writing to AWG Began at 2018-10-11 21:59:18.654000
# Measuring on VNA  Began at 2018-10-11 21:59:20.711000
# Measuring on Scope  Began at 2018-10-11 21:59:26.001000
# Writing to AWG Began at 2018-10-11 21:59:29.081000
# Measuring on VNA  Began at 2018-10-11 21:59:31.164000
# Measuring on Scope  Began at 2018-10-11 21:59:36.459000
# Writing to AWG Began at 2018-10-11 21:59:39.572000
# Measuring on VNA  Began at 2018-10-11 21:59:41.655000
# Measuring on Scope  Began at 2018-10-11 21:59:46.923000
# Writing to AWG Began at 2018-10-11 21:59:49.936000
# Measuring on VNA  Began at 2018-10-11 21:59:52.011000
# Measuring on Scope  Began at 2018-10-11 21:59:57.274000
# Sweep 2
# f : 992500000.0
#  ended at 2018-10-11 22:00:00.388000
#  taking 106 seonds
# Sweep 3
# f : 995000000.0
#  began at 2018-10-11 22:00:00.388000
# Writing to AWG Began at 2018-10-11 22:00:00.418000
# Measuring on VNA  Began at 2018-10-11 22:00:02.488000
# Measuring on Scope  Began at 2018-10-11 22:00:07.756000
# Writing to AWG Began at 2018-10-11 22:00:10.896000
# Measuring on VNA  Began at 2018-10-11 22:00:12.961000
# Measuring on Scope  Began at 2018-10-11 22:00:18.280000
# Writing to AWG Began at 2018-10-11 22:00:21.333000
# Measuring on VNA  Began at 2018-10-11 22:00:23.414000
# Measuring on Scope  Began at 2018-10-11 22:00:28.683000
# Writing to AWG Began at 2018-10-11 22:00:31.790000
# Measuring on VNA  Began at 2018-10-11 22:00:33.885000
# Measuring on Scope  Began at 2018-10-11 22:00:39.169000
# Writing to AWG Began at 2018-10-11 22:00:42.352000
# Measuring on VNA  Began at 2018-10-11 22:00:44.463000
# Measuring on Scope  Began at 2018-10-11 22:00:49.732000
# Writing to AWG Began at 2018-10-11 22:00:52.858000
# Measuring on VNA  Began at 2018-10-11 22:00:54.965000
# Measuring on Scope  Began at 2018-10-11 22:01:00.248000
# Writing to AWG Began at 2018-10-11 22:01:03.276000
# Measuring on VNA  Began at 2018-10-11 22:01:05.367000
# Measuring on Scope  Began at 2018-10-11 22:01:10.625000
# Writing to AWG Began at 2018-10-11 22:01:13.813000
# Measuring on VNA  Began at 2018-10-11 22:01:15.888000
# Measuring on Scope  Began at 2018-10-11 22:01:21.133000
# Writing to AWG Began at 2018-10-11 22:01:24.334000
# Measuring on VNA  Began at 2018-10-11 22:01:26.443000
# Measuring on Scope  Began at 2018-10-11 22:01:31.672000
# Writing to AWG Began at 2018-10-11 22:01:34.728000
# Measuring on VNA  Began at 2018-10-11 22:01:36.835000
# Measuring on Scope  Began at 2018-10-11 22:01:42.082000
# Sweep 3
# f : 995000000.0
#  ended at 2018-10-11 22:01:45.130000
#  taking 104 seonds
# Sweep 4
# f : 997500000.0
#  began at 2018-10-11 22:01:45.130000
# Writing to AWG Began at 2018-10-11 22:01:45.160000
# Measuring on VNA  Began at 2018-10-11 22:01:47.254000
# Measuring on Scope  Began at 2018-10-11 22:01:52.541000
# Writing to AWG Began at 2018-10-11 22:01:55.552000
# Measuring on VNA  Began at 2018-10-11 22:01:57.649000
# Measuring on Scope  Began at 2018-10-11 22:02:02.910000
# Writing to AWG Began at 2018-10-11 22:02:06.204000
# Measuring on VNA  Began at 2018-10-11 22:02:08.275000
# Measuring on Scope  Began at 2018-10-11 22:02:13.549000
# Writing to AWG Began at 2018-10-11 22:02:16.642000
# Measuring on VNA  Began at 2018-10-11 22:02:18.754000
# Measuring on Scope  Began at 2018-10-11 22:02:24.033000
# Writing to AWG Began at 2018-10-11 22:02:27.161000
# Measuring on VNA  Began at 2018-10-11 22:02:29.242000
# Measuring on Scope  Began at 2018-10-11 22:02:34.480000
# Writing to AWG Began at 2018-10-11 22:02:37.562000
# Measuring on VNA  Began at 2018-10-11 22:02:39.645000
# Measuring on Scope  Began at 2018-10-11 22:02:44.969000
# Writing to AWG Began at 2018-10-11 22:02:48.074000
# Measuring on VNA  Began at 2018-10-11 22:02:50.176000
# Measuring on Scope  Began at 2018-10-11 22:02:55.369000
# Writing to AWG Began at 2018-10-11 22:02:58.450000
# Measuring on VNA  Began at 2018-10-11 22:03:00.536000
# Measuring on Scope  Began at 2018-10-11 22:03:05.780000
# Writing to AWG Began at 2018-10-11 22:03:10.668000
# ...
# Measuring on VNA  Began at 2018-10-11 22:41:23.474000
# Measuring on Scope  Began at 2018-10-11 22:41:28.721000
# Writing to AWG Began at 2018-10-11 22:41:38.603000
# Measuring on VNA  Began at 2018-10-11 22:41:42.795000
# Measuring on Scope  Began at 2018-10-11 22:41:48.065000
# Writing to AWG Began at 2018-10-11 22:41:54.540000
# Measuring on VNA  Began at 2018-10-11 22:41:58.711000
# Measuring on Scope  Began at 2018-10-11 22:42:03.955000
# Writing to AWG Began at 2018-10-11 22:42:10.619000
# Measuring on VNA  Began at 2018-10-11 22:42:14.716000
# Measuring on Scope  Began at 2018-10-11 22:42:20.011000
# Writing to AWG Began at 2018-10-11 22:42:26.806000
# Measuring on VNA  Began at 2018-10-11 22:42:30.927000
# Measuring on Scope  Began at 2018-10-11 22:42:36.169000
# Writing to AWG Began at 2018-10-11 22:42:42.698000
# Measuring on VNA  Began at 2018-10-11 22:42:46.825000
# Measuring on Scope  Began at 2018-10-11 22:42:52.075000
# Writing to AWG Began at 2018-10-11 22:42:59.096000
# Measuring on VNA  Began at 2018-10-11 22:43:03.213000
# Measuring on Scope  Began at 2018-10-11 22:43:08.464000
# Writing to AWG Began at 2018-10-11 22:43:14.735000
# Measuring on VNA  Began at 2018-10-11 22:43:18.850000
# Measuring on Scope  Began at 2018-10-11 22:43:24.103000
# Writing to AWG Began at 2018-10-11 22:43:30.802000
# Measuring on VNA  Began at 2018-10-11 22:43:34.932000
# Measuring on Scope  Began at 2018-10-11 22:43:40.219000
# Writing to AWG Began at 2018-10-11 22:43:46.891000
# Measuring on VNA  Began at 2018-10-11 22:43:51.021000
# Measuring on Scope  Began at 2018-10-11 22:43:56.304000
# Sweep 2
# f : 999925000.0
#  ended at 2018-10-11 22:44:00.966000
#  taking 163 seonds
# Sweep 3
# f : 999950000.0
#  began at 2018-10-11 22:44:00.966000
# Writing to AWG Began at 2018-10-11 22:44:03.015000
# Measuring on VNA  Began at 2018-10-11 22:44:07.144000
# Measuring on Scope  Began at 2018-10-11 22:44:12.437000
# Writing to AWG Began at 2018-10-11 22:44:18.838000
# Measuring on VNA  Began at 2018-10-11 22:44:22.975000
# Measuring on Scope  Began at 2018-10-11 22:44:28.246000
# Writing to AWG Began at 2018-10-11 22:44:34.805000
# Measuring on VNA  Began at 2018-10-11 22:44:38.944000
# Measuring on Scope  Began at 2018-10-11 22:44:44.204000
# Writing to AWG Began at 2018-10-11 22:44:50.820000
# Measuring on VNA  Began at 2018-10-11 22:44:54.928000
# Measuring on Scope  Began at 2018-10-11 22:45:00.213000
# Writing to AWG Began at 2018-10-11 22:45:06.975000
# Measuring on VNA  Began at 2018-10-11 22:45:11.087000
# Measuring on Scope  Began at 2018-10-11 22:45:16.370000
# Writing to AWG Began at 2018-10-11 22:45:23.264000
# Measuring on VNA  Began at 2018-10-11 22:45:27.376000
# Measuring on Scope  Began at 2018-10-11 22:45:32.650000
# Writing to AWG Began at 2018-10-11 22:45:39.355000
# Measuring on VNA  Began at 2018-10-11 22:45:43.474000
# Measuring on Scope  Began at 2018-10-11 22:45:48.694000
# Writing to AWG Began at 2018-10-11 22:45:55.505000
# Measuring on VNA  Began at 2018-10-11 22:45:59.635000
# Measuring on Scope  Began at 2018-10-11 22:46:04.881000
# Writing to AWG Began at 2018-10-11 22:46:11.559000
# Measuring on VNA  Began at 2018-10-11 22:46:15.729000
# Measuring on Scope  Began at 2018-10-11 22:46:20.913000
# Writing to AWG Began at 2018-10-11 22:46:27.934000
# Measuring on VNA  Began at 2018-10-11 22:46:32.067000
# Measuring on Scope  Began at 2018-10-11 22:46:37.301000
# Sweep 3
# f : 999950000.0
#  ended at 2018-10-11 22:46:41.841000
#  taking 160 seonds
# Sweep 4
# f : 999975000.0
#  began at 2018-10-11 22:46:41.841000
# Writing to AWG Began at 2018-10-11 22:46:43.862000
# Measuring on VNA  Began at 2018-10-11 22:46:48.739000
# Measuring on Scope  Began at 2018-10-11 22:46:53.963000
# Writing to AWG Began at 2018-10-11 22:47:00.481000
# Measuring on VNA  Began at 2018-10-11 22:47:04.666000
# Measuring on Scope  Began at 2018-10-11 22:47:09.933000
# Writing to AWG Began at 2018-10-11 22:47:16.515000
# Measuring on VNA  Began at 2018-10-11 22:47:20.658000
# Measuring on Scope  Began at 2018-10-11 22:47:26.004000
# Writing to AWG Began at 2018-10-11 22:47:32.967000
# Measuring on VNA  Began at 2018-10-11 22:47:37.135000
# Measuring on Scope  Began at 2018-10-11 22:47:42.410000
# Writing to AWG Began at 2018-10-11 22:47:49.344000
# Measuring on VNA  Began at 2018-10-11 22:47:53.469000
# Measuring on Scope  Began at 2018-10-11 22:47:58.735000
# Writing to AWG Began at 2018-10-11 22:48:05.514000
# Measuring on VNA  Began at 2018-10-11 22:48:09.612000
# Measuring on Scope  Began at 2018-10-11 22:48:14.814000
# Writing to AWG Began at 2018-10-11 22:48:21.493000
# Measuring on VNA  Began at 2018-10-11 22:48:25.631000
# Measuring on Scope  Began at 2018-10-11 22:48:30.837000
# Writing to AWG Began at 2018-10-11 22:48:38.330000
# Measuring on VNA  Began at 2018-10-11 22:48:42.439000
# Measuring on Scope  Began at 2018-10-11 22:48:47.729000
# Writing to AWG Began at 2018-10-11 22:48:54.515000
# Measuring on VNA  Began at 2018-10-11 22:48:58.695000
# Measuring on Scope  Began at 2018-10-11 22:49:03.961000
# Writing to AWG Began at 2018-10-11 22:49:10.746000
# Measuring on VNA  Began at 2018-10-11 22:49:14.905000
# Measuring on Scope  Began at 2018-10-11 22:49:20.136000
# Sweep 4
# f : 999975000.0
#  ended at 2018-10-11 22:49:25.190000
#  taking 163 seonds
# Sweep 5
# f : 1000000000.0
#  began at 2018-10-11 22:49:25.190000
# Writing to AWG Began at 2018-10-11 22:49:27.228000
# Measuring on VNA  Began at 2018-10-11 22:49:31.409000
# Measuring on Scope  Began at 2018-10-11 22:49:36.659000
# Writing to AWG Began at 2018-10-11 22:49:43.325000
# Measuring on VNA  Began at 2018-10-11 22:49:47.493000
# Measuring on Scope  Began at 2018-10-11 22:49:52.708000
# Writing to AWG Began at 2018-10-11 22:49:59.522000
# Measuring on VNA  Began at 2018-10-11 22:50:03.701000
# Measuring on Scope  Began at 2018-10-11 22:50:08.876000
# Writing to AWG Began at 2018-10-11 22:50:15.936000
# Measuring on VNA  Began at 2018-10-11 22:50:20.117000
# Measuring on Scope  Began at 2018-10-11 22:50:25.349000
# Writing to AWG Began at 2018-10-11 22:50:32.367000
# Measuring on VNA  Began at 2018-10-11 22:50:36.501000
# Measuring on Scope  Began at 2018-10-11 22:50:41.726000
# Writing to AWG Began at 2018-10-11 22:50:48.399000
# Measuring on VNA  Began at 2018-10-11 22:50:52.596000
# Measuring on Scope  Began at 2018-10-11 22:50:57.790000
# Writing to AWG Began at 2018-10-11 22:51:04.325000
# Measuring on VNA  Began at 2018-10-11 22:51:08.471000
# Measuring on Scope  Began at 2018-10-11 22:51:13.719000
# Writing to AWG Began at 2018-10-11 22:51:20.610000
# Measuring on VNA  Began at 2018-10-11 22:51:24.767000
# Measuring on Scope  Began at 2018-10-11 22:51:30.017000
# Writing to AWG Began at 2018-10-11 22:51:36.878000
# Measuring on VNA  Began at 2018-10-11 22:51:41.093000
# Measuring on Scope  Began at 2018-10-11 22:51:46.362000
# Writing to AWG Began at 2018-10-11 22:51:53.560000
# Measuring on VNA  Began at 2018-10-11 22:51:57.754000
# Measuring on Scope  Began at 2018-10-11 22:52:03.028000
# Sweep 5
# f : 1000000000.0
#  ended at 2018-10-11 22:52:07.942000
#  taking 162 seonds
# Sweep 6
# f : 1000025000.0
#  began at 2018-10-11 22:52:07.942000
# Writing to AWG Began at 2018-10-11 22:52:09.976000
# Measuring on VNA  Began at 2018-10-11 22:52:14.126000
# Measuring on Scope  Began at 2018-10-11 22:52:19.347000
# Writing to AWG Began at 2018-10-11 22:52:26.534000
# Measuring on VNA  Began at 2018-10-11 22:52:30.706000
# Measuring on Scope  Began at 2018-10-11 22:52:35.953000
# Writing to AWG Began at 2018-10-11 22:52:43.069000
# Measuring on VNA  Began at 2018-10-11 22:52:47.250000
# Measuring on Scope  Began at 2018-10-11 22:52:52.524000
# Writing to AWG Began at 2018-10-11 22:53:00.084000
# Measuring on VNA  Began at 2018-10-11 22:53:04.232000
# Measuring on Scope  Began at 2018-10-11 22:53:09.467000
# Writing to AWG Began at 2018-10-11 22:53:20.613000
# Measuring on VNA  Began at 2018-10-11 22:53:24.716000
# Measuring on Scope  Began at 2018-10-11 22:53:29.937000
# Writing to AWG Began at 2018-10-11 22:53:37.341000
# Measuring on VNA  Began at 2018-10-11 22:53:41.434000
# Measuring on Scope  Began at 2018-10-11 22:53:46.652000
# Writing to AWG Began at 2018-10-11 22:53:53.475000
# Measuring on VNA  Began at 2018-10-11 22:53:57.606000
# Measuring on Scope  Began at 2018-10-11 22:54:02.854000
# Writing to AWG Began at 2018-10-11 22:54:09.564000
# Measuring on VNA  Began at 2018-10-11 22:54:13.714000
# Measuring on Scope  Began at 2018-10-11 22:54:18.945000
# Writing to AWG Began at 2018-10-11 22:54:25.703000
# Measuring on VNA  Began at 2018-10-11 22:54:29.840000
# Measuring on Scope  Began at 2018-10-11 22:54:35.059000
# Writing to AWG Began at 2018-10-11 22:54:42.588000
# Measuring on VNA  Began at 2018-10-11 22:54:46.751000
# Measuring on Scope  Began at 2018-10-11 22:54:51.952000
# Sweep 6
# f : 1000025000.0
#  ended at 2018-10-11 22:54:57.455000
#  taking 169 seonds
# Sweep 7
# f : 1000050000.0
#  began at 2018-10-11 22:54:57.455000
# Writing to AWG Began at 2018-10-11 22:54:59.494000
# Measuring on VNA  Began at 2018-10-11 22:55:03.644000
# Measuring on Scope  Began at 2018-10-11 22:55:08.836000
# Writing to AWG Began at 2018-10-11 22:55:24.307000
# Measuring on VNA  Began at 2018-10-11 22:55:28.450000
# Measuring on Scope  Began at 2018-10-11 22:55:33.699000
# Writing to AWG Began at 2018-10-11 22:55:40.546000
# Measuring on VNA  Began at 2018-10-11 22:55:44.682000
# Measuring on Scope  Began at 2018-10-11 22:55:49.914000
# Writing to AWG Began at 2018-10-11 22:55:56.826000
# Measuring on VNA  Began at 2018-10-11 22:56:00.963000
# Measuring on Scope  Began at 2018-10-11 22:56:06.216000
# Writing to AWG Began at 2018-10-11 22:56:13.429000
# Measuring on VNA  Began at 2018-10-11 22:56:17.514000
# Measuring on Scope  Began at 2018-10-11 22:56:22.833000
# Writing to AWG Began at 2018-10-11 22:56:29.684000
# Measuring on VNA  Began at 2018-10-11 22:56:33.777000
# Measuring on Scope  Began at 2018-10-11 22:56:39.037000
# Writing to AWG Began at 2018-10-11 22:56:46.337000
# Measuring on VNA  Began at 2018-10-11 22:56:50.436000
# Measuring on Scope  Began at 2018-10-11 22:56:55.699000
# Writing to AWG Began at 2018-10-11 22:57:02.440000
# Measuring on VNA  Began at 2018-10-11 22:57:06.576000
# Measuring on Scope  Began at 2018-10-11 22:57:11.828000
# Writing to AWG Began at 2018-10-11 22:57:18.931000
# Measuring on VNA  Began at 2018-10-11 22:57:23.059000
# Measuring on Scope  Began at 2018-10-11 22:57:28.312000
# Writing to AWG Began at 2018-10-11 22:57:35.336000
# Measuring on VNA  Began at 2018-10-11 22:57:39.502000
# Measuring on Scope  Began at 2018-10-11 22:57:44.808000
# Sweep 7
# f : 1000050000.0
#  ended at 2018-10-11 22:57:50.280000
#  taking 172 seonds
# Sweep 8
# f : 1000075000.0
#  began at 2018-10-11 22:57:50.280000
# Writing to AWG Began at 2018-10-11 22:57:52.314000
# Measuring on VNA  Began at 2018-10-11 22:57:56.482000
# Measuring on Scope  Began at 2018-10-11 22:58:01.721000
# Writing to AWG Began at 2018-10-11 22:58:08.870000
# Measuring on VNA  Began at 2018-10-11 22:58:13.017000
# Measuring on Scope  Began at 2018-10-11 22:58:18.241000
# Writing to AWG Began at 2018-10-11 22:58:26.076000
# Measuring on VNA  Began at 2018-10-11 22:58:30.250000
# Measuring on Scope  Began at 2018-10-11 22:58:35.536000
# Writing to AWG Began at 2018-10-11 22:58:42.494000
# Measuring on VNA  Began at 2018-10-11 22:58:46.619000
# Measuring on Scope  Began at 2018-10-11 22:58:51.942000
# Writing to AWG Began at 2018-10-11 22:58:58.992000
# Measuring on VNA  Began at 2018-10-11 22:59:03.135000
# Measuring on Scope  Began at 2018-10-11 22:59:08.359000
# Writing to AWG Began at 2018-10-11 22:59:15.425000
# Measuring on VNA  Began at 2018-10-11 22:59:19.584000
# Measuring on Scope  Began at 2018-10-11 22:59:24.860000
# Writing to AWG Began at 2018-10-11 22:59:31.805000
# Measuring on VNA  Began at 2018-10-11 22:59:35.932000
# Measuring on Scope  Began at 2018-10-11 22:59:41.124000
# Writing to AWG Began at 2018-10-11 22:59:48.076000
# Measuring on VNA  Began at 2018-10-11 22:59:52.181000
# Measuring on Scope  Began at 2018-10-11 22:59:57.465000
# Writing to AWG Began at 2018-10-11 23:00:04.963000
# Measuring on VNA  Began at 2018-10-11 23:00:09.115000
# Measuring on Scope  Began at 2018-10-11 23:00:14.371000
# Writing to AWG Began at 2018-10-11 23:00:21.396000
# Measuring on VNA  Began at 2018-10-11 23:00:25.543000
# Measuring on Scope  Began at 2018-10-11 23:00:30.805000
# Sweep 8
# f : 1000075000.0
#  ended at 2018-10-11 23:00:35.941000
#  taking 165 seonds
# Sweep 9
# f : 1000100000.0
#  began at 2018-10-11 23:00:35.941000
# Writing to AWG Began at 2018-10-11 23:00:37.972000
# Measuring on VNA  Began at 2018-10-11 23:00:42.164000
# Measuring on Scope  Began at 2018-10-11 23:00:47.447000
# Writing to AWG Began at 2018-10-11 23:00:54.285000
# Measuring on VNA  Began at 2018-10-11 23:00:58.475000
# Measuring on Scope  Began at 2018-10-11 23:01:03.831000
# Writing to AWG Began at 2018-10-11 23:01:11.273000
# Measuring on VNA  Began at 2018-10-11 23:01:15.447000
# Measuring on Scope  Began at 2018-10-11 23:01:20.634000
# Writing to AWG Began at 2018-10-11 23:01:27.829000
# Measuring on VNA  Began at 2018-10-11 23:01:31.978000
# Measuring on Scope  Began at 2018-10-11 23:01:37.236000
# Writing to AWG Began at 2018-10-11 23:01:44.462000
# Measuring on VNA  Began at 2018-10-11 23:01:48.558000
# Measuring on Scope  Began at 2018-10-11 23:01:53.898000
# Writing to AWG Began at 2018-10-11 23:02:01.541000
# Measuring on VNA  Began at 2018-10-11 23:02:05.660000
# Measuring on Scope  Began at 2018-10-11 23:02:10.928000
# Writing to AWG Began at 2018-10-11 23:02:18.020000
# Measuring on VNA  Began at 2018-10-11 23:02:22.180000
# Measuring on Scope  Began at 2018-10-11 23:02:27.456000
# Writing to AWG Began at 2018-10-11 23:02:34.484000
# Measuring on VNA  Began at 2018-10-11 23:02:38.650000
# Measuring on Scope  Began at 2018-10-11 23:02:43.969000
# Writing to AWG Began at 2018-10-11 23:02:51.223000
# Measuring on VNA  Began at 2018-10-11 23:02:55.347000
# Measuring on Scope  Began at 2018-10-11 23:03:00.620000
# Writing to AWG Began at 2018-10-11 23:03:07.646000
# Measuring on VNA  Began at 2018-10-11 23:03:11.821000
# Measuring on Scope  Began at 2018-10-11 23:03:17.026000
# Sweep 9
# f : 1000100000.0
#  ended at 2018-10-11 23:03:22.663000
#  taking 166 seonds
# Sweep 10
# f : 1000125000.0
#  began at 2018-10-11 23:03:22.663000
# Writing to AWG Began at 2018-10-11 23:03:24.656000
# Measuring on VNA  Began at 2018-10-11 23:03:28.834000
# Measuring on Scope  Began at 2018-10-11 23:03:34.076000
# Writing to AWG Began at 2018-10-11 23:03:41.527000
# Measuring on VNA  Began at 2018-10-11 23:03:45.709000
# Measuring on Scope  Began at 2018-10-11 23:03:50.960000
# Writing to AWG Began at 2018-10-11 23:03:58.062000
# Measuring on VNA  Began at 2018-10-11 23:04:02.287000
# Measuring on Scope  Began at 2018-10-11 23:04:07.584000
# Writing to AWG Began at 2018-10-11 23:04:14.885000
# Measuring on VNA  Began at 2018-10-11 23:04:19.020000
# Measuring on Scope  Began at 2018-10-11 23:04:24.266000
# Writing to AWG Began at 2018-10-11 23:04:31.520000
# Measuring on VNA  Began at 2018-10-11 23:04:35.740000
# Measuring on Scope  Began at 2018-10-11 23:04:40.962000
# Writing to AWG Began at 2018-10-11 23:04:48.422000
# Measuring on VNA  Began at 2018-10-11 23:04:52.536000
# Measuring on Scope  Began at 2018-10-11 23:04:57.853000
# Writing to AWG Began at 2018-10-11 23:05:05.691000
# Measuring on VNA  Began at 2018-10-11 23:05:09.831000
# Measuring on Scope  Began at 2018-10-11 23:05:15.132000
# Writing to AWG Began at 2018-10-11 23:05:22.306000
# Measuring on VNA  Began at 2018-10-11 23:05:26.401000
# Measuring on Scope  Began at 2018-10-11 23:05:31.662000
# Writing to AWG Began at 2018-10-11 23:05:38.999000
# Measuring on VNA  Began at 2018-10-11 23:05:43.159000
# Measuring on Scope  Began at 2018-10-11 23:05:48.456000
# Writing to AWG Began at 2018-10-11 23:05:55.475000
# Measuring on VNA  Began at 2018-10-11 23:05:59.678000
# Measuring on Scope  Began at 2018-10-11 23:06:05.001000
# Sweep 10
# f : 1000125000.0
#  ended at 2018-10-11 23:06:10.199000
#  taking 167 seonds

# %%
vna.get_IFBW()
# Out:
# 10.0

# %%
vna.trigger_sweep()
time.sleep(2*sweep_wait_time)

# %%
vna.write("CALC:PAR:SEL '{0}'".format("a4"))
a4_trace_string = vna.query("CALC:DATA? SDATA")
a4_trace = a4_trace_string.replace("\n","").split(",")
a4_real = a4_trace[0::2]
a4_imaginary = a4_trace[1::2]
complex_a4 =np.array([complex(float(real_value),
                                 float(a4_imaginary[index])) for index,real_value in enumerate(a4_real)])

# %%
complex_a4
# Out:
# array([-0.08358406+0.04738595j, -0.07842599-0.05542507j,
#         0.08350133-0.04730311j, -0.06751042+0.06816535j,
#         0.094614  -0.0161505j , -0.02378619-0.09293872j,
#         0.02864228-0.09185587j,  0.08524416-0.04456601j,
#         0.0417732 +0.08670677j, -0.08897697-0.03687557j,
#         0.08542072+0.04460545j])
