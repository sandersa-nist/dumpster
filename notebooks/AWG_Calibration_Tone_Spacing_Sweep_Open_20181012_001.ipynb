# %% [markdown]
# # A sweep of tone spacing for the AWG calibration

# %%
# import the pyMez packages default API
from pyMez import *
# import the Fitting module for Signal Generation and Fitting, note the namespace Code.Analysis.Fitting also works
from pyMez.Code.Analysis.Fitting import *
# Out:
# Importing pyMez, this should take roughly 30 seconds
# Importing Code.DataHandlers.GeneralModels
# It took 1.274 s to import Code.DataHandlers.GeneralModels
# Importing Code.DataHandlers.HTMLModels
# It took 0.26 s to import Code.DataHandlers.HTMLModels
# Importing Code.DataHandlers.NISTModels
# The module smithplot was not found,please put it on the python path
# It took 2.066 s to import Code.DataHandlers.NISTModels
# Importing Code.DataHandlers.TouchstoneModels
# The module smithplot was not found,please put it on the python path
# It took 0.02 s to import Code.DataHandlers.TouchstoneModels
# Importing Code.DataHandlers.XMLModels
# It took 0.25 s to import Code.DataHandlers.XMLModels
# Importing Code.DataHandlers.ZipModels
# It took 0.033 s to import Code.DataHandlers.ZipModels
# Importing Code.InstrumentControl.Experiments
# It took 4.903 s to import Code.InstrumentControl.Experiments
# Importing Code.InstrumentControl.Instruments
# It took 0.01 s to import Code.InstrumentControl.Instruments
# Importing Code.Utils.Names
# It took 0.01 s to import Code.Utils.Names
# It took 8.826 s to import all of the active modules

# %% [markdown]
# ## Setup Variables that do not change with tone spacing

# %%
# none of these instruments have xml instrument sheets, need to add them
psg_address="GPIB1::19"
vna_address="GPIB1::16"
awg_address="GPIB1::10"
scope_address="GPIB1::7::INSTR"
pm_address="GPIB1::13"
# ----------------------
vna=VNA(vna_address)
scope=HighSpeedOscope(scope_address)
awg=VisaInstrument(awg_address)
pm=PowerMeter(pm_address)
# ----------------


# this is local to the computer taking the data, the data should be copied to Q:\public\Aric\AWG_Phase_Calibration_20180927
data_directory=r'C:\Share\AWG_Phase_Calibration_20181001\Comb_Locked_PSG\Zero_Phase_10Hz_Open'
# Experimental variables

# the psg frequency acts as the master clock
psg_amplitude=12. #psg amplitude in dBm
psg_frequency=10.*10.**9 # 10 GHz
time_step=1./psg_frequency # time step for the awg
fundamental_frequency = 1.*10.**9 # Center of the passband or fundemental frequency in Hz
number_tones = 11 # Number of tones in the modulation bandwidth including the fundamental, should be odd
number_harmonics = 1# Number of harmonics to use. The frequency grid will be n*(f-df), n*f, n*(f+df), etc
# Select the phase for the multisine    
multisine_phase="zero"
#multisine_phase="schroeder"
number_envelopes=1.

# Measurement Phase Reference Setup 
round_multisine_before_writing=True # Rounds the multisine to a desired bitdepth before writing to AWG
bit_depth=8
waveform_name="Calibration_Phase_Reference" # name of the waveform to write to the 
bin_format=True # If the wave is in 16 bit bin format
marker_1=True # If marker one is to be set
marker_1_n_repeats=1 # the rep rate of the marker as a function of number of repeats per time sequence
marker_2=False
marker_2_n_repeats=1

# VNA setup 
vna_IFBW=10
comb_frequency = 2.5*10**6
number_phases=10
vna.set_IFBW(vna_IFBW)

# Power Meter Setup
# pm.set_units("W")
# Out:
# The information sheet was not found defaulting to address
# The information sheet was not found defaulting to address
# The information sheet was not found defaulting to address
# The information sheet was not found defaulting to address

# %%
# Setup the traces that we might want
# Delete all of the traces that we do not need, in this case I will delete  all of them it leaves one trace
trace_string=vna.query("CALC:PAR:CAT?")
trace_list=trace_string.replace("\n","").split(",")[0::3] #remove endline, split on , and then take every third one
for trace in trace_list:
    vna.write("CALC:PAR:DEL '{0}'".format(trace))
print("Existing traces are {0}".format(vna.query("CALC:PAR:CAT?")))
# set up the traces, we use drive_port=1 sense all of the inputs are turned off, there are combs on port 2, port 3

# first we add a trace for a each reference reciever (R1=a1)
for i in range(4):
    vna.add_trace(trace_name="a{0}".format(i+1),trace_parameter="R{0}".format(i+1),drive_port=1)
# now we add a trace for each b reciever (labelled A,B,C,D)
for i,receiver in enumerate(["A","B","C","D"]):
    vna.add_trace(trace_name="b{0}".format(i+1),trace_parameter="{0}".format(receiver),drive_port=1)
    
# now we want a ratio of R1R4 (a1/a4) <- this is the calibration phase reference / measurement phase reference
vna.add_trace(trace_name="ratio",trace_parameter="R1R4",drive_port="1")
vna.add_trace(trace_name="b_ratio",trace_parameter="b1a4",drive_port="1")

vna.add_trace(trace_name="comb_ratio",trace_parameter="a1b2",drive_port="1")
print("Existing traces are {0}".format(vna.query("CALC:PAR:CAT?")))
# Out:
# Existing traces are "a1,a1,1"
#
# Existing traces are "a1,a1,1,a2,R2,1,a3,R3,1,a4,R4,1,b1,A,1,b2,B,1,b3,C,1,b4,D,1,ratio,R1/R4,1,b_ratio,b1/a4,1,comb_ratio,a1/b2,1"

# %%
tone_spacings=[10*10**6,5*10**6,2.5*10**6,2.5*10**5,2.5*10**4]
comb_spacings=[10*10**6,5*10**6,2.5*10**6]

# %%
for tone_spacing in tone_spacings:
    comb_spacing=tone_spacing in comb_spacings
    print(comb_spacing)
# Out:
# True
# True
# True
# False
# False

# %%
for tone_spacing in tone_spacings:
    comb_spacing = tone_spacing in comb_spacings
    summary_data=[]
    # now calculate the frequency_list
    frequency_list=[]
    for harmonic in range(number_harmonics):
        frequency_array=np.linspace((harmonic+1)*(fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                    (harmonic+1)*(fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)
        frequency_list=frequency_list+frequency_array.tolist()
    time_max=number_envelopes/tone_spacing
    number_time_points=int(round(time_max/time_step))
    time_shift=0.*time_step
    sweep_wait_time=2.5*float(len(frequency_list))/float(vna_IFBW)
    sweep_directory=os.path.join(data_directory,"{0}_Tones_{1:.0f}KHz_Spacing".format(number_tones,10**-3*tone_spacing))
    os.mkdir(sweep_directory)
    # first create the multisine
    sine_function=FunctionalModel(parameters=["f","phi"],variables=["t"],equation="cos(2*pi*f*t+phi)")
    time_list=np.linspace(0.+time_shift,time_max+time_shift-time_step,number_time_points)

    # calculate the phases 
    phase_list = [0. for i in range(len(frequency_list))]
    if re.search("sch",multisine_phase,re.IGNORECASE):
        phase_list=[]
        for frequency_index,frequency in enumerate(frequency_list):
            k=(frequency_index+1)%number_tones
            schroeder_phase=-k*(k-1)*np.pi/number_tones
            phase_list.append(schroeder_phase)
    # initialize multisine to a set of zeros
    multisine=np.array([0 for i in range(number_time_points)])
    # add each component
    for frequency_index,frequency in enumerate(frequency_list):
        sine_function.set_parameters({"f":frequency,"phi":phase_list[frequency_index]})
        multisine_component=sine_function(time_list)
        multisine=multisine+multisine_component

    # substract the mean
    # multisine=multisine-np.mean(multisine)
    # normalize the multisine
    # multisine=1/max(multisine)*multisine

    # round the multisine to the nearest bitdepth before writing
    if round_multisine_before_writing:
        discrete_steps=np.linspace(min(multisine),max(multisine),2**bit_depth)
        rounded_multisine=[]
        int_multisine=[]
        for value in multisine:
            difference_array=abs(discrete_steps-value)
            minimum_location=np.argmin(difference_array)
            rounded_multisine.append(discrete_steps[minimum_location])
            int_multisine.append(minimum_location)
        if bin_format:
            multisine=np.array(int_multisine,dtype=np.uint16)
            # Shift, now to add the marker add + 2**14 or +2**15 at the desired location
            multisine=multisine*2**6
        else:
            multisine=rounded_multisine

    # now we add the marker. 
    if marker_1:

        distance=int(np.floor(float(len(multisine))/float(marker_1_n_repeats)))
        for i in range(marker_1_n_repeats):
            try:
                multisine[i*distance]=multisine[i*distance]+2**14
            except:
                pass
    # I am guessing that this has the possibility of kiling the oscope trigger
    if bin_format:
        # turn AWG's output 1 & 2 OFF
        awg.write(':OUTPUT1:STATE OFF')
        awg.write(':OUTPUT2:STATE OFF')
        # wait...
        time.sleep(0.1)
        # UNRUN state
        awg.write('AWGCONTROL:STOP')
        # wait...
        time.sleep(0.5)

        # delete any older waveform with the same name
        awg.write('WLISt:WAVeform:DELete "{0}"'.format(waveform_name))
        time.sleep(0.05)

        # create new waveform
        awg.write('WLISt:WAVeform:NEW "{0}", {1}, INT'.format(waveform_name,len(multisine)))
        # download data
        awg.resource.write_binary_values('WLISt:WAVeform:DATA "{0}",'.format(waveform_name), multisine, datatype='H', is_big_endian=False)
        time.sleep(.1)
        # assign new waveform to channel 1 & 2
        awg.write('SOURce1:WAVeform "{0}"'.format(waveform_name))
        awg.write('SOURce2:WAVeform "{0}"'.format(waveform_name))

        # check for errors
        error_str = awg.query('SYSTEM:ERROR:NEXT?')
        # wait...
        time.sleep(.1)
        # AWG on RUN state
        awg.write('AWGCONTROL:RUN')
        # wait...
        time.sleep(0.5)
        # check if there is any errors on AWG's buffer
        error_str = awg.query('SYSTEM:ERROR:NEXT?')
        if error_str == '0,"No error"\n':
            # turn AWG's output 1 OFF
            awg.write(':OUTPUT1:STATE ON')
            awg.write(':OUTPUT2:STATE ON')

    if number_harmonics is 1:    
        vna.set_frequency((fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                        (fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)  
    else:
        for harmonic in range(number_harmonics):
            vna.add_segment((harmonic+1)*(fundamental_frequency-tone_spacing*(number_tones-1)/2),
                                        (harmonic+1)*(fundamental_frequency+tone_spacing*(number_tones-1)/2),number_tones)

    single_cosine=FunctionalModel(variables=["t"],parameters=["f","phi"],equation="cos(2*pi*f*t+phi)")

    phase_sweep_list=[2*np.pi*i/number_phases for i in range(number_phases)]
    # Loop to measure the phase
    start_timer=datetime.datetime.now()
    print("Calibration Began at {0}".format(start_timer))
    for frequency_index,frequency in enumerate(frequency_list[:]):
        begin_sweep_timer=datetime.datetime.now()
        print("Sweep {0} \nf : {1}\n began at {2} ".format(frequency_index,frequency,begin_sweep_timer))
        for phase_index,phase in enumerate(phase_sweep_list):

             #create the sine to write
            # ----------------------------------------------------------------------------------------------------------
            single_cosine.set_parameters({"f":frequency,"phi":phase})
            tone_data=single_cosine(time_list)

            # round the multisine to the nearest bitdepth before writing
            if round_multisine_before_writing:
                discrete_steps=np.linspace(min(tone_data),max(tone_data),2**bit_depth)
                rounded_tone_data=[]
                int_tone_data=[]
                for value in tone_data:
                    difference_array=abs(discrete_steps-value)
                    minimum_location=np.argmin(difference_array)
                    rounded_tone_data.append(discrete_steps[minimum_location])
                    int_tone_data.append(minimum_location)
                if bin_format:
                    tone_data=np.array(int_tone_data,dtype=np.uint16)
                    # Shift, now to add the marker add + 2**14 or +2**15 at the desired location
                    tone_data=tone_data*2**6
                else:
                    tone_data=rounded_tone_data

            timer=datetime.datetime.now()
            print("Writing to AWG Began at {0} ".format(timer))
            # write tone to AWG
            # --------------------------------------------------------
            tone_waveform_name="Tone_{0}_Phase_{1:.0f}_Calibration".format(frequency_index,phase*180/np.pi)
            # save the wave for good measure
            out_file=open(os.path.join(sweep_directory,"{0}.bin".format(tone_waveform_name)),"wb")
            out_file.write(tone_data)
            out_file.close()
            # plot 
            plt.close()
            plt.plot(time_list,tone_data)
            plt.xlabel("Time (s)")
            plt.ylabel("Amplitude (arb)")
            plt.title(tone_waveform_name)
            plt.savefig(os.path.join(sweep_directory,"{0}.png".format(tone_waveform_name)))
            #plt.show();

            if bin_format:
                # turn AWG's output 1 
                awg.write(':OUTPUT1:STATE OFF')
                time.sleep(0.1)
                # UNRUN state
                awg.write('AWGCONTROL:STOP')
                # wait...
                time.sleep(0.5)

                # delete any older waveform with the same name
                awg.write('WLISt:WAVeform:DELete "{0}"'.format(tone_waveform_name))
                time.sleep(0.05)

                # create new waveform
                awg.write('WLISt:WAVeform:NEW "{0}", {1}, INT'.format(tone_waveform_name,len(tone_data)))
                # download data
                awg.resource.write_binary_values('WLISt:WAVeform:DATA "{0}",'.format(tone_waveform_name), 
                                                 tone_data, datatype='H', is_big_endian=False)
                time.sleep(0.1)
                # assign new waveform to channel 1 
                awg.write('SOURce1:WAVeform "{0}"'.format(tone_waveform_name))


                # check for errors
                error_str = awg.query('SYSTEM:ERROR:NEXT?')
                # wait...
                time.sleep(.1)
                # AWG on RUN state
                awg.write('AWGCONTROL:RUN')
                # wait...
                time.sleep(0.5)
                # check if there is any errors on AWG's buffer
                error_str = awg.query('SYSTEM:ERROR:NEXT?')
                if error_str == '0,"No error"\n':
                    # turn AWG's output 1 ON
                    awg.write(':OUTPUT1:STATE ON')
                    
            timer=datetime.datetime.now()
            print("Measuring on VNA  Began at {0} ".format(timer))                
            # Measure on VNA
            # ---------------------------------------------------------------------------------------------------------
            # now the measured trace should be the multisine we can trigger and display the ratio to be sure
            vna.trigger_sweep()
            time.sleep(sweep_wait_time)
            # read_trace needs to have some work
            # Here we read a1/a4, a1, a4
            #------------------------------------------------------------------------------------
            vna.write("CALC:PAR:SEL '{0}'".format("ratio"))
            ratio_trace_string = vna.query("CALC:DATA? SDATA")
            ratio_trace = ratio_trace_string.replace("\n","").split(",")
            ratio_real = ratio_trace[0::2]
            ratio_imaginary = ratio_trace[1::2]
            complex_ratio =np.array([complex(float(real_value),
                                             float(ratio_imaginary[index])) for index,real_value in enumerate(ratio_real)])
                 
            vna.write("CALC:PAR:SEL '{0}'".format("b_ratio"))    
            b_ratio_trace_string = vna.query("CALC:DATA? SDATA")
            b_ratio_trace = b_ratio_trace_string.replace("\n","").split(",")
            b_ratio_real = b_ratio_trace[0::2]
            b_ratio_imaginary = b_ratio_trace[1::2]
            b_complex_ratio =np.array([complex(float(real_value),
                                             float(b_ratio_imaginary[index])) for index,real_value in enumerate(b_ratio_real)])

            vna.write("CALC:PAR:SEL '{0}'".format("a1"))
            a1_trace_string = vna.query("CALC:DATA? SDATA")
            a1_trace = a1_trace_string.replace("\n","").split(",")
            a1_real = a1_trace[0::2]
            a1_imaginary = a1_trace[1::2]
            complex_a1 =np.array([complex(float(real_value),
                                             float(a1_imaginary[index])) for index,real_value in enumerate(a1_real)])
            
            vna.write("CALC:PAR:SEL '{0}'".format("b1"))
            b1_trace_string = vna.query("CALC:DATA? SDATA")
            b1_trace = b1_trace_string.replace("\n","").split(",")
            b1_real = b1_trace[0::2]
            b1_imaginary = b1_trace[1::2]
            complex_b1 =np.array([complex(float(real_value),
                                             float(b1_imaginary[index])) for index,real_value in enumerate(b1_real)])

            vna.write("CALC:PAR:SEL '{0}'".format("a4"))
            a4_trace_string = vna.query("CALC:DATA? SDATA")
            a4_trace = a4_trace_string.replace("\n","").split(",")
            a4_real = a4_trace[0::2]
            a4_imaginary = a4_trace[1::2]
            complex_a4 =np.array([complex(float(real_value),
                                             float(a4_imaginary[index])) for index,real_value in enumerate(a4_real)])
            # If the tone spacing is on the comb grid, we want a1/b2, b2, b3
            if comb_spacing:
                # this block should be replaced with vna.read_trace
                vna.write("CALC:PAR:SEL '{0}'".format("b2"))
                b2_trace_string = vna.query("CALC:DATA? SDATA")
                b2_trace = b2_trace_string.replace("\n","").split(",")
                b2_real = b2_trace[0::2]
                b2_imaginary = b2_trace[1::2]
                complex_b2 =np.array([complex(float(real_value),
                                                 float(b2_imaginary[index])) for index,real_value in enumerate(b2_real)])                

                vna.write("CALC:PAR:SEL '{0}'".format("b3"))
                b3_trace_string = vna.query("CALC:DATA? SDATA")
                b3_trace = b3_trace_string.replace("\n","").split(",")
                b3_real = b3_trace[0::2]
                b3_imaginary = b3_trace[1::2]
                complex_b3 =np.array([complex(float(real_value),
                                                 float(b3_imaginary[index])) for index,real_value in enumerate(b3_real)])                
                             
                vna.write("CALC:PAR:SEL '{0}'".format("comb_ratio"))
                comb_ratio_trace_string = vna.query("CALC:DATA? SDATA")
                comb_ratio_trace = comb_ratio_trace_string.replace("\n","").split(",")
                comb_ratio_real = comb_ratio_trace[0::2]
                comb_ratio_imaginary = comb_ratio_trace[1::2]
                complex_comb_ratio =np.array([complex(float(real_value),
                                                 float(comb_ratio_imaginary[index])) for index,real_value in enumerate(comb_ratio_real)])                
                             

                vna_data=[map(lambda x:float(x),[frequency_list[index],
                           real_value,
                           ratio_imaginary[index],
                           b_ratio_real[index],b_ratio_imaginary[index],
                           a1_real[index],a1_imaginary[index],
                           b1_real[index],b1_imaginary[index],
                           a4_real[index],a4_imaginary[index],
                           comb_ratio_real[index],comb_ratio_imaginary[index],
                           b2_real[index],b2_imaginary[index],
                           b3_real[index],b3_imaginary[index]]) for index,real_value in enumerate(ratio_real)]
                
                
                column_names=["Frequency",
                                         "reA1_Div_A4","imA1_Div_A4",
                                         "reB1_Div_A4","imB1_Div_A4",
                                         "reA1","imA1","reB1","imB1",
                                         "reA4","imA4",
                                         "reA1_Div_B2","imA1_Div_B2",
                                         "reB2","imB2","reB3","imB3"]
                options={"column_names":column_names,
                         "column_types":["float" for i in range(len(column_names))],
                         "directory":sweep_directory,"specific_descriptor":tone_waveform_name,
                         "general_descriptor":"Vna_Reciever_Values","extension":"txt","data":vna_data}                    
            else:
                
                vna_data=[map(lambda x:float(x),[frequency_list[index],
                           real_value,
                           ratio_imaginary[index],
                           b_ratio_real[index],b_ratio_imaginary[index],
                           a1_real[index],a1_imaginary[index],
                           b1_real[index],b1_imaginary[index],                      
                           a4_real[index],a4_imaginary[index]]) for index,real_value in enumerate(ratio_real)]
                column_names=["Frequency","reA1_Div_A4","imA1_Div_A4",
                              "reB1_Div_A4","imB1_Div_A4",
                              "reA1","imA1","reB1","imB1","reA4","imA4"]
                options={"column_names":column_names,
                         "column_types":["float" for i in range(len(column_names))],
                         "directory":sweep_directory,"specific_descriptor":tone_waveform_name,
                         "general_descriptor":"Vna_Reciever_Values","extension":"txt","data":vna_data}
            ratio_data_table=AsciiDataTable(None,**options)
            ratio_data_table.save()
            ratio_data_table.save_schema(change_extension(ratio_data_table.path,new_extension="schema"))
            plt.close()
            plt.plot(frequency_list,abs(complex_ratio),'b-o')
            plt.xlabel("Frequency (Hz)")
            plt.ylabel("Linear Magnitude")
            plt.title("Magnitude Measured on VNA")
            plt.savefig(os.path.join(sweep_directory,"Magnitude_Plot_Ratio_{0}.png".format(tone_waveform_name)))
            #plt.show();
            plt.close()
            plt.plot(np.array(frequency_list),np.angle(complex_ratio,deg=1),"b-o")
            plt.xlabel("Frequency(Hz)")
            plt.ylabel("Phase (Degrees)")
            plt.title("Phase Measured on VNA")
            plt.savefig(os.path.join(sweep_directory,"Phase_Plot_Ratio_{0}.png".format(tone_waveform_name)))
            #plt.show();
            timer=datetime.datetime.now()
            print("Measuring on Scope  Began at {0} ".format(timer))
            time.sleep(.1)
            # Measure on Power Meter
            # ---------------------------------------------------------------------------------------------------------
#             pm.set_frequency(frequency)
#             power_reading=pm.get_reading()
            
            
            
            
            
#             wave_trace=scope.measure_waves()
#             time.sleep(.1)
#             plt.close()            
#             plt.plot(wave_trace["Time"],wave_trace["CHAN2"],label="SUT")
#             plt.plot(wave_trace["Time"],wave_trace["CHAN3"],label="I")
#             plt.plot(wave_trace["Time"],wave_trace["CHAN4"],label="Q")
#             plt.legend()
#             plt.savefig(os.path.join(sweep_directory,"Scope_{0}.png".format(tone_waveform_name)))
#             #plt.show();
#             fit_cosine=FunctionalModel(variables=["t"],parameters=["A","phi"],equation="A*cos(2*pi*t*{0}+phi)".format(frequency))
#             x_data=10**-9*np.array(map(lambda x:float(x),wave_trace["Time"]))
#             y_data=np.array(map(lambda x:float(x),wave_trace["CHAN2"]))
#             fit_cosine.fit_data(x_data=x_data,y_data=y_data)
#             plt.close()
#             plt.plot(x_data,fit_cosine(x_data),label="Fit")
#             plt.plot(x_data,y_data,label="CHAN2")
#             fit_parameters=fit_cosine.parameter_values
#             plt.title("Amplitude: {A} Phase: {phi}".format(**fit_parameters))
#             plt.legend()
#             plt.savefig(os.path.join(sweep_directory,"Scope_Fit_{0}.png".format(tone_waveform_name)))
#             #plt.show();
#             wave_trace.options["fit_equation"]="{0}".format(fit_cosine)
#             wave_trace.options["fit_parameters"]=fit_parameters
#             wave_trace.save(os.path.join(sweep_directory,"{0}_Scope_Measurement.txt".format(tone_waveform_name)))
#             wave_trace.save_schema(change_extension(wave_trace.path,new_extension="schema"))

            
            # Calculate the Summary Row, A table of Tone Index, Frequency, AWG Set Amplitude, AWG Set Phase, Scope Measured Amp
            # Scope MEasured Phase, VNA Measured Amp, VNA Measured Phase and optional values if comb_spacing
            tone_index=frequency_index+1 # starts at 1
            summary_frequency=frequency  # I know it is not needed just a reminder
            AWG_set_amplitude = .5 # set by the awg after the write of the binary wave
            AWG_set_phase=phase*180/np.pi 
            
            vna_measured_amplitude=abs(complex_ratio[frequency_index])
            vna_measured_phase=np.angle(complex_ratio[frequency_index],deg=True)
            reflected_vna_measured_amplitude=abs(b_complex_ratio[frequency_index])
            reflected_vna_measured_phase=np.angle(b_complex_ratio[frequency_index],deg=True)
            if comb_spacing:
                vna_measured_amplitude_comb=abs(complex_comb_ratio[frequency_index])
                vna_measured_phase_comb=np.angle(complex_comb_ratio[frequency_index],deg=True)
                summary_row=[tone_index,summary_frequency,
                             AWG_set_amplitude,AWG_set_phase,
                             vna_measured_amplitude,vna_measured_phase,
                             reflected_vna_measured_amplitude,reflected_vna_measured_phase,
                             vna_measured_amplitude_comb,vna_measured_phase_comb]
            else:
                summary_row=[tone_index,summary_frequency,
                                 AWG_set_amplitude,AWG_set_phase,
                                 vna_measured_amplitude,vna_measured_phase,
                                 reflected_vna_measured_amplitude,reflected_vna_measured_phase]
            # Delete last waveform
            if phase_index>0:
                awg.write('WLISt:WAVeform:DELete "{0}"'.format(last_waveform_name))
            last_waveform_name=tone_waveform_name
            summary_data.append(summary_row)
            
        if comb_spacing:
            summary_column_names=["Tone","Frequency","AWG_Set_Amplitude","AWG_Set_Phase",
                                  "Vna_Amplitude","Vna_Phase","B1_Vna_Amplitude","B1_Vna_Phase",
                                  "Vna_Comb_Referenced_Amplitude","Vna_Comb_Referenced_Phase"]
            summary_column_units=[None,"Hz","Volts","Degrees",
                                  "Volts","Degrees",
                                  "Volts","Degrees",
                                  "Volts","Degrees"]
        else:
            summary_column_names=["Tone","Frequency","AWG_Set_Amplitude","AWG_Set_Phase",
                                  "Vna_Amplitude","Vna_Phase","B1_Vna_Amplitude","B1_Vna_Phase"]
            summary_column_units=[None,"Hz","Volts","Degrees",
                                  "Volts","Degrees"
                                  "Volts","Degrees"]
            
        summary_options={"column_names":summary_column_names,
                         "column_types":["float" for i in range(len(summary_column_names))],
                         "column_units":summary_column_units,
                         "directory":sweep_directory,
                         "specific_descriptor":"{0}_Tones_{1:.0f}KHz_Spacing".format(number_tones,10**3*tone_spacing),
                         "general_descriptor":"Summary","extension":"txt","data":summary_data,
                         "metadata":{"Timestamp":"{0}".format(datetime.datetime.now()),
                                     "sweep":"{0}_Tones_{1:.0f}KHz_Spacing".format(number_tones,10**3*tone_spacing),
                                    "tone_spacing":tone_spacing,"number_tones":number_tones,
                                     "multisine_phase":multisine_phase,"number_harmonics":number_harmonics,
                                    "frequnecy_list":frequency_list}} 
        summary_table=AsciiDataTable(None,**summary_options)
        summary_table.save()
        summary_table.save_schema(change_extension(summary_table.path,new_extension="schema"))
        end_sweep_timer=datetime.datetime.now()
        difference=end_sweep_timer-begin_sweep_timer
        print("Sweep {0} \nf : {1}\n ended at {2}\n taking {3} seonds ".format(frequency_index,
                                                                               frequency,
                                                                               end_sweep_timer,
                                                                               difference.seconds))
# Out:
# Calibration Began at 2018-10-12 14:27:51.726000
# Sweep 0
# f : 950000000.0
#  began at 2018-10-12 14:27:51.726000
# Writing to AWG Began at 2018-10-12 14:27:51.736000
# Measuring on VNA  Began at 2018-10-12 14:27:53.934000
# Measuring on Scope  Began at 2018-10-12 14:27:59.261000
# Writing to AWG Began at 2018-10-12 14:27:59.381000
# Measuring on VNA  Began at 2018-10-12 14:28:01.474000
# Measuring on Scope  Began at 2018-10-12 14:28:06.681000
# Writing to AWG Began at 2018-10-12 14:28:06.801000
# Measuring on VNA  Began at 2018-10-12 14:28:08.914000
# Measuring on Scope  Began at 2018-10-12 14:28:14.141000
# Writing to AWG Began at 2018-10-12 14:28:14.261000
# Measuring on VNA  Began at 2018-10-12 14:28:16.431000
# Measuring on Scope  Began at 2018-10-12 14:28:21.682000
# Writing to AWG Began at 2018-10-12 14:28:21.802000
# Measuring on VNA  Began at 2018-10-12 14:28:23.944000
# Measuring on Scope  Began at 2018-10-12 14:28:29.207000
# Writing to AWG Began at 2018-10-12 14:28:29.327000
# Measuring on VNA  Began at 2018-10-12 14:28:31.440000
# Measuring on Scope  Began at 2018-10-12 14:28:36.726000
# Writing to AWG Began at 2018-10-12 14:28:36.846000
# Measuring on VNA  Began at 2018-10-12 14:28:38.996000
# Measuring on Scope  Began at 2018-10-12 14:28:44.188000
# Writing to AWG Began at 2018-10-12 14:28:44.308000
# Measuring on VNA  Began at 2018-10-12 14:28:46.426000
# Measuring on Scope  Began at 2018-10-12 14:28:51.699000
# Writing to AWG Began at 2018-10-12 14:28:51.819000
# Measuring on VNA  Began at 2018-10-12 14:28:53.943000
# Measuring on Scope  Began at 2018-10-12 14:28:59.368000
# Writing to AWG Began at 2018-10-12 14:28:59.496000
# Measuring on VNA  Began at 2018-10-12 14:29:01.581000
# Measuring on Scope  Began at 2018-10-12 14:29:06.904000
# Sweep 0
# f : 950000000.0
#  ended at 2018-10-12 14:29:07.024000
#  taking 75 seonds
# Sweep 1
# f : 960000000.0
#  began at 2018-10-12 14:29:07.024000
# Writing to AWG Began at 2018-10-12 14:29:07.034000
# Measuring on VNA  Began at 2018-10-12 14:29:09.119000
# Measuring on Scope  Began at 2018-10-12 14:29:14.431000
# Writing to AWG Began at 2018-10-12 14:29:14.551000
# Measuring on VNA  Began at 2018-10-12 14:29:16.663000
# Measuring on Scope  Began at 2018-10-12 14:29:21.870000
# Writing to AWG Began at 2018-10-12 14:29:21.990000
# Measuring on VNA  Began at 2018-10-12 14:29:24.070000
# Measuring on Scope  Began at 2018-10-12 14:29:29.423000
# Writing to AWG Began at 2018-10-12 14:29:29.543000
# Measuring on VNA  Began at 2018-10-12 14:29:31.597000
# Measuring on Scope  Began at 2018-10-12 14:29:36.916000
# Writing to AWG Began at 2018-10-12 14:29:37.037000
# Measuring on VNA  Began at 2018-10-12 14:29:39.111000
# Measuring on Scope  Began at 2018-10-12 14:29:44.384000
# Writing to AWG Began at 2018-10-12 14:29:44.494000
# Measuring on VNA  Began at 2018-10-12 14:29:46.657000
# Measuring on Scope  Began at 2018-10-12 14:29:51.894000
# Writing to AWG Began at 2018-10-12 14:29:52.025000
# Measuring on VNA  Began at 2018-10-12 14:29:54.144000
# Measuring on Scope  Began at 2018-10-12 14:29:59.475000
# Writing to AWG Began at 2018-10-12 14:29:59.585000
# Measuring on VNA  Began at 2018-10-12 14:30:01.663000
# Measuring on Scope  Began at 2018-10-12 14:30:06.964000
# Writing to AWG Began at 2018-10-12 14:30:07.084000
# Measuring on VNA  Began at 2018-10-12 14:30:09.154000
# Measuring on Scope  Began at 2018-10-12 14:30:14.443000
# Writing to AWG Began at 2018-10-12 14:30:14.573000
# Measuring on VNA  Began at 2018-10-12 14:30:17.285000
# Measuring on Scope  Began at 2018-10-12 14:30:22.569000
# Sweep 1
# f : 960000000.0
#  ended at 2018-10-12 14:30:22.689000
#  taking 75 seonds
# Sweep 2
# f : 970000000.0
#  began at 2018-10-12 14:30:22.689000
# Writing to AWG Began at 2018-10-12 14:30:22.709000
# Measuring on VNA  Began at 2018-10-12 14:30:24.803000
# Measuring on Scope  Began at 2018-10-12 14:30:30.136000
# Writing to AWG Began at 2018-10-12 14:30:30.256000
# Measuring on VNA  Began at 2018-10-12 14:30:32.352000
# Measuring on Scope  Began at 2018-10-12 14:30:37.616000
# Writing to AWG Began at 2018-10-12 14:30:37.726000
# Measuring on VNA  Began at 2018-10-12 14:30:39.830000
# Measuring on Scope  Began at 2018-10-12 14:30:45.084000
# Writing to AWG Began at 2018-10-12 14:30:45.204000
# Measuring on VNA  Began at 2018-10-12 14:30:47.286000
# Measuring on Scope  Began at 2018-10-12 14:30:52.745000
# Writing to AWG Began at 2018-10-12 14:30:52.865000
# Measuring on VNA  Began at 2018-10-12 14:30:54.914000
# Measuring on Scope  Began at 2018-10-12 14:31:00.187000
# Writing to AWG Began at 2018-10-12 14:31:00.307000
# Measuring on VNA  Began at 2018-10-12 14:31:02.410000
# Measuring on Scope  Began at 2018-10-12 14:31:07.615000
# Writing to AWG Began at 2018-10-12 14:31:07.735000
# Measuring on VNA  Began at 2018-10-12 14:31:09.805000
# Measuring on Scope  Began at 2018-10-12 14:31:15.103000
# Writing to AWG Began at 2018-10-12 14:31:15.223000
# Measuring on VNA  Began at 2018-10-12 14:31:17.278000
# Measuring on Scope  Began at 2018-10-12 14:31:22.627000
# Writing to AWG Began at 2018-10-12 14:31:22.747000
# Measuring on VNA  Began at 2018-10-12 14:31:24.859000
# Measuring on Scope  Began at 2018-10-12 14:31:30.166000
# Writing to AWG Began at 2018-10-12 14:31:30.286000
# Measuring on VNA  Began at 2018-10-12 14:31:32.391000
# Measuring on Scope  Began at 2018-10-12 14:31:37.698000
# Sweep 2
# f : 970000000.0
#  ended at 2018-10-12 14:31:37.828000
#  taking 75 seonds
# Sweep 3
# f : 980000000.0
#  began at 2018-10-12 14:31:37.828000
# Writing to AWG Began at 2018-10-12 14:31:37.848000
# Measuring on VNA  Began at 2018-10-12 14:31:39.908000
# Measuring on Scope  Began at 2018-10-12 14:31:45.210000
# Writing to AWG Began at 2018-10-12 14:31:45.330000
# Measuring on VNA  Began at 2018-10-12 14:31:47.405000
# Measuring on Scope  Began at 2018-10-12 14:31:52.721000
# Writing to AWG Began at 2018-10-12 14:31:52.841000
# Measuring on VNA  Began at 2018-10-12 14:31:54.906000
# Measuring on Scope  Began at 2018-10-12 14:32:00.130000
# Writing to AWG Began at 2018-10-12 14:32:00.250000
# Measuring on VNA  Began at 2018-10-12 14:32:02.342000
# Measuring on Scope  Began at 2018-10-12 14:32:07.762000
# Writing to AWG Began at 2018-10-12 14:32:07.882000
# Measuring on VNA  Began at 2018-10-12 14:32:10.016000
# Measuring on Scope  Began at 2018-10-12 14:32:15.256000
# Writing to AWG Began at 2018-10-12 14:32:15.376000
# Measuring on VNA  Began at 2018-10-12 14:32:17.476000
# Measuring on Scope  Began at 2018-10-12 14:32:22.768000
# Writing to AWG Began at 2018-10-12 14:32:22.888000
# Measuring on VNA  Began at 2018-10-12 14:32:24.958000
# Measuring on Scope  Began at 2018-10-12 14:32:30.185000
# Writing to AWG Began at 2018-10-12 14:32:30.305000
# Measuring on VNA  Began at 2018-10-12 14:32:32.413000
# Measuring on Scope  Began at 2018-10-12 14:32:37.688000
# Writing to AWG Began at 2018-10-12 14:32:37.808000
# Measuring on VNA  Began at 2018-10-12 14:32:39.895000
# Measuring on Scope  Began at 2018-10-12 14:32:45.168000
# Writing to AWG Began at 2018-10-12 14:32:45.278000
# Measuring on VNA  Began at 2018-10-12 14:32:47.408000
# Measuring on Scope  Began at 2018-10-12 14:32:52.681000
# Sweep 3
# f : 980000000.0
#  ended at 2018-10-12 14:32:52.811000
#  taking 74 seonds
# Sweep 4
# f : 990000000.0
#  began at 2018-10-12 14:32:52.811000
# Writing to AWG Began at 2018-10-12 14:32:52.821000
# Measuring on VNA  Began at 2018-10-12 14:32:54.933000
# Measuring on Scope  Began at 2018-10-12 14:33:00.189000
# Writing to AWG Began at 2018-10-12 14:33:00.309000
# Measuring on VNA  Began at 2018-10-12 14:33:02.406000
# Measuring on Scope  Began at 2018-10-12 14:33:07.737000
# Writing to AWG Began at 2018-10-12 14:33:07.857000
# Measuring on VNA  Began at 2018-10-12 14:33:09.955000
# Measuring on Scope  Began at 2018-10-12 14:33:15.218000
# Writing to AWG Began at 2018-10-12 14:33:15.338000
# Measuring on VNA  Began at 2018-10-12 14:33:17.460000
# Measuring on Scope  Began at 2018-10-12 14:33:22.696000
# Writing to AWG Began at 2018-10-12 14:33:22.816000
# Measuring on VNA  Began at 2018-10-12 14:33:24.894000
# Measuring on Scope  Began at 2018-10-12 14:33:30.185000
# Writing to AWG Began at 2018-10-12 14:33:30.305000
# Measuring on VNA  Began at 2018-10-12 14:33:32.405000
# Measuring on Scope  Began at 2018-10-12 14:33:37.754000
# Writing to AWG Began at 2018-10-12 14:33:37.874000
# Measuring on VNA  Began at 2018-10-12 14:33:39.972000
# Measuring on Scope  Began at 2018-10-12 14:33:45.460000
# Writing to AWG Began at 2018-10-12 14:33:45.580000
# Measuring on VNA  Began at 2018-10-12 14:33:47.673000
# Measuring on Scope  Began at 2018-10-12 14:33:52.930000
# Writing to AWG Began at 2018-10-12 14:33:53.040000
# Measuring on VNA  Began at 2018-10-12 14:33:55.109000
# Measuring on Scope  Began at 2018-10-12 14:34:00.384000
# Writing to AWG Began at 2018-10-12 14:34:00.504000
# Measuring on VNA  Began at 2018-10-12 14:34:02.617000
# Measuring on Scope  Began at 2018-10-12 14:34:07.903000
# Sweep 4
# f : 990000000.0
#  ended at 2018-10-12 14:34:08.033000
#  taking 75 seonds
# Sweep 5
# f : 1000000000.0
#  began at 2018-10-12 14:34:08.033000
# Writing to AWG Began at 2018-10-12 14:34:08.053000
# Measuring on VNA  Began at 2018-10-12 14:34:10.143000
# Measuring on Scope  Began at 2018-10-12 14:34:15.463000
# Writing to AWG Began at 2018-10-12 14:34:15.583000
# Measuring on VNA  Began at 2018-10-12 14:34:17.655000
# Measuring on Scope  Began at 2018-10-12 14:34:22.927000
# Writing to AWG Began at 2018-10-12 14:34:23.037000
# Measuring on VNA  Began at 2018-10-12 14:34:25.091000
# Measuring on Scope  Began at 2018-10-12 14:34:30.384000
# Writing to AWG Began at 2018-10-12 14:34:30.504000
# Measuring on VNA  Began at 2018-10-12 14:34:32.598000
# Measuring on Scope  Began at 2018-10-12 14:34:37.873000
# Writing to AWG Began at 2018-10-12 14:34:37.993000
# Measuring on VNA  Began at 2018-10-12 14:34:40.092000
# Measuring on Scope  Began at 2018-10-12 14:34:45.318000
# Writing to AWG Began at 2018-10-12 14:34:45.438000
# Measuring on VNA  Began at 2018-10-12 14:34:47.522000
# Measuring on Scope  Began at 2018-10-12 14:34:52.792000
# Writing to AWG Began at 2018-10-12 14:34:52.912000
# Measuring on VNA  Began at 2018-10-12 14:34:54.992000
# Measuring on Scope  Began at 2018-10-12 14:35:00.236000
# Writing to AWG Began at 2018-10-12 14:35:00.376000
# Measuring on VNA  Began at 2018-10-12 14:35:02.443000
# Measuring on Scope  Began at 2018-10-12 14:35:07.742000
# Writing to AWG Began at 2018-10-12 14:35:07.870000
# Measuring on VNA  Began at 2018-10-12 14:35:09.959000
# Measuring on Scope  Began at 2018-10-12 14:35:15.236000
# Writing to AWG Began at 2018-10-12 14:35:15.356000
# Measuring on VNA  Began at 2018-10-12 14:35:17.450000
# Measuring on Scope  Began at 2018-10-12 14:35:22.780000
# Sweep 5
# f : 1000000000.0
#  ended at 2018-10-12 14:35:22.910000
#  taking 74 seonds
# Sweep 6
# f : 1010000000.0
#  began at 2018-10-12 14:35:22.910000
# Writing to AWG Began at 2018-10-12 14:35:22.930000
# Measuring on VNA  Began at 2018-10-12 14:35:24.973000
# Measuring on Scope  Began at 2018-10-12 14:35:30.246000
# Writing to AWG Began at 2018-10-12 14:35:30.366000
# Measuring on VNA  Began at 2018-10-12 14:35:32.434000
# Measuring on Scope  Began at 2018-10-12 14:35:37.724000
# Writing to AWG Began at 2018-10-12 14:35:37.844000
# Measuring on VNA  Began at 2018-10-12 14:35:40.248000
# Measuring on Scope  Began at 2018-10-12 14:35:45.512000
# Writing to AWG Began at 2018-10-12 14:35:45.632000
# Measuring on VNA  Began at 2018-10-12 14:35:47.734000
# Measuring on Scope  Began at 2018-10-12 14:35:53.058000
# Writing to AWG Began at 2018-10-12 14:35:53.178000
# Measuring on VNA  Began at 2018-10-12 14:35:55.298000
# Measuring on Scope  Began at 2018-10-12 14:36:00.577000
# Writing to AWG Began at 2018-10-12 14:36:00.697000
# Measuring on VNA  Began at 2018-10-12 14:36:02.762000
# Measuring on Scope  Began at 2018-10-12 14:36:08.075000
# Writing to AWG Began at 2018-10-12 14:36:08.195000
# Measuring on VNA  Began at 2018-10-12 14:36:10.325000
# Measuring on Scope  Began at 2018-10-12 14:36:15.649000
# Writing to AWG Began at 2018-10-12 14:36:15.769000
# Measuring on VNA  Began at 2018-10-12 14:36:17.903000
# Measuring on Scope  Began at 2018-10-12 14:36:23.200000
# Writing to AWG Began at 2018-10-12 14:36:23.310000
# Measuring on VNA  Began at 2018-10-12 14:36:25.332000
# Measuring on Scope  Began at 2018-10-12 14:36:30.605000
# Writing to AWG Began at 2018-10-12 14:36:30.715000
# Measuring on VNA  Began at 2018-10-12 14:36:32.777000
# Measuring on Scope  Began at 2018-10-12 14:36:38.085000
# Sweep 6
# f : 1010000000.0
#  ended at 2018-10-12 14:36:38.225000
#  taking 75 seonds
# Sweep 7
# f : 1020000000.0
#  began at 2018-10-12 14:36:38.225000
# Writing to AWG Began at 2018-10-12 14:36:38.235000
# Measuring on VNA  Began at 2018-10-12 14:36:40.313000
# Measuring on Scope  Began at 2018-10-12 14:36:45.609000
# Writing to AWG Began at 2018-10-12 14:36:45.729000
# Measuring on VNA  Began at 2018-10-12 14:36:47.847000
# Measuring on Scope  Began at 2018-10-12 14:36:53.146000
# Writing to AWG Began at 2018-10-12 14:36:53.276000
# Measuring on VNA  Began at 2018-10-12 14:36:55.373000
# Measuring on Scope  Began at 2018-10-12 14:37:00.674000
# Writing to AWG Began at 2018-10-12 14:37:00.794000
# Measuring on VNA  Began at 2018-10-12 14:37:02.886000
# Measuring on Scope  Began at 2018-10-12 14:37:08.195000
# Writing to AWG Began at 2018-10-12 14:37:08.305000
# Measuring on VNA  Began at 2018-10-12 14:37:10.404000
# Measuring on Scope  Began at 2018-10-12 14:37:15.718000
# Writing to AWG Began at 2018-10-12 14:37:15.838000
# Measuring on VNA  Began at 2018-10-12 14:37:17.916000
# Measuring on Scope  Began at 2018-10-12 14:37:23.228000
# Writing to AWG Began at 2018-10-12 14:37:23.348000
# Measuring on VNA  Began at 2018-10-12 14:37:25.468000
# Measuring on Scope  Began at 2018-10-12 14:37:30.711000
# Writing to AWG Began at 2018-10-12 14:37:30.831000
# Measuring on VNA  Began at 2018-10-12 14:37:32.971000
# Measuring on Scope  Began at 2018-10-12 14:37:38.235000
# Writing to AWG Began at 2018-10-12 14:37:38.355000
# Measuring on VNA  Began at 2018-10-12 14:37:40.435000
# Measuring on Scope  Began at 2018-10-12 14:37:45.749000
# Writing to AWG Began at 2018-10-12 14:37:45.869000
# Measuring on VNA  Began at 2018-10-12 14:37:47.998000
# Measuring on Scope  Began at 2018-10-12 14:37:53.264000
# Sweep 7
# f : 1020000000.0
#  ended at 2018-10-12 14:37:53.404000
#  taking 75 seonds
# Sweep 8
# f : 1030000000.0
#  began at 2018-10-12 14:37:53.404000
# Writing to AWG Began at 2018-10-12 14:37:53.414000
# Measuring on VNA  Began at 2018-10-12 14:37:55.481000
# Measuring on Scope  Began at 2018-10-12 14:38:00.705000
# Writing to AWG Began at 2018-10-12 14:38:00.825000
# Measuring on VNA  Began at 2018-10-12 14:38:02.922000
# Measuring on Scope  Began at 2018-10-12 14:38:08.646000
# Writing to AWG Began at 2018-10-12 14:38:08.766000
# Measuring on VNA  Began at 2018-10-12 14:38:10.856000
# Measuring on Scope  Began at 2018-10-12 14:38:16.156000
# Writing to AWG Began at 2018-10-12 14:38:16.276000
# Measuring on VNA  Began at 2018-10-12 14:38:18.342000
# Measuring on Scope  Began at 2018-10-12 14:38:23.606000
# Writing to AWG Began at 2018-10-12 14:38:23.726000
# Measuring on VNA  Began at 2018-10-12 14:38:25.777000
# Measuring on Scope  Began at 2018-10-12 14:38:31.099000
# Writing to AWG Began at 2018-10-12 14:38:31.219000
# Measuring on VNA  Began at 2018-10-12 14:38:33.277000
# Measuring on Scope  Began at 2018-10-12 14:38:38.595000
# Writing to AWG Began at 2018-10-12 14:38:38.715000
# Measuring on VNA  Began at 2018-10-12 14:38:40.778000
# Measuring on Scope  Began at 2018-10-12 14:38:46.106000
# Writing to AWG Began at 2018-10-12 14:38:46.226000
# Measuring on VNA  Began at 2018-10-12 14:38:48.328000
# Measuring on Scope  Began at 2018-10-12 14:38:53.569000
# Writing to AWG Began at 2018-10-12 14:38:53.689000
# Measuring on VNA  Began at 2018-10-12 14:38:55.775000
# Measuring on Scope  Began at 2018-10-12 14:39:01.128000
# Writing to AWG Began at 2018-10-12 14:39:01.248000
# Measuring on VNA  Began at 2018-10-12 14:39:03.276000
# Measuring on Scope  Began at 2018-10-12 14:39:08.569000
# Sweep 8
# f : 1030000000.0
#  ended at 2018-10-12 14:39:08.709000
#  taking 75 seonds
# Sweep 9
# f : 1040000000.0
#  began at 2018-10-12 14:39:08.709000
# Writing to AWG Began at 2018-10-12 14:39:08.719000
# Measuring on VNA  Began at 2018-10-12 14:39:10.796000
# Measuring on Scope  Began at 2018-10-12 14:39:16.079000
# Writing to AWG Began at 2018-10-12 14:39:16.189000
# Measuring on VNA  Began at 2018-10-12 14:39:18.275000
# Measuring on Scope  Began at 2018-10-12 14:39:23.553000
# Writing to AWG Began at 2018-10-12 14:39:23.683000
# Measuring on VNA  Began at 2018-10-12 14:39:25.796000
# Measuring on Scope  Began at 2018-10-12 14:39:31.083000
# Writing to AWG Began at 2018-10-12 14:39:31.203000
# Measuring on VNA  Began at 2018-10-12 14:39:33.272000
# Measuring on Scope  Began at 2018-10-12 14:39:38.516000
# Writing to AWG Began at 2018-10-12 14:39:38.636000
# Measuring on VNA  Began at 2018-10-12 14:39:40.696000
# Measuring on Scope  Began at 2018-10-12 14:39:45.975000
# Writing to AWG Began at 2018-10-12 14:39:46.095000
# Measuring on VNA  Began at 2018-10-12 14:39:48.181000
# Measuring on Scope  Began at 2018-10-12 14:39:53.457000
# Writing to AWG Began at 2018-10-12 14:39:53.577000
# Measuring on VNA  Began at 2018-10-12 14:39:55.650000
# Measuring on Scope  Began at 2018-10-12 14:40:00.975000
# Writing to AWG Began at 2018-10-12 14:40:01.096000
# Measuring on VNA  Began at 2018-10-12 14:40:03.186000
# Measuring on Scope  Began at 2018-10-12 14:40:08.453000
# Writing to AWG Began at 2018-10-12 14:40:08.563000
# Measuring on VNA  Began at 2018-10-12 14:40:10.647000
# Measuring on Scope  Began at 2018-10-12 14:40:15.940000
# Writing to AWG Began at 2018-10-12 14:40:16.050000
# Measuring on VNA  Began at 2018-10-12 14:40:18.087000
# Measuring on Scope  Began at 2018-10-12 14:40:23.395000
# Sweep 9
# f : 1040000000.0
#  ended at 2018-10-12 14:40:23.535000
#  taking 74 seonds
# Sweep 10
# f : 1050000000.0
#  began at 2018-10-12 14:40:23.535000
# Writing to AWG Began at 2018-10-12 14:40:23.555000
# Measuring on VNA  Began at 2018-10-12 14:40:25.654000
# Measuring on Scope  Began at 2018-10-12 14:40:30.861000
# Writing to AWG Began at 2018-10-12 14:40:30.981000
# Measuring on VNA  Began at 2018-10-12 14:40:33.047000
# Measuring on Scope  Began at 2018-10-12 14:40:38.294000
# Writing to AWG Began at 2018-10-12 14:40:38.414000
# Measuring on VNA  Began at 2018-10-12 14:40:40.501000
# Measuring on Scope  Began at 2018-10-12 14:40:45.808000
# Writing to AWG Began at 2018-10-12 14:40:45.928000
# Measuring on VNA  Began at 2018-10-12 14:40:48.032000
# Measuring on Scope  Began at 2018-10-12 14:40:53.338000
# Writing to AWG Began at 2018-10-12 14:40:53.458000
# Measuring on VNA  Began at 2018-10-12 14:40:55.526000
# Measuring on Scope  Began at 2018-10-12 14:41:00.769000
# Writing to AWG Began at 2018-10-12 14:41:00.889000
# Measuring on VNA  Began at 2018-10-12 14:41:02.979000
# Measuring on Scope  Began at 2018-10-12 14:41:08.746000
# Writing to AWG Began at 2018-10-12 14:41:08.866000
# Measuring on VNA  Began at 2018-10-12 14:41:10.949000
# Measuring on Scope  Began at 2018-10-12 14:41:16.239000
# Writing to AWG Began at 2018-10-12 14:41:16.369000
# Measuring on VNA  Began at 2018-10-12 14:41:18.446000
# Measuring on Scope  Began at 2018-10-12 14:41:23.721000
# Writing to AWG Began at 2018-10-12 14:41:23.841000
# Measuring on VNA  Began at 2018-10-12 14:41:25.900000
# Measuring on Scope  Began at 2018-10-12 14:41:31.170000
# Writing to AWG Began at 2018-10-12 14:41:31.290000
# Measuring on VNA  Began at 2018-10-12 14:41:33.450000
# Measuring on Scope  Began at 2018-10-12 14:41:38.747000
# Sweep 10
# f : 1050000000.0
#  ended at 2018-10-12 14:41:38.887000
#  taking 75 seonds
# Calibration Began at 2018-10-12 14:41:40.947000
# Sweep 0
# f : 975000000.0
#  began at 2018-10-12 14:41:40.947000
# Writing to AWG Began at 2018-10-12 14:41:40.967000
# Measuring on VNA  Began at 2018-10-12 14:41:43.040000
# Measuring on Scope  Began at 2018-10-12 14:41:48.361000
# Writing to AWG Began at 2018-10-12 14:41:48.491000
# Measuring on VNA  Began at 2018-10-12 14:41:50.544000
# Measuring on Scope  Began at 2018-10-12 14:41:55.819000
# Writing to AWG Began at 2018-10-12 14:41:55.949000
# Measuring on VNA  Began at 2018-10-12 14:41:58.067000
# Measuring on Scope  Began at 2018-10-12 14:42:03.410000
# Writing to AWG Began at 2018-10-12 14:42:03.550000
# Measuring on VNA  Began at 2018-10-12 14:42:05.646000
# Measuring on Scope  Began at 2018-10-12 14:42:10.911000
# Writing to AWG Began at 2018-10-12 14:42:11.041000
# Measuring on VNA  Began at 2018-10-12 14:42:13.161000
# Measuring on Scope  Began at 2018-10-12 14:42:18.471000
# Writing to AWG Began at 2018-10-12 14:42:18.591000
# Measuring on VNA  Began at 2018-10-12 14:42:20.676000
# Measuring on Scope  Began at 2018-10-12 14:42:25.966000
# Writing to AWG Began at 2018-10-12 14:42:26.096000
# Measuring on VNA  Began at 2018-10-12 14:42:28.216000
# Measuring on Scope  Began at 2018-10-12 14:42:33.502000
# Writing to AWG Began at 2018-10-12 14:42:33.616000
# Measuring on VNA  Began at 2018-10-12 14:42:35.678000
# Measuring on Scope  Began at 2018-10-12 14:42:40.962000
# Writing to AWG Began at 2018-10-12 14:42:41.102000
# Measuring on VNA  Began at 2018-10-12 14:42:43.177000
# Measuring on Scope  Began at 2018-10-12 14:42:48.493000
# Writing to AWG Began at 2018-10-12 14:42:48.623000
# Measuring on VNA  Began at 2018-10-12 14:42:50.713000
# Measuring on Scope  Began at 2018-10-12 14:42:56.006000
# Sweep 0
# f : 975000000.0
#  ended at 2018-10-12 14:42:56.126000
#  taking 75 seonds
# Sweep 1
# f : 980000000.0
#  began at 2018-10-12 14:42:56.126000
# Writing to AWG Began at 2018-10-12 14:42:56.166000
# Measuring on VNA  Began at 2018-10-12 14:42:58.218000
# Measuring on Scope  Began at 2018-10-12 14:43:03.479000
# Writing to AWG Began at 2018-10-12 14:43:03.619000
# Measuring on VNA  Began at 2018-10-12 14:43:05.693000
# Measuring on Scope  Began at 2018-10-12 14:43:11
# Writing to AWG Began at 2018-10-12 14:43:11.130000
# Measuring on VNA  Began at 2018-10-12 14:43:13.206000
# Measuring on Scope  Began at 2018-10-12 14:43:18.501000
# Writing to AWG Began at 2018-10-12 14:43:18.631000
# Measuring on VNA  Began at 2018-10-12 14:43:20.698000
# Measuring on Scope  Began at 2018-10-12 14:43:25.991000
# Writing to AWG Began at 2018-10-12 14:43:26.121000
# Measuring on VNA  Began at 2018-10-12 14:43:28.181000
# Measuring on Scope  Began at 2018-10-12 14:43:33.394000
# Writing to AWG Began at 2018-10-12 14:43:33.524000
# Measuring on VNA  Began at 2018-10-12 14:43:35.604000
# Measuring on Scope  Began at 2018-10-12 14:43:40.845000
# Writing to AWG Began at 2018-10-12 14:43:40.955000
# Measuring on VNA  Began at 2018-10-12 14:43:43.057000
# Measuring on Scope  Began at 2018-10-12 14:43:48.335000
# Writing to AWG Began at 2018-10-12 14:43:48.465000
# Measuring on VNA  Began at 2018-10-12 14:43:50.545000
# Measuring on Scope  Began at 2018-10-12 14:43:55.781000
# Writing to AWG Began at 2018-10-12 14:43:55.912000
# Measuring on VNA  Began at 2018-10-12 14:43:57.984000
# Measuring on Scope  Began at 2018-10-12 14:44:03.265000
# Writing to AWG Began at 2018-10-12 14:44:03.385000
# Measuring on VNA  Began at 2018-10-12 14:44:05.489000
# Measuring on Scope  Began at 2018-10-12 14:44:10.843000
# Sweep 1
# f : 980000000.0
#  ended at 2018-10-12 14:44:10.973000
#  taking 74 seonds
# Sweep 2
# f : 985000000.0
#  began at 2018-10-12 14:44:10.973000
# Writing to AWG Began at 2018-10-12 14:44:10.993000
# Measuring on VNA  Began at 2018-10-12 14:44:13.096000
# Measuring on Scope  Began at 2018-10-12 14:44:18.411000
# Writing to AWG Began at 2018-10-12 14:44:18.521000
# Measuring on VNA  Began at 2018-10-12 14:44:20.630000
# Measuring on Scope  Began at 2018-10-12 14:44:25.952000
# Writing to AWG Began at 2018-10-12 14:44:26.092000
# Measuring on VNA  Began at 2018-10-12 14:44:28.190000
# Measuring on Scope  Began at 2018-10-12 14:44:33.505000
# Writing to AWG Began at 2018-10-12 14:44:33.645000
# Measuring on VNA  Began at 2018-10-12 14:44:35.720000
# Measuring on Scope  Began at 2018-10-12 14:44:40.946000
# Writing to AWG Began at 2018-10-12 14:44:41.096000
# Measuring on VNA  Began at 2018-10-12 14:44:43.189000
# Measuring on Scope  Began at 2018-10-12 14:44:48.982000
# Writing to AWG Began at 2018-10-12 14:44:49.112000
# Measuring on VNA  Began at 2018-10-12 14:44:51.173000
# Measuring on Scope  Began at 2018-10-12 14:44:56.467000
# Writing to AWG Began at 2018-10-12 14:44:56.607000
# Measuring on VNA  Began at 2018-10-12 14:44:58.690000
# Measuring on Scope  Began at 2018-10-12 14:45:03.965000
# Writing to AWG Began at 2018-10-12 14:45:04.075000
# Measuring on VNA  Began at 2018-10-12 14:45:06.150000
# Measuring on Scope  Began at 2018-10-12 14:45:11.441000
# Writing to AWG Began at 2018-10-12 14:45:11.571000
# Measuring on VNA  Began at 2018-10-12 14:45:13.697000
# Measuring on Scope  Began at 2018-10-12 14:45:19.045000
# Writing to AWG Began at 2018-10-12 14:45:19.175000
# Measuring on VNA  Began at 2018-10-12 14:45:21.253000
# Measuring on Scope  Began at 2018-10-12 14:45:26.576000
# Sweep 2
# f : 985000000.0
#  ended at 2018-10-12 14:45:26.696000
#  taking 75 seonds
# Sweep 3
# f : 990000000.0
#  began at 2018-10-12 14:45:26.696000
# Writing to AWG Began at 2018-10-12 14:45:26.726000
# Measuring on VNA  Began at 2018-10-12 14:45:28.847000
# Measuring on Scope  Began at 2018-10-12 14:45:34.192000
# Writing to AWG Began at 2018-10-12 14:45:34.302000
# Measuring on VNA  Began at 2018-10-12 14:45:36.394000
# Measuring on Scope  Began at 2018-10-12 14:45:41.609000
# Writing to AWG Began at 2018-10-12 14:45:41.739000
# Measuring on VNA  Began at 2018-10-12 14:45:43.835000
# Measuring on Scope  Began at 2018-10-12 14:45:49.115000
# Writing to AWG Began at 2018-10-12 14:45:49.245000
# Measuring on VNA  Began at 2018-10-12 14:45:51.333000
# Measuring on Scope  Began at 2018-10-12 14:45:56.539000
# Writing to AWG Began at 2018-10-12 14:45:56.659000
# Measuring on VNA  Began at 2018-10-12 14:45:58.759000
# Measuring on Scope  Began at 2018-10-12 14:46:03.953000
# Writing to AWG Began at 2018-10-12 14:46:04.073000
# Measuring on VNA  Began at 2018-10-12 14:46:06.165000
# Measuring on Scope  Began at 2018-10-12 14:46:11.453000
# Writing to AWG Began at 2018-10-12 14:46:11.573000
# Measuring on VNA  Began at 2018-10-12 14:46:13.665000
# Measuring on Scope  Began at 2018-10-12 14:46:18.959000
# Writing to AWG Began at 2018-10-12 14:46:19.099000
# Measuring on VNA  Began at 2018-10-12 14:46:21.149000
# Measuring on Scope  Began at 2018-10-12 14:46:26.379000
# Writing to AWG Began at 2018-10-12 14:46:26.509000
# Measuring on VNA  Began at 2018-10-12 14:46:28.649000
# Measuring on Scope  Began at 2018-10-12 14:46:33.866000
# Writing to AWG Began at 2018-10-12 14:46:33.986000
# Measuring on VNA  Began at 2018-10-12 14:46:36.052000
# Measuring on Scope  Began at 2018-10-12 14:46:41.366000
# Sweep 3
# f : 990000000.0
#  ended at 2018-10-12 14:46:41.496000
#  taking 74 seonds
# Sweep 4
# f : 995000000.0
#  began at 2018-10-12 14:46:41.496000
# Writing to AWG Began at 2018-10-12 14:46:41.526000
# Measuring on VNA  Began at 2018-10-12 14:46:43.643000
# Measuring on Scope  Began at 2018-10-12 14:46:48.957000
# Writing to AWG Began at 2018-10-12 14:46:49.097000
# Measuring on VNA  Began at 2018-10-12 14:46:51.177000
# Measuring on Scope  Began at 2018-10-12 14:46:56.423000
# Writing to AWG Began at 2018-10-12 14:46:56.553000
# Measuring on VNA  Began at 2018-10-12 14:46:58.649000
# Measuring on Scope  Began at 2018-10-12 14:47:03.929000
# Writing to AWG Began at 2018-10-12 14:47:04.070000
# Measuring on VNA  Began at 2018-10-12 14:47:06.144000
# Measuring on Scope  Began at 2018-10-12 14:47:11.472000
# Writing to AWG Began at 2018-10-12 14:47:11.602000
# Measuring on VNA  Began at 2018-10-12 14:47:13.642000
# Measuring on Scope  Began at 2018-10-12 14:47:18.962000
# Writing to AWG Began at 2018-10-12 14:47:19.102000
# Measuring on VNA  Began at 2018-10-12 14:47:21.158000
# Measuring on Scope  Began at 2018-10-12 14:47:26.443000
# Writing to AWG Began at 2018-10-12 14:47:26.583000
# Measuring on VNA  Began at 2018-10-12 14:47:28.677000
# Measuring on Scope  Began at 2018-10-12 14:47:33.961000
# Writing to AWG Began at 2018-10-12 14:47:34.101000
# Measuring on VNA  Began at 2018-10-12 14:47:36.156000
# Measuring on Scope  Began at 2018-10-12 14:47:41.370000
# Writing to AWG Began at 2018-10-12 14:47:41.510000
# Measuring on VNA  Began at 2018-10-12 14:47:43.586000
# Measuring on Scope  Began at 2018-10-12 14:47:48.879000
# Writing to AWG Began at 2018-10-12 14:47:49.019000
# Measuring on VNA  Began at 2018-10-12 14:47:51.125000
# Measuring on Scope  Began at 2018-10-12 14:47:56.372000
# Sweep 4
# f : 995000000.0
#  ended at 2018-10-12 14:47:56.502000
#  taking 75 seonds
# Sweep 5
# f : 1000000000.0
#  began at 2018-10-12 14:47:56.502000
# Writing to AWG Began at 2018-10-12 14:47:56.532000
# Measuring on VNA  Began at 2018-10-12 14:47:58.627000
# Measuring on Scope  Began at 2018-10-12 14:48:03.873000
# Writing to AWG Began at 2018-10-12 14:48:04.003000
# Measuring on VNA  Began at 2018-10-12 14:48:06.082000
# Measuring on Scope  Began at 2018-10-12 14:48:11.442000
# Writing to AWG Began at 2018-10-12 14:48:11.572000
# Measuring on VNA  Began at 2018-10-12 14:48:13.646000
# Measuring on Scope  Began at 2018-10-12 14:48:18.861000
# Writing to AWG Began at 2018-10-12 14:48:18.981000
# Measuring on VNA  Began at 2018-10-12 14:48:21.100000
# Measuring on Scope  Began at 2018-10-12 14:48:26.433000
# Writing to AWG Began at 2018-10-12 14:48:26.563000
# Measuring on VNA  Began at 2018-10-12 14:48:28.643000
# Measuring on Scope  Began at 2018-10-12 14:48:33.930000
# Writing to AWG Began at 2018-10-12 14:48:34.060000
# Measuring on VNA  Began at 2018-10-12 14:48:36.146000
# Measuring on Scope  Began at 2018-10-12 14:48:41.510000
# Writing to AWG Began at 2018-10-12 14:48:41.640000
# Measuring on VNA  Began at 2018-10-12 14:48:43.767000
# Measuring on Scope  Began at 2018-10-12 14:48:49.061000
# Writing to AWG Began at 2018-10-12 14:48:49.191000
# Measuring on VNA  Began at 2018-10-12 14:48:51.263000
# Measuring on Scope  Began at 2018-10-12 14:48:56.481000
# Writing to AWG Began at 2018-10-12 14:48:56.611000
# Measuring on VNA  Began at 2018-10-12 14:48:58.693000
# Measuring on Scope  Began at 2018-10-12 14:49:03.939000
# Writing to AWG Began at 2018-10-12 14:49:04.059000
# Measuring on VNA  Began at 2018-10-12 14:49:06.122000
# Measuring on Scope  Began at 2018-10-12 14:49:11.358000
# Sweep 5
# f : 1000000000.0
#  ended at 2018-10-12 14:49:11.478000
#  taking 74 seonds
# Sweep 6
# f : 1005000000.0
#  began at 2018-10-12 14:49:11.478000
# Writing to AWG Began at 2018-10-12 14:49:11.498000
# Measuring on VNA  Began at 2018-10-12 14:49:13.531000
# Measuring on Scope  Began at 2018-10-12 14:49:19.429000
# Writing to AWG Began at 2018-10-12 14:49:19.539000
# Measuring on VNA  Began at 2018-10-12 14:49:21.609000
# Measuring on Scope  Began at 2018-10-12 14:49:26.834000
# Writing to AWG Began at 2018-10-12 14:49:26.954000
# Measuring on VNA  Began at 2018-10-12 14:49:29.005000
# Measuring on Scope  Began at 2018-10-12 14:49:34.223000
# Writing to AWG Began at 2018-10-12 14:49:34.343000
# Measuring on VNA  Began at 2018-10-12 14:49:36.380000
# Measuring on Scope  Began at 2018-10-12 14:49:41.599000
# Writing to AWG Began at 2018-10-12 14:49:41.719000
# Measuring on VNA  Began at 2018-10-12 14:49:43.778000
# Measuring on Scope  Began at 2018-10-12 14:49:49.049000
# Writing to AWG Began at 2018-10-12 14:49:49.179000
# Measuring on VNA  Began at 2018-10-12 14:49:51.237000
# Measuring on Scope  Began at 2018-10-12 14:49:56.506000
# Writing to AWG Began at 2018-10-12 14:49:56.646000
# Measuring on VNA  Began at 2018-10-12 14:49:58.770000
# Measuring on Scope  Began at 2018-10-12 14:50:04.071000
# Writing to AWG Began at 2018-10-12 14:50:04.211000
# Measuring on VNA  Began at 2018-10-12 14:50:06.311000
# Measuring on Scope  Began at 2018-10-12 14:50:11.550000
# Writing to AWG Began at 2018-10-12 14:50:11.690000
# Measuring on VNA  Began at 2018-10-12 14:50:13.733000
# Measuring on Scope  Began at 2018-10-12 14:50:19.037000
# Writing to AWG Began at 2018-10-12 14:50:19.157000
# Measuring on VNA  Began at 2018-10-12 14:50:21.201000
# Measuring on Scope  Began at 2018-10-12 14:50:26.503000
# Sweep 6
# f : 1005000000.0
#  ended at 2018-10-12 14:50:26.643000
#  taking 75 seonds
# Sweep 7
# f : 1010000000.0
#  began at 2018-10-12 14:50:26.643000
# Writing to AWG Began at 2018-10-12 14:50:26.663000
# Measuring on VNA  Began at 2018-10-12 14:50:28.749000
# Measuring on Scope  Began at 2018-10-12 14:50:34.034000
# Writing to AWG Began at 2018-10-12 14:50:34.164000
# Measuring on VNA  Began at 2018-10-12 14:50:36.269000
# Measuring on Scope  Began at 2018-10-12 14:50:41.592000
# Writing to AWG Began at 2018-10-12 14:50:41.722000
# Measuring on VNA  Began at 2018-10-12 14:50:43.827000
# Measuring on Scope  Began at 2018-10-12 14:50:49.162000
# Writing to AWG Began at 2018-10-12 14:50:49.292000
# Measuring on VNA  Began at 2018-10-12 14:50:51.393000
# Measuring on Scope  Began at 2018-10-12 14:50:56.697000
# Writing to AWG Began at 2018-10-12 14:50:56.817000
# Measuring on VNA  Began at 2018-10-12 14:50:58.875000
# Measuring on Scope  Began at 2018-10-12 14:51:04.184000
# Writing to AWG Began at 2018-10-12 14:51:04.314000
# Measuring on VNA  Began at 2018-10-12 14:51:06.392000
# Measuring on Scope  Began at 2018-10-12 14:51:11.671000
# Writing to AWG Began at 2018-10-12 14:51:11.801000
# Measuring on VNA  Began at 2018-10-12 14:51:13.903000
# Measuring on Scope  Began at 2018-10-12 14:51:19.239000
# Writing to AWG Began at 2018-10-12 14:51:19.369000
# Measuring on VNA  Began at 2018-10-12 14:51:21.458000
# Measuring on Scope  Began at 2018-10-12 14:51:26.750000
# Writing to AWG Began at 2018-10-12 14:51:26.880000
# Measuring on VNA  Began at 2018-10-12 14:51:28.969000
# Measuring on Scope  Began at 2018-10-12 14:51:34.189000
# Writing to AWG Began at 2018-10-12 14:51:34.299000
# Measuring on VNA  Began at 2018-10-12 14:51:36.312000
# Measuring on Scope  Began at 2018-10-12 14:51:41.640000
# Sweep 7
# f : 1010000000.0
#  ended at 2018-10-12 14:51:41.760000
#  taking 75 seonds
# Sweep 8
# f : 1015000000.0
#  began at 2018-10-12 14:51:41.760000
# Writing to AWG Began at 2018-10-12 14:51:41.770000
# Measuring on VNA  Began at 2018-10-12 14:51:43.889000
# Measuring on Scope  Began at 2018-10-12 14:51:49.213000
# Writing to AWG Began at 2018-10-12 14:51:49.353000
# Measuring on VNA  Began at 2018-10-12 14:51:51.467000
# Measuring on Scope  Began at 2018-10-12 14:51:56.731000
# Writing to AWG Began at 2018-10-12 14:51:56.861000
# Measuring on VNA  Began at 2018-10-12 14:51:58.947000
# Measuring on Scope  Began at 2018-10-12 14:52:04.211000
# Writing to AWG Began at 2018-10-12 14:52:04.351000
# Measuring on VNA  Began at 2018-10-12 14:52:06.439000
# Measuring on Scope  Began at 2018-10-12 14:52:11.677000
# Writing to AWG Began at 2018-10-12 14:52:11.817000
# Measuring on VNA  Began at 2018-10-12 14:52:13.934000
# Measuring on Scope  Began at 2018-10-12 14:52:19.155000
# Writing to AWG Began at 2018-10-12 14:52:19.285000
# Measuring on VNA  Began at 2018-10-12 14:52:21.388000
# Measuring on Scope  Began at 2018-10-12 14:52:26.715000
# Writing to AWG Began at 2018-10-12 14:52:26.855000
# Measuring on VNA  Began at 2018-10-12 14:52:28.949000
# Measuring on Scope  Began at 2018-10-12 14:52:34.300000
# Writing to AWG Began at 2018-10-12 14:52:34.440000
# Measuring on VNA  Began at 2018-10-12 14:52:36.522000
# Measuring on Scope  Began at 2018-10-12 14:52:41.695000
# Writing to AWG Began at 2018-10-12 14:52:41.805000
# Measuring on VNA  Began at 2018-10-12 14:52:43.876000
# Measuring on Scope  Began at 2018-10-12 14:52:49.123000
# Writing to AWG Began at 2018-10-12 14:52:49.233000
# Measuring on VNA  Began at 2018-10-12 14:52:51.299000
# Measuring on Scope  Began at 2018-10-12 14:52:56.553000
# Sweep 8
# f : 1015000000.0
#  ended at 2018-10-12 14:52:56.693000
#  taking 74 seonds
# Sweep 9
# f : 1020000000.0
#  began at 2018-10-12 14:52:56.693000
# Writing to AWG Began at 2018-10-12 14:52:56.713000
# Measuring on VNA  Began at 2018-10-12 14:52:58.786000
# Measuring on Scope  Began at 2018-10-12 14:53:04.086000
# Writing to AWG Began at 2018-10-12 14:53:04.216000
# Measuring on VNA  Began at 2018-10-12 14:53:06.327000
# Measuring on Scope  Began at 2018-10-12 14:53:11.600000
# Writing to AWG Began at 2018-10-12 14:53:11.730000
# Measuring on VNA  Began at 2018-10-12 14:53:13.844000
# Measuring on Scope  Began at 2018-10-12 14:53:19.167000
# Writing to AWG Began at 2018-10-12 14:53:19.297000
# Measuring on VNA  Began at 2018-10-12 14:53:21.411000
# Measuring on Scope  Began at 2018-10-12 14:53:26.705000
# Writing to AWG Began at 2018-10-12 14:53:26.825000
# Measuring on VNA  Began at 2018-10-12 14:53:28.980000
# Measuring on Scope  Began at 2018-10-12 14:53:34.318000
# Writing to AWG Began at 2018-10-12 14:53:34.438000
# Measuring on VNA  Began at 2018-10-12 14:53:36.521000
# Measuring on Scope  Began at 2018-10-12 14:53:41.855000
# Writing to AWG Began at 2018-10-12 14:53:41.975000
# Measuring on VNA  Began at 2018-10-12 14:53:44.092000
# Measuring on Scope  Began at 2018-10-12 14:53:49.375000
# Writing to AWG Began at 2018-10-12 14:53:49.505000
# Measuring on VNA  Began at 2018-10-12 14:53:51.582000
# Measuring on Scope  Began at 2018-10-12 14:53:56.789000
# Writing to AWG Began at 2018-10-12 14:53:56.919000
# Measuring on VNA  Began at 2018-10-12 14:53:59.017000
# Measuring on Scope  Began at 2018-10-12 14:54:04.308000
# Writing to AWG Began at 2018-10-12 14:54:04.438000
# Measuring on VNA  Began at 2018-10-12 14:54:06.547000
# Measuring on Scope  Began at 2018-10-12 14:54:11.882000
# Sweep 9
# f : 1020000000.0
#  ended at 2018-10-12 14:54:12.022000
#  taking 75 seonds
# Sweep 10
# f : 1025000000.0
#  began at 2018-10-12 14:54:12.022000
# Writing to AWG Began at 2018-10-12 14:54:12.042000
# Measuring on VNA  Began at 2018-10-12 14:54:14.138000
# Measuring on Scope  Began at 2018-10-12 14:54:19.466000
# Writing to AWG Began at 2018-10-12 14:54:19.606000
# Measuring on VNA  Began at 2018-10-12 14:54:21.688000
# Measuring on Scope  Began at 2018-10-12 14:54:26.966000
# Writing to AWG Began at 2018-10-12 14:54:27.106000
# Measuring on VNA  Began at 2018-10-12 14:54:29.202000
# Measuring on Scope  Began at 2018-10-12 14:54:34.546000
# Writing to AWG Began at 2018-10-12 14:54:34.686000
# Measuring on VNA  Began at 2018-10-12 14:54:36.807000
# Measuring on Scope  Began at 2018-10-12 14:54:42.030000
# Writing to AWG Began at 2018-10-12 14:54:42.170000
# Measuring on VNA  Began at 2018-10-12 14:54:44.251000
# Measuring on Scope  Began at 2018-10-12 14:54:50.357000
# Writing to AWG Began at 2018-10-12 14:54:50.497000
# Measuring on VNA  Began at 2018-10-12 14:54:52.578000
# Measuring on Scope  Began at 2018-10-12 14:54:57.848000
# Writing to AWG Began at 2018-10-12 14:54:57.988000
# Measuring on VNA  Began at 2018-10-12 14:55:00.134000
# Measuring on Scope  Began at 2018-10-12 14:55:05.462000
# Writing to AWG Began at 2018-10-12 14:55:05.582000
# Measuring on VNA  Began at 2018-10-12 14:55:07.655000
# Measuring on Scope  Began at 2018-10-12 14:55:12.965000
# Writing to AWG Began at 2018-10-12 14:55:13.105000
# Measuring on VNA  Began at 2018-10-12 14:55:15.187000
# Measuring on Scope  Began at 2018-10-12 14:55:20.481000
# Writing to AWG Began at 2018-10-12 14:55:20.601000
# Measuring on VNA  Began at 2018-10-12 14:55:22.723000
# Measuring on Scope  Began at 2018-10-12 14:55:27.996000
# Sweep 10
# f : 1025000000.0
#  ended at 2018-10-12 14:55:28.146000
#  taking 76 seonds
# Calibration Began at 2018-10-12 14:55:30.198000
# Sweep 0
# f : 987500000.0
#  began at 2018-10-12 14:55:30.208000
# Writing to AWG Began at 2018-10-12 14:55:30.248000
# Measuring on VNA  Began at 2018-10-12 14:55:32.386000
# Measuring on Scope  Began at 2018-10-12 14:55:37.665000
# Writing to AWG Began at 2018-10-12 14:55:37.835000
# Measuring on VNA  Began at 2018-10-12 14:55:39.965000
# Measuring on Scope  Began at 2018-10-12 14:55:45.245000
# Writing to AWG Began at 2018-10-12 14:55:45.385000
# Measuring on VNA  Began at 2018-10-12 14:55:47.532000
# Measuring on Scope  Began at 2018-10-12 14:55:52.863000
# Writing to AWG Began at 2018-10-12 14:55:53.013000
# Measuring on VNA  Began at 2018-10-12 14:55:55.157000
# Measuring on Scope  Began at 2018-10-12 14:56:00.390000
# Writing to AWG Began at 2018-10-12 14:56:00.530000
# Measuring on VNA  Began at 2018-10-12 14:56:02.633000
# Measuring on Scope  Began at 2018-10-12 14:56:07.880000
# Writing to AWG Began at 2018-10-12 14:56:08.020000
# Measuring on VNA  Began at 2018-10-12 14:56:10.133000
# Measuring on Scope  Began at 2018-10-12 14:56:15.421000
# Writing to AWG Began at 2018-10-12 14:56:15.571000
# Measuring on VNA  Began at 2018-10-12 14:56:17.656000
# Measuring on Scope  Began at 2018-10-12 14:56:22.942000
# Writing to AWG Began at 2018-10-12 14:56:23.092000
# Measuring on VNA  Began at 2018-10-12 14:56:25.203000
# Measuring on Scope  Began at 2018-10-12 14:56:30.465000
# Writing to AWG Began at 2018-10-12 14:56:30.615000
# Measuring on VNA  Began at 2018-10-12 14:56:32.708000
# Measuring on Scope  Began at 2018-10-12 14:56:38.007000
# Writing to AWG Began at 2018-10-12 14:56:38.157000
# Measuring on VNA  Began at 2018-10-12 14:56:40.241000
# Measuring on Scope  Began at 2018-10-12 14:56:45.461000
# Sweep 0
# f : 987500000.0
#  ended at 2018-10-12 14:56:45.581000
#  taking 75 seonds
# Sweep 1
# f : 990000000.0
#  began at 2018-10-12 14:56:45.581000
# Writing to AWG Began at 2018-10-12 14:56:45.631000
# Measuring on VNA  Began at 2018-10-12 14:56:47.728000
# Measuring on Scope  Began at 2018-10-12 14:56:52.971000
# Writing to AWG Began at 2018-10-12 14:56:53.121000
# Measuring on VNA  Began at 2018-10-12 14:56:55.211000
# Measuring on Scope  Began at 2018-10-12 14:57:00.519000
# Writing to AWG Began at 2018-10-12 14:57:00.659000
# Measuring on VNA  Began at 2018-10-12 14:57:02.773000
# Measuring on Scope  Began at 2018-10-12 14:57:08.132000
# Writing to AWG Began at 2018-10-12 14:57:08.262000
# Measuring on VNA  Began at 2018-10-12 14:57:10.383000
# Measuring on Scope  Began at 2018-10-12 14:57:15.696000
# Writing to AWG Began at 2018-10-12 14:57:15.846000
# Measuring on VNA  Began at 2018-10-12 14:57:18.012000
# Measuring on Scope  Began at 2018-10-12 14:57:23.369000
# Writing to AWG Began at 2018-10-12 14:57:23.529000
# Measuring on VNA  Began at 2018-10-12 14:57:25.639000
# Measuring on Scope  Began at 2018-10-12 14:57:30.846000
# Writing to AWG Began at 2018-10-12 14:57:30.966000
# Measuring on VNA  Began at 2018-10-12 14:57:33.107000
# Measuring on Scope  Began at 2018-10-12 14:57:38.366000
# Writing to AWG Began at 2018-10-12 14:57:38.506000
# Measuring on VNA  Began at 2018-10-12 14:57:40.636000
# Measuring on Scope  Began at 2018-10-12 14:57:45.953000
# Writing to AWG Began at 2018-10-12 14:57:46.113000
# Measuring on VNA  Began at 2018-10-12 14:57:48.213000
# Measuring on Scope  Began at 2018-10-12 14:57:53.467000
# Writing to AWG Began at 2018-10-12 14:57:53.617000
# Measuring on VNA  Began at 2018-10-12 14:57:55.725000
# Measuring on Scope  Began at 2018-10-12 14:58:01.013000
# Sweep 1
# f : 990000000.0
#  ended at 2018-10-12 14:58:01.143000
#  taking 75 seonds
# Sweep 2
# f : 992500000.0
#  began at 2018-10-12 14:58:01.143000
# Writing to AWG Began at 2018-10-12 14:58:01.183000
# Measuring on VNA  Began at 2018-10-12 14:58:03.307000
# Measuring on Scope  Began at 2018-10-12 14:58:08.650000
# Writing to AWG Began at 2018-10-12 14:58:08.810000
# Measuring on VNA  Began at 2018-10-12 14:58:10.907000
# Measuring on Scope  Began at 2018-10-12 14:58:16.199000
# Writing to AWG Began at 2018-10-12 14:58:16.359000
# Measuring on VNA  Began at 2018-10-12 14:58:18.469000
# Measuring on Scope  Began at 2018-10-12 14:58:23.779000
# Writing to AWG Began at 2018-10-12 14:58:23.929000
# Measuring on VNA  Began at 2018-10-12 14:58:26.061000
# Measuring on Scope  Began at 2018-10-12 14:58:31.366000
# Writing to AWG Began at 2018-10-12 14:58:31.496000
# Measuring on VNA  Began at 2018-10-12 14:58:33.590000
# Measuring on Scope  Began at 2018-10-12 14:58:38.869000
# Writing to AWG Began at 2018-10-12 14:58:39.029000
# Measuring on VNA  Began at 2018-10-12 14:58:41.137000
# Measuring on Scope  Began at 2018-10-12 14:58:46.367000
# Writing to AWG Began at 2018-10-12 14:58:46.517000
# Measuring on VNA  Began at 2018-10-12 14:58:48.633000
# Measuring on Scope  Began at 2018-10-12 14:58:54.003000
# Writing to AWG Began at 2018-10-12 14:58:54.163000
# Measuring on VNA  Began at 2018-10-12 14:58:56.266000
# Measuring on Scope  Began at 2018-10-12 14:59:01.564000
# Writing to AWG Began at 2018-10-12 14:59:01.714000
# Measuring on VNA  Began at 2018-10-12 14:59:03.856000
# Measuring on Scope  Began at 2018-10-12 14:59:09.176000
# Writing to AWG Began at 2018-10-12 14:59:09.326000
# Measuring on VNA  Began at 2018-10-12 14:59:11.433000
# Measuring on Scope  Began at 2018-10-12 14:59:16.699000
# Sweep 2
# f : 992500000.0
#  ended at 2018-10-12 14:59:16.829000
#  taking 75 seonds
# Sweep 3
# f : 995000000.0
#  began at 2018-10-12 14:59:16.829000
# Writing to AWG Began at 2018-10-12 14:59:16.869000
# Measuring on VNA  Began at 2018-10-12 14:59:19.010000
# Measuring on Scope  Began at 2018-10-12 14:59:24.296000
# Writing to AWG Began at 2018-10-12 14:59:24.436000
# Measuring on VNA  Began at 2018-10-12 14:59:26.540000
# Measuring on Scope  Began at 2018-10-12 14:59:31.911000
# Writing to AWG Began at 2018-10-12 14:59:32.061000
# Measuring on VNA  Began at 2018-10-12 14:59:34.160000
# Measuring on Scope  Began at 2018-10-12 14:59:39.439000
# Writing to AWG Began at 2018-10-12 14:59:39.579000
# Measuring on VNA  Began at 2018-10-12 14:59:41.669000
# Measuring on Scope  Began at 2018-10-12 14:59:46.952000
# Writing to AWG Began at 2018-10-12 14:59:47.082000
# Measuring on VNA  Began at 2018-10-12 14:59:49.180000
# Measuring on Scope  Began at 2018-10-12 14:59:54.464000
# Writing to AWG Began at 2018-10-12 14:59:54.604000
# Measuring on VNA  Began at 2018-10-12 14:59:56.726000
# Measuring on Scope  Began at 2018-10-12 15:00:01.943000
# Writing to AWG Began at 2018-10-12 15:00:02.083000
# Measuring on VNA  Began at 2018-10-12 15:00:04.199000
# Measuring on Scope  Began at 2018-10-12 15:00:09.505000
# Writing to AWG Began at 2018-10-12 15:00:09.645000
# Measuring on VNA  Began at 2018-10-12 15:00:11.755000
# Measuring on Scope  Began at 2018-10-12 15:00:16.926000
# Writing to AWG Began at 2018-10-12 15:00:17.076000
# Measuring on VNA  Began at 2018-10-12 15:00:19.806000
# Measuring on Scope  Began at 2018-10-12 15:00:25.037000
# Writing to AWG Began at 2018-10-12 15:00:25.187000
# Measuring on VNA  Began at 2018-10-12 15:00:27.324000
# Measuring on Scope  Began at 2018-10-12 15:00:32.637000
# Sweep 3
# f : 995000000.0
#  ended at 2018-10-12 15:00:32.767000
#  taking 75 seonds
# Sweep 4
# f : 997500000.0
#  began at 2018-10-12 15:00:32.767000
# Writing to AWG Began at 2018-10-12 15:00:32.807000
# Measuring on VNA  Began at 2018-10-12 15:00:34.974000
# Measuring on Scope  Began at 2018-10-12 15:00:40.260000
# Writing to AWG Began at 2018-10-12 15:00:40.380000
# Measuring on VNA  Began at 2018-10-12 15:00:42.492000
# Measuring on Scope  Began at 2018-10-12 15:00:47.779000
# Writing to AWG Began at 2018-10-12 15:00:47.929000
# Measuring on VNA  Began at 2018-10-12 15:00:50.025000
# Measuring on Scope  Began at 2018-10-12 15:00:55.382000
# Writing to AWG Began at 2018-10-12 15:00:55.542000
# Measuring on VNA  Began at 2018-10-12 15:00:57.629000
# Measuring on Scope  Began at 2018-10-12 15:01:02.896000
# Writing to AWG Began at 2018-10-12 15:01:03.026000
# Measuring on VNA  Began at 2018-10-12 15:01:05.132000
# Measuring on Scope  Began at 2018-10-12 15:01:10.403000
# Writing to AWG Began at 2018-10-12 15:01:10.563000
# Measuring on VNA  Began at 2018-10-12 15:01:12.696000
# Measuring on Scope  Began at 2018-10-12 15:01:17.986000
# Writing to AWG Began at 2018-10-12 15:01:18.146000
# Measuring on VNA  Began at 2018-10-12 15:01:20.280000
# Measuring on Scope  Began at 2018-10-12 15:01:25.533000
# Writing to AWG Began at 2018-10-12 15:01:25.673000
# Measuring on VNA  Began at 2018-10-12 15:01:27.837000
# Measuring on Scope  Began at 2018-10-12 15:01:33.130000
# Writing to AWG Began at 2018-10-12 15:01:33.270000
# ...
# Measuring on VNA  Began at 2018-10-12 15:29:31.190000
# Measuring on Scope  Began at 2018-10-12 15:29:36.464000
# Writing to AWG Began at 2018-10-12 15:29:38.787000
# Measuring on VNA  Began at 2018-10-12 15:29:43.001000
# Measuring on Scope  Began at 2018-10-12 15:29:48.178000
# Writing to AWG Began at 2018-10-12 15:29:50.440000
# Measuring on VNA  Began at 2018-10-12 15:29:54.578000
# Measuring on Scope  Began at 2018-10-12 15:29:59.820000
# Writing to AWG Began at 2018-10-12 15:30:02.104000
# Measuring on VNA  Began at 2018-10-12 15:30:06.247000
# Measuring on Scope  Began at 2018-10-12 15:30:11.543000
# Writing to AWG Began at 2018-10-12 15:30:13.827000
# Measuring on VNA  Began at 2018-10-12 15:30:17.987000
# Measuring on Scope  Began at 2018-10-12 15:30:23.170000
# Writing to AWG Began at 2018-10-12 15:30:25.480000
# Measuring on VNA  Began at 2018-10-12 15:30:30.346000
# Measuring on Scope  Began at 2018-10-12 15:30:35.582000
# Writing to AWG Began at 2018-10-12 15:30:37.947000
# Measuring on VNA  Began at 2018-10-12 15:30:42.091000
# Measuring on Scope  Began at 2018-10-12 15:30:47.328000
# Writing to AWG Began at 2018-10-12 15:30:49.600000
# Measuring on VNA  Began at 2018-10-12 15:30:53.699000
# Measuring on Scope  Began at 2018-10-12 15:30:58.900000
# Writing to AWG Began at 2018-10-12 15:31:01.200000
# Measuring on VNA  Began at 2018-10-12 15:31:05.356000
# Measuring on Scope  Began at 2018-10-12 15:31:10.641000
# Writing to AWG Began at 2018-10-12 15:31:12.932000
# Measuring on VNA  Began at 2018-10-12 15:31:17.121000
# Measuring on Scope  Began at 2018-10-12 15:31:22.387000
# Sweep 2
# f : 999925000.0
#  ended at 2018-10-12 15:31:22.517000
#  taking 117 seonds
# Sweep 3
# f : 999950000.0
#  began at 2018-10-12 15:31:22.517000
# Writing to AWG Began at 2018-10-12 15:31:24.661000
# Measuring on VNA  Began at 2018-10-12 15:31:28.859000
# Measuring on Scope  Began at 2018-10-12 15:31:34.038000
# Writing to AWG Began at 2018-10-12 15:31:36.325000
# Measuring on VNA  Began at 2018-10-12 15:31:40.580000
# Measuring on Scope  Began at 2018-10-12 15:31:45.826000
# Writing to AWG Began at 2018-10-12 15:31:48.091000
# Measuring on VNA  Began at 2018-10-12 15:31:52.300000
# Measuring on Scope  Began at 2018-10-12 15:31:57.557000
# Writing to AWG Began at 2018-10-12 15:31:59.787000
# Measuring on VNA  Began at 2018-10-12 15:32:03.954000
# Measuring on Scope  Began at 2018-10-12 15:32:09.231000
# Writing to AWG Began at 2018-10-12 15:32:11.508000
# Measuring on VNA  Began at 2018-10-12 15:32:15.636000
# Measuring on Scope  Began at 2018-10-12 15:32:20.909000
# Writing to AWG Began at 2018-10-12 15:32:23.200000
# Measuring on VNA  Began at 2018-10-12 15:32:27.357000
# Measuring on Scope  Began at 2018-10-12 15:32:32.634000
# Writing to AWG Began at 2018-10-12 15:32:34.936000
# Measuring on VNA  Began at 2018-10-12 15:32:39.106000
# Measuring on Scope  Began at 2018-10-12 15:32:44.362000
# Writing to AWG Began at 2018-10-12 15:32:46.619000
# Measuring on VNA  Began at 2018-10-12 15:32:50.781000
# Measuring on Scope  Began at 2018-10-12 15:32:55.996000
# Writing to AWG Began at 2018-10-12 15:32:58.347000
# Measuring on VNA  Began at 2018-10-12 15:33:02.493000
# Measuring on Scope  Began at 2018-10-12 15:33:07.730000
# Writing to AWG Began at 2018-10-12 15:33:10.084000
# Measuring on VNA  Began at 2018-10-12 15:33:14.264000
# Measuring on Scope  Began at 2018-10-12 15:33:19.523000
# Sweep 3
# f : 999950000.0
#  ended at 2018-10-12 15:33:19.653000
#  taking 117 seonds
# Sweep 4
# f : 999975000.0
#  began at 2018-10-12 15:33:19.653000
# Writing to AWG Began at 2018-10-12 15:33:21.833000
# Measuring on VNA  Began at 2018-10-12 15:33:26.034000
# Measuring on Scope  Began at 2018-10-12 15:33:31.290000
# Writing to AWG Began at 2018-10-12 15:33:33.545000
# Measuring on VNA  Began at 2018-10-12 15:33:37.698000
# Measuring on Scope  Began at 2018-10-12 15:33:42.900000
# Writing to AWG Began at 2018-10-12 15:33:45.136000
# Measuring on VNA  Began at 2018-10-12 15:33:49.247000
# Measuring on Scope  Began at 2018-10-12 15:33:54.436000
# Writing to AWG Began at 2018-10-12 15:33:56.767000
# Measuring on VNA  Began at 2018-10-12 15:34:00.980000
# Measuring on Scope  Began at 2018-10-12 15:34:06.199000
# Writing to AWG Began at 2018-10-12 15:34:08.437000
# Measuring on VNA  Began at 2018-10-12 15:34:12.560000
# Measuring on Scope  Began at 2018-10-12 15:34:17.837000
# Writing to AWG Began at 2018-10-12 15:34:20.118000
# Measuring on VNA  Began at 2018-10-12 15:34:24.226000
# Measuring on Scope  Began at 2018-10-12 15:34:29.507000
# Writing to AWG Began at 2018-10-12 15:34:31.796000
# Measuring on VNA  Began at 2018-10-12 15:34:35.953000
# Measuring on Scope  Began at 2018-10-12 15:34:41.210000
# Writing to AWG Began at 2018-10-12 15:34:43.477000
# Measuring on VNA  Began at 2018-10-12 15:34:47.657000
# Measuring on Scope  Began at 2018-10-12 15:34:52.917000
# Writing to AWG Began at 2018-10-12 15:34:55.230000
# Measuring on VNA  Began at 2018-10-12 15:34:59.353000
# Measuring on Scope  Began at 2018-10-12 15:35:04.673000
# Writing to AWG Began at 2018-10-12 15:35:06.947000
# Measuring on VNA  Began at 2018-10-12 15:35:11.165000
# Measuring on Scope  Began at 2018-10-12 15:35:16.434000
# Sweep 4
# f : 999975000.0
#  ended at 2018-10-12 15:35:16.564000
#  taking 116 seonds
# Sweep 5
# f : 1000000000.0
#  began at 2018-10-12 15:35:16.564000
# Writing to AWG Began at 2018-10-12 15:35:18.753000
# Measuring on VNA  Began at 2018-10-12 15:35:22.965000
# Measuring on Scope  Began at 2018-10-12 15:35:28.274000
# Writing to AWG Began at 2018-10-12 15:35:30.523000
# Measuring on VNA  Began at 2018-10-12 15:35:34.805000
# Measuring on Scope  Began at 2018-10-12 15:35:40.125000
# Writing to AWG Began at 2018-10-12 15:35:42.403000
# Measuring on VNA  Began at 2018-10-12 15:35:46.703000
# Measuring on Scope  Began at 2018-10-12 15:35:51.976000
# Writing to AWG Began at 2018-10-12 15:35:54.230000
# Measuring on VNA  Began at 2018-10-12 15:35:58.463000
# Measuring on Scope  Began at 2018-10-12 15:36:03.756000
# Writing to AWG Began at 2018-10-12 15:36:06.063000
# Measuring on VNA  Began at 2018-10-12 15:36:10.248000
# Measuring on Scope  Began at 2018-10-12 15:36:15.489000
# Writing to AWG Began at 2018-10-12 15:36:17.810000
# Measuring on VNA  Began at 2018-10-12 15:36:21.917000
# Measuring on Scope  Began at 2018-10-12 15:36:27.237000
# Writing to AWG Began at 2018-10-12 15:36:29.541000
# Measuring on VNA  Began at 2018-10-12 15:36:33.640000
# Measuring on Scope  Began at 2018-10-12 15:36:38.848000
# Writing to AWG Began at 2018-10-12 15:36:41.109000
# Measuring on VNA  Began at 2018-10-12 15:36:45.226000
# Measuring on Scope  Began at 2018-10-12 15:36:50.472000
# Writing to AWG Began at 2018-10-12 15:36:52.706000
# Measuring on VNA  Began at 2018-10-12 15:36:56.875000
# Measuring on Scope  Began at 2018-10-12 15:37:02.128000
# Writing to AWG Began at 2018-10-12 15:37:04.429000
# Measuring on VNA  Began at 2018-10-12 15:37:08.563000
# Measuring on Scope  Began at 2018-10-12 15:37:13.796000
# Sweep 5
# f : 1000000000.0
#  ended at 2018-10-12 15:37:13.936000
#  taking 117 seonds
# Sweep 6
# f : 1000025000.0
#  began at 2018-10-12 15:37:13.936000
# Writing to AWG Began at 2018-10-12 15:37:16.102000
# Measuring on VNA  Began at 2018-10-12 15:37:20.182000
# Measuring on Scope  Began at 2018-10-12 15:37:25.433000
# Writing to AWG Began at 2018-10-12 15:37:27.699000
# Measuring on VNA  Began at 2018-10-12 15:37:31.854000
# Measuring on Scope  Began at 2018-10-12 15:37:37.136000
# Writing to AWG Began at 2018-10-12 15:37:39.383000
# Measuring on VNA  Began at 2018-10-12 15:37:43.526000
# Measuring on Scope  Began at 2018-10-12 15:37:48.767000
# Writing to AWG Began at 2018-10-12 15:37:51.033000
# Measuring on VNA  Began at 2018-10-12 15:37:55.136000
# Measuring on Scope  Began at 2018-10-12 15:38:00.343000
# Writing to AWG Began at 2018-10-12 15:38:02.585000
# Measuring on VNA  Began at 2018-10-12 15:38:06.667000
# Measuring on Scope  Began at 2018-10-12 15:38:11.908000
# Writing to AWG Began at 2018-10-12 15:38:14.247000
# Measuring on VNA  Began at 2018-10-12 15:38:18.296000
# Measuring on Scope  Began at 2018-10-12 15:38:23.560000
# Writing to AWG Began at 2018-10-12 15:38:25.853000
# Measuring on VNA  Began at 2018-10-12 15:38:29.924000
# Measuring on Scope  Began at 2018-10-12 15:38:35.208000
# Writing to AWG Began at 2018-10-12 15:38:37.451000
# Measuring on VNA  Began at 2018-10-12 15:38:41.515000
# Measuring on Scope  Began at 2018-10-12 15:38:46.712000
# Writing to AWG Began at 2018-10-12 15:38:48.973000
# Measuring on VNA  Began at 2018-10-12 15:38:53.061000
# Measuring on Scope  Began at 2018-10-12 15:38:58.249000
# Writing to AWG Began at 2018-10-12 15:39:00.592000
# Measuring on VNA  Began at 2018-10-12 15:39:04.692000
# Measuring on Scope  Began at 2018-10-12 15:39:10.014000
# Sweep 6
# f : 1000025000.0
#  ended at 2018-10-12 15:39:10.154000
#  taking 116 seonds
# Sweep 7
# f : 1000050000.0
#  began at 2018-10-12 15:39:10.154000
# Writing to AWG Began at 2018-10-12 15:39:12.315000
# Measuring on VNA  Began at 2018-10-12 15:39:16.422000
# Measuring on Scope  Began at 2018-10-12 15:39:21.663000
# Writing to AWG Began at 2018-10-12 15:39:23.986000
# Measuring on VNA  Began at 2018-10-12 15:39:28.157000
# Measuring on Scope  Began at 2018-10-12 15:39:33.353000
# Writing to AWG Began at 2018-10-12 15:39:35.635000
# Measuring on VNA  Began at 2018-10-12 15:39:39.797000
# Measuring on Scope  Began at 2018-10-12 15:39:45.064000
# Writing to AWG Began at 2018-10-12 15:39:47.368000
# Measuring on VNA  Began at 2018-10-12 15:39:51.500000
# Measuring on Scope  Began at 2018-10-12 15:39:56.767000
# Writing to AWG Began at 2018-10-12 15:39:59.071000
# Measuring on VNA  Began at 2018-10-12 15:40:03.231000
# Measuring on Scope  Began at 2018-10-12 15:40:08.434000
# Writing to AWG Began at 2018-10-12 15:40:10.727000
# Measuring on VNA  Began at 2018-10-12 15:40:14.890000
# Measuring on Scope  Began at 2018-10-12 15:40:20.137000
# Writing to AWG Began at 2018-10-12 15:40:22.409000
# Measuring on VNA  Began at 2018-10-12 15:40:26.596000
# Measuring on Scope  Began at 2018-10-12 15:40:31.839000
# Writing to AWG Began at 2018-10-12 15:40:34.122000
# Measuring on VNA  Began at 2018-10-12 15:40:38.335000
# Measuring on Scope  Began at 2018-10-12 15:40:43.581000
# Writing to AWG Began at 2018-10-12 15:40:45.878000
# Measuring on VNA  Began at 2018-10-12 15:40:50.189000
# Measuring on Scope  Began at 2018-10-12 15:40:55.484000
# Writing to AWG Began at 2018-10-12 15:40:57.815000
# Measuring on VNA  Began at 2018-10-12 15:41:02.063000
# Measuring on Scope  Began at 2018-10-12 15:41:07.328000
# Sweep 7
# f : 1000050000.0
#  ended at 2018-10-12 15:41:07.468000
#  taking 117 seonds
# Sweep 8
# f : 1000075000.0
#  began at 2018-10-12 15:41:07.468000
# Writing to AWG Began at 2018-10-12 15:41:09.657000
# Measuring on VNA  Began at 2018-10-12 15:41:13.897000
# Measuring on Scope  Began at 2018-10-12 15:41:19.140000
# Writing to AWG Began at 2018-10-12 15:41:21.464000
# Measuring on VNA  Began at 2018-10-12 15:41:25.743000
# Measuring on Scope  Began at 2018-10-12 15:41:31
# Writing to AWG Began at 2018-10-12 15:41:33.287000
# Measuring on VNA  Began at 2018-10-12 15:41:37.515000
# Measuring on Scope  Began at 2018-10-12 15:41:42.775000
# Writing to AWG Began at 2018-10-12 15:41:45.062000
# Measuring on VNA  Began at 2018-10-12 15:41:49.207000
# Measuring on Scope  Began at 2018-10-12 15:41:54.516000
# Writing to AWG Began at 2018-10-12 15:41:56.824000
# Measuring on VNA  Began at 2018-10-12 15:42:01.083000
# Measuring on Scope  Began at 2018-10-12 15:42:08.544000
# Writing to AWG Began at 2018-10-12 15:42:10.983000
# Measuring on VNA  Began at 2018-10-12 15:42:15.237000
# Measuring on Scope  Began at 2018-10-12 15:42:20.474000
# Writing to AWG Began at 2018-10-12 15:42:22.731000
# Measuring on VNA  Began at 2018-10-12 15:42:26.991000
# Measuring on Scope  Began at 2018-10-12 15:42:32.190000
# Writing to AWG Began at 2018-10-12 15:42:34.480000
# Measuring on VNA  Began at 2018-10-12 15:42:38.689000
# Measuring on Scope  Began at 2018-10-12 15:42:43.959000
# Writing to AWG Began at 2018-10-12 15:42:46.286000
# Measuring on VNA  Began at 2018-10-12 15:42:50.483000
# Measuring on Scope  Began at 2018-10-12 15:42:55.710000
# Writing to AWG Began at 2018-10-12 15:42:58.076000
# Measuring on VNA  Began at 2018-10-12 15:43:02.364000
# Measuring on Scope  Began at 2018-10-12 15:43:07.676000
# Sweep 8
# f : 1000075000.0
#  ended at 2018-10-12 15:43:07.806000
#  taking 120 seonds
# Sweep 9
# f : 1000100000.0
#  began at 2018-10-12 15:43:07.806000
# Writing to AWG Began at 2018-10-12 15:43:09.941000
# Measuring on VNA  Began at 2018-10-12 15:43:14.217000
# Measuring on Scope  Began at 2018-10-12 15:43:19.416000
# Writing to AWG Began at 2018-10-12 15:43:21.738000
# Measuring on VNA  Began at 2018-10-12 15:43:25.990000
# Measuring on Scope  Began at 2018-10-12 15:43:31.262000
# Writing to AWG Began at 2018-10-12 15:43:33.536000
# Measuring on VNA  Began at 2018-10-12 15:43:37.795000
# Measuring on Scope  Began at 2018-10-12 15:43:43.060000
# Writing to AWG Began at 2018-10-12 15:43:45.312000
# Measuring on VNA  Began at 2018-10-12 15:43:49.543000
# Measuring on Scope  Began at 2018-10-12 15:43:54.831000
# Writing to AWG Began at 2018-10-12 15:43:57.138000
# Measuring on VNA  Began at 2018-10-12 15:44:01.362000
# Measuring on Scope  Began at 2018-10-12 15:44:06.630000
# Writing to AWG Began at 2018-10-12 15:44:08.912000
# Measuring on VNA  Began at 2018-10-12 15:44:13.127000
# Measuring on Scope  Began at 2018-10-12 15:44:18.349000
# Writing to AWG Began at 2018-10-12 15:44:20.640000
# Measuring on VNA  Began at 2018-10-12 15:44:24.862000
# Measuring on Scope  Began at 2018-10-12 15:44:30.099000
# Writing to AWG Began at 2018-10-12 15:44:32.425000
# Measuring on VNA  Began at 2018-10-12 15:44:36.669000
# Measuring on Scope  Began at 2018-10-12 15:44:41.945000
# Writing to AWG Began at 2018-10-12 15:44:44.235000
# Measuring on VNA  Began at 2018-10-12 15:44:48.486000
# Measuring on Scope  Began at 2018-10-12 15:44:53.690000
# Writing to AWG Began at 2018-10-12 15:44:55.975000
# Measuring on VNA  Began at 2018-10-12 15:45:00.298000
# Measuring on Scope  Began at 2018-10-12 15:45:05.566000
# Sweep 9
# f : 1000100000.0
#  ended at 2018-10-12 15:45:05.706000
#  taking 117 seonds
# Sweep 10
# f : 1000125000.0
#  began at 2018-10-12 15:45:05.706000
# Writing to AWG Began at 2018-10-12 15:45:07.860000
# Measuring on VNA  Began at 2018-10-12 15:45:12.156000
# Measuring on Scope  Began at 2018-10-12 15:45:17.376000
# Writing to AWG Began at 2018-10-12 15:45:19.709000
# Measuring on VNA  Began at 2018-10-12 15:45:24.020000
# Measuring on Scope  Began at 2018-10-12 15:45:29.233000
# Writing to AWG Began at 2018-10-12 15:45:31.482000
# Measuring on VNA  Began at 2018-10-12 15:45:35.765000
# Measuring on Scope  Began at 2018-10-12 15:45:41.023000
# Writing to AWG Began at 2018-10-12 15:45:43.303000
# Measuring on VNA  Began at 2018-10-12 15:45:47.596000
# Measuring on Scope  Began at 2018-10-12 15:45:52.870000
# Writing to AWG Began at 2018-10-12 15:45:55.122000
# Measuring on VNA  Began at 2018-10-12 15:45:59.426000
# Measuring on Scope  Began at 2018-10-12 15:46:04.679000
# Writing to AWG Began at 2018-10-12 15:46:06.986000
# Measuring on VNA  Began at 2018-10-12 15:46:11.247000
# Measuring on Scope  Began at 2018-10-12 15:46:16.485000
# Writing to AWG Began at 2018-10-12 15:46:18.752000
# Measuring on VNA  Began at 2018-10-12 15:46:23.013000
# Measuring on Scope  Began at 2018-10-12 15:46:28.246000
# Writing to AWG Began at 2018-10-12 15:46:30.499000
# Measuring on VNA  Began at 2018-10-12 15:46:34.765000
# Measuring on Scope  Began at 2018-10-12 15:46:40.012000
# Writing to AWG Began at 2018-10-12 15:46:42.267000
# Measuring on VNA  Began at 2018-10-12 15:46:46.519000
# Measuring on Scope  Began at 2018-10-12 15:46:51.772000
# Writing to AWG Began at 2018-10-12 15:46:54.002000
# Measuring on VNA  Began at 2018-10-12 15:46:58.313000
# Measuring on Scope  Began at 2018-10-12 15:47:03.510000
# Sweep 10
# f : 1000125000.0
#  ended at 2018-10-12 15:47:03.650000
#  taking 117 seonds
